# %%
import os
import sys
import time
#sys.path.append('../..')

from datasets.get_datasets import *
from revision import *
from transfer import *
from mapping import *
from boostsrl import boostsrl
import numpy as np
import random
import json

# %%
def get_best(sPreds, tPreds, srcFacts, tarFacts, n_sentences=50000, forceHead=None):
    '''Return best mapping found given source and target predicates and facts'''
    srcPreds = sPreds
    tarPreds = mapping.clean_preds(tPreds)
    start = time.time()
    results = {}
    source = KnowledgeGraph()
    source.background(srcPreds)
    source.facts(srcFacts)
    target = KnowledgeGraph()
    target.background(tarPreds)
    target.facts(tarFacts)
    results['Knowledge compiling time'] = time.time() - start
    new_start = time.time()
    source.generate_sentences(max_depth=4, n_sentences=n_sentences)
    target.generate_sentences(max_depth=4, n_sentences=n_sentences)
    results['Generating paths time'] = time.time() - new_start
    new_start = time.time()
    source_sentences = set([' '.join(i) for i in source.sentences if len(i) > 1])
    target_sentences = set([' '.join(i) for i in target.sentences if len(i) > 1])
    best = -1
    best_mapping_size = 0
    best_mapping = None
    fHead = None if not forceHead else mapping.find_pred(forceHead, tarPreds)
    possible_mappings = mapping.mapping(srcPreds, tarPreds, forceHead=fHead)
    # return None if incompatible forceHead is defined
    if not len(possible_mappings):
        return ({}, None)
    results['Generating mappings time'] = time.time() - new_start
    new_start = time.time()
    results['Possible mappings'] = len(possible_mappings)
    scores = []
    for mapping_dict in possible_mappings:
        score = mapping.mapping_score(mapping_dict, source_sentences, target_sentences)
        scores.append((mapping_dict, score, len(mapping_dict)))
    scores = sorted(scores, key=lambda tup: (tup[1], tup[2]), reverse=True)
    results['Finding best mapping'] = time.time() - new_start
    results['Total time'] = time.time() - start
    
    unaries = []
    for srcPred in srcPreds:
        s = mapping.get_types(srcPred)
        if len(s[1]) == 1:
            unaries.append(s[0])
    ret = []
    for el in scores:
        best_mapping = el[0]
        mapd = []
        for key, value in best_mapping.items():
            if key in unaries:
                string = key + '(A) -> ' + value + '(A)'
            else:
                string = key + '(A,B) -> ' + (value if value[0] != '_' else value[1:]) + ('(A,B)' if value[0] != '_' else '(B,A)')
            mapd.append(string)
        ret.append((mapd, el[1], el[2]))
    return (ret, results)

# %%
seed = 0

bk = {
      'imdb': ['workedunder(+person,+person).',
              'workedunder(+person,-person).',
              'workedunder(-person,+person).',
              'female(+person).',
              'actor(+person).',
              'director(+person).',
              'movie(+movie,+person).',
              'movie(+movie,-person).',
              'movie(-movie,+person).',
              'genre(+person,+genre).'],
      'uwcse': ['professor(+person).',
        'student(+person).',
        'advisedby(+person,+person).',
        'advisedby(+person,-person).',
        'advisedby(-person,+person).',
        'tempadvisedby(+person,+person).',
        'tempadvisedby(+person,-person).',
        'tempadvisedby(-person,+person).',
        'ta(+course,+person,+quarter).',
        'ta(-course,-person,+quarter).',
        'ta(+course,-person,-quarter).',
        'ta(-course,+person,-quarter).',
        'hasposition(+person,+faculty).',
        'hasposition(+person,-faculty).',
        'hasposition(-person,+faculty).',
        'publication(+title,+person).',
        'publication(+title,-person).',
        'publication(-title,+person).',
        'inphase(+person,+prequals).',
        'inphase(+person,-prequals).',
        'inphase(-person,+prequals).',
        'courselevel(+course,+level).',
        'courselevel(+course,-level).',
        'courselevel(-course,+level).',
        'yearsinprogram(+person,+year).',
        'yearsinprogram(-person,+year).',
        'yearsinprogram(+person,-year).',
        'projectmember(+project,+person).',
        'projectmember(+project,-person).',
        'projectmember(-project,+person).',
        'sameproject(+project,+project).',
        'sameproject(+project,-project).',
        'sameproject(-project,+project).',
        'samecourse(+course,+course).',
        'samecourse(+course,-course).',
        'samecourse(-course,+course).',
        'sameperson(+person,+person).',
        'sameperson(+person,-person).',
        'sameperson(-person,+person).',]}

# %%
source = 'uwcse'
target = 'imdb'
predicate = 'advisedby'
to_predicate = 'workedunder'

source_balanced = 1
balanced = 1
firstRun = False
n_runs = 28
folds = 3
print_function = None

nodeSize = 2
numOfClauses = 8
maxTreeDepth = 3

# Load source dataset
src_total_data = datasets.load(source, bk[source], seed=seed)
src_data = datasets.load(source, bk[source], target=predicate, balanced=source_balanced, seed=seed)

# Group and shuffle
src_facts = datasets.group_folds(src_data[0])
src_pos = datasets.group_folds(src_data[1])
src_neg = datasets.group_folds(src_data[2])

# %%
# learning from source dataset
background = boostsrl.modes(bk[source], [predicate], useStdLogicVariables=False, maxTreeDepth=maxTreeDepth, nodeSize=nodeSize, numOfClauses=numOfClauses)
[model, total_revision_time, source_structured, will, variances] = revision.learn_model(background, boostsrl, predicate, src_pos, src_neg, src_facts, refine=None, trees=10, print_function=print_function)

preds = mapping.get_preds(source_structured, bk[source])
print('Predicates from source: %s' % preds + '\n')

# learn from first folds
i = 0

# Load total target dataset
tar_total_data = datasets.load(target, bk[target], seed=seed)

[tar_train_pos, tar_test_pos] = datasets.get_kfold_small(i, tar_total_data[0])

# transfer
mapping_rules, mapping_results = get_best(preds, bk[target], datasets.group_folds(src_total_data[0]), tar_train_pos, forceHead=to_predicate)
# Out:
# Predicates from source: ['advisedby(person,person).', 'projectmember(project,person).', 'publication(title,person).', 'ta(course,person,quarter).', 'professor(person).', 'student(person).', 'tempadvisedby(person,person).']

# %%
len(mapping_rules)
# Out:
# 288

# %%
mapping_rules
# Out:
# [(['professor(A) -> director(A)',
#    'advisedby(A,B) -> workedunder(A,B)',
#    'publication(A,B) -> movie(A,B)',
#    'projectmember(A,B) -> genre(B,A)',
#    'student(A) -> actor(A)'],
#   0.504950495049505,
#   5),
#  (['professor(A) -> director(A)',
#    'advisedby(A,B) -> workedunder(A,B)',
#    'publication(A,B) -> movie(A,B)',
#    'projectmember(A,B) -> genre(B,A)',
#    'student(A) -> female(A)'],
#   0.49019607843137253,
#   5),
#  (['advisedby(A,B) -> workedunder(A,B)',
#    'publication(A,B) -> movie(A,B)',
#    'projectmember(A,B) -> genre(B,A)',
#    'student(A) -> actor(A)'],
#   0.3829787234042553,
#   4),
#  (['advisedby(A,B) -> workedunder(A,B)',
#    'publication(A,B) -> movie(A,B)',
#    'projectmember(A,B) -> genre(B,A)',
#    'student(A) -> female(A)'],
#   0.3684210526315789,
#   4),
#  (['professor(A) -> director(A)',
#    'publication(A,B) -> movie(A,B)',
#    'advisedby(A,B) -> workedunder(A,B)',
#    'student(A) -> actor(A)'],
#   0.35714285714285715,
#   4),
#  (['professor(A) -> actor(A)',
#    'publication(A,B) -> movie(A,B)',
#    'advisedby(A,B) -> workedunder(B,A)',
#    'student(A) -> director(A)'],
#   0.35714285714285715,
#   4),
#  (['professor(A) -> director(A)',
#    'advisedby(A,B) -> workedunder(A,B)',
#    'publication(A,B) -> movie(A,B)',
#    'projectmember(A,B) -> genre(B,A)'],
#   0.35353535353535354,
#   4),
#  (['professor(A) -> director(A)',
#    'advisedby(A,B) -> workedunder(A,B)',
#    'publication(A,B) -> movie(A,B)',
#    'projectmember(A,B) -> movie(A,B)',
#    'student(A) -> actor(A)'],
#   0.35,
#   5),
#  (['professor(A) -> actor(A)',
#    'advisedby(A,B) -> workedunder(B,A)',
#    'publication(A,B) -> movie(A,B)',
#    'projectmember(A,B) -> movie(A,B)',
#    'student(A) -> director(A)'],
#   0.35,
#   5),
#  (['professor(A) -> actor(A)',
#    'advisedby(A,B) -> workedunder(A,B)',
#    'publication(A,B) -> movie(A,B)',
#    'projectmember(A,B) -> genre(B,A)',
#    'student(A) -> female(A)'],
#   0.34513274336283184,
#   5),
#  (['professor(A) -> female(A)',
#    'advisedby(A,B) -> workedunder(A,B)',
#    'publication(A,B) -> movie(A,B)',
#    'projectmember(A,B) -> genre(B,A)',
#    'student(A) -> actor(A)'],
#   0.34513274336283184,
#   5),
#  (['professor(A) -> actor(A)',
#    'advisedby(A,B) -> workedunder(B,A)',
#    'publication(A,B) -> movie(A,B)',
#    'projectmember(A,B) -> genre(B,A)',
#    'student(A) -> director(A)'],
#   0.34513274336283184,
#   5),
#  (['professor(A) -> director(A)',
#    'publication(A,B) -> movie(A,B)',
#    'advisedby(A,B) -> workedunder(A,B)',
#    'student(A) -> female(A)'],
#   0.3434343434343434,
#   4),
#  (['professor(A) -> female(A)',
#    'publication(A,B) -> movie(A,B)',
#    'advisedby(A,B) -> workedunder(B,A)',
#    'student(A) -> director(A)'],
#   0.3434343434343434,
#   4),
#  (['professor(A) -> director(A)',
#    'advisedby(A,B) -> workedunder(A,B)',
#    'publication(A,B) -> movie(A,B)',
#    'projectmember(A,B) -> movie(A,B)',
#    'student(A) -> female(A)'],
#   0.33663366336633666,
#   5),
#  (['professor(A) -> female(A)',
#    'advisedby(A,B) -> workedunder(B,A)',
#    'publication(A,B) -> movie(A,B)',
#    'projectmember(A,B) -> movie(A,B)',
#    'student(A) -> director(A)'],
#   0.33663366336633666,
#   5),
#  (['professor(A) -> female(A)',
#    'advisedby(A,B) -> workedunder(B,A)',
#    'publication(A,B) -> movie(A,B)',
#    'projectmember(A,B) -> genre(B,A)',
#    'student(A) -> director(A)'],
#   0.3333333333333333,
#   5),
#  (['professor(A) -> actor(A)',
#    'advisedby(A,B) -> workedunder(B,A)',
#    'publication(A,B) -> genre(B,A)',
#    'projectmember(A,B) -> movie(A,B)',
#    'student(A) -> director(A)'],
#   0.3217391304347826,
#   5),
#  (['professor(A) -> actor(A)',
#    'advisedby(A,B) -> workedunder(A,B)',
#    'publication(A,B) -> movie(A,B)',
#    'projectmember(A,B) -> genre(B,A)',
#    'student(A) -> actor(A)'],
#   0.32142857142857145,
#   5),
#  (['professor(A) -> female(A)',
#    'advisedby(A,B) -> workedunder(B,A)',
#    'publication(A,B) -> genre(B,A)',
#    'projectmember(A,B) -> movie(A,B)',
#    'student(A) -> director(A)'],
#   0.3103448275862069,
#   5),
#  (['professor(A) -> director(A)',
#    'advisedby(A,B) -> workedunder(A,B)',
#    'publication(A,B) -> movie(A,B)',
#    'projectmember(A,B) -> genre(B,A)',
#    'student(A) -> director(A)'],
#   0.30973451327433627,
#   5),
#  (['professor(A) -> female(A)',
#    'advisedby(A,B) -> workedunder(A,B)',
#    'publication(A,B) -> movie(A,B)',
#    'projectmember(A,B) -> genre(B,A)',
#    'student(A) -> female(A)'],
#   0.30973451327433627,
#   5),
#  (['professor(A) -> actor(A)',
#    'advisedby(A,B) -> workedunder(B,A)',
#    'publication(A,B) -> movie(A,B)',
#    'projectmember(A,B) -> genre(B,A)'],
#   0.2761904761904762,
#   4),
#  (['professor(A) -> actor(A)',
#    'publication(A,B) -> movie(A,B)',
#    'advisedby(A,B) -> workedunder(B,A)'],
#   0.2717391304347826,
#   3),
#  (['publication(A,B) -> movie(A,B)',
#    'advisedby(A,B) -> workedunder(A,B)',
#    'student(A) -> actor(A)'],
#   0.26881720430107525,
#   3),
#  (['professor(A) -> director(A)',
#    'advisedby(A,B) -> workedunder(A,B)',
#    'publication(A,B) -> genre(B,A)',
#    'projectmember(A,B) -> movie(A,B)',
#    'student(A) -> actor(A)'],
#   0.26666666666666666,
#   5),
#  (['professor(A) -> director(A)',
#    'advisedby(A,B) -> workedunder(A,B)',
#    'publication(A,B) -> genre(B,A)',
#    'projectmember(A,B) -> movie(A,B)',
#    'student(A) -> female(A)'],
#   0.26666666666666666,
#   5),
#  (['professor(A) -> actor(A)',
#    'advisedby(A,B) -> workedunder(B,A)',
#    'publication(A,B) -> movie(A,B)',
#    'projectmember(A,B) -> genre(B,A)',
#    'student(A) -> female(A)'],
#   0.26666666666666666,
#   5),
#  (['professor(A) -> female(A)',
#    'advisedby(A,B) -> workedunder(B,A)',
#    'publication(A,B) -> movie(A,B)',
#    'projectmember(A,B) -> genre(B,A)',
#    'student(A) -> actor(A)'],
#   0.26666666666666666,
#   5),
#  (['professor(A) -> actor(A)',
#    'publication(A,B) -> movie(A,B)',
#    'advisedby(A,B) -> workedunder(A,B)',
#    'student(A) -> female(A)'],
#   0.26666666666666666,
#   4),
#  (['professor(A) -> female(A)',
#    'publication(A,B) -> movie(A,B)',
#    'advisedby(A,B) -> workedunder(A,B)',
#    'student(A) -> actor(A)'],
#   0.26666666666666666,
#   4),
#  (['professor(A) -> actor(A)',
#    'publication(A,B) -> movie(A,B)',
#    'advisedby(A,B) -> workedunder(B,A)',
#    'student(A) -> female(A)'],
#   0.26666666666666666,
#   4),
#  (['professor(A) -> female(A)',
#    'publication(A,B) -> movie(A,B)',
#    'advisedby(A,B) -> workedunder(B,A)',
#    'student(A) -> actor(A)'],
#   0.26666666666666666,
#   4),
#  (['advisedby(A,B) -> workedunder(A,B)',
#    'publication(A,B) -> movie(A,B)',
#    'projectmember(A,B) -> movie(A,B)',
#    'student(A) -> actor(A)'],
#   0.26595744680851063,
#   4),
#  (['professor(A) -> actor(A)',
#    'advisedby(A,B) -> workedunder(B,A)',
#    'publication(A,B) -> movie(A,B)',
#    'projectmember(A,B) -> movie(A,B)'],
#   0.26595744680851063,
#   4),
#  (['professor(A) -> female(A)',
#    'advisedby(A,B) -> workedunder(B,A)',
#    'publication(A,B) -> movie(A,B)',
#    'projectmember(A,B) -> genre(B,A)'],
#   0.2641509433962264,
#   4),
#  (['professor(A) -> actor(A)',
#    'advisedby(A,B) -> workedunder(A,B)',
#    'publication(A,B) -> movie(A,B)',
#    'projectmember(A,B) -> movie(A,B)',
#    'student(A) -> female(A)'],
#   0.2616822429906542,
#   5),
#  (['professor(A) -> female(A)',
#    'advisedby(A,B) -> workedunder(A,B)',
#    'publication(A,B) -> movie(A,B)',
#    'projectmember(A,B) -> movie(A,B)',
#    'student(A) -> actor(A)'],
#   0.2616822429906542,
#   5),
#  (['professor(A) -> actor(A)',
#    'advisedby(A,B) -> workedunder(B,A)',
#    'publication(A,B) -> movie(A,B)',
#    'projectmember(A,B) -> movie(A,B)',
#    'student(A) -> female(A)'],
#   0.2616822429906542,
#   5),
#  (['professor(A) -> female(A)',
#    'advisedby(A,B) -> workedunder(B,A)',
#    'publication(A,B) -> movie(A,B)',
#    'projectmember(A,B) -> movie(A,B)',
#    'student(A) -> actor(A)'],
#   0.2616822429906542,
#   5),
#  (['professor(A) -> female(A)',
#    'publication(A,B) -> movie(A,B)',
#    'advisedby(A,B) -> workedunder(B,A)'],
#   0.25806451612903225,
#   3),
#  (['publication(A,B) -> movie(A,B)',
#    'advisedby(A,B) -> workedunder(A,B)',
#    'student(A) -> female(A)'],
#   0.2553191489361702,
#   3),
#  (['advisedby(A,B) -> workedunder(A,B)',
#    'publication(A,B) -> movie(A,B)',
#    'projectmember(A,B) -> movie(A,B)',
#    'student(A) -> female(A)'],
#   0.25263157894736843,
#   4),
#  (['professor(A) -> female(A)',
#    'advisedby(A,B) -> workedunder(B,A)',
#    'publication(A,B) -> movie(A,B)',
#    'projectmember(A,B) -> movie(A,B)'],
#   0.25263157894736843,
#   4),
#  (['professor(A) -> actor(A)',
#    'advisedby(A,B) -> workedunder(B,A)',
#    'publication(A,B) -> movie(A,B)',
#    'projectmember(A,B) -> genre(B,A)',
#    'student(A) -> actor(A)'],
#   0.24369747899159663,
#   5),
#  (['professor(A) -> actor(A)',
#    'advisedby(A,B) -> workedunder(A,B)',
#    'publication(A,B) -> movie(A,B)',
#    'projectmember(A,B) -> genre(B,A)'],
#   0.24074074074074073,
#   4),
#  (['professor(A) -> actor(A)',
#    'publication(A,B) -> movie(A,B)',
#    'advisedby(A,B) -> workedunder(A,B)',
#    'student(A) -> actor(A)'],
#   0.2403846153846154,
#   4),
#  (['professor(A) -> actor(A)',
#    'publication(A,B) -> movie(A,B)',
#    'advisedby(A,B) -> workedunder(B,A)',
#    'student(A) -> actor(A)'],
#   0.2403846153846154,
#   4),
#  (['advisedby(A,B) -> workedunder(A,B)',
#    'publication(A,B) -> movie(A,B)',
#    'projectmember(A,B) -> genre(B,A)'],
#   0.2391304347826087,
#   3),
#  (['professor(A) -> director(A)',
#    'advisedby(A,B) -> workedunder(A,B)',
#    'publication(A,B) -> genre(B,A)',
#    'projectmember(A,B) -> genre(B,A)',
#    'student(A) -> actor(A)'],
#   0.23853211009174313,
#   5),
#  (['professor(A) -> director(A)',
#    'advisedby(A,B) -> workedunder(A,B)',
#    'publication(A,B) -> genre(B,A)',
#    'projectmember(A,B) -> genre(B,A)',
#    'student(A) -> female(A)'],
#   0.23853211009174313,
#   5),
#  (['professor(A) -> actor(A)',
#    'advisedby(A,B) -> workedunder(A,B)',
#    'publication(A,B) -> movie(A,B)',
#    'projectmember(A,B) -> movie(A,B)',
#    'student(A) -> actor(A)'],
#   0.23809523809523808,
#   5),
#  (['professor(A) -> actor(A)',
#    'advisedby(A,B) -> workedunder(B,A)',
#    'publication(A,B) -> movie(A,B)',
#    'projectmember(A,B) -> movie(A,B)',
#    'student(A) -> actor(A)'],
#   0.23809523809523808,
#   5),
#  (['advisedby(A,B) -> workedunder(B,A)',
#    'publication(A,B) -> genre(B,A)',
#    'projectmember(A,B) -> movie(A,B)',
#    'student(A) -> director(A)'],
#   0.23809523809523808,
#   4),
#  (['advisedby(A,B) -> workedunder(B,A)',
#    'publication(A,B) -> movie(A,B)',
#    'projectmember(A,B) -> genre(B,A)',
#    'student(A) -> director(A)'],
#   0.23809523809523808,
#   4),
#  (['professor(A) -> director(A)',
#    'advisedby(A,B) -> workedunder(B,A)',
#    'publication(A,B) -> movie(A,B)',
#    'projectmember(A,B) -> genre(B,A)',
#    'student(A) -> director(A)'],
#   0.23333333333333334,
#   5),
#  (['professor(A) -> female(A)',
#    'advisedby(A,B) -> workedunder(B,A)',
#    'publication(A,B) -> movie(A,B)',
#    'projectmember(A,B) -> genre(B,A)',
#    'student(A) -> female(A)'],
#   0.23333333333333334,
#   5),
#  (['professor(A) -> actor(A)',
#    'publication(A,B) -> genre(B,A)',
#    'advisedby(A,B) -> workedunder(B,A)',
#    'student(A) -> director(A)'],
#   0.23148148148148148,
#   4),
#  (['professor(A) -> female(A)',
#    'publication(A,B) -> genre(B,A)',
#    'advisedby(A,B) -> workedunder(B,A)',
#    'student(A) -> director(A)'],
#   0.23148148148148148,
#   4),
#  (['professor(A) -> female(A)',
#    'advisedby(A,B) -> workedunder(A,B)',
#    'publication(A,B) -> movie(A,B)',
#    'projectmember(A,B) -> genre(B,A)'],
#   0.22935779816513763,
#   4),
#  (['professor(A) -> actor(A)',
#    'advisedby(A,B) -> workedunder(B,A)',
#    'publication(A,B) -> genre(B,A)',
#    'projectmember(A,B) -> movie(A,B)'],
#   0.22935779816513763,
#   4),
#  (['professor(A) -> female(A)',
#    'publication(A,B) -> movie(A,B)',
#    'advisedby(A,B) -> workedunder(A,B)',
#    'student(A) -> female(A)'],
#   0.22857142857142856,
#   4),
#  (['professor(A) -> female(A)',
#    'publication(A,B) -> movie(A,B)',
#    'advisedby(A,B) -> workedunder(B,A)',
#    'student(A) -> female(A)'],
#   0.22857142857142856,
#   4),
#  (['professor(A) -> actor(A)',
#    'advisedby(A,B) -> workedunder(B,A)',
#    'publication(A,B) -> genre(B,A)',
#    'projectmember(A,B) -> genre(B,A)',
#    'student(A) -> director(A)'],
#   0.22727272727272727,
#   5),
#  (['professor(A) -> female(A)',
#    'advisedby(A,B) -> workedunder(B,A)',
#    'publication(A,B) -> genre(B,A)',
#    'projectmember(A,B) -> genre(B,A)',
#    'student(A) -> director(A)'],
#   0.22727272727272727,
#   5),
#  (['professor(A) -> female(A)',
#    'advisedby(A,B) -> workedunder(A,B)',
#    'publication(A,B) -> movie(A,B)',
#    'projectmember(A,B) -> movie(A,B)',
#    'student(A) -> female(A)'],
#   0.22641509433962265,
#   5),
#  (['professor(A) -> female(A)',
#    'advisedby(A,B) -> workedunder(B,A)',
#    'publication(A,B) -> movie(A,B)',
#    'projectmember(A,B) -> movie(A,B)',
#    'student(A) -> female(A)'],
#   0.22641509433962265,
#   5),
#  (['advisedby(A,B) -> workedunder(A,B)',
#    'publication(A,B) -> movie(A,B)',
#    'projectmember(A,B) -> genre(B,A)',
#    'student(A) -> director(A)'],
#   0.22641509433962265,
#   4),
#  (['professor(A) -> actor(A)',
#    'advisedby(A,B) -> workedunder(A,B)',
#    'publication(A,B) -> movie(A,B)',
#    'projectmember(A,B) -> genre(B,A)',
#    'student(A) -> director(A)'],
#   0.22580645161290322,
#   5),
#  (['professor(A) -> director(A)',
#    'publication(A,B) -> genre(B,A)',
#    'advisedby(A,B) -> workedunder(A,B)',
#    'student(A) -> actor(A)'],
#   0.22018348623853212,
#   4),
#  (['professor(A) -> director(A)',
#    'publication(A,B) -> genre(B,A)',
#    'advisedby(A,B) -> workedunder(A,B)',
#    'student(A) -> female(A)'],
#   0.22018348623853212,
#   4),
#  (['professor(A) -> director(A)',
#    'publication(A,B) -> movie(A,B)',
#    'advisedby(A,B) -> workedunder(A,B)'],
#   0.21875,
#   3),
#  (['professor(A) -> female(A)',
#    'advisedby(A,B) -> workedunder(B,A)',
#    'publication(A,B) -> genre(B,A)',
#    'projectmember(A,B) -> movie(A,B)'],
#   0.21818181818181817,
#   4),
#  (['professor(A) -> director(A)',
#    'advisedby(A,B) -> workedunder(A,B)',
#    'projectmember(A,B) -> genre(B,A)',
#    'student(A) -> actor(A)'],
#   0.21739130434782608,
#   4),
#  (['professor(A) -> director(A)',
#    'advisedby(A,B) -> workedunder(A,B)',
#    'projectmember(A,B) -> genre(B,A)',
#    'student(A) -> female(A)'],
#   0.21739130434782608,
#   4),
#  (['publication(A,B) -> movie(A,B)',
#    'advisedby(A,B) -> workedunder(B,A)',
#    'student(A) -> director(A)'],
#   0.21649484536082475,
#   3),
#  (['professor(A) -> female(A)',
#    'advisedby(A,B) -> workedunder(A,B)',
#    'publication(A,B) -> movie(A,B)',
#    'projectmember(A,B) -> genre(B,A)',
#    'student(A) -> director(A)'],
#   0.216,
#   5),
#  (['professor(A) -> director(A)',
#    'advisedby(A,B) -> workedunder(A,B)',
#    'publication(A,B) -> movie(A,B)',
#    'projectmember(A,B) -> movie(A,B)'],
#   0.21428571428571427,
#   4),
#  (['advisedby(A,B) -> workedunder(B,A)',
#    'publication(A,B) -> movie(A,B)',
#    'projectmember(A,B) -> movie(A,B)',
#    'student(A) -> director(A)'],
#   0.21428571428571427,
#   4),
#  (['professor(A) -> director(A)',
#    'advisedby(A,B) -> workedunder(B,A)',
#    'publication(A,B) -> genre(B,A)',
#    'projectmember(A,B) -> movie(A,B)',
#    'student(A) -> director(A)'],
#   0.21311475409836064,
#   5),
#  (['professor(A) -> director(A)',
#    'advisedby(A,B) -> workedunder(B,A)',
#    'publication(A,B) -> movie(A,B)',
#    'projectmember(A,B) -> genre(B,A)',
#    'student(A) -> actor(A)'],
#   0.20634920634920634,
#   5),
#  (['professor(A) -> actor(A)',
#    'advisedby(A,B) -> workedunder(B,A)',
#    'publication(A,B) -> genre(B,A)',
#    'projectmember(A,B) -> movie(A,B)',
#    'student(A) -> actor(A)'],
#   0.2032520325203252,
#   5),
#  (['professor(A) -> actor(A)',
#    'advisedby(A,B) -> workedunder(B,A)',
#    'publication(A,B) -> genre(B,A)',
#    'projectmember(A,B) -> movie(A,B)',
#    'student(A) -> female(A)'],
#   0.1968503937007874,
#   5),
#  (['professor(A) -> director(A)',
#    'advisedby(A,B) -> workedunder(B,A)',
#    'publication(A,B) -> movie(A,B)',
#    'projectmember(A,B) -> genre(B,A)',
#    'student(A) -> female(A)'],
#   0.1968503937007874,
#   5),
#  (['professor(A) -> director(A)',
#    'advisedby(A,B) -> workedunder(A,B)',
#    'publication(A,B) -> genre(B,A)',
#    'projectmember(A,B) -> movie(A,B)'],
#   0.19642857142857142,
#   4),
#  (['professor(A) -> director(A)',
#    'advisedby(A,B) -> workedunder(B,A)',
#    'publication(A,B) -> movie(A,B)',
#    'projectmember(A,B) -> genre(B,A)'],
#   0.19642857142857142,
#   4),
#  (['professor(A) -> director(A)',
#    'publication(A,B) -> movie(A,B)',
#    'advisedby(A,B) -> workedunder(A,B)',
#    'student(A) -> director(A)'],
#   0.19444444444444445,
#   4),
#  (['professor(A) -> director(A)',
#    'publication(A,B) -> movie(A,B)',
#    'advisedby(A,B) -> workedunder(B,A)',
#    'student(A) -> director(A)'],
#   0.19444444444444445,
#   4),
#  (['professor(A) -> female(A)',
#    'advisedby(A,B) -> workedunder(B,A)',
#    'publication(A,B) -> genre(B,A)',
#    'projectmember(A,B) -> movie(A,B)',
#    'student(A) -> female(A)'],
#   0.1935483870967742,
#   5),
#  (['professor(A) -> director(A)',
#    'advisedby(A,B) -> workedunder(A,B)',
#    'publication(A,B) -> movie(A,B)',
#    'projectmember(A,B) -> movie(A,B)',
#    'student(A) -> director(A)'],
#   0.1926605504587156,
#   5),
#  (['professor(A) -> director(A)',
#    'advisedby(A,B) -> workedunder(B,A)',
#    'publication(A,B) -> movie(A,B)',
#    'projectmember(A,B) -> movie(A,B)',
#    'student(A) -> director(A)'],
#   0.1926605504587156,
#   5),
#  (['advisedby(A,B) -> workedunder(B,A)',
#    'publication(A,B) -> movie(A,B)',
#    'projectmember(A,B) -> genre(B,A)',
#    'student(A) -> actor(A)'],
#   0.1926605504587156,
#   4),
#  (['professor(A) -> actor(A)',
#    'advisedby(A,B) -> workedunder(B,A)',
#    'projectmember(A,B) -> movie(A,B)',
#    'student(A) -> director(A)'],
#   0.19148936170212766,
#   4),
#  (['professor(A) -> female(A)',
#    'advisedby(A,B) -> workedunder(B,A)',
#    'publication(A,B) -> genre(B,A)',
#    'projectmember(A,B) -> movie(A,B)',
#    'student(A) -> actor(A)'],
#   0.1875,
#   5),
#  (['professor(A) -> director(A)',
#    'advisedby(A,B) -> workedunder(A,B)',
#    'publication(A,B) -> genre(B,A)',
#    'projectmember(A,B) -> movie(A,B)',
#    'student(A) -> director(A)'],
#   0.184,
#   5),
#  (['advisedby(A,B) -> workedunder(A,B)',
#    'publication(A,B) -> genre(B,A)',
#    'projectmember(A,B) -> movie(A,B)',
#    'student(A) -> actor(A)'],
#   0.18181818181818182,
#   4),
#  (['advisedby(A,B) -> workedunder(A,B)',
#    'publication(A,B) -> genre(B,A)',
#    'projectmember(A,B) -> movie(A,B)',
#    'student(A) -> female(A)'],
#   0.18181818181818182,
#   4),
#  (['advisedby(A,B) -> workedunder(B,A)',
#    'publication(A,B) -> movie(A,B)',
#    'projectmember(A,B) -> genre(B,A)',
#    'student(A) -> female(A)'],
#   0.18181818181818182,
#   4),
#  (['professor(A) -> female(A)',
#    'advisedby(A,B) -> workedunder(B,A)',
#    'projectmember(A,B) -> movie(A,B)',
#    'student(A) -> director(A)'],
#   0.17894736842105263,
#   4),
#  (['professor(A) -> director(A)',
#    'advisedby(A,B) -> workedunder(A,B)',
#    'publication(A,B) -> genre(B,A)',
#    'projectmember(A,B) -> genre(B,A)'],
#   0.1782178217821782,
#   4),
#  (['advisedby(A,B) -> workedunder(B,A)',
#    'publication(A,B) -> movie(A,B)',
#    'projectmember(A,B) -> genre(B,A)'],
#   0.17525773195876287,
#   3),
#  (['professor(A) -> actor(A)',
#    'advisedby(A,B) -> workedunder(A,B)',
#    'publication(A,B) -> genre(B,A)',
#    'projectmember(A,B) -> movie(A,B)',
#    'student(A) -> actor(A)'],
#   0.1746031746031746,
#   5),
#  (['professor(A) -> actor(A)',
#    'publication(A,B) -> movie(A,B)',
#    'advisedby(A,B) -> workedunder(A,B)'],
#   0.17,
#   3),
#  (['professor(A) -> actor(A)',
#    'advisedby(A,B) -> workedunder(A,B)',
#    'publication(A,B) -> genre(B,A)',
#    'projectmember(A,B) -> movie(A,B)',
#    'student(A) -> female(A)'],
#   0.16923076923076924,
#   5),
#  (['publication(A,B) -> movie(A,B)',
#    'advisedby(A,B) -> workedunder(B,A)',
#    'student(A) -> actor(A)'],
#   0.16831683168316833,
#   3),
#  (['publication(A,B) -> genre(B,A)',
#    'advisedby(A,B) -> workedunder(B,A)',
#    'student(A) -> director(A)'],
#   0.16831683168316833,
#   3),
#  (['professor(A) -> actor(A)',
#    'advisedby(A,B) -> workedunder(A,B)',
#    'publication(A,B) -> movie(A,B)',
#    'projectmember(A,B) -> movie(A,B)'],
#   0.16666666666666666,
#   4),
#  (['professor(A) -> actor(A)',
#    'publication(A,B) -> movie(A,B)',
#    'advisedby(A,B) -> workedunder(A,B)',
#    'student(A) -> director(A)'],
#   0.16666666666666666,
#   4),
#  (['advisedby(A,B) -> workedunder(B,A)',
#    'publication(A,B) -> movie(A,B)',
#    'projectmember(A,B) -> movie(A,B)',
#    'student(A) -> actor(A)'],
#   0.16666666666666666,
#   4),
#  (['advisedby(A,B) -> workedunder(B,A)',
#    'publication(A,B) -> genre(B,A)',
#    'projectmember(A,B) -> genre(B,A)',
#    'student(A) -> director(A)'],
#   0.16666666666666666,
#   4),
#  (['professor(A) -> director(A)',
#    'publication(A,B) -> movie(A,B)',
#    'advisedby(A,B) -> workedunder(B,A)',
#    'student(A) -> actor(A)'],
#   0.16666666666666666,
#   4),
#  (['professor(A) -> female(A)',
#    'advisedby(A,B) -> workedunder(A,B)',
#    'publication(A,B) -> genre(B,A)',
#    'projectmember(A,B) -> movie(A,B)',
#    'student(A) -> female(A)'],
#   0.16535433070866143,
#   5),
#  (['professor(A) -> director(A)',
#    'advisedby(A,B) -> workedunder(B,A)',
#    'publication(A,B) -> genre(B,A)',
#    'projectmember(A,B) -> movie(A,B)'],
#   0.16521739130434782,
#   4),
#  (['professor(A) -> actor(A)',
#    'advisedby(A,B) -> workedunder(A,B)',
#    'publication(A,B) -> movie(A,B)',
#    'projectmember(A,B) -> movie(A,B)',
#    'student(A) -> director(A)'],
#   0.16379310344827586,
#   5),
#  (['professor(A) -> director(A)',
#    'advisedby(A,B) -> workedunder(B,A)',
#    'publication(A,B) -> movie(A,B)',
#    'projectmember(A,B) -> movie(A,B)',
#    'student(A) -> actor(A)'],
#   0.16379310344827586,
#   5),
#  (['professor(A) -> director(A)',
#    'advisedby(A,B) -> workedunder(A,B)',
#    'publication(A,B) -> genre(B,A)',
#    'projectmember(A,B) -> genre(B,A)',
#    'student(A) -> director(A)'],
#   0.16071428571428573,
#   5),
#  (['professor(A) -> female(A)',
#    'advisedby(A,B) -> workedunder(A,B)',
#    'publication(A,B) -> genre(B,A)',
#    'projectmember(A,B) -> movie(A,B)',
#    'student(A) -> actor(A)'],
#   0.16030534351145037,
#   5),
#  (['professor(A) -> female(A)',
#    'publication(A,B) -> movie(A,B)',
#    'advisedby(A,B) -> workedunder(A,B)'],
#   0.15841584158415842,
#   3),
#  (['professor(A) -> director(A)',
#    'publication(A,B) -> genre(B,A)',
#    'advisedby(A,B) -> workedunder(A,B)'],
#   0.15841584158415842,
#   3),
#  (['publication(A,B) -> movie(A,B)',
#    'advisedby(A,B) -> workedunder(B,A)',
#    'student(A) -> female(A)'],
#   0.1568627450980392,
#   3),
#  (['professor(A) -> female(A)',
#    'publication(A,B) -> movie(A,B)',
#    'advisedby(A,B) -> workedunder(A,B)',
#    'student(A) -> director(A)'],
#   0.1565217391304348,
#   4),
#  (['professor(A) -> director(A)',
#    'publication(A,B) -> movie(A,B)',
#    'advisedby(A,B) -> workedunder(B,A)',
#    'student(A) -> female(A)'],
#   0.1565217391304348,
#   4),
#  (['professor(A) -> female(A)',
#    'advisedby(A,B) -> workedunder(A,B)',
#    'publication(A,B) -> movie(A,B)',
#    'projectmember(A,B) -> movie(A,B)'],
#   0.1553398058252427,
#   4),
#  (['advisedby(A,B) -> workedunder(A,B)',
#    'publication(A,B) -> genre(B,A)',
#    'projectmember(A,B) -> genre(B,A)',
#    'student(A) -> actor(A)'],
#   0.1553398058252427,
#   4),
#  (['advisedby(A,B) -> workedunder(A,B)',
#    'publication(A,B) -> genre(B,A)',
#    'projectmember(A,B) -> genre(B,A)',
#    'student(A) -> female(A)'],
#   0.1553398058252427,
#   4),
#  (['advisedby(A,B) -> workedunder(B,A)',
#    'publication(A,B) -> movie(A,B)',
#    'projectmember(A,B) -> movie(A,B)',
#    'student(A) -> female(A)'],
#   0.1553398058252427,
#   4),
#  (['professor(A) -> director(A)',
#    'advisedby(A,B) -> workedunder(A,B)',
#    'projectmember(A,B) -> movie(A,B)',
#    'student(A) -> actor(A)'],
#   0.15463917525773196,
#   4),
#  (['professor(A) -> director(A)',
#    'advisedby(A,B) -> workedunder(A,B)',
#    'projectmember(A,B) -> movie(A,B)',
#    'student(A) -> female(A)'],
#   0.15463917525773196,
#   4),
#  (['professor(A) -> female(A)',
#    'advisedby(A,B) -> workedunder(A,B)',
#    'publication(A,B) -> movie(A,B)',
#    'projectmember(A,B) -> movie(A,B)',
#    'student(A) -> director(A)'],
#   0.15384615384615385,
#   5),
#  (['professor(A) -> director(A)',
#    'advisedby(A,B) -> workedunder(B,A)',
#    'publication(A,B) -> movie(A,B)',
#    'projectmember(A,B) -> movie(A,B)',
#    'student(A) -> female(A)'],
#   0.15384615384615385,
#   5),
#  (['professor(A) -> director(A)',
#    'publication(A,B) -> genre(B,A)',
#    'advisedby(A,B) -> workedunder(A,B)',
#    'student(A) -> director(A)'],
#   0.15178571428571427,
#   4),
#  (['professor(A) -> director(A)',
#    'publication(A,B) -> genre(B,A)',
#    'advisedby(A,B) -> workedunder(B,A)',
#    'student(A) -> director(A)'],
#   0.15178571428571427,
#   4),
#  (['advisedby(A,B) -> workedunder(B,A)',
#    'publication(A,B) -> genre(B,A)',
#    'projectmember(A,B) -> movie(A,B)'],
#   0.15151515151515152,
#   3),
#  (['professor(A) -> director(A)',
#    'advisedby(A,B) -> workedunder(B,A)',
#    'publication(A,B) -> genre(B,A)',
#    'projectmember(A,B) -> genre(B,A)',
#    'student(A) -> director(A)'],
#   0.1504424778761062,
#   5),
#  (['professor(A) -> director(A)',
#    'publication(A,B) -> movie(A,B)',
#    'advisedby(A,B) -> workedunder(B,A)'],
#   0.14705882352941177,
#   3),
#  (['professor(A) -> actor(A)',
#    'publication(A,B) -> genre(B,A)',
#    'advisedby(A,B) -> workedunder(B,A)'],
#   0.14705882352941177,
#   3),
#  (['professor(A) -> female(A)',
#    'publication(A,B) -> genre(B,A)',
#    'advisedby(A,B) -> workedunder(B,A)'],
#   0.14705882352941177,
#   3),
#  (['publication(A,B) -> movie(A,B)',
#    'advisedby(A,B) -> workedunder(A,B)',
#    'student(A) -> director(A)'],
#   0.14563106796116504,
#   3),
#  (['publication(A,B) -> genre(B,A)',
#    'advisedby(A,B) -> workedunder(A,B)',
#    'student(A) -> actor(A)'],
#   0.14563106796116504,
#   3),
#  (['publication(A,B) -> genre(B,A)',
#    'advisedby(A,B) -> workedunder(A,B)',
#    'student(A) -> female(A)'],
#   0.14563106796116504,
#   3),
#  (['advisedby(A,B) -> workedunder(A,B)',
#    'publication(A,B) -> movie(A,B)',
#    'projectmember(A,B) -> movie(A,B)',
#    'student(A) -> director(A)'],
#   0.14423076923076922,
#   4),
#  (['professor(A) -> director(A)',
#    'advisedby(A,B) -> workedunder(B,A)',
#    'publication(A,B) -> movie(A,B)',
#    'projectmember(A,B) -> movie(A,B)'],
#   0.14423076923076922,
#   4),
#  (['professor(A) -> actor(A)',
#    'advisedby(A,B) -> workedunder(B,A)',
#    'publication(A,B) -> genre(B,A)',
#    'projectmember(A,B) -> genre(B,A)'],
#   0.14423076923076922,
#   4),
#  (['professor(A) -> female(A)',
#    'advisedby(A,B) -> workedunder(B,A)',
#    'publication(A,B) -> genre(B,A)',
#    'projectmember(A,B) -> genre(B,A)'],
#   0.14423076923076922,
#   4),
#  (['professor(A) -> director(A)',
#    'advisedby(A,B) -> workedunder(B,A)',
#    'publication(A,B) -> genre(B,A)',
#    'projectmember(A,B) -> movie(A,B)',
#    'student(A) -> actor(A)'],
#   0.14285714285714285,
#   5),
#  (['professor(A) -> director(A)',
#    'advisedby(A,B) -> workedunder(B,A)',
#    'publication(A,B) -> genre(B,A)',
#    'projectmember(A,B) -> movie(A,B)',
#    'student(A) -> female(A)'],
#   0.14285714285714285,
#   5),
#  (['publication(A,B) -> movie(A,B)', 'advisedby(A,B) -> workedunder(A,B)'],
#   0.14285714285714285,
#   2),
#  (['publication(A,B) -> movie(A,B)', 'advisedby(A,B) -> workedunder(B,A)'],
#   0.14285714285714285,
#   2),
#  (['advisedby(A,B) -> workedunder(A,B)',
#    'publication(A,B) -> movie(A,B)',
#    'projectmember(A,B) -> movie(A,B)'],
#   0.14130434782608695,
#   3),
#  (['advisedby(A,B) -> workedunder(B,A)',
#    'publication(A,B) -> movie(A,B)',
#    'projectmember(A,B) -> movie(A,B)'],
#   0.14130434782608695,
#   3),
#  (['professor(A) -> actor(A)',
#    'advisedby(A,B) -> workedunder(A,B)',
#    'publication(A,B) -> genre(B,A)',
#    'projectmember(A,B) -> genre(B,A)',
#    'student(A) -> actor(A)'],
#   0.14035087719298245,
#   5),
#  (['professor(A) -> female(A)',
#    'advisedby(A,B) -> workedunder(A,B)',
#    'publication(A,B) -> genre(B,A)',
#    'projectmember(A,B) -> genre(B,A)',
#    'student(A) -> female(A)'],
#   0.14035087719298245,
#   5),
#  (['advisedby(A,B) -> workedunder(A,B)',
#    'publication(A,B) -> genre(B,A)',
#    'projectmember(A,B) -> movie(A,B)',
#    'student(A) -> director(A)'],
#   0.14035087719298245,
#   4),
#  (['advisedby(A,B) -> workedunder(A,B)',
#    'projectmember(A,B) -> genre(B,A)',
#    'student(A) -> actor(A)'],
#   0.13636363636363635,
#   3),
#  (['advisedby(A,B) -> workedunder(A,B)',
#    'projectmember(A,B) -> genre(B,A)',
#    'student(A) -> female(A)'],
#   0.13636363636363635,
#   3),
#  (['professor(A) -> actor(A)',
#    'advisedby(A,B) -> workedunder(A,B)',
#    'publication(A,B) -> genre(B,A)',
#    'projectmember(A,B) -> genre(B,A)',
#    'student(A) -> female(A)'],
#   0.13445378151260504,
#   5),
#  (['professor(A) -> female(A)',
#    'advisedby(A,B) -> workedunder(A,B)',
#    'publication(A,B) -> genre(B,A)',
#    'projectmember(A,B) -> genre(B,A)',
#    'student(A) -> actor(A)'],
#   0.13445378151260504,
#   5),
#  (['professor(A) -> actor(A)',
#    'advisedby(A,B) -> workedunder(A,B)',
#    'publication(A,B) -> genre(B,A)',
#    'projectmember(A,B) -> movie(A,B)',
#    'student(A) -> director(A)'],
#   0.13432835820895522,
#   5),
#  (['advisedby(A,B) -> workedunder(A,B)',
#    'publication(A,B) -> genre(B,A)',
#    'projectmember(A,B) -> genre(B,A)',
#    'student(A) -> director(A)'],
#   0.13333333333333333,
#   4),
#  (['professor(A) -> director(A)',
#    'advisedby(A,B) -> workedunder(A,B)',
#    'projectmember(A,B) -> genre(B,A)'],
#   0.13186813186813187,
#   3),
#  (['professor(A) -> actor(A)',
#    'advisedby(A,B) -> workedunder(B,A)',
#    'projectmember(A,B) -> movie(A,B)'],
#   0.13186813186813187,
#   3),
#  (['professor(A) -> actor(A)',
#    'publication(A,B) -> genre(B,A)',
#    'advisedby(A,B) -> workedunder(A,B)',
#    'student(A) -> actor(A)'],
#   0.13157894736842105,
#   4),
#  (['professor(A) -> female(A)',
#    'publication(A,B) -> genre(B,A)',
#    'advisedby(A,B) -> workedunder(A,B)',
#    'student(A) -> female(A)'],
#   0.13157894736842105,
#   4),
#  (['professor(A) -> actor(A)',
#    'publication(A,B) -> genre(B,A)',
#    'advisedby(A,B) -> workedunder(B,A)',
#    'student(A) -> actor(A)'],
#   0.13157894736842105,
#   4),
#  (['professor(A) -> female(A)',
#    'publication(A,B) -> genre(B,A)',
#    'advisedby(A,B) -> workedunder(B,A)',
#    'student(A) -> female(A)'],
#   0.13157894736842105,
#   4),
#  (['professor(A) -> actor(A)',
#    'advisedby(A,B) -> workedunder(B,A)',
#    'publication(A,B) -> genre(B,A)',
#    'projectmember(A,B) -> genre(B,A)',
#    'student(A) -> actor(A)'],
#   0.13043478260869565,
#   5),
#  (['professor(A) -> female(A)',
#    'advisedby(A,B) -> workedunder(B,A)',
#    'publication(A,B) -> genre(B,A)',
#    'projectmember(A,B) -> genre(B,A)',
#    'student(A) -> female(A)'],
#   0.13043478260869565,
#   5),
#  (['advisedby(A,B) -> workedunder(B,A)',
#    'publication(A,B) -> genre(B,A)',
#    'projectmember(A,B) -> movie(A,B)',
#    'student(A) -> actor(A)'],
#   0.13043478260869565,
#   4),
#  (['advisedby(A,B) -> workedunder(B,A)',
#    'publication(A,B) -> genre(B,A)',
#    'projectmember(A,B) -> movie(A,B)',
#    'student(A) -> female(A)'],
#   0.13043478260869565,
#   4),
#  (['professor(A) -> actor(A)',
#    'publication(A,B) -> genre(B,A)',
#    'advisedby(A,B) -> workedunder(A,B)',
#    'student(A) -> female(A)'],
#   0.1271186440677966,
#   4),
#  (['professor(A) -> female(A)',
#    'publication(A,B) -> genre(B,A)',
#    'advisedby(A,B) -> workedunder(A,B)',
#    'student(A) -> actor(A)'],
#   0.1271186440677966,
#   4),
#  (['professor(A) -> actor(A)',
#    'publication(A,B) -> genre(B,A)',
#    'advisedby(A,B) -> workedunder(B,A)',
#    'student(A) -> female(A)'],
#   0.1271186440677966,
#   4),
#  (['professor(A) -> female(A)',
#    'publication(A,B) -> genre(B,A)',
#    'advisedby(A,B) -> workedunder(B,A)',
#    'student(A) -> actor(A)'],
#   0.1271186440677966,
#   4),
#  (['professor(A) -> female(A)',
#    'advisedby(A,B) -> workedunder(A,B)',
#    'publication(A,B) -> genre(B,A)',
#    'projectmember(A,B) -> movie(A,B)',
#    'student(A) -> director(A)'],
#   0.1259259259259259,
#   5),
#  (['professor(A) -> actor(A)',
#    'advisedby(A,B) -> workedunder(B,A)',
#    'publication(A,B) -> genre(B,A)',
#    'projectmember(A,B) -> genre(B,A)',
#    'student(A) -> female(A)'],
#   0.125,
#   5),
#  (['professor(A) -> female(A)',
#    'advisedby(A,B) -> workedunder(B,A)',
#    'publication(A,B) -> genre(B,A)',
#    'projectmember(A,B) -> genre(B,A)',
#    'student(A) -> actor(A)'],
#   0.125,
#   5),
#  (['publication(A,B) -> genre(B,A)',
#    'advisedby(A,B) -> workedunder(A,B)',
#    'student(A) -> director(A)'],
#   0.12380952380952381,
#   3),
#  (['professor(A) -> director(A)',
#    'advisedby(A,B) -> workedunder(B,A)',
#    'publication(A,B) -> genre(B,A)',
#    'projectmember(A,B) -> genre(B,A)'],
#   0.12264150943396226,
#   4),
#  (['professor(A) -> actor(A)',
#    'advisedby(A,B) -> workedunder(A,B)',
#    'projectmember(A,B) -> genre(B,A)',
#    'student(A) -> actor(A)'],
#   0.12,
#   4),
#  (['professor(A) -> actor(A)',
#    'advisedby(A,B) -> workedunder(A,B)',
#    'projectmember(A,B) -> genre(B,A)',
#    'student(A) -> female(A)'],
#   0.12,
#   4),
#  (['professor(A) -> director(A)',
#    'advisedby(A,B) -> workedunder(A,B)',
#    'projectmember(A,B) -> genre(B,A)',
#    'student(A) -> director(A)'],
#   0.12,
#   4),
#  (['professor(A) -> female(A)',
#    'advisedby(A,B) -> workedunder(A,B)',
#    'projectmember(A,B) -> genre(B,A)',
#    'student(A) -> actor(A)'],
#   0.12,
#   4),
#  (['professor(A) -> female(A)',
#    'advisedby(A,B) -> workedunder(A,B)',
#    'projectmember(A,B) -> genre(B,A)',
#    'student(A) -> female(A)'],
#   0.12,
#   4),
#  (['professor(A) -> actor(A)',
#    'advisedby(A,B) -> workedunder(B,A)',
#    'projectmember(A,B) -> movie(A,B)',
#    'student(A) -> actor(A)'],
#   0.12,
#   4),
#  (['professor(A) -> actor(A)',
#    'advisedby(A,B) -> workedunder(B,A)',
#    'projectmember(A,B) -> movie(A,B)',
#    'student(A) -> female(A)'],
#   0.12,
#   4),
#  (['professor(A) -> female(A)',
#    'advisedby(A,B) -> workedunder(B,A)',
#    'projectmember(A,B) -> movie(A,B)'],
#   0.11956521739130435,
#   3),
#  (['advisedby(A,B) -> workedunder(A,B)',
#    'publication(A,B) -> genre(B,A)',
#    'projectmember(A,B) -> movie(A,B)'],
#   0.11764705882352941,
#   3),
#  (['professor(A) -> actor(A)',
#    'advisedby(A,B) -> workedunder(A,B)',
#    'publication(A,B) -> genre(B,A)',
#    'projectmember(A,B) -> movie(A,B)'],
#   0.11666666666666667,
#   4),
#  (['professor(A) -> actor(A)',
#    'advisedby(A,B) -> workedunder(A,B)',
#    'publication(A,B) -> genre(B,A)',
#    'projectmember(A,B) -> genre(B,A)',
#    'student(A) -> director(A)'],
#   0.11570247933884298,
#   5),
#  (['professor(A) -> female(A)',
#    'advisedby(A,B) -> workedunder(A,B)',
#    'publication(A,B) -> genre(B,A)',
#    'projectmember(A,B) -> genre(B,A)',
#    'student(A) -> director(A)'],
#   0.11570247933884298,
#   5),
#  (['professor(A) -> director(A)',
#    'publication(A,B) -> genre(B,A)',
#    'advisedby(A,B) -> workedunder(B,A)'],
#   0.11428571428571428,
#   3),
#  (['professor(A) -> director(A)',
#    'advisedby(A,B) -> workedunder(A,B)',
#    'student(A) -> actor(A)'],
#   0.1111111111111111,
#   3),
#  (['professor(A) -> director(A)',
#    'advisedby(A,B) -> workedunder(A,B)',
#    'student(A) -> female(A)'],
#   0.1111111111111111,
#   3),
#  (['professor(A) -> actor(A)',
#    'advisedby(A,B) -> workedunder(B,A)',
#    'student(A) -> director(A)'],
#   0.1111111111111111,
#   3),
#  (['professor(A) -> female(A)',
#    'advisedby(A,B) -> workedunder(B,A)',
#    'student(A) -> director(A)'],
#   0.1111111111111111,
#   3),
#  (['professor(A) -> actor(A)',
#    'advisedby(A,B) -> workedunder(A,B)',
#    'projectmember(A,B) -> movie(A,B)',
#    'student(A) -> actor(A)'],
#   0.10891089108910891,
#   4),
#  (['professor(A) -> actor(A)',
#    'advisedby(A,B) -> workedunder(A,B)',
#    'projectmember(A,B) -> movie(A,B)',
#    'student(A) -> female(A)'],
#   0.10891089108910891,
#   4),
#  (['professor(A) -> female(A)',
#    'advisedby(A,B) -> workedunder(B,A)',
#    'projectmember(A,B) -> movie(A,B)',
#    'student(A) -> actor(A)'],
#   0.10891089108910891,
#   4),
#  (['professor(A) -> female(A)',
#    'advisedby(A,B) -> workedunder(B,A)',
#    'projectmember(A,B) -> movie(A,B)',
#    'student(A) -> female(A)'],
#   0.10891089108910891,
#   4),
#  (['professor(A) -> actor(A)',
#    'advisedby(A,B) -> workedunder(B,A)',
#    'projectmember(A,B) -> genre(B,A)',
#    'student(A) -> director(A)'],
#   0.10891089108910891,
#   4),
#  (['professor(A) -> female(A)',
#    'advisedby(A,B) -> workedunder(B,A)',
#    'projectmember(A,B) -> genre(B,A)',
#    'student(A) -> director(A)'],
#   0.10891089108910891,
#   4),
#  (['professor(A) -> actor(A)',
#    'publication(A,B) -> genre(B,A)',
#    'advisedby(A,B) -> workedunder(A,B)',
#    'student(A) -> director(A)'],
#   0.10833333333333334,
#   4),
#  (['professor(A) -> female(A)',
#    'publication(A,B) -> genre(B,A)',
#    'advisedby(A,B) -> workedunder(A,B)',
#    'student(A) -> director(A)'],
#   0.10833333333333334,
#   4),
#  (['professor(A) -> female(A)',
#    'advisedby(A,B) -> workedunder(A,B)',
#    'publication(A,B) -> genre(B,A)',
#    'projectmember(A,B) -> movie(A,B)'],
#   0.10743801652892562,
#   4),
#  (['professor(A) -> director(A)',
#    'advisedby(A,B) -> workedunder(B,A)',
#    'publication(A,B) -> genre(B,A)',
#    'projectmember(A,B) -> genre(B,A)',
#    'student(A) -> actor(A)'],
#   0.10655737704918032,
#   5),
#  (['professor(A) -> director(A)',
#    'advisedby(A,B) -> workedunder(B,A)',
#    'publication(A,B) -> genre(B,A)',
#    'projectmember(A,B) -> genre(B,A)',
#    'student(A) -> female(A)'],
#   0.10655737704918032,
#   5),
#  (['advisedby(A,B) -> workedunder(A,B)',
#    'publication(A,B) -> genre(B,A)',
#    'projectmember(A,B) -> genre(B,A)'],
#   0.10526315789473684,
#   3),
#  (['professor(A) -> director(A)',
#    'publication(A,B) -> genre(B,A)',
#    'advisedby(A,B) -> workedunder(B,A)',
#    'student(A) -> actor(A)'],
#   0.09917355371900827,
#   4),
#  (['professor(A) -> director(A)',
#    'publication(A,B) -> genre(B,A)',
#    'advisedby(A,B) -> workedunder(B,A)',
#    'student(A) -> female(A)'],
#   0.09917355371900827,
#   4),
#  (['advisedby(A,B) -> workedunder(A,B)',
#    'projectmember(A,B) -> movie(A,B)',
#    'student(A) -> actor(A)'],
#   0.0989010989010989,
#   3),
#  (['advisedby(A,B) -> workedunder(A,B)',
#    'projectmember(A,B) -> movie(A,B)',
#    'student(A) -> female(A)'],
#   0.0989010989010989,
#   3),
#  (['professor(A) -> female(A)',
#    'advisedby(A,B) -> workedunder(A,B)',
#    'projectmember(A,B) -> movie(A,B)',
#    'student(A) -> actor(A)'],
#   0.09803921568627451,
#   4),
#  (['professor(A) -> female(A)',
#    'advisedby(A,B) -> workedunder(A,B)',
#    'projectmember(A,B) -> movie(A,B)',
#    'student(A) -> female(A)'],
#   0.09803921568627451,
#   4),
#  (['publication(A,B) -> genre(B,A)', 'advisedby(A,B) -> workedunder(A,B)'],
#   0.09473684210526316,
#   2),
#  (['publication(A,B) -> genre(B,A)', 'advisedby(A,B) -> workedunder(B,A)'],
#   0.09473684210526316,
#   2),
#  (['advisedby(A,B) -> workedunder(B,A)',
#    'publication(A,B) -> genre(B,A)',
#    'projectmember(A,B) -> genre(B,A)'],
#   0.09375,
#   3),
#  (['professor(A) -> actor(A)',
#    'advisedby(A,B) -> workedunder(A,B)',
#    'publication(A,B) -> genre(B,A)',
#    'projectmember(A,B) -> genre(B,A)'],
#   0.09174311926605505,
#   4),
#  (['professor(A) -> female(A)',
#    'advisedby(A,B) -> workedunder(A,B)',
#    'publication(A,B) -> genre(B,A)',
#    'projectmember(A,B) -> genre(B,A)'],
#   0.09174311926605505,
#   4),
#  (['advisedby(A,B) -> workedunder(B,A)',
#    'projectmember(A,B) -> movie(A,B)',
#    'student(A) -> director(A)'],
#   0.08695652173913043,
#   3),
#  (['professor(A) -> actor(A)',
#    'publication(A,B) -> genre(B,A)',
#    'advisedby(A,B) -> workedunder(A,B)'],
#   0.08333333333333333,
#   3),
#  (['professor(A) -> female(A)',
#    'publication(A,B) -> genre(B,A)',
#    'advisedby(A,B) -> workedunder(A,B)'],
#   0.08333333333333333,
#   3),
#  (['publication(A,B) -> genre(B,A)',
#    'advisedby(A,B) -> workedunder(B,A)',
#    'student(A) -> actor(A)'],
#   0.08256880733944955,
#   3),
#  (['publication(A,B) -> genre(B,A)',
#    'advisedby(A,B) -> workedunder(B,A)',
#    'student(A) -> female(A)'],
#   0.08256880733944955,
#   3),
#  (['advisedby(A,B) -> workedunder(B,A)',
#    'publication(A,B) -> genre(B,A)',
#    'projectmember(A,B) -> genre(B,A)',
#    'student(A) -> actor(A)'],
#   0.08181818181818182,
#   4),
#  (['advisedby(A,B) -> workedunder(B,A)',
#    'publication(A,B) -> genre(B,A)',
#    'projectmember(A,B) -> genre(B,A)',
#    'student(A) -> female(A)'],
#   0.08181818181818182,
#   4),
#  (['professor(A) -> director(A)',
#    'advisedby(A,B) -> workedunder(B,A)',
#    'projectmember(A,B) -> movie(A,B)',
#    'student(A) -> director(A)'],
#   0.07692307692307693,
#   4),
#  (['professor(A) -> director(A)',
#    'advisedby(A,B) -> workedunder(A,B)',
#    'projectmember(A,B) -> movie(A,B)'],
#   0.07291666666666667,
#   3),
#  (['professor(A) -> actor(A)',
#    'advisedby(A,B) -> workedunder(B,A)',
#    'projectmember(A,B) -> genre(B,A)'],
#   0.07291666666666667,
#   3),
#  (['professor(A) -> female(A)',
#    'advisedby(A,B) -> workedunder(B,A)',
#    'projectmember(A,B) -> genre(B,A)'],
#   0.07291666666666667,
#   3),
#  (['advisedby(A,B) -> workedunder(A,B)', 'projectmember(A,B) -> genre(B,A)'],
#   0.06896551724137931,
#   2),
#  (['advisedby(A,B) -> workedunder(A,B)', 'student(A) -> actor(A)'],
#   0.06896551724137931,
#   2),
#  (['advisedby(A,B) -> workedunder(A,B)', 'student(A) -> female(A)'],
#   0.06896551724137931,
#   2),
#  (['professor(A) -> actor(A)', 'advisedby(A,B) -> workedunder(B,A)'],
#   0.06896551724137931,
#   2),
#  (['professor(A) -> female(A)', 'advisedby(A,B) -> workedunder(B,A)'],
#   0.06896551724137931,
#   2),
#  (['professor(A) -> director(A)',
#    'advisedby(A,B) -> workedunder(A,B)',
#    'projectmember(A,B) -> movie(A,B)',
#    'student(A) -> director(A)'],
#   0.06666666666666667,
#   4),
#  (['professor(A) -> actor(A)',
#    'advisedby(A,B) -> workedunder(B,A)',
#    'projectmember(A,B) -> genre(B,A)',
#    'student(A) -> actor(A)'],
#   0.06666666666666667,
#   4),
#  (['professor(A) -> actor(A)',
#    'advisedby(A,B) -> workedunder(B,A)',
#    'projectmember(A,B) -> genre(B,A)',
#    'student(A) -> female(A)'],
#   0.06666666666666667,
#   4),
#  (['professor(A) -> director(A)',
#    'advisedby(A,B) -> workedunder(B,A)',
#    'projectmember(A,B) -> genre(B,A)',
#    'student(A) -> director(A)'],
#   0.06666666666666667,
#   4),
#  (['professor(A) -> female(A)',
#    'advisedby(A,B) -> workedunder(B,A)',
#    'projectmember(A,B) -> genre(B,A)',
#    'student(A) -> actor(A)'],
#   0.06666666666666667,
#   4),
#  (['professor(A) -> female(A)',
#    'advisedby(A,B) -> workedunder(B,A)',
#    'projectmember(A,B) -> genre(B,A)',
#    'student(A) -> female(A)'],
#   0.06666666666666667,
#   4),
#  (['advisedby(A,B) -> workedunder(A,B)',
#    'projectmember(A,B) -> genre(B,A)',
#    'student(A) -> director(A)'],
#   0.06382978723404255,
#   3),
#  (['professor(A) -> actor(A)',
#    'advisedby(A,B) -> workedunder(A,B)',
#    'student(A) -> actor(A)'],
#   0.06382978723404255,
#   3),
#  (['professor(A) -> actor(A)',
#    'advisedby(A,B) -> workedunder(A,B)',
#    'student(A) -> female(A)'],
#   0.06382978723404255,
#   3),
#  (['professor(A) -> female(A)',
#    'advisedby(A,B) -> workedunder(A,B)',
#    'student(A) -> actor(A)'],
#   0.06382978723404255,
#   3),
#  (['professor(A) -> female(A)',
#    'advisedby(A,B) -> workedunder(A,B)',
#    'student(A) -> female(A)'],
#   0.06382978723404255,
#   3),
#  (['professor(A) -> actor(A)',
#    'advisedby(A,B) -> workedunder(B,A)',
#    'student(A) -> actor(A)'],
#   0.06382978723404255,
#   3),
#  (['professor(A) -> actor(A)',
#    'advisedby(A,B) -> workedunder(B,A)',
#    'student(A) -> female(A)'],
#   0.06382978723404255,
#   3),
#  (['professor(A) -> female(A)',
#    'advisedby(A,B) -> workedunder(B,A)',
#    'student(A) -> actor(A)'],
#   0.06382978723404255,
#   3),
#  (['professor(A) -> female(A)',
#    'advisedby(A,B) -> workedunder(B,A)',
#    'student(A) -> female(A)'],
#   0.06382978723404255,
#   3),
#  (['professor(A) -> actor(A)',
#    'advisedby(A,B) -> workedunder(A,B)',
#    'projectmember(A,B) -> genre(B,A)'],
#   0.061855670103092786,
#   3),
#  (['professor(A) -> female(A)',
#    'advisedby(A,B) -> workedunder(A,B)',
#    'projectmember(A,B) -> genre(B,A)'],
#   0.061855670103092786,
#   3),
#  (['professor(A) -> actor(A)',
#    'advisedby(A,B) -> workedunder(A,B)',
#    'projectmember(A,B) -> genre(B,A)',
#    'student(A) -> director(A)'],
#   0.05660377358490566,
#   4),
#  (['professor(A) -> female(A)',
#    'advisedby(A,B) -> workedunder(A,B)',
#    'projectmember(A,B) -> genre(B,A)',
#    'student(A) -> director(A)'],
#   0.05660377358490566,
#   4),
#  (['advisedby(A,B) -> workedunder(B,A)',
#    'projectmember(A,B) -> genre(B,A)',
#    'student(A) -> director(A)'],
#   0.05263157894736842,
#   3),
#  (['professor(A) -> actor(A)',
#    'advisedby(A,B) -> workedunder(A,B)',
#    'projectmember(A,B) -> movie(A,B)'],
#   0.05102040816326531,
#   3),
#  (['professor(A) -> director(A)',
#    'advisedby(A,B) -> workedunder(B,A)',
#    'projectmember(A,B) -> genre(B,A)'],
#   0.05102040816326531,
#   3),
#  (['professor(A) -> actor(A)',
#    'advisedby(A,B) -> workedunder(A,B)',
#    'projectmember(A,B) -> movie(A,B)',
#    'student(A) -> director(A)'],
#   0.04672897196261682,
#   4),
#  (['professor(A) -> director(A)',
#    'advisedby(A,B) -> workedunder(B,A)',
#    'projectmember(A,B) -> genre(B,A)',
#    'student(A) -> actor(A)'],
#   0.04672897196261682,
#   4),
#  (['professor(A) -> director(A)',
#    'advisedby(A,B) -> workedunder(B,A)',
#    'projectmember(A,B) -> genre(B,A)',
#    'student(A) -> female(A)'],
#   0.04672897196261682,
#   4),
#  (['professor(A) -> director(A)', 'advisedby(A,B) -> workedunder(A,B)'],
#   0.0449438202247191,
#   2),
#  (['advisedby(A,B) -> workedunder(B,A)', 'projectmember(A,B) -> movie(A,B)'],
#   0.0449438202247191,
#   2),
#  (['advisedby(A,B) -> workedunder(B,A)', 'student(A) -> director(A)'],
#   0.0449438202247191,
#   2),
#  (['professor(A) -> director(A)',
#    'advisedby(A,B) -> workedunder(A,B)',
#    'student(A) -> director(A)'],
#   0.041666666666666664,
#   3),
#  (['advisedby(A,B) -> workedunder(B,A)',
#    'projectmember(A,B) -> movie(A,B)',
#    'student(A) -> actor(A)'],
#   0.041666666666666664,
#   3),
#  (['advisedby(A,B) -> workedunder(B,A)',
#    'projectmember(A,B) -> movie(A,B)',
#    'student(A) -> female(A)'],
#   0.041666666666666664,
#   3),
#  (['professor(A) -> director(A)',
#    'advisedby(A,B) -> workedunder(B,A)',
#    'student(A) -> director(A)'],
#   0.041666666666666664,
#   3),
#  (['professor(A) -> female(A)',
#    'advisedby(A,B) -> workedunder(A,B)',
#    'projectmember(A,B) -> movie(A,B)'],
#   0.04040404040404041,
#   3),
#  (['professor(A) -> director(A)',
#    'advisedby(A,B) -> workedunder(B,A)',
#    'projectmember(A,B) -> movie(A,B)'],
#   0.04040404040404041,
#   3),
#  (['professor(A) -> female(A)',
#    'advisedby(A,B) -> workedunder(A,B)',
#    'projectmember(A,B) -> movie(A,B)',
#    'student(A) -> director(A)'],
#   0.037037037037037035,
#   4),
#  (['professor(A) -> director(A)',
#    'advisedby(A,B) -> workedunder(B,A)',
#    'projectmember(A,B) -> movie(A,B)',
#    'student(A) -> actor(A)'],
#   0.037037037037037035,
#   4),
#  (['professor(A) -> director(A)',
#    'advisedby(A,B) -> workedunder(B,A)',
#    'projectmember(A,B) -> movie(A,B)',
#    'student(A) -> female(A)'],
#   0.037037037037037035,
#   4),
#  (['advisedby(A,B) -> workedunder(A,B)', 'projectmember(A,B) -> movie(A,B)'],
#   0.03333333333333333,
#   2),
#  (['advisedby(A,B) -> workedunder(B,A)', 'projectmember(A,B) -> genre(B,A)'],
#   0.03333333333333333,
#   2),
#  (['advisedby(A,B) -> workedunder(A,B)',
#    'projectmember(A,B) -> movie(A,B)',
#    'student(A) -> director(A)'],
#   0.030927835051546393,
#   3),
#  (['advisedby(A,B) -> workedunder(B,A)',
#    'projectmember(A,B) -> genre(B,A)',
#    'student(A) -> actor(A)'],
#   0.030927835051546393,
#   3),
#  (['advisedby(A,B) -> workedunder(B,A)',
#    'projectmember(A,B) -> genre(B,A)',
#    'student(A) -> female(A)'],
#   0.030927835051546393,
#   3),
#  (['advisedby(A,B) -> workedunder(A,B)'], 0.023255813953488372, 1),
#  (['advisedby(A,B) -> workedunder(B,A)'], 0.023255813953488372, 1),
#  (['professor(A) -> actor(A)', 'advisedby(A,B) -> workedunder(A,B)'],
#   0.02197802197802198,
#   2),
#  (['professor(A) -> female(A)', 'advisedby(A,B) -> workedunder(A,B)'],
#   0.02197802197802198,
#   2),
#  (['advisedby(A,B) -> workedunder(A,B)', 'student(A) -> director(A)'],
#   0.02197802197802198,
#   2),
#  (['professor(A) -> director(A)', 'advisedby(A,B) -> workedunder(B,A)'],
#   0.02197802197802198,
#   2),
#  (['advisedby(A,B) -> workedunder(B,A)', 'student(A) -> actor(A)'],
#   0.02197802197802198,
#   2),
#  (['advisedby(A,B) -> workedunder(B,A)', 'student(A) -> female(A)'],
#   0.02197802197802198,
#   2),
#  (['professor(A) -> actor(A)',
#    'advisedby(A,B) -> workedunder(A,B)',
#    'student(A) -> director(A)'],
#   0.02040816326530612,
#   3),
#  (['professor(A) -> female(A)',
#    'advisedby(A,B) -> workedunder(A,B)',
#    'student(A) -> director(A)'],
#   0.02040816326530612,
#   3),
#  (['professor(A) -> director(A)',
#    'advisedby(A,B) -> workedunder(B,A)',
#    'student(A) -> actor(A)'],
#   0.02040816326530612,
#   3),
#  (['professor(A) -> director(A)',
#    'advisedby(A,B) -> workedunder(B,A)',
#    'student(A) -> female(A)'],
#   0.02040816326530612,
#   3)]

# %%
# Load new predicate target dataset
new_target = to_predicate
tar_data = datasets.load(target, bk[target], target=new_target, balanced=balanced, seed=seed)

# Group and shuffle
[tar_train_facts, tar_test_facts] =  datasets.get_kfold_small(i, tar_data[0])
[tar_train_pos, tar_test_pos] =  datasets.get_kfold_small(i, tar_data[1])
[tar_train_neg, tar_test_neg] =  datasets.get_kfold_small(i, tar_data[2])

background = boostsrl.modes(bk[target], [new_target], useStdLogicVariables=False, maxTreeDepth=maxTreeDepth, nodeSize=nodeSize, numOfClauses=numOfClauses)

aucroc_scores = []
for rule in mapping_rules:
    # learning from scratch
    transferred_structured = transfer.transfer(source_structured, rule[0])
    [model, t_results, structured, will, variances] = revision.learn_test_model(background, boostsrl, new_target, tar_train_pos, tar_train_neg, tar_train_facts, tar_test_pos, tar_test_neg, tar_test_facts, refine=revision.get_boosted_refine_file(transferred_structured), trees=10, print_function=print_function)
    res = (rule[0], t_results['AUC ROC'])
    print(res)
    aucroc_scores.append(res)
# Out:
# (['professor(A) -> director(A)', 'advisedby(A,B) -> workedunder(A,B)', 'publication(A,B) -> movie(A,B)', 'projectmember(A,B) -> genre(B,A)', 'student(A) -> actor(A)'], 1.0)
# (['professor(A) -> director(A)', 'advisedby(A,B) -> workedunder(A,B)', 'publication(A,B) -> movie(A,B)', 'projectmember(A,B) -> genre(B,A)', 'student(A) -> female(A)'], 0.712437)
# (['advisedby(A,B) -> workedunder(A,B)', 'publication(A,B) -> movie(A,B)', 'projectmember(A,B) -> genre(B,A)', 'student(A) -> actor(A)'], 0.98168)
# (['advisedby(A,B) -> workedunder(A,B)', 'publication(A,B) -> movie(A,B)', 'projectmember(A,B) -> genre(B,A)', 'student(A) -> female(A)'], 0.688966)
# (['professor(A) -> director(A)', 'publication(A,B) -> movie(A,B)', 'advisedby(A,B) -> workedunder(A,B)', 'student(A) -> actor(A)'], 1.0)
# (['professor(A) -> actor(A)', 'publication(A,B) -> movie(A,B)', 'advisedby(A,B) -> workedunder(B,A)', 'student(A) -> director(A)'], 1.0)
# (['professor(A) -> director(A)', 'advisedby(A,B) -> workedunder(A,B)', 'publication(A,B) -> movie(A,B)', 'projectmember(A,B) -> genre(B,A)'], 0.995545)
# (['professor(A) -> director(A)', 'advisedby(A,B) -> workedunder(A,B)', 'publication(A,B) -> movie(A,B)', 'projectmember(A,B) -> movie(A,B)', 'student(A) -> actor(A)'], 1.0)
# (['professor(A) -> actor(A)', 'advisedby(A,B) -> workedunder(B,A)', 'publication(A,B) -> movie(A,B)', 'projectmember(A,B) -> movie(A,B)', 'student(A) -> director(A)'], 1.0)
# (['professor(A) -> actor(A)', 'advisedby(A,B) -> workedunder(A,B)', 'publication(A,B) -> movie(A,B)', 'projectmember(A,B) -> genre(B,A)', 'student(A) -> female(A)'], 0.630368)
# (['professor(A) -> female(A)', 'advisedby(A,B) -> workedunder(A,B)', 'publication(A,B) -> movie(A,B)', 'projectmember(A,B) -> genre(B,A)', 'student(A) -> actor(A)'], 0.641104)
# (['professor(A) -> actor(A)', 'advisedby(A,B) -> workedunder(B,A)', 'publication(A,B) -> movie(A,B)', 'projectmember(A,B) -> genre(B,A)', 'student(A) -> director(A)'], 1.0)
# (['professor(A) -> director(A)', 'publication(A,B) -> movie(A,B)', 'advisedby(A,B) -> workedunder(A,B)', 'student(A) -> female(A)'], 0.712437)
# (['professor(A) -> female(A)', 'publication(A,B) -> movie(A,B)', 'advisedby(A,B) -> workedunder(B,A)', 'student(A) -> director(A)'], 0.712437)
# (['professor(A) -> director(A)', 'advisedby(A,B) -> workedunder(A,B)', 'publication(A,B) -> movie(A,B)', 'projectmember(A,B) -> movie(A,B)', 'student(A) -> female(A)'], 0.712437)
# (['professor(A) -> female(A)', 'advisedby(A,B) -> workedunder(B,A)', 'publication(A,B) -> movie(A,B)', 'projectmember(A,B) -> movie(A,B)', 'student(A) -> director(A)'], 0.712437)
# (['professor(A) -> female(A)', 'advisedby(A,B) -> workedunder(B,A)', 'publication(A,B) -> movie(A,B)', 'projectmember(A,B) -> genre(B,A)', 'student(A) -> director(A)'], 0.712437)
# (['professor(A) -> actor(A)', 'advisedby(A,B) -> workedunder(B,A)', 'publication(A,B) -> genre(B,A)', 'projectmember(A,B) -> movie(A,B)', 'student(A) -> director(A)'], 0.972976)
# (['professor(A) -> actor(A)', 'advisedby(A,B) -> workedunder(A,B)', 'publication(A,B) -> movie(A,B)', 'projectmember(A,B) -> genre(B,A)', 'student(A) -> actor(A)'], 0.861963)
# (['professor(A) -> female(A)', 'advisedby(A,B) -> workedunder(B,A)', 'publication(A,B) -> genre(B,A)', 'projectmember(A,B) -> movie(A,B)', 'student(A) -> director(A)'], 0.70794)
# (['professor(A) -> director(A)', 'advisedby(A,B) -> workedunder(A,B)', 'publication(A,B) -> movie(A,B)', 'projectmember(A,B) -> genre(B,A)', 'student(A) -> director(A)'], 0.518405)
# (['professor(A) -> female(A)', 'advisedby(A,B) -> workedunder(A,B)', 'publication(A,B) -> movie(A,B)', 'projectmember(A,B) -> genre(B,A)', 'student(A) -> female(A)'], 0.56135)
# (['professor(A) -> actor(A)', 'advisedby(A,B) -> workedunder(B,A)', 'publication(A,B) -> movie(A,B)', 'projectmember(A,B) -> genre(B,A)'], 0.898773)
# (['professor(A) -> actor(A)', 'publication(A,B) -> movie(A,B)', 'advisedby(A,B) -> workedunder(B,A)'], 0.898773)
# (['publication(A,B) -> movie(A,B)', 'advisedby(A,B) -> workedunder(A,B)', 'student(A) -> actor(A)'], 0.898773)
# (['professor(A) -> director(A)', 'advisedby(A,B) -> workedunder(A,B)', 'publication(A,B) -> genre(B,A)', 'projectmember(A,B) -> movie(A,B)', 'student(A) -> actor(A)'], 0.969325)
# (['professor(A) -> director(A)', 'advisedby(A,B) -> workedunder(A,B)', 'publication(A,B) -> genre(B,A)', 'projectmember(A,B) -> movie(A,B)', 'student(A) -> female(A)'], 0.707055)
# (['professor(A) -> actor(A)', 'advisedby(A,B) -> workedunder(B,A)', 'publication(A,B) -> movie(A,B)', 'projectmember(A,B) -> genre(B,A)', 'student(A) -> female(A)'], 0.641104)
# (['professor(A) -> female(A)', 'advisedby(A,B) -> workedunder(B,A)', 'publication(A,B) -> movie(A,B)', 'projectmember(A,B) -> genre(B,A)', 'student(A) -> actor(A)'], 0.630368)
# (['professor(A) -> actor(A)', 'publication(A,B) -> movie(A,B)', 'advisedby(A,B) -> workedunder(A,B)', 'student(A) -> female(A)'], 0.630368)
# (['professor(A) -> female(A)', 'publication(A,B) -> movie(A,B)', 'advisedby(A,B) -> workedunder(A,B)', 'student(A) -> actor(A)'], 0.641104)
# (['professor(A) -> actor(A)', 'publication(A,B) -> movie(A,B)', 'advisedby(A,B) -> workedunder(B,A)', 'student(A) -> female(A)'], 0.641104)
# (['professor(A) -> female(A)', 'publication(A,B) -> movie(A,B)', 'advisedby(A,B) -> workedunder(B,A)', 'student(A) -> actor(A)'], 0.630368)
# (['advisedby(A,B) -> workedunder(A,B)', 'publication(A,B) -> movie(A,B)', 'projectmember(A,B) -> movie(A,B)', 'student(A) -> actor(A)'], 0.898773)
# (['professor(A) -> actor(A)', 'advisedby(A,B) -> workedunder(B,A)', 'publication(A,B) -> movie(A,B)', 'projectmember(A,B) -> movie(A,B)'], 0.898773)
# (['professor(A) -> female(A)', 'advisedby(A,B) -> workedunder(B,A)', 'publication(A,B) -> movie(A,B)', 'projectmember(A,B) -> genre(B,A)'], 0.744317)
# (['professor(A) -> actor(A)', 'advisedby(A,B) -> workedunder(A,B)', 'publication(A,B) -> movie(A,B)', 'projectmember(A,B) -> movie(A,B)', 'student(A) -> female(A)'], 0.630368)
# (['professor(A) -> female(A)', 'advisedby(A,B) -> workedunder(A,B)', 'publication(A,B) -> movie(A,B)', 'projectmember(A,B) -> movie(A,B)', 'student(A) -> actor(A)'], 0.641104)
# (['professor(A) -> actor(A)', 'advisedby(A,B) -> workedunder(B,A)', 'publication(A,B) -> movie(A,B)', 'projectmember(A,B) -> movie(A,B)', 'student(A) -> female(A)'], 0.641104)
# (['professor(A) -> female(A)', 'advisedby(A,B) -> workedunder(B,A)', 'publication(A,B) -> movie(A,B)', 'projectmember(A,B) -> movie(A,B)', 'student(A) -> actor(A)'], 0.630368)
# (['professor(A) -> female(A)', 'publication(A,B) -> movie(A,B)', 'advisedby(A,B) -> workedunder(B,A)'], 0.744317)
# (['publication(A,B) -> movie(A,B)', 'advisedby(A,B) -> workedunder(A,B)', 'student(A) -> female(A)'], 0.744317)
# (['advisedby(A,B) -> workedunder(A,B)', 'publication(A,B) -> movie(A,B)', 'projectmember(A,B) -> movie(A,B)', 'student(A) -> female(A)'], 0.744317)
# (['professor(A) -> female(A)', 'advisedby(A,B) -> workedunder(B,A)', 'publication(A,B) -> movie(A,B)', 'projectmember(A,B) -> movie(A,B)'], 0.744317)
# (['professor(A) -> actor(A)', 'advisedby(A,B) -> workedunder(B,A)', 'publication(A,B) -> movie(A,B)', 'projectmember(A,B) -> genre(B,A)', 'student(A) -> actor(A)'], 0.861963)
# (['professor(A) -> actor(A)', 'advisedby(A,B) -> workedunder(A,B)', 'publication(A,B) -> movie(A,B)', 'projectmember(A,B) -> genre(B,A)'], 0.95092)
# (['professor(A) -> actor(A)', 'publication(A,B) -> movie(A,B)', 'advisedby(A,B) -> workedunder(A,B)', 'student(A) -> actor(A)'], 0.861963)
# (['professor(A) -> actor(A)', 'publication(A,B) -> movie(A,B)', 'advisedby(A,B) -> workedunder(B,A)', 'student(A) -> actor(A)'], 0.861963)
# (['advisedby(A,B) -> workedunder(A,B)', 'publication(A,B) -> movie(A,B)', 'projectmember(A,B) -> genre(B,A)'], 0.97195)
# (['professor(A) -> director(A)', 'advisedby(A,B) -> workedunder(A,B)', 'publication(A,B) -> genre(B,A)', 'projectmember(A,B) -> genre(B,A)', 'student(A) -> actor(A)'], 0.972976)
# (['professor(A) -> director(A)', 'advisedby(A,B) -> workedunder(A,B)', 'publication(A,B) -> genre(B,A)', 'projectmember(A,B) -> genre(B,A)', 'student(A) -> female(A)'], 0.70794)
# (['professor(A) -> actor(A)', 'advisedby(A,B) -> workedunder(A,B)', 'publication(A,B) -> movie(A,B)', 'projectmember(A,B) -> movie(A,B)', 'student(A) -> actor(A)'], 0.861963)
# (['professor(A) -> actor(A)', 'advisedby(A,B) -> workedunder(B,A)', 'publication(A,B) -> movie(A,B)', 'projectmember(A,B) -> movie(A,B)', 'student(A) -> actor(A)'], 0.861963)
# (['advisedby(A,B) -> workedunder(B,A)', 'publication(A,B) -> genre(B,A)', 'projectmember(A,B) -> movie(A,B)', 'student(A) -> director(A)'], 0.962532)
# (['advisedby(A,B) -> workedunder(B,A)', 'publication(A,B) -> movie(A,B)', 'projectmember(A,B) -> genre(B,A)', 'student(A) -> director(A)'], 0.995399)
# (['professor(A) -> director(A)', 'advisedby(A,B) -> workedunder(B,A)', 'publication(A,B) -> movie(A,B)', 'projectmember(A,B) -> genre(B,A)', 'student(A) -> director(A)'], 0.518405)
# (['professor(A) -> female(A)', 'advisedby(A,B) -> workedunder(B,A)', 'publication(A,B) -> movie(A,B)', 'projectmember(A,B) -> genre(B,A)', 'student(A) -> female(A)'], 0.56135)
# (['professor(A) -> actor(A)', 'publication(A,B) -> genre(B,A)', 'advisedby(A,B) -> workedunder(B,A)', 'student(A) -> director(A)'], 0.972976)
# (['professor(A) -> female(A)', 'publication(A,B) -> genre(B,A)', 'advisedby(A,B) -> workedunder(B,A)', 'student(A) -> director(A)'], 0.70794)
# (['professor(A) -> female(A)', 'advisedby(A,B) -> workedunder(A,B)', 'publication(A,B) -> movie(A,B)', 'projectmember(A,B) -> genre(B,A)'], 0.679448)
# (['professor(A) -> actor(A)', 'advisedby(A,B) -> workedunder(B,A)', 'publication(A,B) -> genre(B,A)', 'projectmember(A,B) -> movie(A,B)'], 0.907467)
# (['professor(A) -> female(A)', 'publication(A,B) -> movie(A,B)', 'advisedby(A,B) -> workedunder(A,B)', 'student(A) -> female(A)'], 0.56135)
# (['professor(A) -> female(A)', 'publication(A,B) -> movie(A,B)', 'advisedby(A,B) -> workedunder(B,A)', 'student(A) -> female(A)'], 0.56135)
# (['professor(A) -> actor(A)', 'advisedby(A,B) -> workedunder(B,A)', 'publication(A,B) -> genre(B,A)', 'projectmember(A,B) -> genre(B,A)', 'student(A) -> director(A)'], 0.972976)
# (['professor(A) -> female(A)', 'advisedby(A,B) -> workedunder(B,A)', 'publication(A,B) -> genre(B,A)', 'projectmember(A,B) -> genre(B,A)', 'student(A) -> director(A)'], 0.70794)
# (['professor(A) -> female(A)', 'advisedby(A,B) -> workedunder(A,B)', 'publication(A,B) -> movie(A,B)', 'projectmember(A,B) -> movie(A,B)', 'student(A) -> female(A)'], 0.56135)
# (['professor(A) -> female(A)', 'advisedby(A,B) -> workedunder(B,A)', 'publication(A,B) -> movie(A,B)', 'projectmember(A,B) -> movie(A,B)', 'student(A) -> female(A)'], 0.56135)
# (['advisedby(A,B) -> workedunder(A,B)', 'publication(A,B) -> movie(A,B)', 'projectmember(A,B) -> genre(B,A)', 'student(A) -> director(A)'], 0.607362)
# (['professor(A) -> actor(A)', 'advisedby(A,B) -> workedunder(A,B)', 'publication(A,B) -> movie(A,B)', 'projectmember(A,B) -> genre(B,A)', 'student(A) -> director(A)'], 0.588957)
# (['professor(A) -> director(A)', 'publication(A,B) -> genre(B,A)', 'advisedby(A,B) -> workedunder(A,B)', 'student(A) -> actor(A)'], 0.969325)
# (['professor(A) -> director(A)', 'publication(A,B) -> genre(B,A)', 'advisedby(A,B) -> workedunder(A,B)', 'student(A) -> female(A)'], 0.707055)
# (['professor(A) -> director(A)', 'publication(A,B) -> movie(A,B)', 'advisedby(A,B) -> workedunder(A,B)'], 0.992331)
# (['professor(A) -> female(A)', 'advisedby(A,B) -> workedunder(B,A)', 'publication(A,B) -> genre(B,A)', 'projectmember(A,B) -> movie(A,B)'], 0.663579)
# (['professor(A) -> director(A)', 'advisedby(A,B) -> workedunder(A,B)', 'projectmember(A,B) -> genre(B,A)', 'student(A) -> actor(A)'], 0.972976)
# (['professor(A) -> director(A)', 'advisedby(A,B) -> workedunder(A,B)', 'projectmember(A,B) -> genre(B,A)', 'student(A) -> female(A)'], 0.70794)
# (['publication(A,B) -> movie(A,B)', 'advisedby(A,B) -> workedunder(B,A)', 'student(A) -> director(A)'], 0.992331)
# (['professor(A) -> female(A)', 'advisedby(A,B) -> workedunder(A,B)', 'publication(A,B) -> movie(A,B)', 'projectmember(A,B) -> genre(B,A)', 'student(A) -> director(A)'], 0.538344)
# (['professor(A) -> director(A)', 'advisedby(A,B) -> workedunder(A,B)', 'publication(A,B) -> movie(A,B)', 'projectmember(A,B) -> movie(A,B)'], 0.992331)
# (['advisedby(A,B) -> workedunder(B,A)', 'publication(A,B) -> movie(A,B)', 'projectmember(A,B) -> movie(A,B)', 'student(A) -> director(A)'], 0.992331)
# (['professor(A) -> director(A)', 'advisedby(A,B) -> workedunder(B,A)', 'publication(A,B) -> genre(B,A)', 'projectmember(A,B) -> movie(A,B)', 'student(A) -> director(A)'], 0.518405)
# (['professor(A) -> director(A)', 'advisedby(A,B) -> workedunder(B,A)', 'publication(A,B) -> movie(A,B)', 'projectmember(A,B) -> genre(B,A)', 'student(A) -> actor(A)'], 0.588957)
# (['professor(A) -> actor(A)', 'advisedby(A,B) -> workedunder(B,A)', 'publication(A,B) -> genre(B,A)', 'projectmember(A,B) -> movie(A,B)', 'student(A) -> actor(A)'], 0.861963)
# (['professor(A) -> actor(A)', 'advisedby(A,B) -> workedunder(B,A)', 'publication(A,B) -> genre(B,A)', 'projectmember(A,B) -> movie(A,B)', 'student(A) -> female(A)'], 0.641104)
# (['professor(A) -> director(A)', 'advisedby(A,B) -> workedunder(B,A)', 'publication(A,B) -> movie(A,B)', 'projectmember(A,B) -> genre(B,A)', 'student(A) -> female(A)'], 0.538344)
# (['professor(A) -> director(A)', 'advisedby(A,B) -> workedunder(A,B)', 'publication(A,B) -> genre(B,A)', 'projectmember(A,B) -> movie(A,B)'], 0.957055)
# (['professor(A) -> director(A)', 'advisedby(A,B) -> workedunder(B,A)', 'publication(A,B) -> movie(A,B)', 'projectmember(A,B) -> genre(B,A)'], 0.607362)
# (['professor(A) -> director(A)', 'publication(A,B) -> movie(A,B)', 'advisedby(A,B) -> workedunder(A,B)', 'student(A) -> director(A)'], 0.518405)
# (['professor(A) -> director(A)', 'publication(A,B) -> movie(A,B)', 'advisedby(A,B) -> workedunder(B,A)', 'student(A) -> director(A)'], 0.518405)
# (['professor(A) -> female(A)', 'advisedby(A,B) -> workedunder(B,A)', 'publication(A,B) -> genre(B,A)', 'projectmember(A,B) -> movie(A,B)', 'student(A) -> female(A)'], 0.56135)
# (['professor(A) -> director(A)', 'advisedby(A,B) -> workedunder(A,B)', 'publication(A,B) -> movie(A,B)', 'projectmember(A,B) -> movie(A,B)', 'student(A) -> director(A)'], 0.518405)
# (['professor(A) -> director(A)', 'advisedby(A,B) -> workedunder(B,A)', 'publication(A,B) -> movie(A,B)', 'projectmember(A,B) -> movie(A,B)', 'student(A) -> director(A)'], 0.518405)
# (['advisedby(A,B) -> workedunder(B,A)', 'publication(A,B) -> movie(A,B)', 'projectmember(A,B) -> genre(B,A)', 'student(A) -> actor(A)'], 0.95092)
# (['professor(A) -> actor(A)', 'advisedby(A,B) -> workedunder(B,A)', 'projectmember(A,B) -> movie(A,B)', 'student(A) -> director(A)'], 0.969325)
# (['professor(A) -> female(A)', 'advisedby(A,B) -> workedunder(B,A)', 'publication(A,B) -> genre(B,A)', 'projectmember(A,B) -> movie(A,B)', 'student(A) -> actor(A)'], 0.630368)
# (['professor(A) -> director(A)', 'advisedby(A,B) -> workedunder(A,B)', 'publication(A,B) -> genre(B,A)', 'projectmember(A,B) -> movie(A,B)', 'student(A) -> director(A)'], 0.518405)
# (['advisedby(A,B) -> workedunder(A,B)', 'publication(A,B) -> genre(B,A)', 'projectmember(A,B) -> movie(A,B)', 'student(A) -> actor(A)'], 0.607362)
# (['advisedby(A,B) -> workedunder(A,B)', 'publication(A,B) -> genre(B,A)', 'projectmember(A,B) -> movie(A,B)', 'student(A) -> female(A)'], 0.576687)
# (['advisedby(A,B) -> workedunder(B,A)', 'publication(A,B) -> movie(A,B)', 'projectmember(A,B) -> genre(B,A)', 'student(A) -> female(A)'], 0.679448)
# (['professor(A) -> female(A)', 'advisedby(A,B) -> workedunder(B,A)', 'projectmember(A,B) -> movie(A,B)', 'student(A) -> director(A)'], 0.707055)
# (['professor(A) -> director(A)', 'advisedby(A,B) -> workedunder(A,B)', 'publication(A,B) -> genre(B,A)', 'projectmember(A,B) -> genre(B,A)'], 0.963087)
# (['advisedby(A,B) -> workedunder(B,A)', 'publication(A,B) -> movie(A,B)', 'projectmember(A,B) -> genre(B,A)'], 0.888037)
# (['professor(A) -> actor(A)', 'advisedby(A,B) -> workedunder(A,B)', 'publication(A,B) -> genre(B,A)', 'projectmember(A,B) -> movie(A,B)', 'student(A) -> actor(A)'], 0.861963)
# (['professor(A) -> actor(A)', 'publication(A,B) -> movie(A,B)', 'advisedby(A,B) -> workedunder(A,B)'], 0.95092)
# (['professor(A) -> actor(A)', 'advisedby(A,B) -> workedunder(A,B)', 'publication(A,B) -> genre(B,A)', 'projectmember(A,B) -> movie(A,B)', 'student(A) -> female(A)'], 0.630368)
# (['publication(A,B) -> movie(A,B)', 'advisedby(A,B) -> workedunder(B,A)', 'student(A) -> actor(A)'], 0.95092)
# (['publication(A,B) -> genre(B,A)', 'advisedby(A,B) -> workedunder(B,A)', 'student(A) -> director(A)'], 0.962532)
# (['professor(A) -> actor(A)', 'advisedby(A,B) -> workedunder(A,B)', 'publication(A,B) -> movie(A,B)', 'projectmember(A,B) -> movie(A,B)'], 0.95092)
# (['professor(A) -> actor(A)', 'publication(A,B) -> movie(A,B)', 'advisedby(A,B) -> workedunder(A,B)', 'student(A) -> director(A)'], 0.588957)
# (['advisedby(A,B) -> workedunder(B,A)', 'publication(A,B) -> movie(A,B)', 'projectmember(A,B) -> movie(A,B)', 'student(A) -> actor(A)'], 0.95092)
# (['advisedby(A,B) -> workedunder(B,A)', 'publication(A,B) -> genre(B,A)', 'projectmember(A,B) -> genre(B,A)', 'student(A) -> director(A)'], 0.963087)
# (['professor(A) -> director(A)', 'publication(A,B) -> movie(A,B)', 'advisedby(A,B) -> workedunder(B,A)', 'student(A) -> actor(A)'], 0.588957)
# (['professor(A) -> female(A)', 'advisedby(A,B) -> workedunder(A,B)', 'publication(A,B) -> genre(B,A)', 'projectmember(A,B) -> movie(A,B)', 'student(A) -> female(A)'], 0.56135)
# (['professor(A) -> director(A)', 'advisedby(A,B) -> workedunder(B,A)', 'publication(A,B) -> genre(B,A)', 'projectmember(A,B) -> movie(A,B)'], 0.607362)
# (['professor(A) -> actor(A)', 'advisedby(A,B) -> workedunder(A,B)', 'publication(A,B) -> movie(A,B)', 'projectmember(A,B) -> movie(A,B)', 'student(A) -> director(A)'], 0.588957)
# (['professor(A) -> director(A)', 'advisedby(A,B) -> workedunder(B,A)', 'publication(A,B) -> movie(A,B)', 'projectmember(A,B) -> movie(A,B)', 'student(A) -> actor(A)'], 0.588957)
# (['professor(A) -> director(A)', 'advisedby(A,B) -> workedunder(A,B)', 'publication(A,B) -> genre(B,A)', 'projectmember(A,B) -> genre(B,A)', 'student(A) -> director(A)'], 0.518405)
# (['professor(A) -> female(A)', 'advisedby(A,B) -> workedunder(A,B)', 'publication(A,B) -> genre(B,A)', 'projectmember(A,B) -> movie(A,B)', 'student(A) -> actor(A)'], 0.641104)
# (['professor(A) -> female(A)', 'publication(A,B) -> movie(A,B)', 'advisedby(A,B) -> workedunder(A,B)'], 0.679448)
# (['professor(A) -> director(A)', 'publication(A,B) -> genre(B,A)', 'advisedby(A,B) -> workedunder(A,B)'], 0.957055)
# (['publication(A,B) -> movie(A,B)', 'advisedby(A,B) -> workedunder(B,A)', 'student(A) -> female(A)'], 0.679448)
# (['professor(A) -> female(A)', 'publication(A,B) -> movie(A,B)', 'advisedby(A,B) -> workedunder(A,B)', 'student(A) -> director(A)'], 0.538344)
# (['professor(A) -> director(A)', 'publication(A,B) -> movie(A,B)', 'advisedby(A,B) -> workedunder(B,A)', 'student(A) -> female(A)'], 0.538344)
# (['professor(A) -> female(A)', 'advisedby(A,B) -> workedunder(A,B)', 'publication(A,B) -> movie(A,B)', 'projectmember(A,B) -> movie(A,B)'], 0.679448)
# (['advisedby(A,B) -> workedunder(A,B)', 'publication(A,B) -> genre(B,A)', 'projectmember(A,B) -> genre(B,A)', 'student(A) -> actor(A)'], 0.907467)
# (['advisedby(A,B) -> workedunder(A,B)', 'publication(A,B) -> genre(B,A)', 'projectmember(A,B) -> genre(B,A)', 'student(A) -> female(A)'], 0.663579)
# (['advisedby(A,B) -> workedunder(B,A)', 'publication(A,B) -> movie(A,B)', 'projectmember(A,B) -> movie(A,B)', 'student(A) -> female(A)'], 0.679448)
# (['professor(A) -> director(A)', 'advisedby(A,B) -> workedunder(A,B)', 'projectmember(A,B) -> movie(A,B)', 'student(A) -> actor(A)'], 0.969325)
# (['professor(A) -> director(A)', 'advisedby(A,B) -> workedunder(A,B)', 'projectmember(A,B) -> movie(A,B)', 'student(A) -> female(A)'], 0.707055)
# (['professor(A) -> female(A)', 'advisedby(A,B) -> workedunder(A,B)', 'publication(A,B) -> movie(A,B)', 'projectmember(A,B) -> movie(A,B)', 'student(A) -> director(A)'], 0.538344)
# (['professor(A) -> director(A)', 'advisedby(A,B) -> workedunder(B,A)', 'publication(A,B) -> movie(A,B)', 'projectmember(A,B) -> movie(A,B)', 'student(A) -> female(A)'], 0.538344)
# (['professor(A) -> director(A)', 'publication(A,B) -> genre(B,A)', 'advisedby(A,B) -> workedunder(A,B)', 'student(A) -> director(A)'], 0.518405)
# (['professor(A) -> director(A)', 'publication(A,B) -> genre(B,A)', 'advisedby(A,B) -> workedunder(B,A)', 'student(A) -> director(A)'], 0.518405)
# (['advisedby(A,B) -> workedunder(B,A)', 'publication(A,B) -> genre(B,A)', 'projectmember(A,B) -> movie(A,B)'], 0.879813)
# (['professor(A) -> director(A)', 'advisedby(A,B) -> workedunder(B,A)', 'publication(A,B) -> genre(B,A)', 'projectmember(A,B) -> genre(B,A)', 'student(A) -> director(A)'], 0.518405)
# (['professor(A) -> director(A)', 'publication(A,B) -> movie(A,B)', 'advisedby(A,B) -> workedunder(B,A)'], 0.607362)
# (['professor(A) -> actor(A)', 'publication(A,B) -> genre(B,A)', 'advisedby(A,B) -> workedunder(B,A)'], 0.907467)
# (['professor(A) -> female(A)', 'publication(A,B) -> genre(B,A)', 'advisedby(A,B) -> workedunder(B,A)'], 0.663579)
# (['publication(A,B) -> movie(A,B)', 'advisedby(A,B) -> workedunder(A,B)', 'student(A) -> director(A)'], 0.607362)
# (['publication(A,B) -> genre(B,A)', 'advisedby(A,B) -> workedunder(A,B)', 'student(A) -> actor(A)'], 0.607362)
# (['publication(A,B) -> genre(B,A)', 'advisedby(A,B) -> workedunder(A,B)', 'student(A) -> female(A)'], 0.576687)
# (['advisedby(A,B) -> workedunder(A,B)', 'publication(A,B) -> movie(A,B)', 'projectmember(A,B) -> movie(A,B)', 'student(A) -> director(A)'], 0.607362)
# (['professor(A) -> director(A)', 'advisedby(A,B) -> workedunder(B,A)', 'publication(A,B) -> movie(A,B)', 'projectmember(A,B) -> movie(A,B)'], 0.607362)
# (['professor(A) -> actor(A)', 'advisedby(A,B) -> workedunder(B,A)', 'publication(A,B) -> genre(B,A)', 'projectmember(A,B) -> genre(B,A)'], 0.907467)
# (['professor(A) -> female(A)', 'advisedby(A,B) -> workedunder(B,A)', 'publication(A,B) -> genre(B,A)', 'projectmember(A,B) -> genre(B,A)'], 0.663579)
# (['professor(A) -> director(A)', 'advisedby(A,B) -> workedunder(B,A)', 'publication(A,B) -> genre(B,A)', 'projectmember(A,B) -> movie(A,B)', 'student(A) -> actor(A)'], 0.588957)
# (['professor(A) -> director(A)', 'advisedby(A,B) -> workedunder(B,A)', 'publication(A,B) -> genre(B,A)', 'projectmember(A,B) -> movie(A,B)', 'student(A) -> female(A)'], 0.538344)
# (['publication(A,B) -> movie(A,B)', 'advisedby(A,B) -> workedunder(A,B)'], 0.861963)
# (['publication(A,B) -> movie(A,B)', 'advisedby(A,B) -> workedunder(B,A)'], 0.861963)
# (['advisedby(A,B) -> workedunder(A,B)', 'publication(A,B) -> movie(A,B)', 'projectmember(A,B) -> movie(A,B)'], 0.861963)
# (['advisedby(A,B) -> workedunder(B,A)', 'publication(A,B) -> movie(A,B)', 'projectmember(A,B) -> movie(A,B)'], 0.861963)
# (['professor(A) -> actor(A)', 'advisedby(A,B) -> workedunder(A,B)', 'publication(A,B) -> genre(B,A)', 'projectmember(A,B) -> genre(B,A)', 'student(A) -> actor(A)'], 0.861963)
# (['professor(A) -> female(A)', 'advisedby(A,B) -> workedunder(A,B)', 'publication(A,B) -> genre(B,A)', 'projectmember(A,B) -> genre(B,A)', 'student(A) -> female(A)'], 0.56135)
# (['advisedby(A,B) -> workedunder(A,B)', 'publication(A,B) -> genre(B,A)', 'projectmember(A,B) -> movie(A,B)', 'student(A) -> director(A)'], 0.607362)
# (['advisedby(A,B) -> workedunder(A,B)', 'projectmember(A,B) -> genre(B,A)', 'student(A) -> actor(A)'], 0.907467)
# (['advisedby(A,B) -> workedunder(A,B)', 'projectmember(A,B) -> genre(B,A)', 'student(A) -> female(A)'], 0.663579)
# (['professor(A) -> actor(A)', 'advisedby(A,B) -> workedunder(A,B)', 'publication(A,B) -> genre(B,A)', 'projectmember(A,B) -> genre(B,A)', 'student(A) -> female(A)'], 0.630368)
# (['professor(A) -> female(A)', 'advisedby(A,B) -> workedunder(A,B)', 'publication(A,B) -> genre(B,A)', 'projectmember(A,B) -> genre(B,A)', 'student(A) -> actor(A)'], 0.641104)
# (['professor(A) -> actor(A)', 'advisedby(A,B) -> workedunder(A,B)', 'publication(A,B) -> genre(B,A)', 'projectmember(A,B) -> movie(A,B)', 'student(A) -> director(A)'], 0.588957)
# (['advisedby(A,B) -> workedunder(A,B)', 'publication(A,B) -> genre(B,A)', 'projectmember(A,B) -> genre(B,A)', 'student(A) -> director(A)'], 0.607362)
# (['professor(A) -> director(A)', 'advisedby(A,B) -> workedunder(A,B)', 'projectmember(A,B) -> genre(B,A)'], 0.958909)
# (['professor(A) -> actor(A)', 'advisedby(A,B) -> workedunder(B,A)', 'projectmember(A,B) -> movie(A,B)'], 0.607362)
# (['professor(A) -> actor(A)', 'publication(A,B) -> genre(B,A)', 'advisedby(A,B) -> workedunder(A,B)', 'student(A) -> actor(A)'], 0.861963)
# (['professor(A) -> female(A)', 'publication(A,B) -> genre(B,A)', 'advisedby(A,B) -> workedunder(A,B)', 'student(A) -> female(A)'], 0.56135)
# (['professor(A) -> actor(A)', 'publication(A,B) -> genre(B,A)', 'advisedby(A,B) -> workedunder(B,A)', 'student(A) -> actor(A)'], 0.861963)
# (['professor(A) -> female(A)', 'publication(A,B) -> genre(B,A)', 'advisedby(A,B) -> workedunder(B,A)', 'student(A) -> female(A)'], 0.56135)
# (['professor(A) -> actor(A)', 'advisedby(A,B) -> workedunder(B,A)', 'publication(A,B) -> genre(B,A)', 'projectmember(A,B) -> genre(B,A)', 'student(A) -> actor(A)'], 0.861963)
# (['professor(A) -> female(A)', 'advisedby(A,B) -> workedunder(B,A)', 'publication(A,B) -> genre(B,A)', 'projectmember(A,B) -> genre(B,A)', 'student(A) -> female(A)'], 0.56135)
# (['advisedby(A,B) -> workedunder(B,A)', 'publication(A,B) -> genre(B,A)', 'projectmember(A,B) -> movie(A,B)', 'student(A) -> actor(A)'], 0.95092)
# (['advisedby(A,B) -> workedunder(B,A)', 'publication(A,B) -> genre(B,A)', 'projectmember(A,B) -> movie(A,B)', 'student(A) -> female(A)'], 0.679448)
# (['professor(A) -> actor(A)', 'publication(A,B) -> genre(B,A)', 'advisedby(A,B) -> workedunder(A,B)', 'student(A) -> female(A)'], 0.630368)
# (['professor(A) -> female(A)', 'publication(A,B) -> genre(B,A)', 'advisedby(A,B) -> workedunder(A,B)', 'student(A) -> actor(A)'], 0.641104)
# (['professor(A) -> actor(A)', 'publication(A,B) -> genre(B,A)', 'advisedby(A,B) -> workedunder(B,A)', 'student(A) -> female(A)'], 0.641104)
# (['professor(A) -> female(A)', 'publication(A,B) -> genre(B,A)', 'advisedby(A,B) -> workedunder(B,A)', 'student(A) -> actor(A)'], 0.630368)
# (['professor(A) -> female(A)', 'advisedby(A,B) -> workedunder(A,B)', 'publication(A,B) -> genre(B,A)', 'projectmember(A,B) -> movie(A,B)', 'student(A) -> director(A)'], 0.538344)
# (['professor(A) -> actor(A)', 'advisedby(A,B) -> workedunder(B,A)', 'publication(A,B) -> genre(B,A)', 'projectmember(A,B) -> genre(B,A)', 'student(A) -> female(A)'], 0.641104)
# (['professor(A) -> female(A)', 'advisedby(A,B) -> workedunder(B,A)', 'publication(A,B) -> genre(B,A)', 'projectmember(A,B) -> genre(B,A)', 'student(A) -> actor(A)'], 0.630368)
# (['publication(A,B) -> genre(B,A)', 'advisedby(A,B) -> workedunder(A,B)', 'student(A) -> director(A)'], 0.607362)
# (['professor(A) -> director(A)', 'advisedby(A,B) -> workedunder(B,A)', 'publication(A,B) -> genre(B,A)', 'projectmember(A,B) -> genre(B,A)'], 0.607362)
# (['professor(A) -> actor(A)', 'advisedby(A,B) -> workedunder(A,B)', 'projectmember(A,B) -> genre(B,A)', 'student(A) -> actor(A)'], 0.861963)
# (['professor(A) -> actor(A)', 'advisedby(A,B) -> workedunder(A,B)', 'projectmember(A,B) -> genre(B,A)', 'student(A) -> female(A)'], 0.630368)
# (['professor(A) -> director(A)', 'advisedby(A,B) -> workedunder(A,B)', 'projectmember(A,B) -> genre(B,A)', 'student(A) -> director(A)'], 0.518405)
# (['professor(A) -> female(A)', 'advisedby(A,B) -> workedunder(A,B)', 'projectmember(A,B) -> genre(B,A)', 'student(A) -> actor(A)'], 0.641104)
# (['professor(A) -> female(A)', 'advisedby(A,B) -> workedunder(A,B)', 'projectmember(A,B) -> genre(B,A)', 'student(A) -> female(A)'], 0.56135)
# (['professor(A) -> actor(A)', 'advisedby(A,B) -> workedunder(B,A)', 'projectmember(A,B) -> movie(A,B)', 'student(A) -> actor(A)'], 0.861963)
# (['professor(A) -> actor(A)', 'advisedby(A,B) -> workedunder(B,A)', 'projectmember(A,B) -> movie(A,B)', 'student(A) -> female(A)'], 0.641104)
# (['professor(A) -> female(A)', 'advisedby(A,B) -> workedunder(B,A)', 'projectmember(A,B) -> movie(A,B)'], 0.576687)
# (['advisedby(A,B) -> workedunder(A,B)', 'publication(A,B) -> genre(B,A)', 'projectmember(A,B) -> movie(A,B)'], 0.567485)
# (['professor(A) -> actor(A)', 'advisedby(A,B) -> workedunder(A,B)', 'publication(A,B) -> genre(B,A)', 'projectmember(A,B) -> movie(A,B)'], 0.95092)
# (['professor(A) -> actor(A)', 'advisedby(A,B) -> workedunder(A,B)', 'publication(A,B) -> genre(B,A)', 'projectmember(A,B) -> genre(B,A)', 'student(A) -> director(A)'], 0.588957)
# (['professor(A) -> female(A)', 'advisedby(A,B) -> workedunder(A,B)', 'publication(A,B) -> genre(B,A)', 'projectmember(A,B) -> genre(B,A)', 'student(A) -> director(A)'], 0.538344)
# (['professor(A) -> director(A)', 'publication(A,B) -> genre(B,A)', 'advisedby(A,B) -> workedunder(B,A)'], 0.607362)
# (['professor(A) -> director(A)', 'advisedby(A,B) -> workedunder(A,B)', 'student(A) -> actor(A)'], 0.969325)
# (['professor(A) -> director(A)', 'advisedby(A,B) -> workedunder(A,B)', 'student(A) -> female(A)'], 0.707055)
# (['professor(A) -> actor(A)', 'advisedby(A,B) -> workedunder(B,A)', 'student(A) -> director(A)'], 0.969325)
# (['professor(A) -> female(A)', 'advisedby(A,B) -> workedunder(B,A)', 'student(A) -> director(A)'], 0.707055)
# (['professor(A) -> actor(A)', 'advisedby(A,B) -> workedunder(A,B)', 'projectmember(A,B) -> movie(A,B)', 'student(A) -> actor(A)'], 0.861963)
# (['professor(A) -> actor(A)', 'advisedby(A,B) -> workedunder(A,B)', 'projectmember(A,B) -> movie(A,B)', 'student(A) -> female(A)'], 0.630368)
# (['professor(A) -> female(A)', 'advisedby(A,B) -> workedunder(B,A)', 'projectmember(A,B) -> movie(A,B)', 'student(A) -> actor(A)'], 0.630368)
# (['professor(A) -> female(A)', 'advisedby(A,B) -> workedunder(B,A)', 'projectmember(A,B) -> movie(A,B)', 'student(A) -> female(A)'], 0.56135)
# (['professor(A) -> actor(A)', 'advisedby(A,B) -> workedunder(B,A)', 'projectmember(A,B) -> genre(B,A)', 'student(A) -> director(A)'], 0.969325)
# (['professor(A) -> female(A)', 'advisedby(A,B) -> workedunder(B,A)', 'projectmember(A,B) -> genre(B,A)', 'student(A) -> director(A)'], 0.707055)
# (['professor(A) -> actor(A)', 'publication(A,B) -> genre(B,A)', 'advisedby(A,B) -> workedunder(A,B)', 'student(A) -> director(A)'], 0.588957)
# (['professor(A) -> female(A)', 'publication(A,B) -> genre(B,A)', 'advisedby(A,B) -> workedunder(A,B)', 'student(A) -> director(A)'], 0.538344)
# (['professor(A) -> female(A)', 'advisedby(A,B) -> workedunder(A,B)', 'publication(A,B) -> genre(B,A)', 'projectmember(A,B) -> movie(A,B)'], 0.679448)
# (['professor(A) -> director(A)', 'advisedby(A,B) -> workedunder(B,A)', 'publication(A,B) -> genre(B,A)', 'projectmember(A,B) -> genre(B,A)', 'student(A) -> actor(A)'], 0.588957)
# (['professor(A) -> director(A)', 'advisedby(A,B) -> workedunder(B,A)', 'publication(A,B) -> genre(B,A)', 'projectmember(A,B) -> genre(B,A)', 'student(A) -> female(A)'], 0.538344)
# (['advisedby(A,B) -> workedunder(A,B)', 'publication(A,B) -> genre(B,A)', 'projectmember(A,B) -> genre(B,A)'], 0.892582)
# (['professor(A) -> director(A)', 'publication(A,B) -> genre(B,A)', 'advisedby(A,B) -> workedunder(B,A)', 'student(A) -> actor(A)'], 0.588957)
# (['professor(A) -> director(A)', 'publication(A,B) -> genre(B,A)', 'advisedby(A,B) -> workedunder(B,A)', 'student(A) -> female(A)'], 0.538344)
# (['advisedby(A,B) -> workedunder(A,B)', 'projectmember(A,B) -> movie(A,B)', 'student(A) -> actor(A)'], 0.607362)
# (['advisedby(A,B) -> workedunder(A,B)', 'projectmember(A,B) -> movie(A,B)', 'student(A) -> female(A)'], 0.576687)
# (['professor(A) -> female(A)', 'advisedby(A,B) -> workedunder(A,B)', 'projectmember(A,B) -> movie(A,B)', 'student(A) -> actor(A)'], 0.641104)
# (['professor(A) -> female(A)', 'advisedby(A,B) -> workedunder(A,B)', 'projectmember(A,B) -> movie(A,B)', 'student(A) -> female(A)'], 0.56135)
# (['publication(A,B) -> genre(B,A)', 'advisedby(A,B) -> workedunder(A,B)'], 0.567485)
# (['publication(A,B) -> genre(B,A)', 'advisedby(A,B) -> workedunder(B,A)'], 0.879813)
# (['advisedby(A,B) -> workedunder(B,A)', 'publication(A,B) -> genre(B,A)', 'projectmember(A,B) -> genre(B,A)'], 0.891471)
# (['professor(A) -> actor(A)', 'advisedby(A,B) -> workedunder(A,B)', 'publication(A,B) -> genre(B,A)', 'projectmember(A,B) -> genre(B,A)'], 0.95092)
# (['professor(A) -> female(A)', 'advisedby(A,B) -> workedunder(A,B)', 'publication(A,B) -> genre(B,A)', 'projectmember(A,B) -> genre(B,A)'], 0.679448)
# (['advisedby(A,B) -> workedunder(B,A)', 'projectmember(A,B) -> movie(A,B)', 'student(A) -> director(A)'], 0.95092)
# (['professor(A) -> actor(A)', 'publication(A,B) -> genre(B,A)', 'advisedby(A,B) -> workedunder(A,B)'], 0.95092)
# (['professor(A) -> female(A)', 'publication(A,B) -> genre(B,A)', 'advisedby(A,B) -> workedunder(A,B)'], 0.679448)
# (['publication(A,B) -> genre(B,A)', 'advisedby(A,B) -> workedunder(B,A)', 'student(A) -> actor(A)'], 0.95092)
# (['publication(A,B) -> genre(B,A)', 'advisedby(A,B) -> workedunder(B,A)', 'student(A) -> female(A)'], 0.679448)
# (['advisedby(A,B) -> workedunder(B,A)', 'publication(A,B) -> genre(B,A)', 'projectmember(A,B) -> genre(B,A)', 'student(A) -> actor(A)'], 0.95092)
# (['advisedby(A,B) -> workedunder(B,A)', 'publication(A,B) -> genre(B,A)', 'projectmember(A,B) -> genre(B,A)', 'student(A) -> female(A)'], 0.679448)
# (['professor(A) -> director(A)', 'advisedby(A,B) -> workedunder(B,A)', 'projectmember(A,B) -> movie(A,B)', 'student(A) -> director(A)'], 0.518405)
# (['professor(A) -> director(A)', 'advisedby(A,B) -> workedunder(A,B)', 'projectmember(A,B) -> movie(A,B)'], 0.95092)
# (['professor(A) -> actor(A)', 'advisedby(A,B) -> workedunder(B,A)', 'projectmember(A,B) -> genre(B,A)'], 0.607362)
# (['professor(A) -> female(A)', 'advisedby(A,B) -> workedunder(B,A)', 'projectmember(A,B) -> genre(B,A)'], 0.576687)
# (['advisedby(A,B) -> workedunder(A,B)', 'projectmember(A,B) -> genre(B,A)'], 0.953174)
# (['advisedby(A,B) -> workedunder(A,B)', 'student(A) -> actor(A)'], 0.607362)
# (['advisedby(A,B) -> workedunder(A,B)', 'student(A) -> female(A)'], 0.576687)
# (['professor(A) -> actor(A)', 'advisedby(A,B) -> workedunder(B,A)'], 0.607362)
# (['professor(A) -> female(A)', 'advisedby(A,B) -> workedunder(B,A)'], 0.576687)
# (['professor(A) -> director(A)', 'advisedby(A,B) -> workedunder(A,B)', 'projectmember(A,B) -> movie(A,B)', 'student(A) -> director(A)'], 0.518405)
# (['professor(A) -> actor(A)', 'advisedby(A,B) -> workedunder(B,A)', 'projectmember(A,B) -> genre(B,A)', 'student(A) -> actor(A)'], 0.861963)
# (['professor(A) -> actor(A)', 'advisedby(A,B) -> workedunder(B,A)', 'projectmember(A,B) -> genre(B,A)', 'student(A) -> female(A)'], 0.641104)
# (['professor(A) -> director(A)', 'advisedby(A,B) -> workedunder(B,A)', 'projectmember(A,B) -> genre(B,A)', 'student(A) -> director(A)'], 0.518405)
# (['professor(A) -> female(A)', 'advisedby(A,B) -> workedunder(B,A)', 'projectmember(A,B) -> genre(B,A)', 'student(A) -> actor(A)'], 0.630368)
# (['professor(A) -> female(A)', 'advisedby(A,B) -> workedunder(B,A)', 'projectmember(A,B) -> genre(B,A)', 'student(A) -> female(A)'], 0.56135)
# (['advisedby(A,B) -> workedunder(A,B)', 'projectmember(A,B) -> genre(B,A)', 'student(A) -> director(A)'], 0.607362)
# (['professor(A) -> actor(A)', 'advisedby(A,B) -> workedunder(A,B)', 'student(A) -> actor(A)'], 0.861963)
# (['professor(A) -> actor(A)', 'advisedby(A,B) -> workedunder(A,B)', 'student(A) -> female(A)'], 0.630368)
# (['professor(A) -> female(A)', 'advisedby(A,B) -> workedunder(A,B)', 'student(A) -> actor(A)'], 0.641104)
# (['professor(A) -> female(A)', 'advisedby(A,B) -> workedunder(A,B)', 'student(A) -> female(A)'], 0.56135)
# (['professor(A) -> actor(A)', 'advisedby(A,B) -> workedunder(B,A)', 'student(A) -> actor(A)'], 0.861963)
# (['professor(A) -> actor(A)', 'advisedby(A,B) -> workedunder(B,A)', 'student(A) -> female(A)'], 0.641104)
# (['professor(A) -> female(A)', 'advisedby(A,B) -> workedunder(B,A)', 'student(A) -> actor(A)'], 0.630368)
# (['professor(A) -> female(A)', 'advisedby(A,B) -> workedunder(B,A)', 'student(A) -> female(A)'], 0.56135)
# (['professor(A) -> actor(A)', 'advisedby(A,B) -> workedunder(A,B)', 'projectmember(A,B) -> genre(B,A)'], 0.95092)
# (['professor(A) -> female(A)', 'advisedby(A,B) -> workedunder(A,B)', 'projectmember(A,B) -> genre(B,A)'], 0.679448)
# (['professor(A) -> actor(A)', 'advisedby(A,B) -> workedunder(A,B)', 'projectmember(A,B) -> genre(B,A)', 'student(A) -> director(A)'], 0.588957)
# (['professor(A) -> female(A)', 'advisedby(A,B) -> workedunder(A,B)', 'projectmember(A,B) -> genre(B,A)', 'student(A) -> director(A)'], 0.538344)
# (['advisedby(A,B) -> workedunder(B,A)', 'projectmember(A,B) -> genre(B,A)', 'student(A) -> director(A)'], 0.957055)
# (['professor(A) -> actor(A)', 'advisedby(A,B) -> workedunder(A,B)', 'projectmember(A,B) -> movie(A,B)'], 0.95092)
# (['professor(A) -> director(A)', 'advisedby(A,B) -> workedunder(B,A)', 'projectmember(A,B) -> genre(B,A)'], 0.607362)
# (['professor(A) -> actor(A)', 'advisedby(A,B) -> workedunder(A,B)', 'projectmember(A,B) -> movie(A,B)', 'student(A) -> director(A)'], 0.588957)
# (['professor(A) -> director(A)', 'advisedby(A,B) -> workedunder(B,A)', 'projectmember(A,B) -> genre(B,A)', 'student(A) -> actor(A)'], 0.588957)
# (['professor(A) -> director(A)', 'advisedby(A,B) -> workedunder(B,A)', 'projectmember(A,B) -> genre(B,A)', 'student(A) -> female(A)'], 0.538344)
# (['professor(A) -> director(A)', 'advisedby(A,B) -> workedunder(A,B)'], 0.95092)
# (['advisedby(A,B) -> workedunder(B,A)', 'projectmember(A,B) -> movie(A,B)'], 0.941661)
# (['advisedby(A,B) -> workedunder(B,A)', 'student(A) -> director(A)'], 0.95092)
# (['professor(A) -> director(A)', 'advisedby(A,B) -> workedunder(A,B)', 'student(A) -> director(A)'], 0.518405)
# (['advisedby(A,B) -> workedunder(B,A)', 'projectmember(A,B) -> movie(A,B)', 'student(A) -> actor(A)'], 0.95092)
# (['advisedby(A,B) -> workedunder(B,A)', 'projectmember(A,B) -> movie(A,B)', 'student(A) -> female(A)'], 0.679448)
# (['professor(A) -> director(A)', 'advisedby(A,B) -> workedunder(B,A)', 'student(A) -> director(A)'], 0.518405)
# (['professor(A) -> female(A)', 'advisedby(A,B) -> workedunder(A,B)', 'projectmember(A,B) -> movie(A,B)'], 0.679448)
# (['professor(A) -> director(A)', 'advisedby(A,B) -> workedunder(B,A)', 'projectmember(A,B) -> movie(A,B)'], 0.607362)
# (['professor(A) -> female(A)', 'advisedby(A,B) -> workedunder(A,B)', 'projectmember(A,B) -> movie(A,B)', 'student(A) -> director(A)'], 0.538344)
# (['professor(A) -> director(A)', 'advisedby(A,B) -> workedunder(B,A)', 'projectmember(A,B) -> movie(A,B)', 'student(A) -> actor(A)'], 0.588957)
# (['professor(A) -> director(A)', 'advisedby(A,B) -> workedunder(B,A)', 'projectmember(A,B) -> movie(A,B)', 'student(A) -> female(A)'], 0.538344)
# (['advisedby(A,B) -> workedunder(A,B)', 'projectmember(A,B) -> movie(A,B)'], 0.941661)
# (['advisedby(A,B) -> workedunder(B,A)', 'projectmember(A,B) -> genre(B,A)'], 0.950487)
# (['advisedby(A,B) -> workedunder(A,B)', 'projectmember(A,B) -> movie(A,B)', 'student(A) -> director(A)'], 0.607362)
# (['advisedby(A,B) -> workedunder(B,A)', 'projectmember(A,B) -> genre(B,A)', 'student(A) -> actor(A)'], 0.95092)
# (['advisedby(A,B) -> workedunder(B,A)', 'projectmember(A,B) -> genre(B,A)', 'student(A) -> female(A)'], 0.679448)
# (['advisedby(A,B) -> workedunder(A,B)'], 0.941661)
# (['advisedby(A,B) -> workedunder(B,A)'], 0.941661)
# (['professor(A) -> actor(A)', 'advisedby(A,B) -> workedunder(A,B)'], 0.95092)
# (['professor(A) -> female(A)', 'advisedby(A,B) -> workedunder(A,B)'], 0.679448)
# (['advisedby(A,B) -> workedunder(A,B)', 'student(A) -> director(A)'], 0.607362)
# (['professor(A) -> director(A)', 'advisedby(A,B) -> workedunder(B,A)'], 0.607362)
# (['advisedby(A,B) -> workedunder(B,A)', 'student(A) -> actor(A)'], 0.95092)
# (['advisedby(A,B) -> workedunder(B,A)', 'student(A) -> female(A)'], 0.679448)
# (['professor(A) -> actor(A)', 'advisedby(A,B) -> workedunder(A,B)', 'student(A) -> director(A)'], 0.588957)
# (['professor(A) -> female(A)', 'advisedby(A,B) -> workedunder(A,B)', 'student(A) -> director(A)'], 0.538344)
# (['professor(A) -> director(A)', 'advisedby(A,B) -> workedunder(B,A)', 'student(A) -> actor(A)'], 0.588957)
# (['professor(A) -> director(A)', 'advisedby(A,B) -> workedunder(B,A)', 'student(A) -> female(A)'], 0.538344)

# %%
aucroc_scores = sorted(aucroc_scores, key=lambda tup: (tup[1]), reverse=True)

# %%
aucroc_scores
# Out:
# [(['professor(A) -> director(A)',
#    'advisedby(A,B) -> workedunder(A,B)',
#    'publication(A,B) -> movie(A,B)',
#    'projectmember(A,B) -> genre(B,A)',
#    'student(A) -> actor(A)'],
#   1.0),
#  (['professor(A) -> director(A)',
#    'publication(A,B) -> movie(A,B)',
#    'advisedby(A,B) -> workedunder(A,B)',
#    'student(A) -> actor(A)'],
#   1.0),
#  (['professor(A) -> actor(A)',
#    'publication(A,B) -> movie(A,B)',
#    'advisedby(A,B) -> workedunder(B,A)',
#    'student(A) -> director(A)'],
#   1.0),
#  (['professor(A) -> director(A)',
#    'advisedby(A,B) -> workedunder(A,B)',
#    'publication(A,B) -> movie(A,B)',
#    'projectmember(A,B) -> movie(A,B)',
#    'student(A) -> actor(A)'],
#   1.0),
#  (['professor(A) -> actor(A)',
#    'advisedby(A,B) -> workedunder(B,A)',
#    'publication(A,B) -> movie(A,B)',
#    'projectmember(A,B) -> movie(A,B)',
#    'student(A) -> director(A)'],
#   1.0),
#  (['professor(A) -> actor(A)',
#    'advisedby(A,B) -> workedunder(B,A)',
#    'publication(A,B) -> movie(A,B)',
#    'projectmember(A,B) -> genre(B,A)',
#    'student(A) -> director(A)'],
#   1.0),
#  (['professor(A) -> director(A)',
#    'advisedby(A,B) -> workedunder(A,B)',
#    'publication(A,B) -> movie(A,B)',
#    'projectmember(A,B) -> genre(B,A)'],
#   0.995545),
#  (['advisedby(A,B) -> workedunder(B,A)',
#    'publication(A,B) -> movie(A,B)',
#    'projectmember(A,B) -> genre(B,A)',
#    'student(A) -> director(A)'],
#   0.995399),
#  (['professor(A) -> director(A)',
#    'publication(A,B) -> movie(A,B)',
#    'advisedby(A,B) -> workedunder(A,B)'],
#   0.992331),
#  (['publication(A,B) -> movie(A,B)',
#    'advisedby(A,B) -> workedunder(B,A)',
#    'student(A) -> director(A)'],
#   0.992331),
#  (['professor(A) -> director(A)',
#    'advisedby(A,B) -> workedunder(A,B)',
#    'publication(A,B) -> movie(A,B)',
#    'projectmember(A,B) -> movie(A,B)'],
#   0.992331),
#  (['advisedby(A,B) -> workedunder(B,A)',
#    'publication(A,B) -> movie(A,B)',
#    'projectmember(A,B) -> movie(A,B)',
#    'student(A) -> director(A)'],
#   0.992331),
#  (['advisedby(A,B) -> workedunder(A,B)',
#    'publication(A,B) -> movie(A,B)',
#    'projectmember(A,B) -> genre(B,A)',
#    'student(A) -> actor(A)'],
#   0.98168),
#  (['professor(A) -> actor(A)',
#    'advisedby(A,B) -> workedunder(B,A)',
#    'publication(A,B) -> genre(B,A)',
#    'projectmember(A,B) -> movie(A,B)',
#    'student(A) -> director(A)'],
#   0.972976),
#  (['professor(A) -> director(A)',
#    'advisedby(A,B) -> workedunder(A,B)',
#    'publication(A,B) -> genre(B,A)',
#    'projectmember(A,B) -> genre(B,A)',
#    'student(A) -> actor(A)'],
#   0.972976),
#  (['professor(A) -> actor(A)',
#    'publication(A,B) -> genre(B,A)',
#    'advisedby(A,B) -> workedunder(B,A)',
#    'student(A) -> director(A)'],
#   0.972976),
#  (['professor(A) -> actor(A)',
#    'advisedby(A,B) -> workedunder(B,A)',
#    'publication(A,B) -> genre(B,A)',
#    'projectmember(A,B) -> genre(B,A)',
#    'student(A) -> director(A)'],
#   0.972976),
#  (['professor(A) -> director(A)',
#    'advisedby(A,B) -> workedunder(A,B)',
#    'projectmember(A,B) -> genre(B,A)',
#    'student(A) -> actor(A)'],
#   0.972976),
#  (['advisedby(A,B) -> workedunder(A,B)',
#    'publication(A,B) -> movie(A,B)',
#    'projectmember(A,B) -> genre(B,A)'],
#   0.97195),
#  (['professor(A) -> director(A)',
#    'advisedby(A,B) -> workedunder(A,B)',
#    'publication(A,B) -> genre(B,A)',
#    'projectmember(A,B) -> movie(A,B)',
#    'student(A) -> actor(A)'],
#   0.969325),
#  (['professor(A) -> director(A)',
#    'publication(A,B) -> genre(B,A)',
#    'advisedby(A,B) -> workedunder(A,B)',
#    'student(A) -> actor(A)'],
#   0.969325),
#  (['professor(A) -> actor(A)',
#    'advisedby(A,B) -> workedunder(B,A)',
#    'projectmember(A,B) -> movie(A,B)',
#    'student(A) -> director(A)'],
#   0.969325),
#  (['professor(A) -> director(A)',
#    'advisedby(A,B) -> workedunder(A,B)',
#    'projectmember(A,B) -> movie(A,B)',
#    'student(A) -> actor(A)'],
#   0.969325),
#  (['professor(A) -> director(A)',
#    'advisedby(A,B) -> workedunder(A,B)',
#    'student(A) -> actor(A)'],
#   0.969325),
#  (['professor(A) -> actor(A)',
#    'advisedby(A,B) -> workedunder(B,A)',
#    'student(A) -> director(A)'],
#   0.969325),
#  (['professor(A) -> actor(A)',
#    'advisedby(A,B) -> workedunder(B,A)',
#    'projectmember(A,B) -> genre(B,A)',
#    'student(A) -> director(A)'],
#   0.969325),
#  (['professor(A) -> director(A)',
#    'advisedby(A,B) -> workedunder(A,B)',
#    'publication(A,B) -> genre(B,A)',
#    'projectmember(A,B) -> genre(B,A)'],
#   0.963087),
#  (['advisedby(A,B) -> workedunder(B,A)',
#    'publication(A,B) -> genre(B,A)',
#    'projectmember(A,B) -> genre(B,A)',
#    'student(A) -> director(A)'],
#   0.963087),
#  (['advisedby(A,B) -> workedunder(B,A)',
#    'publication(A,B) -> genre(B,A)',
#    'projectmember(A,B) -> movie(A,B)',
#    'student(A) -> director(A)'],
#   0.962532),
#  (['publication(A,B) -> genre(B,A)',
#    'advisedby(A,B) -> workedunder(B,A)',
#    'student(A) -> director(A)'],
#   0.962532),
#  (['professor(A) -> director(A)',
#    'advisedby(A,B) -> workedunder(A,B)',
#    'projectmember(A,B) -> genre(B,A)'],
#   0.958909),
#  (['professor(A) -> director(A)',
#    'advisedby(A,B) -> workedunder(A,B)',
#    'publication(A,B) -> genre(B,A)',
#    'projectmember(A,B) -> movie(A,B)'],
#   0.957055),
#  (['professor(A) -> director(A)',
#    'publication(A,B) -> genre(B,A)',
#    'advisedby(A,B) -> workedunder(A,B)'],
#   0.957055),
#  (['advisedby(A,B) -> workedunder(B,A)',
#    'projectmember(A,B) -> genre(B,A)',
#    'student(A) -> director(A)'],
#   0.957055),
#  (['advisedby(A,B) -> workedunder(A,B)', 'projectmember(A,B) -> genre(B,A)'],
#   0.953174),
#  (['professor(A) -> actor(A)',
#    'advisedby(A,B) -> workedunder(A,B)',
#    'publication(A,B) -> movie(A,B)',
#    'projectmember(A,B) -> genre(B,A)'],
#   0.95092),
#  (['advisedby(A,B) -> workedunder(B,A)',
#    'publication(A,B) -> movie(A,B)',
#    'projectmember(A,B) -> genre(B,A)',
#    'student(A) -> actor(A)'],
#   0.95092),
#  (['professor(A) -> actor(A)',
#    'publication(A,B) -> movie(A,B)',
#    'advisedby(A,B) -> workedunder(A,B)'],
#   0.95092),
#  (['publication(A,B) -> movie(A,B)',
#    'advisedby(A,B) -> workedunder(B,A)',
#    'student(A) -> actor(A)'],
#   0.95092),
#  (['professor(A) -> actor(A)',
#    'advisedby(A,B) -> workedunder(A,B)',
#    'publication(A,B) -> movie(A,B)',
#    'projectmember(A,B) -> movie(A,B)'],
#   0.95092),
#  (['advisedby(A,B) -> workedunder(B,A)',
#    'publication(A,B) -> movie(A,B)',
#    'projectmember(A,B) -> movie(A,B)',
#    'student(A) -> actor(A)'],
#   0.95092),
#  (['advisedby(A,B) -> workedunder(B,A)',
#    'publication(A,B) -> genre(B,A)',
#    'projectmember(A,B) -> movie(A,B)',
#    'student(A) -> actor(A)'],
#   0.95092),
#  (['professor(A) -> actor(A)',
#    'advisedby(A,B) -> workedunder(A,B)',
#    'publication(A,B) -> genre(B,A)',
#    'projectmember(A,B) -> movie(A,B)'],
#   0.95092),
#  (['professor(A) -> actor(A)',
#    'advisedby(A,B) -> workedunder(A,B)',
#    'publication(A,B) -> genre(B,A)',
#    'projectmember(A,B) -> genre(B,A)'],
#   0.95092),
#  (['advisedby(A,B) -> workedunder(B,A)',
#    'projectmember(A,B) -> movie(A,B)',
#    'student(A) -> director(A)'],
#   0.95092),
#  (['professor(A) -> actor(A)',
#    'publication(A,B) -> genre(B,A)',
#    'advisedby(A,B) -> workedunder(A,B)'],
#   0.95092),
#  (['publication(A,B) -> genre(B,A)',
#    'advisedby(A,B) -> workedunder(B,A)',
#    'student(A) -> actor(A)'],
#   0.95092),
#  (['advisedby(A,B) -> workedunder(B,A)',
#    'publication(A,B) -> genre(B,A)',
#    'projectmember(A,B) -> genre(B,A)',
#    'student(A) -> actor(A)'],
#   0.95092),
#  (['professor(A) -> director(A)',
#    'advisedby(A,B) -> workedunder(A,B)',
#    'projectmember(A,B) -> movie(A,B)'],
#   0.95092),
#  (['professor(A) -> actor(A)',
#    'advisedby(A,B) -> workedunder(A,B)',
#    'projectmember(A,B) -> genre(B,A)'],
#   0.95092),
#  (['professor(A) -> actor(A)',
#    'advisedby(A,B) -> workedunder(A,B)',
#    'projectmember(A,B) -> movie(A,B)'],
#   0.95092),
#  (['professor(A) -> director(A)', 'advisedby(A,B) -> workedunder(A,B)'],
#   0.95092),
#  (['advisedby(A,B) -> workedunder(B,A)', 'student(A) -> director(A)'],
#   0.95092),
#  (['advisedby(A,B) -> workedunder(B,A)',
#    'projectmember(A,B) -> movie(A,B)',
#    'student(A) -> actor(A)'],
#   0.95092),
#  (['advisedby(A,B) -> workedunder(B,A)',
#    'projectmember(A,B) -> genre(B,A)',
#    'student(A) -> actor(A)'],
#   0.95092),
#  (['professor(A) -> actor(A)', 'advisedby(A,B) -> workedunder(A,B)'], 0.95092),
#  (['advisedby(A,B) -> workedunder(B,A)', 'student(A) -> actor(A)'], 0.95092),
#  (['advisedby(A,B) -> workedunder(B,A)', 'projectmember(A,B) -> genre(B,A)'],
#   0.950487),
#  (['advisedby(A,B) -> workedunder(B,A)', 'projectmember(A,B) -> movie(A,B)'],
#   0.941661),
#  (['advisedby(A,B) -> workedunder(A,B)', 'projectmember(A,B) -> movie(A,B)'],
#   0.941661),
#  (['advisedby(A,B) -> workedunder(A,B)'], 0.941661),
#  (['advisedby(A,B) -> workedunder(B,A)'], 0.941661),
#  (['professor(A) -> actor(A)',
#    'advisedby(A,B) -> workedunder(B,A)',
#    'publication(A,B) -> genre(B,A)',
#    'projectmember(A,B) -> movie(A,B)'],
#   0.907467),
#  (['advisedby(A,B) -> workedunder(A,B)',
#    'publication(A,B) -> genre(B,A)',
#    'projectmember(A,B) -> genre(B,A)',
#    'student(A) -> actor(A)'],
#   0.907467),
#  (['professor(A) -> actor(A)',
#    'publication(A,B) -> genre(B,A)',
#    'advisedby(A,B) -> workedunder(B,A)'],
#   0.907467),
#  (['professor(A) -> actor(A)',
#    'advisedby(A,B) -> workedunder(B,A)',
#    'publication(A,B) -> genre(B,A)',
#    'projectmember(A,B) -> genre(B,A)'],
#   0.907467),
#  (['advisedby(A,B) -> workedunder(A,B)',
#    'projectmember(A,B) -> genre(B,A)',
#    'student(A) -> actor(A)'],
#   0.907467),
#  (['professor(A) -> actor(A)',
#    'advisedby(A,B) -> workedunder(B,A)',
#    'publication(A,B) -> movie(A,B)',
#    'projectmember(A,B) -> genre(B,A)'],
#   0.898773),
#  (['professor(A) -> actor(A)',
#    'publication(A,B) -> movie(A,B)',
#    'advisedby(A,B) -> workedunder(B,A)'],
#   0.898773),
#  (['publication(A,B) -> movie(A,B)',
#    'advisedby(A,B) -> workedunder(A,B)',
#    'student(A) -> actor(A)'],
#   0.898773),
#  (['advisedby(A,B) -> workedunder(A,B)',
#    'publication(A,B) -> movie(A,B)',
#    'projectmember(A,B) -> movie(A,B)',
#    'student(A) -> actor(A)'],
#   0.898773),
#  (['professor(A) -> actor(A)',
#    'advisedby(A,B) -> workedunder(B,A)',
#    'publication(A,B) -> movie(A,B)',
#    'projectmember(A,B) -> movie(A,B)'],
#   0.898773),
#  (['advisedby(A,B) -> workedunder(A,B)',
#    'publication(A,B) -> genre(B,A)',
#    'projectmember(A,B) -> genre(B,A)'],
#   0.892582),
#  (['advisedby(A,B) -> workedunder(B,A)',
#    'publication(A,B) -> genre(B,A)',
#    'projectmember(A,B) -> genre(B,A)'],
#   0.891471),
#  (['advisedby(A,B) -> workedunder(B,A)',
#    'publication(A,B) -> movie(A,B)',
#    'projectmember(A,B) -> genre(B,A)'],
#   0.888037),
#  (['advisedby(A,B) -> workedunder(B,A)',
#    'publication(A,B) -> genre(B,A)',
#    'projectmember(A,B) -> movie(A,B)'],
#   0.879813),
#  (['publication(A,B) -> genre(B,A)', 'advisedby(A,B) -> workedunder(B,A)'],
#   0.879813),
#  (['professor(A) -> actor(A)',
#    'advisedby(A,B) -> workedunder(A,B)',
#    'publication(A,B) -> movie(A,B)',
#    'projectmember(A,B) -> genre(B,A)',
#    'student(A) -> actor(A)'],
#   0.861963),
#  (['professor(A) -> actor(A)',
#    'advisedby(A,B) -> workedunder(B,A)',
#    'publication(A,B) -> movie(A,B)',
#    'projectmember(A,B) -> genre(B,A)',
#    'student(A) -> actor(A)'],
#   0.861963),
#  (['professor(A) -> actor(A)',
#    'publication(A,B) -> movie(A,B)',
#    'advisedby(A,B) -> workedunder(A,B)',
#    'student(A) -> actor(A)'],
#   0.861963),
#  (['professor(A) -> actor(A)',
#    'publication(A,B) -> movie(A,B)',
#    'advisedby(A,B) -> workedunder(B,A)',
#    'student(A) -> actor(A)'],
#   0.861963),
#  (['professor(A) -> actor(A)',
#    'advisedby(A,B) -> workedunder(A,B)',
#    'publication(A,B) -> movie(A,B)',
#    'projectmember(A,B) -> movie(A,B)',
#    'student(A) -> actor(A)'],
#   0.861963),
#  (['professor(A) -> actor(A)',
#    'advisedby(A,B) -> workedunder(B,A)',
#    'publication(A,B) -> movie(A,B)',
#    'projectmember(A,B) -> movie(A,B)',
#    'student(A) -> actor(A)'],
#   0.861963),
#  (['professor(A) -> actor(A)',
#    'advisedby(A,B) -> workedunder(B,A)',
#    'publication(A,B) -> genre(B,A)',
#    'projectmember(A,B) -> movie(A,B)',
#    'student(A) -> actor(A)'],
#   0.861963),
#  (['professor(A) -> actor(A)',
#    'advisedby(A,B) -> workedunder(A,B)',
#    'publication(A,B) -> genre(B,A)',
#    'projectmember(A,B) -> movie(A,B)',
#    'student(A) -> actor(A)'],
#   0.861963),
#  (['publication(A,B) -> movie(A,B)', 'advisedby(A,B) -> workedunder(A,B)'],
#   0.861963),
#  (['publication(A,B) -> movie(A,B)', 'advisedby(A,B) -> workedunder(B,A)'],
#   0.861963),
#  (['advisedby(A,B) -> workedunder(A,B)',
#    'publication(A,B) -> movie(A,B)',
#    'projectmember(A,B) -> movie(A,B)'],
#   0.861963),
#  (['advisedby(A,B) -> workedunder(B,A)',
#    'publication(A,B) -> movie(A,B)',
#    'projectmember(A,B) -> movie(A,B)'],
#   0.861963),
#  (['professor(A) -> actor(A)',
#    'advisedby(A,B) -> workedunder(A,B)',
#    'publication(A,B) -> genre(B,A)',
#    'projectmember(A,B) -> genre(B,A)',
#    'student(A) -> actor(A)'],
#   0.861963),
#  (['professor(A) -> actor(A)',
#    'publication(A,B) -> genre(B,A)',
#    'advisedby(A,B) -> workedunder(A,B)',
#    'student(A) -> actor(A)'],
#   0.861963),
#  (['professor(A) -> actor(A)',
#    'publication(A,B) -> genre(B,A)',
#    'advisedby(A,B) -> workedunder(B,A)',
#    'student(A) -> actor(A)'],
#   0.861963),
#  (['professor(A) -> actor(A)',
#    'advisedby(A,B) -> workedunder(B,A)',
#    'publication(A,B) -> genre(B,A)',
#    'projectmember(A,B) -> genre(B,A)',
#    'student(A) -> actor(A)'],
#   0.861963),
#  (['professor(A) -> actor(A)',
#    'advisedby(A,B) -> workedunder(A,B)',
#    'projectmember(A,B) -> genre(B,A)',
#    'student(A) -> actor(A)'],
#   0.861963),
#  (['professor(A) -> actor(A)',
#    'advisedby(A,B) -> workedunder(B,A)',
#    'projectmember(A,B) -> movie(A,B)',
#    'student(A) -> actor(A)'],
#   0.861963),
#  (['professor(A) -> actor(A)',
#    'advisedby(A,B) -> workedunder(A,B)',
#    'projectmember(A,B) -> movie(A,B)',
#    'student(A) -> actor(A)'],
#   0.861963),
#  (['professor(A) -> actor(A)',
#    'advisedby(A,B) -> workedunder(B,A)',
#    'projectmember(A,B) -> genre(B,A)',
#    'student(A) -> actor(A)'],
#   0.861963),
#  (['professor(A) -> actor(A)',
#    'advisedby(A,B) -> workedunder(A,B)',
#    'student(A) -> actor(A)'],
#   0.861963),
#  (['professor(A) -> actor(A)',
#    'advisedby(A,B) -> workedunder(B,A)',
#    'student(A) -> actor(A)'],
#   0.861963),
#  (['professor(A) -> female(A)',
#    'advisedby(A,B) -> workedunder(B,A)',
#    'publication(A,B) -> movie(A,B)',
#    'projectmember(A,B) -> genre(B,A)'],
#   0.744317),
#  (['professor(A) -> female(A)',
#    'publication(A,B) -> movie(A,B)',
#    'advisedby(A,B) -> workedunder(B,A)'],
#   0.744317),
#  (['publication(A,B) -> movie(A,B)',
#    'advisedby(A,B) -> workedunder(A,B)',
#    'student(A) -> female(A)'],
#   0.744317),
#  (['advisedby(A,B) -> workedunder(A,B)',
#    'publication(A,B) -> movie(A,B)',
#    'projectmember(A,B) -> movie(A,B)',
#    'student(A) -> female(A)'],
#   0.744317),
#  (['professor(A) -> female(A)',
#    'advisedby(A,B) -> workedunder(B,A)',
#    'publication(A,B) -> movie(A,B)',
#    'projectmember(A,B) -> movie(A,B)'],
#   0.744317),
#  (['professor(A) -> director(A)',
#    'advisedby(A,B) -> workedunder(A,B)',
#    'publication(A,B) -> movie(A,B)',
#    'projectmember(A,B) -> genre(B,A)',
#    'student(A) -> female(A)'],
#   0.712437),
#  (['professor(A) -> director(A)',
#    'publication(A,B) -> movie(A,B)',
#    'advisedby(A,B) -> workedunder(A,B)',
#    'student(A) -> female(A)'],
#   0.712437),
#  (['professor(A) -> female(A)',
#    'publication(A,B) -> movie(A,B)',
#    'advisedby(A,B) -> workedunder(B,A)',
#    'student(A) -> director(A)'],
#   0.712437),
#  (['professor(A) -> director(A)',
#    'advisedby(A,B) -> workedunder(A,B)',
#    'publication(A,B) -> movie(A,B)',
#    'projectmember(A,B) -> movie(A,B)',
#    'student(A) -> female(A)'],
#   0.712437),
#  (['professor(A) -> female(A)',
#    'advisedby(A,B) -> workedunder(B,A)',
#    'publication(A,B) -> movie(A,B)',
#    'projectmember(A,B) -> movie(A,B)',
#    'student(A) -> director(A)'],
#   0.712437),
#  (['professor(A) -> female(A)',
#    'advisedby(A,B) -> workedunder(B,A)',
#    'publication(A,B) -> movie(A,B)',
#    'projectmember(A,B) -> genre(B,A)',
#    'student(A) -> director(A)'],
#   0.712437),
#  (['professor(A) -> female(A)',
#    'advisedby(A,B) -> workedunder(B,A)',
#    'publication(A,B) -> genre(B,A)',
#    'projectmember(A,B) -> movie(A,B)',
#    'student(A) -> director(A)'],
#   0.70794),
#  (['professor(A) -> director(A)',
#    'advisedby(A,B) -> workedunder(A,B)',
#    'publication(A,B) -> genre(B,A)',
#    'projectmember(A,B) -> genre(B,A)',
#    'student(A) -> female(A)'],
#   0.70794),
#  (['professor(A) -> female(A)',
#    'publication(A,B) -> genre(B,A)',
#    'advisedby(A,B) -> workedunder(B,A)',
#    'student(A) -> director(A)'],
#   0.70794),
#  (['professor(A) -> female(A)',
#    'advisedby(A,B) -> workedunder(B,A)',
#    'publication(A,B) -> genre(B,A)',
#    'projectmember(A,B) -> genre(B,A)',
#    'student(A) -> director(A)'],
#   0.70794),
#  (['professor(A) -> director(A)',
#    'advisedby(A,B) -> workedunder(A,B)',
#    'projectmember(A,B) -> genre(B,A)',
#    'student(A) -> female(A)'],
#   0.70794),
#  (['professor(A) -> director(A)',
#    'advisedby(A,B) -> workedunder(A,B)',
#    'publication(A,B) -> genre(B,A)',
#    'projectmember(A,B) -> movie(A,B)',
#    'student(A) -> female(A)'],
#   0.707055),
#  (['professor(A) -> director(A)',
#    'publication(A,B) -> genre(B,A)',
#    'advisedby(A,B) -> workedunder(A,B)',
#    'student(A) -> female(A)'],
#   0.707055),
#  (['professor(A) -> female(A)',
#    'advisedby(A,B) -> workedunder(B,A)',
#    'projectmember(A,B) -> movie(A,B)',
#    'student(A) -> director(A)'],
#   0.707055),
#  (['professor(A) -> director(A)',
#    'advisedby(A,B) -> workedunder(A,B)',
#    'projectmember(A,B) -> movie(A,B)',
#    'student(A) -> female(A)'],
#   0.707055),
#  (['professor(A) -> director(A)',
#    'advisedby(A,B) -> workedunder(A,B)',
#    'student(A) -> female(A)'],
#   0.707055),
#  (['professor(A) -> female(A)',
#    'advisedby(A,B) -> workedunder(B,A)',
#    'student(A) -> director(A)'],
#   0.707055),
#  (['professor(A) -> female(A)',
#    'advisedby(A,B) -> workedunder(B,A)',
#    'projectmember(A,B) -> genre(B,A)',
#    'student(A) -> director(A)'],
#   0.707055),
#  (['advisedby(A,B) -> workedunder(A,B)',
#    'publication(A,B) -> movie(A,B)',
#    'projectmember(A,B) -> genre(B,A)',
#    'student(A) -> female(A)'],
#   0.688966),
#  (['professor(A) -> female(A)',
#    'advisedby(A,B) -> workedunder(A,B)',
#    'publication(A,B) -> movie(A,B)',
#    'projectmember(A,B) -> genre(B,A)'],
#   0.679448),
#  (['advisedby(A,B) -> workedunder(B,A)',
#    'publication(A,B) -> movie(A,B)',
#    'projectmember(A,B) -> genre(B,A)',
#    'student(A) -> female(A)'],
#   0.679448),
#  (['professor(A) -> female(A)',
#    'publication(A,B) -> movie(A,B)',
#    'advisedby(A,B) -> workedunder(A,B)'],
#   0.679448),
#  (['publication(A,B) -> movie(A,B)',
#    'advisedby(A,B) -> workedunder(B,A)',
#    'student(A) -> female(A)'],
#   0.679448),
#  (['professor(A) -> female(A)',
#    'advisedby(A,B) -> workedunder(A,B)',
#    'publication(A,B) -> movie(A,B)',
#    'projectmember(A,B) -> movie(A,B)'],
#   0.679448),
#  (['advisedby(A,B) -> workedunder(B,A)',
#    'publication(A,B) -> movie(A,B)',
#    'projectmember(A,B) -> movie(A,B)',
#    'student(A) -> female(A)'],
#   0.679448),
#  (['advisedby(A,B) -> workedunder(B,A)',
#    'publication(A,B) -> genre(B,A)',
#    'projectmember(A,B) -> movie(A,B)',
#    'student(A) -> female(A)'],
#   0.679448),
#  (['professor(A) -> female(A)',
#    'advisedby(A,B) -> workedunder(A,B)',
#    'publication(A,B) -> genre(B,A)',
#    'projectmember(A,B) -> movie(A,B)'],
#   0.679448),
#  (['professor(A) -> female(A)',
#    'advisedby(A,B) -> workedunder(A,B)',
#    'publication(A,B) -> genre(B,A)',
#    'projectmember(A,B) -> genre(B,A)'],
#   0.679448),
#  (['professor(A) -> female(A)',
#    'publication(A,B) -> genre(B,A)',
#    'advisedby(A,B) -> workedunder(A,B)'],
#   0.679448),
#  (['publication(A,B) -> genre(B,A)',
#    'advisedby(A,B) -> workedunder(B,A)',
#    'student(A) -> female(A)'],
#   0.679448),
#  (['advisedby(A,B) -> workedunder(B,A)',
#    'publication(A,B) -> genre(B,A)',
#    'projectmember(A,B) -> genre(B,A)',
#    'student(A) -> female(A)'],
#   0.679448),
#  (['professor(A) -> female(A)',
#    'advisedby(A,B) -> workedunder(A,B)',
#    'projectmember(A,B) -> genre(B,A)'],
#   0.679448),
#  (['advisedby(A,B) -> workedunder(B,A)',
#    'projectmember(A,B) -> movie(A,B)',
#    'student(A) -> female(A)'],
#   0.679448),
#  (['professor(A) -> female(A)',
#    'advisedby(A,B) -> workedunder(A,B)',
#    'projectmember(A,B) -> movie(A,B)'],
#   0.679448),
#  (['advisedby(A,B) -> workedunder(B,A)',
#    'projectmember(A,B) -> genre(B,A)',
#    'student(A) -> female(A)'],
#   0.679448),
#  (['professor(A) -> female(A)', 'advisedby(A,B) -> workedunder(A,B)'],
#   0.679448),
#  (['advisedby(A,B) -> workedunder(B,A)', 'student(A) -> female(A)'], 0.679448),
#  (['professor(A) -> female(A)',
#    'advisedby(A,B) -> workedunder(B,A)',
#    'publication(A,B) -> genre(B,A)',
#    'projectmember(A,B) -> movie(A,B)'],
#   0.663579),
#  (['advisedby(A,B) -> workedunder(A,B)',
#    'publication(A,B) -> genre(B,A)',
#    'projectmember(A,B) -> genre(B,A)',
#    'student(A) -> female(A)'],
#   0.663579),
#  (['professor(A) -> female(A)',
#    'publication(A,B) -> genre(B,A)',
#    'advisedby(A,B) -> workedunder(B,A)'],
#   0.663579),
#  (['professor(A) -> female(A)',
#    'advisedby(A,B) -> workedunder(B,A)',
#    'publication(A,B) -> genre(B,A)',
#    'projectmember(A,B) -> genre(B,A)'],
#   0.663579),
#  (['advisedby(A,B) -> workedunder(A,B)',
#    'projectmember(A,B) -> genre(B,A)',
#    'student(A) -> female(A)'],
#   0.663579),
#  (['professor(A) -> female(A)',
#    'advisedby(A,B) -> workedunder(A,B)',
#    'publication(A,B) -> movie(A,B)',
#    'projectmember(A,B) -> genre(B,A)',
#    'student(A) -> actor(A)'],
#   0.641104),
#  (['professor(A) -> actor(A)',
#    'advisedby(A,B) -> workedunder(B,A)',
#    'publication(A,B) -> movie(A,B)',
#    'projectmember(A,B) -> genre(B,A)',
#    'student(A) -> female(A)'],
#   0.641104),
#  (['professor(A) -> female(A)',
#    'publication(A,B) -> movie(A,B)',
#    'advisedby(A,B) -> workedunder(A,B)',
#    'student(A) -> actor(A)'],
#   0.641104),
#  (['professor(A) -> actor(A)',
#    'publication(A,B) -> movie(A,B)',
#    'advisedby(A,B) -> workedunder(B,A)',
#    'student(A) -> female(A)'],
#   0.641104),
#  (['professor(A) -> female(A)',
#    'advisedby(A,B) -> workedunder(A,B)',
#    'publication(A,B) -> movie(A,B)',
#    'projectmember(A,B) -> movie(A,B)',
#    'student(A) -> actor(A)'],
#   0.641104),
#  (['professor(A) -> actor(A)',
#    'advisedby(A,B) -> workedunder(B,A)',
#    'publication(A,B) -> movie(A,B)',
#    'projectmember(A,B) -> movie(A,B)',
#    'student(A) -> female(A)'],
#   0.641104),
#  (['professor(A) -> actor(A)',
#    'advisedby(A,B) -> workedunder(B,A)',
#    'publication(A,B) -> genre(B,A)',
#    'projectmember(A,B) -> movie(A,B)',
#    'student(A) -> female(A)'],
#   0.641104),
#  (['professor(A) -> female(A)',
#    'advisedby(A,B) -> workedunder(A,B)',
#    'publication(A,B) -> genre(B,A)',
#    'projectmember(A,B) -> movie(A,B)',
#    'student(A) -> actor(A)'],
#   0.641104),
#  (['professor(A) -> female(A)',
#    'advisedby(A,B) -> workedunder(A,B)',
#    'publication(A,B) -> genre(B,A)',
#    'projectmember(A,B) -> genre(B,A)',
#    'student(A) -> actor(A)'],
#   0.641104),
#  (['professor(A) -> female(A)',
#    'publication(A,B) -> genre(B,A)',
#    'advisedby(A,B) -> workedunder(A,B)',
#    'student(A) -> actor(A)'],
#   0.641104),
#  (['professor(A) -> actor(A)',
#    'publication(A,B) -> genre(B,A)',
#    'advisedby(A,B) -> workedunder(B,A)',
#    'student(A) -> female(A)'],
#   0.641104),
#  (['professor(A) -> actor(A)',
#    'advisedby(A,B) -> workedunder(B,A)',
#    'publication(A,B) -> genre(B,A)',
#    'projectmember(A,B) -> genre(B,A)',
#    'student(A) -> female(A)'],
#   0.641104),
#  (['professor(A) -> female(A)',
#    'advisedby(A,B) -> workedunder(A,B)',
#    'projectmember(A,B) -> genre(B,A)',
#    'student(A) -> actor(A)'],
#   0.641104),
#  (['professor(A) -> actor(A)',
#    'advisedby(A,B) -> workedunder(B,A)',
#    'projectmember(A,B) -> movie(A,B)',
#    'student(A) -> female(A)'],
#   0.641104),
#  (['professor(A) -> female(A)',
#    'advisedby(A,B) -> workedunder(A,B)',
#    'projectmember(A,B) -> movie(A,B)',
#    'student(A) -> actor(A)'],
#   0.641104),
#  (['professor(A) -> actor(A)',
#    'advisedby(A,B) -> workedunder(B,A)',
#    'projectmember(A,B) -> genre(B,A)',
#    'student(A) -> female(A)'],
#   0.641104),
#  (['professor(A) -> female(A)',
#    'advisedby(A,B) -> workedunder(A,B)',
#    'student(A) -> actor(A)'],
#   0.641104),
#  (['professor(A) -> actor(A)',
#    'advisedby(A,B) -> workedunder(B,A)',
#    'student(A) -> female(A)'],
#   0.641104),
#  (['professor(A) -> actor(A)',
#    'advisedby(A,B) -> workedunder(A,B)',
#    'publication(A,B) -> movie(A,B)',
#    'projectmember(A,B) -> genre(B,A)',
#    'student(A) -> female(A)'],
#   0.630368),
#  (['professor(A) -> female(A)',
#    'advisedby(A,B) -> workedunder(B,A)',
#    'publication(A,B) -> movie(A,B)',
#    'projectmember(A,B) -> genre(B,A)',
#    'student(A) -> actor(A)'],
#   0.630368),
#  (['professor(A) -> actor(A)',
#    'publication(A,B) -> movie(A,B)',
#    'advisedby(A,B) -> workedunder(A,B)',
#    'student(A) -> female(A)'],
#   0.630368),
#  (['professor(A) -> female(A)',
#    'publication(A,B) -> movie(A,B)',
#    'advisedby(A,B) -> workedunder(B,A)',
#    'student(A) -> actor(A)'],
#   0.630368),
#  (['professor(A) -> actor(A)',
#    'advisedby(A,B) -> workedunder(A,B)',
#    'publication(A,B) -> movie(A,B)',
#    'projectmember(A,B) -> movie(A,B)',
#    'student(A) -> female(A)'],
#   0.630368),
#  (['professor(A) -> female(A)',
#    'advisedby(A,B) -> workedunder(B,A)',
#    'publication(A,B) -> movie(A,B)',
#    'projectmember(A,B) -> movie(A,B)',
#    'student(A) -> actor(A)'],
#   0.630368),
#  (['professor(A) -> female(A)',
#    'advisedby(A,B) -> workedunder(B,A)',
#    'publication(A,B) -> genre(B,A)',
#    'projectmember(A,B) -> movie(A,B)',
#    'student(A) -> actor(A)'],
#   0.630368),
#  (['professor(A) -> actor(A)',
#    'advisedby(A,B) -> workedunder(A,B)',
#    'publication(A,B) -> genre(B,A)',
#    'projectmember(A,B) -> movie(A,B)',
#    'student(A) -> female(A)'],
#   0.630368),
#  (['professor(A) -> actor(A)',
#    'advisedby(A,B) -> workedunder(A,B)',
#    'publication(A,B) -> genre(B,A)',
#    'projectmember(A,B) -> genre(B,A)',
#    'student(A) -> female(A)'],
#   0.630368),
#  (['professor(A) -> actor(A)',
#    'publication(A,B) -> genre(B,A)',
#    'advisedby(A,B) -> workedunder(A,B)',
#    'student(A) -> female(A)'],
#   0.630368),
#  (['professor(A) -> female(A)',
#    'publication(A,B) -> genre(B,A)',
#    'advisedby(A,B) -> workedunder(B,A)',
#    'student(A) -> actor(A)'],
#   0.630368),
#  (['professor(A) -> female(A)',
#    'advisedby(A,B) -> workedunder(B,A)',
#    'publication(A,B) -> genre(B,A)',
#    'projectmember(A,B) -> genre(B,A)',
#    'student(A) -> actor(A)'],
#   0.630368),
#  (['professor(A) -> actor(A)',
#    'advisedby(A,B) -> workedunder(A,B)',
#    'projectmember(A,B) -> genre(B,A)',
#    'student(A) -> female(A)'],
#   0.630368),
#  (['professor(A) -> actor(A)',
#    'advisedby(A,B) -> workedunder(A,B)',
#    'projectmember(A,B) -> movie(A,B)',
#    'student(A) -> female(A)'],
#   0.630368),
#  (['professor(A) -> female(A)',
#    'advisedby(A,B) -> workedunder(B,A)',
#    'projectmember(A,B) -> movie(A,B)',
#    'student(A) -> actor(A)'],
#   0.630368),
#  (['professor(A) -> female(A)',
#    'advisedby(A,B) -> workedunder(B,A)',
#    'projectmember(A,B) -> genre(B,A)',
#    'student(A) -> actor(A)'],
#   0.630368),
#  (['professor(A) -> actor(A)',
#    'advisedby(A,B) -> workedunder(A,B)',
#    'student(A) -> female(A)'],
#   0.630368),
#  (['professor(A) -> female(A)',
#    'advisedby(A,B) -> workedunder(B,A)',
#    'student(A) -> actor(A)'],
#   0.630368),
#  (['advisedby(A,B) -> workedunder(A,B)',
#    'publication(A,B) -> movie(A,B)',
#    'projectmember(A,B) -> genre(B,A)',
#    'student(A) -> director(A)'],
#   0.607362),
#  (['professor(A) -> director(A)',
#    'advisedby(A,B) -> workedunder(B,A)',
#    'publication(A,B) -> movie(A,B)',
#    'projectmember(A,B) -> genre(B,A)'],
#   0.607362),
#  (['advisedby(A,B) -> workedunder(A,B)',
#    'publication(A,B) -> genre(B,A)',
#    'projectmember(A,B) -> movie(A,B)',
#    'student(A) -> actor(A)'],
#   0.607362),
#  (['professor(A) -> director(A)',
#    'advisedby(A,B) -> workedunder(B,A)',
#    'publication(A,B) -> genre(B,A)',
#    'projectmember(A,B) -> movie(A,B)'],
#   0.607362),
#  (['professor(A) -> director(A)',
#    'publication(A,B) -> movie(A,B)',
#    'advisedby(A,B) -> workedunder(B,A)'],
#   0.607362),
#  (['publication(A,B) -> movie(A,B)',
#    'advisedby(A,B) -> workedunder(A,B)',
#    'student(A) -> director(A)'],
#   0.607362),
#  (['publication(A,B) -> genre(B,A)',
#    'advisedby(A,B) -> workedunder(A,B)',
#    'student(A) -> actor(A)'],
#   0.607362),
#  (['advisedby(A,B) -> workedunder(A,B)',
#    'publication(A,B) -> movie(A,B)',
#    'projectmember(A,B) -> movie(A,B)',
#    'student(A) -> director(A)'],
#   0.607362),
#  (['professor(A) -> director(A)',
#    'advisedby(A,B) -> workedunder(B,A)',
#    'publication(A,B) -> movie(A,B)',
#    'projectmember(A,B) -> movie(A,B)'],
#   0.607362),
#  (['advisedby(A,B) -> workedunder(A,B)',
#    'publication(A,B) -> genre(B,A)',
#    'projectmember(A,B) -> movie(A,B)',
#    'student(A) -> director(A)'],
#   0.607362),
#  (['advisedby(A,B) -> workedunder(A,B)',
#    'publication(A,B) -> genre(B,A)',
#    'projectmember(A,B) -> genre(B,A)',
#    'student(A) -> director(A)'],
#   0.607362),
#  (['professor(A) -> actor(A)',
#    'advisedby(A,B) -> workedunder(B,A)',
#    'projectmember(A,B) -> movie(A,B)'],
#   0.607362),
#  (['publication(A,B) -> genre(B,A)',
#    'advisedby(A,B) -> workedunder(A,B)',
#    'student(A) -> director(A)'],
#   0.607362),
#  (['professor(A) -> director(A)',
#    'advisedby(A,B) -> workedunder(B,A)',
#    'publication(A,B) -> genre(B,A)',
#    'projectmember(A,B) -> genre(B,A)'],
#   0.607362),
#  (['professor(A) -> director(A)',
#    'publication(A,B) -> genre(B,A)',
#    'advisedby(A,B) -> workedunder(B,A)'],
#   0.607362),
#  (['advisedby(A,B) -> workedunder(A,B)',
#    'projectmember(A,B) -> movie(A,B)',
#    'student(A) -> actor(A)'],
#   0.607362),
#  (['professor(A) -> actor(A)',
#    'advisedby(A,B) -> workedunder(B,A)',
#    'projectmember(A,B) -> genre(B,A)'],
#   0.607362),
#  (['advisedby(A,B) -> workedunder(A,B)', 'student(A) -> actor(A)'], 0.607362),
#  (['professor(A) -> actor(A)', 'advisedby(A,B) -> workedunder(B,A)'],
#   0.607362),
#  (['advisedby(A,B) -> workedunder(A,B)',
#    'projectmember(A,B) -> genre(B,A)',
#    'student(A) -> director(A)'],
#   0.607362),
#  (['professor(A) -> director(A)',
#    'advisedby(A,B) -> workedunder(B,A)',
#    'projectmember(A,B) -> genre(B,A)'],
#   0.607362),
#  (['professor(A) -> director(A)',
#    'advisedby(A,B) -> workedunder(B,A)',
#    'projectmember(A,B) -> movie(A,B)'],
#   0.607362),
#  (['advisedby(A,B) -> workedunder(A,B)',
#    'projectmember(A,B) -> movie(A,B)',
#    'student(A) -> director(A)'],
#   0.607362),
#  (['advisedby(A,B) -> workedunder(A,B)', 'student(A) -> director(A)'],
#   0.607362),
#  (['professor(A) -> director(A)', 'advisedby(A,B) -> workedunder(B,A)'],
#   0.607362),
#  (['professor(A) -> actor(A)',
#    'advisedby(A,B) -> workedunder(A,B)',
#    'publication(A,B) -> movie(A,B)',
#    'projectmember(A,B) -> genre(B,A)',
#    'student(A) -> director(A)'],
#   0.588957),
#  (['professor(A) -> director(A)',
#    'advisedby(A,B) -> workedunder(B,A)',
#    'publication(A,B) -> movie(A,B)',
#    'projectmember(A,B) -> genre(B,A)',
#    'student(A) -> actor(A)'],
#   0.588957),
#  (['professor(A) -> actor(A)',
#    'publication(A,B) -> movie(A,B)',
#    'advisedby(A,B) -> workedunder(A,B)',
#    'student(A) -> director(A)'],
#   0.588957),
#  (['professor(A) -> director(A)',
#    'publication(A,B) -> movie(A,B)',
#    'advisedby(A,B) -> workedunder(B,A)',
#    'student(A) -> actor(A)'],
#   0.588957),
#  (['professor(A) -> actor(A)',
#    'advisedby(A,B) -> workedunder(A,B)',
#    'publication(A,B) -> movie(A,B)',
#    'projectmember(A,B) -> movie(A,B)',
#    'student(A) -> director(A)'],
#   0.588957),
#  (['professor(A) -> director(A)',
#    'advisedby(A,B) -> workedunder(B,A)',
#    'publication(A,B) -> movie(A,B)',
#    'projectmember(A,B) -> movie(A,B)',
#    'student(A) -> actor(A)'],
#   0.588957),
#  (['professor(A) -> director(A)',
#    'advisedby(A,B) -> workedunder(B,A)',
#    'publication(A,B) -> genre(B,A)',
#    'projectmember(A,B) -> movie(A,B)',
#    'student(A) -> actor(A)'],
#   0.588957),
#  (['professor(A) -> actor(A)',
#    'advisedby(A,B) -> workedunder(A,B)',
#    'publication(A,B) -> genre(B,A)',
#    'projectmember(A,B) -> movie(A,B)',
#    'student(A) -> director(A)'],
#   0.588957),
#  (['professor(A) -> actor(A)',
#    'advisedby(A,B) -> workedunder(A,B)',
#    'publication(A,B) -> genre(B,A)',
#    'projectmember(A,B) -> genre(B,A)',
#    'student(A) -> director(A)'],
#   0.588957),
#  (['professor(A) -> actor(A)',
#    'publication(A,B) -> genre(B,A)',
#    'advisedby(A,B) -> workedunder(A,B)',
#    'student(A) -> director(A)'],
#   0.588957),
#  (['professor(A) -> director(A)',
#    'advisedby(A,B) -> workedunder(B,A)',
#    'publication(A,B) -> genre(B,A)',
#    'projectmember(A,B) -> genre(B,A)',
#    'student(A) -> actor(A)'],
#   0.588957),
#  (['professor(A) -> director(A)',
#    'publication(A,B) -> genre(B,A)',
#    'advisedby(A,B) -> workedunder(B,A)',
#    'student(A) -> actor(A)'],
#   0.588957),
#  (['professor(A) -> actor(A)',
#    'advisedby(A,B) -> workedunder(A,B)',
#    'projectmember(A,B) -> genre(B,A)',
#    'student(A) -> director(A)'],
#   0.588957),
#  (['professor(A) -> actor(A)',
#    'advisedby(A,B) -> workedunder(A,B)',
#    'projectmember(A,B) -> movie(A,B)',
#    'student(A) -> director(A)'],
#   0.588957),
#  (['professor(A) -> director(A)',
#    'advisedby(A,B) -> workedunder(B,A)',
#    'projectmember(A,B) -> genre(B,A)',
#    'student(A) -> actor(A)'],
#   0.588957),
#  (['professor(A) -> director(A)',
#    'advisedby(A,B) -> workedunder(B,A)',
#    'projectmember(A,B) -> movie(A,B)',
#    'student(A) -> actor(A)'],
#   0.588957),
#  (['professor(A) -> actor(A)',
#    'advisedby(A,B) -> workedunder(A,B)',
#    'student(A) -> director(A)'],
#   0.588957),
#  (['professor(A) -> director(A)',
#    'advisedby(A,B) -> workedunder(B,A)',
#    'student(A) -> actor(A)'],
#   0.588957),
#  (['advisedby(A,B) -> workedunder(A,B)',
#    'publication(A,B) -> genre(B,A)',
#    'projectmember(A,B) -> movie(A,B)',
#    'student(A) -> female(A)'],
#   0.576687),
#  (['publication(A,B) -> genre(B,A)',
#    'advisedby(A,B) -> workedunder(A,B)',
#    'student(A) -> female(A)'],
#   0.576687),
#  (['professor(A) -> female(A)',
#    'advisedby(A,B) -> workedunder(B,A)',
#    'projectmember(A,B) -> movie(A,B)'],
#   0.576687),
#  (['advisedby(A,B) -> workedunder(A,B)',
#    'projectmember(A,B) -> movie(A,B)',
#    'student(A) -> female(A)'],
#   0.576687),
#  (['professor(A) -> female(A)',
#    'advisedby(A,B) -> workedunder(B,A)',
#    'projectmember(A,B) -> genre(B,A)'],
#   0.576687),
#  (['advisedby(A,B) -> workedunder(A,B)', 'student(A) -> female(A)'], 0.576687),
#  (['professor(A) -> female(A)', 'advisedby(A,B) -> workedunder(B,A)'],
#   0.576687),
#  (['advisedby(A,B) -> workedunder(A,B)',
#    'publication(A,B) -> genre(B,A)',
#    'projectmember(A,B) -> movie(A,B)'],
#   0.567485),
#  (['publication(A,B) -> genre(B,A)', 'advisedby(A,B) -> workedunder(A,B)'],
#   0.567485),
#  (['professor(A) -> female(A)',
#    'advisedby(A,B) -> workedunder(A,B)',
#    'publication(A,B) -> movie(A,B)',
#    'projectmember(A,B) -> genre(B,A)',
#    'student(A) -> female(A)'],
#   0.56135),
#  (['professor(A) -> female(A)',
#    'advisedby(A,B) -> workedunder(B,A)',
#    'publication(A,B) -> movie(A,B)',
#    'projectmember(A,B) -> genre(B,A)',
#    'student(A) -> female(A)'],
#   0.56135),
#  (['professor(A) -> female(A)',
#    'publication(A,B) -> movie(A,B)',
#    'advisedby(A,B) -> workedunder(A,B)',
#    'student(A) -> female(A)'],
#   0.56135),
#  (['professor(A) -> female(A)',
#    'publication(A,B) -> movie(A,B)',
#    'advisedby(A,B) -> workedunder(B,A)',
#    'student(A) -> female(A)'],
#   0.56135),
#  (['professor(A) -> female(A)',
#    'advisedby(A,B) -> workedunder(A,B)',
#    'publication(A,B) -> movie(A,B)',
#    'projectmember(A,B) -> movie(A,B)',
#    'student(A) -> female(A)'],
#   0.56135),
#  (['professor(A) -> female(A)',
#    'advisedby(A,B) -> workedunder(B,A)',
#    'publication(A,B) -> movie(A,B)',
#    'projectmember(A,B) -> movie(A,B)',
#    'student(A) -> female(A)'],
#   0.56135),
#  (['professor(A) -> female(A)',
#    'advisedby(A,B) -> workedunder(B,A)',
#    'publication(A,B) -> genre(B,A)',
#    'projectmember(A,B) -> movie(A,B)',
#    'student(A) -> female(A)'],
#   0.56135),
#  (['professor(A) -> female(A)',
#    'advisedby(A,B) -> workedunder(A,B)',
#    'publication(A,B) -> genre(B,A)',
#    'projectmember(A,B) -> movie(A,B)',
#    'student(A) -> female(A)'],
#   0.56135),
#  (['professor(A) -> female(A)',
#    'advisedby(A,B) -> workedunder(A,B)',
#    'publication(A,B) -> genre(B,A)',
#    'projectmember(A,B) -> genre(B,A)',
#    'student(A) -> female(A)'],
#   0.56135),
#  (['professor(A) -> female(A)',
#    'publication(A,B) -> genre(B,A)',
#    'advisedby(A,B) -> workedunder(A,B)',
#    'student(A) -> female(A)'],
#   0.56135),
#  (['professor(A) -> female(A)',
#    'publication(A,B) -> genre(B,A)',
#    'advisedby(A,B) -> workedunder(B,A)',
#    'student(A) -> female(A)'],
#   0.56135),
#  (['professor(A) -> female(A)',
#    'advisedby(A,B) -> workedunder(B,A)',
#    'publication(A,B) -> genre(B,A)',
#    'projectmember(A,B) -> genre(B,A)',
#    'student(A) -> female(A)'],
#   0.56135),
#  (['professor(A) -> female(A)',
#    'advisedby(A,B) -> workedunder(A,B)',
#    'projectmember(A,B) -> genre(B,A)',
#    'student(A) -> female(A)'],
#   0.56135),
#  (['professor(A) -> female(A)',
#    'advisedby(A,B) -> workedunder(B,A)',
#    'projectmember(A,B) -> movie(A,B)',
#    'student(A) -> female(A)'],
#   0.56135),
#  (['professor(A) -> female(A)',
#    'advisedby(A,B) -> workedunder(A,B)',
#    'projectmember(A,B) -> movie(A,B)',
#    'student(A) -> female(A)'],
#   0.56135),
#  (['professor(A) -> female(A)',
#    'advisedby(A,B) -> workedunder(B,A)',
#    'projectmember(A,B) -> genre(B,A)',
#    'student(A) -> female(A)'],
#   0.56135),
#  (['professor(A) -> female(A)',
#    'advisedby(A,B) -> workedunder(A,B)',
#    'student(A) -> female(A)'],
#   0.56135),
#  (['professor(A) -> female(A)',
#    'advisedby(A,B) -> workedunder(B,A)',
#    'student(A) -> female(A)'],
#   0.56135),
#  (['professor(A) -> female(A)',
#    'advisedby(A,B) -> workedunder(A,B)',
#    'publication(A,B) -> movie(A,B)',
#    'projectmember(A,B) -> genre(B,A)',
#    'student(A) -> director(A)'],
#   0.538344),
#  (['professor(A) -> director(A)',
#    'advisedby(A,B) -> workedunder(B,A)',
#    'publication(A,B) -> movie(A,B)',
#    'projectmember(A,B) -> genre(B,A)',
#    'student(A) -> female(A)'],
#   0.538344),
#  (['professor(A) -> female(A)',
#    'publication(A,B) -> movie(A,B)',
#    'advisedby(A,B) -> workedunder(A,B)',
#    'student(A) -> director(A)'],
#   0.538344),
#  (['professor(A) -> director(A)',
#    'publication(A,B) -> movie(A,B)',
#    'advisedby(A,B) -> workedunder(B,A)',
#    'student(A) -> female(A)'],
#   0.538344),
#  (['professor(A) -> female(A)',
#    'advisedby(A,B) -> workedunder(A,B)',
#    'publication(A,B) -> movie(A,B)',
#    'projectmember(A,B) -> movie(A,B)',
#    'student(A) -> director(A)'],
#   0.538344),
#  (['professor(A) -> director(A)',
#    'advisedby(A,B) -> workedunder(B,A)',
#    'publication(A,B) -> movie(A,B)',
#    'projectmember(A,B) -> movie(A,B)',
#    'student(A) -> female(A)'],
#   0.538344),
#  (['professor(A) -> director(A)',
#    'advisedby(A,B) -> workedunder(B,A)',
#    'publication(A,B) -> genre(B,A)',
#    'projectmember(A,B) -> movie(A,B)',
#    'student(A) -> female(A)'],
#   0.538344),
#  (['professor(A) -> female(A)',
#    'advisedby(A,B) -> workedunder(A,B)',
#    'publication(A,B) -> genre(B,A)',
#    'projectmember(A,B) -> movie(A,B)',
#    'student(A) -> director(A)'],
#   0.538344),
#  (['professor(A) -> female(A)',
#    'advisedby(A,B) -> workedunder(A,B)',
#    'publication(A,B) -> genre(B,A)',
#    'projectmember(A,B) -> genre(B,A)',
#    'student(A) -> director(A)'],
#   0.538344),
#  (['professor(A) -> female(A)',
#    'publication(A,B) -> genre(B,A)',
#    'advisedby(A,B) -> workedunder(A,B)',
#    'student(A) -> director(A)'],
#   0.538344),
#  (['professor(A) -> director(A)',
#    'advisedby(A,B) -> workedunder(B,A)',
#    'publication(A,B) -> genre(B,A)',
#    'projectmember(A,B) -> genre(B,A)',
#    'student(A) -> female(A)'],
#   0.538344),
#  (['professor(A) -> director(A)',
#    'publication(A,B) -> genre(B,A)',
#    'advisedby(A,B) -> workedunder(B,A)',
#    'student(A) -> female(A)'],
#   0.538344),
#  (['professor(A) -> female(A)',
#    'advisedby(A,B) -> workedunder(A,B)',
#    'projectmember(A,B) -> genre(B,A)',
#    'student(A) -> director(A)'],
#   0.538344),
#  (['professor(A) -> director(A)',
#    'advisedby(A,B) -> workedunder(B,A)',
#    'projectmember(A,B) -> genre(B,A)',
#    'student(A) -> female(A)'],
#   0.538344),
#  (['professor(A) -> female(A)',
#    'advisedby(A,B) -> workedunder(A,B)',
#    'projectmember(A,B) -> movie(A,B)',
#    'student(A) -> director(A)'],
#   0.538344),
#  (['professor(A) -> director(A)',
#    'advisedby(A,B) -> workedunder(B,A)',
#    'projectmember(A,B) -> movie(A,B)',
#    'student(A) -> female(A)'],
#   0.538344),
#  (['professor(A) -> female(A)',
#    'advisedby(A,B) -> workedunder(A,B)',
#    'student(A) -> director(A)'],
#   0.538344),
#  (['professor(A) -> director(A)',
#    'advisedby(A,B) -> workedunder(B,A)',
#    'student(A) -> female(A)'],
#   0.538344),
#  (['professor(A) -> director(A)',
#    'advisedby(A,B) -> workedunder(A,B)',
#    'publication(A,B) -> movie(A,B)',
#    'projectmember(A,B) -> genre(B,A)',
#    'student(A) -> director(A)'],
#   0.518405),
#  (['professor(A) -> director(A)',
#    'advisedby(A,B) -> workedunder(B,A)',
#    'publication(A,B) -> movie(A,B)',
#    'projectmember(A,B) -> genre(B,A)',
#    'student(A) -> director(A)'],
#   0.518405),
#  (['professor(A) -> director(A)',
#    'advisedby(A,B) -> workedunder(B,A)',
#    'publication(A,B) -> genre(B,A)',
#    'projectmember(A,B) -> movie(A,B)',
#    'student(A) -> director(A)'],
#   0.518405),
#  (['professor(A) -> director(A)',
#    'publication(A,B) -> movie(A,B)',
#    'advisedby(A,B) -> workedunder(A,B)',
#    'student(A) -> director(A)'],
#   0.518405),
#  (['professor(A) -> director(A)',
#    'publication(A,B) -> movie(A,B)',
#    'advisedby(A,B) -> workedunder(B,A)',
#    'student(A) -> director(A)'],
#   0.518405),
#  (['professor(A) -> director(A)',
#    'advisedby(A,B) -> workedunder(A,B)',
#    'publication(A,B) -> movie(A,B)',
#    'projectmember(A,B) -> movie(A,B)',
#    'student(A) -> director(A)'],
#   0.518405),
#  (['professor(A) -> director(A)',
#    'advisedby(A,B) -> workedunder(B,A)',
#    'publication(A,B) -> movie(A,B)',
#    'projectmember(A,B) -> movie(A,B)',
#    'student(A) -> director(A)'],
#   0.518405),
#  (['professor(A) -> director(A)',
#    'advisedby(A,B) -> workedunder(A,B)',
#    'publication(A,B) -> genre(B,A)',
#    'projectmember(A,B) -> movie(A,B)',
#    'student(A) -> director(A)'],
#   0.518405),
#  (['professor(A) -> director(A)',
#    'advisedby(A,B) -> workedunder(A,B)',
#    'publication(A,B) -> genre(B,A)',
#    'projectmember(A,B) -> genre(B,A)',
#    'student(A) -> director(A)'],
#   0.518405),
#  (['professor(A) -> director(A)',
#    'publication(A,B) -> genre(B,A)',
#    'advisedby(A,B) -> workedunder(A,B)',
#    'student(A) -> director(A)'],
#   0.518405),
#  (['professor(A) -> director(A)',
#    'publication(A,B) -> genre(B,A)',
#    'advisedby(A,B) -> workedunder(B,A)',
#    'student(A) -> director(A)'],
#   0.518405),
#  (['professor(A) -> director(A)',
#    'advisedby(A,B) -> workedunder(B,A)',
#    'publication(A,B) -> genre(B,A)',
#    'projectmember(A,B) -> genre(B,A)',
#    'student(A) -> director(A)'],
#   0.518405),
#  (['professor(A) -> director(A)',
#    'advisedby(A,B) -> workedunder(A,B)',
#    'projectmember(A,B) -> genre(B,A)',
#    'student(A) -> director(A)'],
#   0.518405),
#  (['professor(A) -> director(A)',
#    'advisedby(A,B) -> workedunder(B,A)',
#    'projectmember(A,B) -> movie(A,B)',
#    'student(A) -> director(A)'],
#   0.518405),
#  (['professor(A) -> director(A)',
#    'advisedby(A,B) -> workedunder(A,B)',
#    'projectmember(A,B) -> movie(A,B)',
#    'student(A) -> director(A)'],
#   0.518405),
#  (['professor(A) -> director(A)',
#    'advisedby(A,B) -> workedunder(B,A)',
#    'projectmember(A,B) -> genre(B,A)',
#    'student(A) -> director(A)'],
#   0.518405),
#  (['professor(A) -> director(A)',
#    'advisedby(A,B) -> workedunder(A,B)',
#    'student(A) -> director(A)'],
#   0.518405),
#  (['professor(A) -> director(A)',
#    'advisedby(A,B) -> workedunder(B,A)',
#    'student(A) -> director(A)'],
#   0.518405)]
