# %% [markdown]
# #### Os testes foram realizados com a proporção de 2 exemplos negativos para cada exemplo positivo. O dataset foi dividido em 3 folds e o número máximo de literais por nó é de 2 literais, número máximo de 8 cláusulas e uma profundidade máxima da árvore de tamanho 3. O domínio utilizado foi o NELL Finances e 10 boosted trees foram aprendidos.

# %%
import os
import sys
import time

from datasets.get_datasets import *
from revision import *
from transfer import *
from mapping import *
from boostsrl import boostsrl
import numpy as np
import random
import json

balanced = 2
firstRun = False
n_runs = 2
n_folds = 3

nodeSize = 2
numOfClauses = 8
maxTreeDepth = 3

seed = 0
target = 'nell_finances'
new_target = 'companyeconomicsector'

# %% [markdown]
# #### A serguir tem-se os modes utilizados no aprendizado. O predicado artificial ceoeconomicsector(person, sector) foi removido. Sem o predicado inverso do target companyeconomicsector, nenhum outro predicado possui o tipo sector, portanto não era possível aprender nenhuma regra relevante e com isso o resultado alternava em torno de AUC ROC 0.5.
#
# #### Com o predicado inverso economicsectorcompany presente nos modes, o aprendizado da regra companyeconomicsector(A, B) :- economicsectorcompany(B, A) seria possível resultando em AUC ROC 1.0. Para evitar o aprendizado dessa regra foi utilizado o operador mode (\`) que impede que o algoritmo use variáveis da cabeça da cláusula.

# %%
bk = ['countryhascompanyoffice(+country,+company).',
        'countryhascompanyoffice(+country,-company).',
        'countryhascompanyoffice(-country,+company).',
        'companyeconomicsector(+company,+sector).',
        'companyeconomicsector(+company,-sector).',
        'companyeconomicsector(-company,+sector).',
        #'economicsectorcompany(+sector,+company).',
        'economicsectorcompany(+sector,`company).',
        'economicsectorcompany(`sector,+company).',
        #'ceoeconomicsector(+person,+sector).',
        #'ceoeconomicsector(+person,-sector).',
        #'ceoeconomicsector(-person,+sector).',
        'companyceo(+company,+person).',
        'companyceo(+company,-person).',
        'companyceo(-company,+person).',
        'companyalsoknownas(+company,+company).',
        'companyalsoknownas(+company,-company).',
        'companyalsoknownas(-company,+company).',
        'cityhascompanyoffice(+city,+company).',
        'cityhascompanyoffice(+city,-company).',
        'cityhascompanyoffice(-city,+company).',
        'acquired(+company,+company).',
        'acquired(+company,-company).',
        'acquired(-company,+company).',
        #'ceoof(+person,+company).',
        #'ceoof(+person,-company).',
        #'ceoof(-person,+company).',
        'bankbankincountry(+person,+country).',
        'bankbankincountry(+person,-country).',
        'bankbankincountry(-person,+country).',
        'bankboughtbank(+company,+company).',
        'bankboughtbank(+company,-company).',
        'bankboughtbank(-company,+company).',
        'bankchiefexecutiveceo(+company,+person).',
        'bankchiefexecutiveceo(+company,-person).',
        'bankchiefexecutiveceo(-company,+person).']

# %%
background = boostsrl.modes(bk, [new_target], useStdLogicVariables=False, maxTreeDepth=maxTreeDepth, nodeSize=nodeSize, numOfClauses=numOfClauses)

# %% [markdown]
# #### Aprendizado do zero com as árvores do primeiro fold

# %%
# Load new predicate target dataset
tar_data = datasets.load(target, bk, target=new_target, balanced=balanced, seed=seed)
results = []

for i in range(n_folds):
    [tar_train_facts, tar_test_facts] =  [tar_data[0][0], tar_data[0][0]]
    to_folds_pos = datasets.split_into_folds(tar_data[1][0], n_folds=n_folds, seed=seed)
    to_folds_neg = datasets.split_into_folds(tar_data[2][0], n_folds=n_folds, seed=seed)
    [tar_train_pos, tar_test_pos] =  datasets.get_kfold_small(i, to_folds_pos)
    [tar_train_neg, tar_test_neg] =  datasets.get_kfold_small(i, to_folds_neg)
    
    [model, t_results, structured, will, variances] = revision.learn_test_model(background, boostsrl, new_target, tar_train_pos, tar_train_neg, tar_train_facts, tar_test_pos, tar_test_neg, tar_test_facts, trees=10, print_function=None)
    results.append(t_results)
    
    if i == 0:
        for line in will:
            print(line)
    print('\n')
    print('Fold ' + str(i+1))
    print(t_results)
print('\n')
auc_roc = np.array([item['AUC ROC'] for item in results])
auc_pr = np.array([item['AUC PR'] for item in results])
cll = np.array([item['CLL'] for item in results])
print('AUC ROC: %.3f +/- %.3f' % (auc_roc.mean(), 2 * auc_roc.std()))
print('AUC PR: %.3f +/- %.3f' % (auc_pr.mean(), 2 * auc_pr.std()))
print('CLL: %.3f +/- %.3f' % (cll.mean(), 2 * cll.std()))
# Out:
# WILL Produced-Tree #1
# % FOR companyeconomicsector(A, B):
# %   if ( acquired(C, A), economicsectorcompany(B, C) )
# %   then return 0.8581489350995123;  // std dev = 0,000, 16,000 (wgt'ed) examples reached here.  /* #pos=16 */
# %   else if ( acquired(D, A) )
# %   | then if ( companyalsoknownas(A, E), economicsectorcompany(B, E) )
# %   | | then return 0.8581489350995121;  // std dev = 2,11e-08, 3,000 (wgt'ed) examples reached here.  /* #pos=3 */
# %   | | else if ( acquired(F, D), cityhascompanyoffice(G, D) )
# %   | | | then return 0.2581489350995123;  // std dev = 1,549, 10,000 (wgt'ed) examples reached here.  /* #neg=6 #pos=4 */
# %   | | | else return 0.010926712877290107;  // std dev = 3,053, 72,000 (wgt'ed) examples reached here.  /* #neg=61 #pos=11 */
# %   | else if ( acquired(A, H), economicsectorcompany(B, H) )
# %   | | then if ( cityhascompanyoffice(I, A) )
# %   | | | then return 0.8581489350995123;  // std dev = 0,000, 6,000 (wgt'ed) examples reached here.  /* #pos=6 */
# %   | | | else return 0.6581489350995122;  // std dev = 0,894, 5,000 (wgt'ed) examples reached here.  /* #neg=1 #pos=4 */
# %   | | else if ( acquired(A, J), cityhascompanyoffice(K, J) )
# %   | | | then return -0.05851773156715447;  // std dev = 1,354, 24,000 (wgt'ed) examples reached here.  /* #neg=22 #pos=2 */
# %   | | | else return 0.19096386511506036;  // std dev = 11,949, 643,000 (wgt'ed) examples reached here.  /* #neg=429 #pos=214 */
# WILL Produced-Tree #2
# % FOR companyeconomicsector(A, B):
# %   if ( countryhascompanyoffice(C, A), bankbankincountry(D, C) )
# %   then if ( acquired(A, E), countryhascompanyoffice(C, E) )
# %   | then return -0.08306505991710014;  // std dev = 0,264, 14,000 (wgt'ed) examples reached here.  /* #neg=13 #pos=1 */
# %   | else if ( companyalsoknownas(A, F), economicsectorcompany(B, F) )
# %   | | then return 0.7574081159480732;  // std dev = 0,093, 3,000 (wgt'ed) examples reached here.  /* #pos=3 */
# %   | | else if ( acquired(A, G), companyceo(G, H) )
# %   | | | then return -0.1667224765776891;  // std dev = 0,000, 7,000 (wgt'ed) examples reached here.  /* #neg=7 */
# %   | | | else return 0.10967905537860836;  // std dev = 3,346, 58,000 (wgt'ed) examples reached here.  /* #neg=42 #pos=16 */
# %   else if ( acquired(I, A), countryhascompanyoffice(J, I) )
# %   | then return 0.08434194822996137;  // std dev = 0,414, 12,000 (wgt'ed) examples reached here.  /* #neg=9 #pos=3 */
# %   | else if ( companyceo(A, K), acquired(A, L) )
# %   | | then if ( companyceo(L, M), acquired(L, N) )
# %   | | | then return 0.4902072812893869;  // std dev = 1,116, 6,000 (wgt'ed) examples reached here.  /* #neg=2 #pos=4 */
# %   | | | else return 0.21671135394266122;  // std dev = 3,335, 51,000 (wgt'ed) examples reached here.  /* #neg=31 #pos=20 */
# %   | | else if ( cityhascompanyoffice(P, A) )
# %   | | | then return 0.14385811135617968;  // std dev = 4,390, 93,000 (wgt'ed) examples reached here.  /* #neg=64 #pos=29 */
# %   | | | else return 0.17677981863628145;  // std dev = 10,899, 535,000 (wgt'ed) examples reached here.  /* #neg=351 #pos=184 */
# WILL Produced-Tree #3
# % FOR companyeconomicsector(A, B):
# %   if ( acquired(C, A), companyceo(C, D) )
# %   then if ( economicsectorcompany(B, C) )
# %   | then return 0.6837181165997936;  // std dev = 0,025, 13,000 (wgt'ed) examples reached here.  /* #pos=13 */
# %   | else if ( companyalsoknownas(C, E), cityhascompanyoffice(F, E) )
# %   | | then if ( cityhascompanyoffice(F, C) )
# %   | | | then return -0.0687543396383578;  // std dev = 0,657, 8,000 (wgt'ed) examples reached here.  /* #neg=7 #pos=1 */
# %   | | | else return 0.42246254056026433;  // std dev = 1,333, 8,000 (wgt'ed) examples reached here.  /* #neg=3 #pos=5 */
# %   | | else if ( bankboughtbank(G, C), cityhascompanyoffice(H, G) )
# %   | | | then return 0.2181514570551185;  // std dev = 1,115, 5,000 (wgt'ed) examples reached here.  /* #neg=3 #pos=2 */
# %   | | | else return -0.0953355654039226;  // std dev = 1,345, 28,000 (wgt'ed) examples reached here.  /* #neg=26 #pos=2 */
# %   else return 0.1392623805991404;  // std dev = 0,465, 717,000 (wgt'ed) examples reached here.  /* #neg=480 #pos=237 */
# WILL Produced-Tree #4
# % FOR companyeconomicsector(A, B):
# %   if ( companyalsoknownas(A, C), economicsectorcompany(B, C) )
# %   then if ( acquired(D, A) )
# %   | then return 0.5497844563888408;  // std dev = 0,048, 3,000 (wgt'ed) examples reached here.  /* #pos=3 */
# %   | else return 0.7562210516817197;  // std dev = 0,098, 4,000 (wgt'ed) examples reached here.  /* #pos=4 */
# %   else if ( acquired(A, E), economicsectorcompany(B, E) )
# %   | then if ( companyceo(A, F) )
# %   | | then if ( companyalsoknownas(A, G) )
# %   | | | then return 0.6595991538897736;  // std dev = 0,037, 4,000 (wgt'ed) examples reached here.  /* #pos=4 */
# %   | | | else return 0.32248249793199035;  // std dev = 0,706, 3,000 (wgt'ed) examples reached here.  /* #neg=1 #pos=2 */
# %   | | else return 0.686344798847314;  // std dev = 0,032, 4,000 (wgt'ed) examples reached here.  /* #pos=4 */
# %   | else if ( countryhascompanyoffice(H, A), acquired(A, I) )
# %   | | then if ( cityhascompanyoffice(J, A) )
# %   | | | then return 0.10466680124388823;  // std dev = 1,436, 11,000 (wgt'ed) examples reached here.  /* #neg=8 #pos=3 */
# %   | | | else return -0.16442053329103903;  // std dev = 0,085, 15,000 (wgt'ed) examples reached here.  /* #neg=15 */
# %   | | else if ( bankboughtbank(K, A), acquired(K, L) )
# %   | | | then return -0.057492715275469584;  // std dev = 0,782, 7,000 (wgt'ed) examples reached here.  /* #neg=6 #pos=1 */
# %   | | | else return 0.11289427175505429;  // std dev = 12,441, 728,000 (wgt'ed) examples reached here.  /* #neg=489 #pos=239 */
# WILL Produced-Tree #5
# % FOR companyeconomicsector(A, B):
# %   return 0;  // std dev = 0,455, 779,000 (wgt'ed) examples reached here.  /* #neg=519 #pos=260 */
# WILL Produced-Tree #6
# % FOR companyeconomicsector(A, B):
# %   if ( companyalsoknownas(A, C), companyceo(C, D) )
# %   then if ( acquired(A, E) )
# %   | then if ( economicsectorcompany(B, E) )
# %   | | then return 0.49049420754250644;  // std dev = 0,022, 3,000 (wgt'ed) examples reached here.  /* #pos=3 */
# %   | | else return 0.04138505450019471;  // std dev = 0,412, 33,000 (wgt'ed) examples reached here.  /* #neg=24 #pos=9 */
# %   | else if ( acquired(C, F), acquired(F, G) )
# %   | | then if ( companyalsoknownas(C, H), economicsectorcompany(B, H) )
# %   | | | then return 0.6770100287337182;  // std dev = 0,348, 4,000 (wgt'ed) examples reached here.  /* #pos=4 */
# %   | | | else return -0.2228064115434157;  // std dev = 0,023, 3,000 (wgt'ed) examples reached here.  /* #neg=3 */
# %   | | else return 0.4814896397137602;  // std dev = 0,835, 4,000 (wgt'ed) examples reached here.  /* #neg=1 #pos=3 */
# %   else if ( acquired(I, A), companyceo(A, J) )
# %   | then return 0.1832618683210899;  // std dev = 0,407, 23,000 (wgt'ed) examples reached here.  /* #neg=12 #pos=11 */
# %   | else if ( acquired(K, A) )
# %   | | then return 0.05836321888348913;  // std dev = 0,387, 69,000 (wgt'ed) examples reached here.  /* #neg=49 #pos=20 */
# %   | | else if ( acquired(A, L) )
# %   | | | then return 0.056002923085513294;  // std dev = 3,658, 78,000 (wgt'ed) examples reached here.  /* #neg=55 #pos=23 */
# %   | | | else return 0.09883510138720898;  // std dev = 11,153, 562,000 (wgt'ed) examples reached here.  /* #neg=375 #pos=187 */
# WILL Produced-Tree #7
# % FOR companyeconomicsector(A, B):
# %   if ( cityhascompanyoffice(C, A) )
# %   then if ( cityhascompanyoffice(C, D), economicsectorcompany(B, D) )
# %   | then if ( companyalsoknownas(D, E), acquired(D, F) )
# %   | | then return 0.6157239648202485;  // std dev = 0,205, 37,000 (wgt'ed) examples reached here.  /* #neg=1 #pos=36 */
# %   | | else if ( bankchiefexecutiveceo(D, G), bankchiefexecutiveceo(A, H) )
# %   | | | then return 0.7571110527536162;  // std dev = 0,005, 3,000 (wgt'ed) examples reached here.  /* #pos=3 */
# %   | | | else return 0.2563678997433702;  // std dev = 2,717, 31,000 (wgt'ed) examples reached here.  /* #neg=15 #pos=16 */
# %   | else return -0.23429207448489403;  // std dev = 0,286, 93,000 (wgt'ed) examples reached here.  /* #neg=93 */
# %   else if ( companyalsoknownas(A, I), countryhascompanyoffice(J, I) )
# %   | then if ( countryhascompanyoffice(K, A) )
# %   | | then return 0.03264742167613833;  // std dev = 0,471, 3,000 (wgt'ed) examples reached here.  /* #neg=2 #pos=1 */
# %   | | else return -0.2574125088499041;  // std dev = 0,089, 5,000 (wgt'ed) examples reached here.  /* #neg=5 */
# %   | else if ( acquired(L, A) )
# %   | | then if ( economicsectorcompany(B, L) )
# %   | | | then return 0.5007771614980666;  // std dev = 0,197, 11,000 (wgt'ed) examples reached here.  /* #pos=11 */
# %   | | | else return -0.02232374774657097;  // std dev = 2,851, 61,000 (wgt'ed) examples reached here.  /* #neg=50 #pos=11 */
# %   | | else return 0.08759041894562054;  // std dev = 0,468, 535,000 (wgt'ed) examples reached here.  /* #neg=353 #pos=182 */
# WILL Produced-Tree #8
# % FOR companyeconomicsector(A, B):
# %   if ( bankboughtbank(C, A), companyceo(A, D) )
# %   then if ( bankboughtbank(E, C) )
# %   | then return 0.11841855943969573;  // std dev = 0,936, 5,000 (wgt'ed) examples reached here.  /* #neg=3 #pos=2 */
# %   | else return -0.18575491386926427;  // std dev = 0,100, 6,000 (wgt'ed) examples reached here.  /* #neg=6 */
# %   else if ( acquired(A, F), economicsectorcompany(B, F) )
# %   | then if ( companyceo(A, G) )
# %   | | then if ( companyalsoknownas(A, H) )
# %   | | | then return 0.3051619503243532;  // std dev = 0,221, 4,000 (wgt'ed) examples reached here.  /* #pos=4 */
# %   | | | else return 0.1284293705574314;  // std dev = 0,588, 3,000 (wgt'ed) examples reached here.  /* #neg=1 #pos=2 */
# %   | | else return 0.45721534388952423;  // std dev = 0,145, 4,000 (wgt'ed) examples reached here.  /* #pos=4 */
# %   | else if ( countryhascompanyoffice(I, A), bankbankincountry(J, I) )
# %   | | then if ( countryhascompanyoffice(I, K), economicsectorcompany(B, K) )
# %   | | | then return 0.43731294965480544;  // std dev = 1,959, 24,000 (wgt'ed) examples reached here.  /* #neg=6 #pos=18 */
# %   | | | else return -0.20097930517385196;  // std dev = 0,334, 49,000 (wgt'ed) examples reached here.  /* #neg=49 */
# %   | | else return 0.06459754136649516;  // std dev = 0,448, 684,000 (wgt'ed) examples reached here.  /* #neg=454 #pos=230 */
# WILL Produced-Tree #9
# % FOR companyeconomicsector(A, B):
# %   if ( companyalsoknownas(A, C), economicsectorcompany(B, C) )
# %   then if ( cityhascompanyoffice(D, A) )
# %   | then return 0.20776972946543534;  // std dev = 0,092, 3,000 (wgt'ed) examples reached here.  /* #pos=3 */
# %   | else return 0.48150864696293894;  // std dev = 0,215, 4,000 (wgt'ed) examples reached here.  /* #pos=4 */
# %   else if ( acquired(E, A), economicsectorcompany(B, E) )
# %   | then if ( companyceo(E, F) )
# %   | | then return 0.32505364163711303;  // std dev = 0,082, 13,000 (wgt'ed) examples reached here.  /* #pos=13 */
# %   | | else return 0.470416125396558;  // std dev = 0,025, 3,000 (wgt'ed) examples reached here.  /* #pos=3 */
# %   | else if ( countryhascompanyoffice(G, A), bankbankincountry(H, G) )
# %   | | then if ( countryhascompanyoffice(G, I), economicsectorcompany(B, I) )
# %   | | | then return 0.2861872419800618;  // std dev = 2,164, 25,000 (wgt'ed) examples reached here.  /* #neg=9 #pos=16 */
# %   | | | else return -0.16984279074780537;  // std dev = 0,303, 53,000 (wgt'ed) examples reached here.  /* #neg=53 */
# %   | | else if ( acquired(A, J), economicsectorcompany(B, J) )
# %   | | | then return 0.31838437960212973;  // std dev = 0,263, 9,000 (wgt'ed) examples reached here.  /* #pos=9 */
# %   | | | else return 0.04266494523273207;  // std dev = 11,652, 669,000 (wgt'ed) examples reached here.  /* #neg=457 #pos=212 */
# WILL Produced-Tree #10
# % FOR companyeconomicsector(A, B):
# %   if ( countryhascompanyoffice(C, A), bankbankincountry(D, C) )
# %   then if ( companyceo(A, E), companyalsoknownas(A, F) )
# %   | then return 0.040613013958767784;  // std dev = 0,272, 21,000 (wgt'ed) examples reached here.  /* #neg=14 #pos=7 */
# %   | else if ( countryhascompanyoffice(C, G), economicsectorcompany(B, G) )
# %   | | then if ( acquired(G, H), companyceo(G, I) )
# %   | | | then return 0.4432627252639562;  // std dev = 0,940, 11,000 (wgt'ed) examples reached here.  /* #neg=1 #pos=10 */
# %   | | | else return -0.09089573492752467;  // std dev = 1,266, 10,000 (wgt'ed) examples reached here.  /* #neg=7 #pos=3 */
# %   | | else return -0.1537849442435094;  // std dev = 0,036, 40,000 (wgt'ed) examples reached here.  /* #neg=40 */
# %   else if ( acquired(A, J), cityhascompanyoffice(K, J) )
# %   | then return -0.0886987340475839;  // std dev = 0,256, 23,000 (wgt'ed) examples reached here.  /* #neg=18 #pos=5 */
# %   | else if ( acquired(A, L), countryhascompanyoffice(M, L) )
# %   | | then if ( acquired(L, N) )
# %   | | | then return 0.25414931700481974;  // std dev = 0,656, 3,000 (wgt'ed) examples reached here.  /* #neg=1 #pos=2 */
# %   | | | else return 0.1586844069655156;  // std dev = 0,871, 4,000 (wgt'ed) examples reached here.  /* #neg=2 #pos=2 */
# %   | | else if ( bankboughtbank(P, A) )
# %   | | | then return 0.136295013776468;  // std dev = 1,671, 12,000 (wgt'ed) examples reached here.  /* #neg=7 #pos=5 */
# %   | | | else return 0.045340989957067174;  // std dev = 11,455, 655,000 (wgt'ed) examples reached here.  /* #neg=429 #pos=226 */
#
#
# {'AUC ROC': 0.71307, 'Inference time': 1.986, 'AUC PR': 0.615502, 'Recall': 0.131274, 'CLL': -0.571887, 'Learning time': 22.918, 'Precision': [0.957746, 0.5], 'F1': 0.2309}
#
#
# {'AUC ROC': 0.655377, 'Inference time': 1.882, 'AUC PR': 0.537519, 'Recall': 0.083012, 'CLL': -0.59354, 'Learning time': 57.467, 'Precision': [0.955556, 0.5], 'F1': 0.152753}
#
#
# {'AUC ROC': 0.720265, 'Inference time': 2.245, 'AUC PR': 0.622386, 'Recall': 0.134615, 'CLL': -0.574275, 'Learning time': 83.116, 'Precision': [0.972222, 0.5], 'F1': 0.236486}
#
#
# AUC ROC: 0.696 +/- 0.058
# AUC PR: 0.592 +/- 0.077
# CLL: -0.580 +/- 0.019

# %% [markdown]
# #### A váriavel refine são os parâmetros que passo para o algoritmo determinando como quero formar suas árvores.
#
# #### id da árvore; caminho do nó; target(A,B) :- literais do nó.; aprende uma subárvore na esquerda?; aprende uma subárvore na direita?
#
# #### Com esse refine portanto estou forçando um único nó economicsectorcompany(B, A) que não é permitido pelos modes e que resulta num AUC ROC 1.0.

# %%
refine = ['0;;companyeconomicsector(A, B) :- economicsectorcompany(B, A).;false;false',
          '1;;companyeconomicsector(A, B) :- economicsectorcompany(B, A).;false;false',
          '2;;companyeconomicsector(A, B) :- economicsectorcompany(B, A).;false;false',
          '3;;companyeconomicsector(A, B) :- economicsectorcompany(B, A).;false;false',
          '4;;companyeconomicsector(A, B) :- economicsectorcompany(B, A).;false;false',
          '5;;companyeconomicsector(A, B) :- economicsectorcompany(B, A).;false;false',
          '6;;companyeconomicsector(A, B) :- economicsectorcompany(B, A).;false;false',
          '7;;companyeconomicsector(A, B) :- economicsectorcompany(B, A).;false;false',
          '8;;companyeconomicsector(A, B) :- economicsectorcompany(B, A).;false;false',
          '9;;companyeconomicsector(A, B) :- economicsectorcompany(B, A).;false;false',
         ]

# Load new predicate target dataset
tar_data = datasets.load(target, bk, target=new_target, balanced=balanced, seed=seed)
results = []

for i in range(n_folds):
    [tar_train_facts, tar_test_facts] =  [tar_data[0][0], tar_data[0][0]]
    to_folds_pos = datasets.split_into_folds(tar_data[1][0], n_folds=n_folds, seed=seed)
    to_folds_neg = datasets.split_into_folds(tar_data[2][0], n_folds=n_folds, seed=seed)
    [tar_train_pos, tar_test_pos] =  datasets.get_kfold_small(i, to_folds_pos)
    [tar_train_neg, tar_test_neg] =  datasets.get_kfold_small(i, to_folds_neg)
    
    [model, t_results, structured, will, variances] = revision.learn_test_model(background, boostsrl, new_target, tar_train_pos, tar_train_neg, tar_train_facts, tar_test_pos, tar_test_neg, tar_test_facts, refine=refine, trees=10, print_function=None)
    results.append(t_results)
    
    if i == 0:
        for line in will:
            print(line)
    print('\n')
    print('Fold ' + str(i+1))
    print(t_results)
print('\n')
auc_roc = np.array([item['AUC ROC'] for item in results])
auc_pr = np.array([item['AUC PR'] for item in results])
cll = np.array([item['CLL'] for item in results])
print('AUC ROC: %.3f +/- %.3f' % (auc_roc.mean(), 2 * auc_roc.std()))
print('AUC PR: %.3f +/- %.3f' % (auc_pr.mean(), 2 * auc_pr.std()))
print('CLL: %.3f +/- %.3f' % (cll.mean(), 2 * cll.std()))
# Out:
# WILL Produced-Tree #1
# % FOR companyeconomicsector(A, B):
# %   if ( economicsectorcompany(B, A) )
# %   then return 0.8581489350995087;  // std dev = 1,07e-06, 260,000 (wgt'ed) examples reached here.  /* #pos=260 */
# %   else return -0.1418510649004879;  // std dev = 0,000, 519,000 (wgt'ed) examples reached here.  /* #neg=519 */
# WILL Produced-Tree #2
# % FOR companyeconomicsector(A, B):
# %   if ( economicsectorcompany(B, A) )
# %   then return 0.7194734122109575;  // std dev = 0,000, 260,000 (wgt'ed) examples reached here.  /* #pos=260 */
# %   else return -0.1254446385283923;  // std dev = 0,000, 519,000 (wgt'ed) examples reached here.  /* #neg=519 */
# WILL Produced-Tree #3
# % FOR companyeconomicsector(A, B):
# %   if ( economicsectorcompany(B, A) )
# %   then return 0.5553664367462832;  // std dev = 3,95e-07, 260,000 (wgt'ed) examples reached here.  /* #pos=260 */
# %   else return -0.11231637819360576;  // std dev = 0,000, 519,000 (wgt'ed) examples reached here.  /* #neg=519 */
# WILL Produced-Tree #4
# % FOR companyeconomicsector(A, B):
# %   if ( economicsectorcompany(B, A) )
# %   then return 0.417513584158311;  // std dev = 0,000, 260,000 (wgt'ed) examples reached here.  /* #pos=260 */
# %   else return -0.10159632948783531;  // std dev = 3,70e-07, 519,000 (wgt'ed) examples reached here.  /* #neg=519 */
# WILL Produced-Tree #5
# % FOR companyeconomicsector(A, B):
# %   if ( economicsectorcompany(B, A) )
# %   then return 0.3207118471601502;  // std dev = 1,33e-07, 260,000 (wgt'ed) examples reached here.  /* #pos=260 */
# %   else return -0.09269127618926154;  // std dev = 0,000, 519,000 (wgt'ed) examples reached here.  /* #neg=519 */
# WILL Produced-Tree #6
# % FOR companyeconomicsector(A, B):
# %   if ( economicsectorcompany(B, A) )
# %   then return 0.25517224256948795;  // std dev = 3,26e-07, 260,000 (wgt'ed) examples reached here.  /* #pos=260 */
# %   else return -0.08518475138839678;  // std dev = 1,48e-07, 519,000 (wgt'ed) examples reached here.  /* #neg=519 */
# WILL Produced-Tree #7
# % FOR companyeconomicsector(A, B):
# %   if ( economicsectorcompany(B, A) )
# %   then return 0.20975771563253484;  // std dev = 2,86e-07, 260,000 (wgt'ed) examples reached here.  /* #pos=260 */
# %   else return -0.07877675473109218;  // std dev = 0,000, 519,000 (wgt'ed) examples reached here.  /* #neg=519 */
# WILL Produced-Tree #8
# % FOR companyeconomicsector(A, B):
# %   if ( economicsectorcompany(B, A) )
# %   then return 0.17709649774527722;  // std dev = 4,21e-08, 260,000 (wgt'ed) examples reached here.  /* #pos=260 */
# %   else return -0.07324622576333682;  // std dev = 1,79e-07, 519,000 (wgt'ed) examples reached here.  /* #neg=519 */
# WILL Produced-Tree #9
# % FOR companyeconomicsector(A, B):
# %   if ( economicsectorcompany(B, A) )
# %   then return 0.15274385809367158;  // std dev = 0,000, 260,000 (wgt'ed) examples reached here.  /* #pos=260 */
# %   else return -0.06842697784420358;  // std dev = 0,000, 519,000 (wgt'ed) examples reached here.  /* #neg=519 */
# WILL Produced-Tree #10
# % FOR companyeconomicsector(A, B):
# %   if ( economicsectorcompany(B, A) )
# %   then return 0.1340070300080112;  // std dev = 0,000, 260,000 (wgt'ed) examples reached here.  /* #pos=260 */
# %   else return -0.06419184008202534;  // std dev = 2,46e-07, 519,000 (wgt'ed) examples reached here.  /* #neg=519 */
#
#
# Fold 1
# {'AUC ROC': 1.0, 'Inference time': 1.061, 'AUC PR': 1.0, 'Recall': 1.0, 'CLL': -0.08386, 'Learning time': 4.622, 'Precision': [1.0, 0.5], 'F1': 1.0}
#
#
# Fold 2
# {'AUC ROC': 1.0, 'Inference time': 1.069, 'AUC PR': 1.0, 'Recall': 1.0, 'CLL': -0.08386, 'Learning time': 3.825, 'Precision': [1.0, 0.5], 'F1': 1.0}
#
#
# Fold 3
# {'AUC ROC': 1.0, 'Inference time': 1.042, 'AUC PR': 1.0, 'Recall': 1.0, 'CLL': -0.083901, 'Learning time': 47.321, 'Precision': [1.0, 0.5], 'F1': 1.0}
#
#
# AUC ROC: 1.000 +/- 0.000
# AUC PR: 1.000 +/- 0.000
# CLL: -0.084 +/- 0.000

# %% [markdown]
# #### Apenas o nó companyceo(A, C), companyceo(D, C), economicsectorcompany(B, D).

# %%
refine = ['0;;companyeconomicsector(A, B) :- companyceo(A, C), companyceo(D, C), economicsectorcompany(B, D).;false;false',
          '1;;companyeconomicsector(A, B) :- companyceo(A, C), companyceo(D, C), economicsectorcompany(B, D).;false;false',
          '2;;companyeconomicsector(A, B) :- companyceo(A, C), companyceo(D, C), economicsectorcompany(B, D).;false;false',
          '3;;companyeconomicsector(A, B) :- companyceo(A, C), companyceo(D, C), economicsectorcompany(B, D).;false;false',
          '4;;companyeconomicsector(A, B) :- companyceo(A, C), companyceo(D, C), economicsectorcompany(B, D).;false;false',
          '5;;companyeconomicsector(A, B) :- companyceo(A, C), companyceo(D, C), economicsectorcompany(B, D).;false;false',
          '6;;companyeconomicsector(A, B) :- companyceo(A, C), companyceo(D, C), economicsectorcompany(B, D).;false;false',
          '7;;companyeconomicsector(A, B) :- companyceo(A, C), companyceo(D, C), economicsectorcompany(B, D).;false;false',
          '8;;companyeconomicsector(A, B) :- companyceo(A, C), companyceo(D, C), economicsectorcompany(B, D).;false;false',
          '9;;companyeconomicsector(A, B) :- companyceo(A, C), companyceo(D, C), economicsectorcompany(B, D).;false;false',
         ]

# Load new predicate target dataset
tar_data = datasets.load(target, bk, target=new_target, balanced=balanced, seed=seed)
results = []

for i in range(n_folds):
    [tar_train_facts, tar_test_facts] =  [tar_data[0][0], tar_data[0][0]]
    to_folds_pos = datasets.split_into_folds(tar_data[1][0], n_folds=n_folds, seed=seed)
    to_folds_neg = datasets.split_into_folds(tar_data[2][0], n_folds=n_folds, seed=seed)
    [tar_train_pos, tar_test_pos] =  datasets.get_kfold_small(i, to_folds_pos)
    [tar_train_neg, tar_test_neg] =  datasets.get_kfold_small(i, to_folds_neg)
    
    [model, t_results, structured, will, variances] = revision.learn_test_model(background, boostsrl, new_target, tar_train_pos, tar_train_neg, tar_train_facts, tar_test_pos, tar_test_neg, tar_test_facts, refine=refine, trees=10, print_function=None)
    results.append(t_results)
    
    if i == 0:
        for line in will:
            print(line)
    print('\n')
    print('Fold ' + str(i+1))
    print(t_results)
print('\n')
auc_roc = np.array([item['AUC ROC'] for item in results])
auc_pr = np.array([item['AUC PR'] for item in results])
cll = np.array([item['CLL'] for item in results])
print('AUC ROC: %.3f +/- %.3f' % (auc_roc.mean(), 2 * auc_roc.std()))
print('AUC PR: %.3f +/- %.3f' % (auc_pr.mean(), 2 * auc_pr.std()))
print('CLL: %.3f +/- %.3f' % (cll.mean(), 2 * cll.std()))
# Out:
# WILL Produced-Tree #1
# % FOR companyeconomicsector(A, B):
# %   if ( companyceo(A, C), companyceo(D, C), economicsectorcompany(B, D) )
# %   then return 0.8581489350995121;  // std dev = 2,06e-07, 46,000 (wgt'ed) examples reached here.  /* #pos=46 */
# %   else return 0.15009982186622042;  // std dev = 12,309, 733,000 (wgt'ed) examples reached here.  /* #neg=519 #pos=214 */
# WILL Produced-Tree #2
# % FOR companyeconomicsector(A, B):
# %   if ( companyceo(A, C), companyceo(D, C), economicsectorcompany(B, D) )
# %   then return 0.719473412210955;  // std dev = 0,000, 46,000 (wgt'ed) examples reached here.  /* #pos=46 */
# %   else return 0.13082844552342424;  // std dev = 12,309, 733,000 (wgt'ed) examples reached here.  /* #neg=519 #pos=214 */
# WILL Produced-Tree #3
# % FOR companyeconomicsector(A, B):
# %   if ( companyceo(A, C), companyceo(D, C), economicsectorcompany(B, D) )
# %   then return 0.5553664367462839;  // std dev = 0,000, 46,000 (wgt'ed) examples reached here.  /* #pos=46 */
# %   else return 0.11235263459398838;  // std dev = 12,309, 733,000 (wgt'ed) examples reached here.  /* #neg=519 #pos=214 */
# WILL Produced-Tree #4
# % FOR companyeconomicsector(A, B):
# %   if ( companyceo(A, C), companyceo(D, C), economicsectorcompany(B, D) )
# %   then return 0.41751358415831025;  // std dev = 0,000, 46,000 (wgt'ed) examples reached here.  /* #pos=46 */
# %   else return 0.09519883024164089;  // std dev = 12,309, 733,000 (wgt'ed) examples reached here.  /* #neg=519 #pos=214 */
# WILL Produced-Tree #5
# % FOR companyeconomicsector(A, B):
# %   if ( companyceo(A, C), companyceo(D, C), economicsectorcompany(B, D) )
# %   then return 0.32071184716014944;  // std dev = 2,98e-08, 46,000 (wgt'ed) examples reached here.  /* #pos=46 */
# %   else return 0.07971832725805762;  // std dev = 12,309, 733,000 (wgt'ed) examples reached here.  /* #neg=519 #pos=214 */
# WILL Produced-Tree #6
# % FOR companyeconomicsector(A, B):
# %   if ( companyceo(A, C), companyceo(D, C), economicsectorcompany(B, D) )
# %   then return 0.2551722425694896;  // std dev = 0,000, 46,000 (wgt'ed) examples reached here.  /* #pos=46 */
# %   else return 0.06608468715169825;  // std dev = 12,309, 733,000 (wgt'ed) examples reached here.  /* #neg=519 #pos=214 */
# WILL Produced-Tree #7
# % FOR companyeconomicsector(A, B):
# %   if ( companyceo(A, C), companyceo(D, C), economicsectorcompany(B, D) )
# %   then return 0.2097577156325355;  // std dev = 5,16e-08, 46,000 (wgt'ed) examples reached here.  /* #pos=46 */
# %   else return 0.054320903681147885;  // std dev = 12,309, 733,000 (wgt'ed) examples reached here.  /* #neg=519 #pos=214 */
# WILL Produced-Tree #8
# % FOR companyeconomicsector(A, B):
# %   if ( companyceo(A, C), companyceo(D, C), economicsectorcompany(B, D) )
# %   then return 0.1770964977452775;  // std dev = 0,000, 46,000 (wgt'ed) examples reached here.  /* #pos=46 */
# %   else return 0.044340229290795556;  // std dev = 12,309, 733,000 (wgt'ed) examples reached here.  /* #neg=519 #pos=214 */
# WILL Produced-Tree #9
# % FOR companyeconomicsector(A, B):
# %   if ( companyceo(A, C), companyceo(D, C), economicsectorcompany(B, D) )
# %   then return 0.15274385809367083;  // std dev = 0,000, 46,000 (wgt'ed) examples reached here.  /* #pos=46 */
# %   else return 0.035987555085466194;  // std dev = 12,309, 733,000 (wgt'ed) examples reached here.  /* #neg=519 #pos=214 */
# WILL Produced-Tree #10
# % FOR companyeconomicsector(A, B):
# %   if ( companyceo(A, C), companyceo(D, C), economicsectorcompany(B, D) )
# %   then return 0.13400703000801104;  // std dev = 2,79e-08, 46,000 (wgt'ed) examples reached here.  /* #pos=46 */
# %   else return 0.0290738938214581;  // std dev = 12,309, 733,000 (wgt'ed) examples reached here.  /* #neg=519 #pos=214 */
#
#
# Fold 1
# {'AUC ROC': 0.57529, 'Inference time': 1.056, 'AUC PR': 0.497876, 'Recall': 0.150579, 'CLL': -0.586929, 'Learning time': 10.447, 'Precision': [1.0, 0.5], 'F1': 0.261745}
#
#
# Fold 2
# {'AUC ROC': 0.585907, 'Inference time': 1.156, 'AUC PR': 0.515912, 'Recall': 0.171815, 'CLL': -0.577635, 'Learning time': 4.41, 'Precision': [1.0, 0.5], 'F1': 0.293245}
#
#
# Fold 3
# {'AUC ROC': 0.577885, 'Inference time': 1.044, 'AUC PR': 0.502903, 'Recall': 0.155769, 'CLL': -0.585122, 'Learning time': 4.901, 'Precision': [1.0, 0.5], 'F1': 0.269551}
#
#
# AUC ROC: 0.580 +/- 0.009
# AUC PR: 0.506 +/- 0.015
# CLL: -0.583 +/- 0.008

# %% [markdown]
# #### O nó companyceo(A, C), companyceo(D, C), economicsectorcompany(B, D). podendo aprender subárvores no ramo da esquerda (TRUE) ou direita (FALSE).

# %%
refine = ['0;;companyeconomicsector(A, B) :- companyceo(A, C), companyceo(D, C), economicsectorcompany(B, D).;true;true',
          '1;;companyeconomicsector(A, B) :- companyceo(A, C), companyceo(D, C), economicsectorcompany(B, D).;true;true',
          '2;;companyeconomicsector(A, B) :- companyceo(A, C), companyceo(D, C), economicsectorcompany(B, D).;true;true',
          '3;;companyeconomicsector(A, B) :- companyceo(A, C), companyceo(D, C), economicsectorcompany(B, D).;true;true',
          '4;;companyeconomicsector(A, B) :- companyceo(A, C), companyceo(D, C), economicsectorcompany(B, D).;true;true',
          '5;;companyeconomicsector(A, B) :- companyceo(A, C), companyceo(D, C), economicsectorcompany(B, D).;true;true',
          '6;;companyeconomicsector(A, B) :- companyceo(A, C), companyceo(D, C), economicsectorcompany(B, D).;true;true',
          '7;;companyeconomicsector(A, B) :- companyceo(A, C), companyceo(D, C), economicsectorcompany(B, D).;true;true',
          '8;;companyeconomicsector(A, B) :- companyceo(A, C), companyceo(D, C), economicsectorcompany(B, D).;true;true',
          '9;;companyeconomicsector(A, B) :- companyceo(A, C), companyceo(D, C), economicsectorcompany(B, D).;true;true',
         ]

# Load new predicate target dataset
tar_data = datasets.load(target, bk, target=new_target, balanced=balanced, seed=seed)
results = []

for i in range(n_folds):
    [tar_train_facts, tar_test_facts] =  [tar_data[0][0], tar_data[0][0]]
    to_folds_pos = datasets.split_into_folds(tar_data[1][0], n_folds=n_folds, seed=seed)
    to_folds_neg = datasets.split_into_folds(tar_data[2][0], n_folds=n_folds, seed=seed)
    [tar_train_pos, tar_test_pos] =  datasets.get_kfold_small(i, to_folds_pos)
    [tar_train_neg, tar_test_neg] =  datasets.get_kfold_small(i, to_folds_neg)
    
    [model, t_results, structured, will, variances] = revision.learn_test_model(background, boostsrl, new_target, tar_train_pos, tar_train_neg, tar_train_facts, tar_test_pos, tar_test_neg, tar_test_facts, refine=refine, trees=10, print_function=None)
    results.append(t_results)
    
    if i == 0:
        for line in will:
            print(line)
    print('\n')
    print('Fold ' + str(i+1))
    print(t_results)
print('\n')
auc_roc = np.array([item['AUC ROC'] for item in results])
auc_pr = np.array([item['AUC PR'] for item in results])
cll = np.array([item['CLL'] for item in results])
print('AUC ROC: %.3f +/- %.3f' % (auc_roc.mean(), 2 * auc_roc.std()))
print('AUC PR: %.3f +/- %.3f' % (auc_pr.mean(), 2 * auc_pr.std()))
print('CLL: %.3f +/- %.3f' % (cll.mean(), 2 * cll.std()))
# Out:
# WILL Produced-Tree #1
# % FOR companyeconomicsector(A, B):
# %   if ( companyceo(A, C), companyceo(D, C), economicsectorcompany(B, D) )
# %   then return 0.8581489350995121;  // std dev = 2,06e-07, 46,000 (wgt'ed) examples reached here.  /* #pos=46 */
# %   else if ( companyceo(A, E) )
# %   | then return -0.14185106490048766;  // std dev = 7,88e-08, 85,000 (wgt'ed) examples reached here.  /* #neg=85 */
# %   | else if ( companyalsoknownas(A, F), companyceo(F, G) )
# %   | | then if ( acquired(F, H), acquired(H, I) )
# %   | | | then return 0.28672036367094084;  // std dev = 1,309, 7,000 (wgt'ed) examples reached here.  /* #neg=4 #pos=3 */
# %   | | | else return 0.6081489350995122;  // std dev = 0,866, 4,000 (wgt'ed) examples reached here.  /* #neg=1 #pos=3 */
# %   | | else if ( acquired(A, J), cityhascompanyoffice(K, J) )
# %   | | | then return -0.0168510649004878;  // std dev = 1,323, 16,000 (wgt'ed) examples reached here.  /* #neg=14 #pos=2 */
# %   | | | else return 0.18987196247470933;  // std dev = 11,733, 621,000 (wgt'ed) examples reached here.  /* #neg=415 #pos=206 */
# WILL Produced-Tree #2
# % FOR companyeconomicsector(A, B):
# %   if ( companyceo(A, C), companyceo(D, C), economicsectorcompany(B, D) )
# %   then return 0.719473412210955;  // std dev = 0,000, 46,000 (wgt'ed) examples reached here.  /* #pos=46 */
# %   else if ( companyceo(A, E) )
# %   | then return -0.12544463852839144;  // std dev = 0,000, 85,000 (wgt'ed) examples reached here.  /* #neg=85 */
# %   | else if ( countryhascompanyoffice(F, A), bankbankincountry(G, F) )
# %   | | then if ( countryhascompanyoffice(F, H), economicsectorcompany(B, H) )
# %   | | | then return 0.4991703338776478;  // std dev = 1,823, 15,000 (wgt'ed) examples reached here.  /* #neg=5 #pos=10 */
# %   | | | else return -0.16411181414972145;  // std dev = 0,047, 27,000 (wgt'ed) examples reached here.  /* #neg=27 */
# %   | | else if ( bankchiefexecutiveceo(A, I) )
# %   | | | then return 0.0045556100969509255;  // std dev = 0,908, 6,000 (wgt'ed) examples reached here.  /* #neg=5 #pos=1 */
# %   | | | else return 0.17173960091864202;  // std dev = 11,576, 600,000 (wgt'ed) examples reached here.  /* #neg=397 #pos=203 */
# WILL Produced-Tree #3
# % FOR companyeconomicsector(A, B):
# %   if ( companyceo(A, C), companyceo(D, C), economicsectorcompany(B, D) )
# %   then return 0.5553664367462839;  // std dev = 0,000, 46,000 (wgt'ed) examples reached here.  /* #pos=46 */
# %   else if ( acquired(A, E) )
# %   | then if ( economicsectorcompany(B, E) )
# %   | | then return 0.6361104136845017;  // std dev = 0,837, 5,000 (wgt'ed) examples reached here.  /* #neg=1 #pos=4 */
# %   | | else if ( companyceo(A, F) )
# %   | | | then return -0.11231637819360632;  // std dev = 2,98e-08, 50,000 (wgt'ed) examples reached here.  /* #neg=50 */
# %   | | | else return 0.030618794693564294;  // std dev = 2,767, 48,000 (wgt'ed) examples reached here.  /* #neg=38 #pos=10 */
# %   | else if ( acquired(G, A), companyalsoknownas(G, H) )
# %   | | then if ( countryhascompanyoffice(I, H), acquired(J, G) )
# %   | | | then return 0.4748716342203155;  // std dev = 0,816, 3,000 (wgt'ed) examples reached here.  /* #neg=1 #pos=2 */
# %   | | | else return -0.06327595869259856;  // std dev = 1,614, 26,000 (wgt'ed) examples reached here.  /* #neg=23 #pos=3 */
# %   | | else if ( acquired(K, A), countryhascompanyoffice(L, K) )
# %   | | | then return 0.0017779795887980336;  // std dev = 1,211, 12,000 (wgt'ed) examples reached here.  /* #neg=10 #pos=2 */
# %   | | | else return 0.13915842160507033;  // std dev = 11,281, 589,000 (wgt'ed) examples reached here.  /* #neg=396 #pos=193 */
# WILL Produced-Tree #4
# % FOR companyeconomicsector(A, B):
# %   if ( companyceo(A, C), companyceo(D, C), economicsectorcompany(B, D) )
# %   then return 0.41751358415831025;  // std dev = 0,000, 46,000 (wgt'ed) examples reached here.  /* #pos=46 */
# %   else if ( companyceo(A, E) )
# %   | then return -0.11108111612604553;  // std dev = 0,134, 85,000 (wgt'ed) examples reached here.  /* #neg=85 */
# %   | else if ( countryhascompanyoffice(F, A), bankbankincountry(G, F) )
# %   | | then if ( countryhascompanyoffice(F, H), economicsectorcompany(B, H) )
# %   | | | then return 0.3951597500767238;  // std dev = 1,814, 15,000 (wgt'ed) examples reached here.  /* #neg=5 #pos=10 */
# %   | | | else return -0.15573880070211338;  // std dev = 0,066, 27,000 (wgt'ed) examples reached here.  /* #neg=27 */
# %   | | else if ( bankchiefexecutiveceo(A, I) )
# %   | | | then return -0.013589603502278521;  // std dev = 0,906, 6,000 (wgt'ed) examples reached here.  /* #neg=5 #pos=1 */
# %   | | | else return 0.1255492169036079;  // std dev = 11,534, 600,000 (wgt'ed) examples reached here.  /* #neg=397 #pos=203 */
# WILL Produced-Tree #5
# % FOR companyeconomicsector(A, B):
# %   if ( companyceo(A, C), companyceo(D, C), economicsectorcompany(B, D) )
# %   then return 0.32071184716014944;  // std dev = 2,98e-08, 46,000 (wgt'ed) examples reached here.  /* #pos=46 */
# %   else if ( companyceo(A, E) )
# %   | then return -0.10059788103095724;  // std dev = 0,123, 85,000 (wgt'ed) examples reached here.  /* #neg=85 */
# %   | else if ( cityhascompanyoffice(F, A) )
# %   | | then if ( cityhascompanyoffice(F, G), economicsectorcompany(B, G) )
# %   | | | then return 0.4597285427625096;  // std dev = 2,886, 40,000 (wgt'ed) examples reached here.  /* #neg=12 #pos=28 */
# %   | | | else return -0.22446451871759235;  // std dev = 0,190, 52,000 (wgt'ed) examples reached here.  /* #neg=52 */
# %   | | else if ( acquired(H, A), economicsectorcompany(B, H) )
# %   | | | then return 0.7748260850969677;  // std dev = 0,042, 8,000 (wgt'ed) examples reached here.  /* #pos=8 */
# %   | | | else return 0.09172299372995565;  // std dev = 10,799, 548,000 (wgt'ed) examples reached here.  /* #neg=370 #pos=178 */
# WILL Produced-Tree #6
# % FOR companyeconomicsector(A, B):
# %   if ( companyceo(A, C), companyceo(D, C), economicsectorcompany(B, D) )
# %   then return 0.2551722425694896;  // std dev = 0,000, 46,000 (wgt'ed) examples reached here.  /* #pos=46 */
# %   else if ( countryhascompanyoffice(E, A), bankbankincountry(F, E) )
# %   | then if ( countryhascompanyoffice(E, G), economicsectorcompany(B, G) )
# %   | | then if ( companyalsoknownas(G, H) )
# %   | | | then return 0.4951423150930733;  // std dev = 0,935, 9,000 (wgt'ed) examples reached here.  /* #neg=1 #pos=8 */
# %   | | | else return -0.06310325004195287;  // std dev = 1,168, 10,000 (wgt'ed) examples reached here.  /* #neg=8 #pos=2 */
# %   | | else return -0.1181740048710399;  // std dev = 0,209, 53,000 (wgt'ed) examples reached here.  /* #neg=53 */
# %   | else if ( companyceo(A, I) )
# %   | | then return -0.09081793259839357;  // std dev = 0,072, 55,000 (wgt'ed) examples reached here.  /* #neg=55 */
# %   | | else if ( acquired(J, A), countryhascompanyoffice(K, J) )
# %   | | | then return -0.111942072884017;  // std dev = 0,938, 9,000 (wgt'ed) examples reached here.  /* #neg=8 #pos=1 */
# %   | | | else return 0.08634766980619296;  // std dev = 11,301, 597,000 (wgt'ed) examples reached here.  /* #neg=394 #pos=203 */
# WILL Produced-Tree #7
# % FOR companyeconomicsector(A, B):
# %   if ( companyceo(A, C), companyceo(D, C), economicsectorcompany(B, D) )
# %   then return 0.2097577156325355;  // std dev = 5,16e-08, 46,000 (wgt'ed) examples reached here.  /* #pos=46 */
# %   else if ( companyceo(A, E) )
# %   | then return -0.08405590480965217;  // std dev = 0,108, 85,000 (wgt'ed) examples reached here.  /* #neg=85 */
# %   | else if ( companyalsoknownas(A, F), economicsectorcompany(B, F) )
# %   | | then return 0.62106434775898;  // std dev = 0,284, 4,000 (wgt'ed) examples reached here.  /* #pos=4 */
# %   | | else if ( acquired(G, A), countryhascompanyoffice(H, G) )
# %   | | | then return -0.06623117547637179;  // std dev = 1,225, 15,000 (wgt'ed) examples reached here.  /* #neg=13 #pos=2 */
# %   | | | else return 0.062105494475429075;  // std dev = 11,387, 629,000 (wgt'ed) examples reached here.  /* #neg=421 #pos=208 */
# WILL Produced-Tree #8
# % FOR companyeconomicsector(A, B):
# %   if ( companyceo(A, C), companyceo(D, C), economicsectorcompany(B, D) )
# %   then return 0.1770964977452775;  // std dev = 0,000, 46,000 (wgt'ed) examples reached here.  /* #pos=46 */
# %   else if ( acquired(E, A), economicsectorcompany(B, E) )
# %   | then return 0.5922918215293863;  // std dev = 0,111, 10,000 (wgt'ed) examples reached here.  /* #pos=10 */
# %   | else if ( companyceo(A, F) )
# %   | | then return -0.07781692706938174;  // std dev = 0,101, 85,000 (wgt'ed) examples reached here.  /* #neg=85 */
# %   | | else if ( acquired(G, A) )
# %   | | | then return -0.0630244618739799;  // std dev = 2,859, 62,000 (wgt'ed) examples reached here.  /* #neg=50 #pos=12 */
# %   | | | else return 0.05287684270759406;  // std dev = 10,956, 576,000 (wgt'ed) examples reached here.  /* #neg=384 #pos=192 */
# WILL Produced-Tree #9
# % FOR companyeconomicsector(A, B):
# %   if ( companyceo(A, C), companyceo(D, C), economicsectorcompany(B, D) )
# %   then return 0.15274385809367083;  // std dev = 0,000, 46,000 (wgt'ed) examples reached here.  /* #pos=46 */
# %   else if ( companyceo(A, E) )
# %   | then return -0.07242135775970679;  // std dev = 0,094, 85,000 (wgt'ed) examples reached here.  /* #neg=85 */
# %   | else if ( companyalsoknownas(A, F), economicsectorcompany(B, F) )
# %   | | then return 0.4744520936105915;  // std dev = 0,259, 4,000 (wgt'ed) examples reached here.  /* #pos=4 */
# %   | | else if ( acquired(G, A), economicsectorcompany(B, G) )
# %   | | | then return 0.44627899351646166;  // std dev = 0,115, 10,000 (wgt'ed) examples reached here.  /* #pos=10 */
# %   | | | else return 0.03032082013408404;  // std dev = 11,303, 634,000 (wgt'ed) examples reached here.  /* #neg=434 #pos=200 */
# WILL Produced-Tree #10
# % FOR companyeconomicsector(A, B):
# %   if ( companyceo(A, C), companyceo(D, C), economicsectorcompany(B, D) )
# %   then return 0.13400703000801104;  // std dev = 2,79e-08, 46,000 (wgt'ed) examples reached here.  /* #pos=46 */
# %   else if ( acquired(A, E) )
# %   | then if ( companyalsoknownas(A, F), acquired(F, G) )
# %   | | then if ( companyceo(A, H) )
# %   | | | then return -0.06138641458824109;  // std dev = 0,004, 20,000 (wgt'ed) examples reached here.  /* #neg=20 */
# %   | | | else return -0.2462859880583559;  // std dev = 0,108, 4,000 (wgt'ed) examples reached here.  /* #neg=4 */
# %   | | else if ( cityhascompanyoffice(I, E) )
# %   | | | then return -0.08453402737235072;  // std dev = 1,055, 23,000 (wgt'ed) examples reached here.  /* #neg=21 #pos=2 */
# %   | | | else return 0.01749265503897112;  // std dev = 2,524, 56,000 (wgt'ed) examples reached here.  /* #neg=44 #pos=12 */
# %   | else if ( companyalsoknownas(A, J) )
# %   | | then if ( economicsectorcompany(B, J) )
# %   | | | then return 0.36651196652510576;  // std dev = 0,229, 4,000 (wgt'ed) examples reached here.  /* #pos=4 */
# %   | | | else return -0.01311504471970482;  // std dev = 2,689, 41,000 (wgt'ed) examples reached here.  /* #neg=30 #pos=11 */
# %   | | else if ( companyceo(A, K) )
# %   | | | then return -0.07460839241806914;  // std dev = 0,029, 29,000 (wgt'ed) examples reached here.  /* #neg=29 */
# %   | | | else return 0.03393887899886911;  // std dev = 10,657, 556,000 (wgt'ed) examples reached here.  /* #neg=371 #pos=185 */
#
#
# Fold 1
# {'AUC ROC': 0.767746, 'Inference time': 1.786, 'AUC PR': 0.6845, 'Recall': 0.22973, 'CLL': -0.513096, 'Learning time': 17.738, 'Precision': [0.983471, 0.5], 'F1': 0.372457}
#
#
# Fold 2
# {'AUC ROC': 0.744626, 'Inference time': 1.523, 'AUC PR': 0.656932, 'Recall': 0.19112, 'CLL': -0.524213, 'Learning time': 14.447, 'Precision': [1.0, 0.5], 'F1': 0.320908}
#
#
# Fold 3
# {'AUC ROC': 0.729432, 'Inference time': 1.283, 'AUC PR': 0.640139, 'Recall': 0.198077, 'CLL': -0.52952, 'Learning time': 7.614, 'Precision': [1.0, 0.5], 'F1': 0.330658}
#
#
# AUC ROC: 0.747 +/- 0.032
# AUC PR: 0.661 +/- 0.037
# CLL: -0.522 +/- 0.014

# %% [markdown]
# #### O nó companyceo(A, C), companyceo(D, C).  podendo aprender subárvores em ambas direções. O algoritmo não foi capaz de aprender o nó economicsectorcompany(B, D) no ramo TRUE, claúsula que mostrou uma precisão maior.

# %%
refine = ['0;;companyeconomicsector(A, B) :- companyceo(A, C), companyceo(D, C).;true;true',
          '1;;companyeconomicsector(A, B) :- companyceo(A, C), companyceo(D, C).;true;true',
          '2;;companyeconomicsector(A, B) :- companyceo(A, C), companyceo(D, C).;true;true',
          '3;;companyeconomicsector(A, B) :- companyceo(A, C), companyceo(D, C).;true;true',
          '4;;companyeconomicsector(A, B) :- companyceo(A, C), companyceo(D, C).;true;true',
          '5;;companyeconomicsector(A, B) :- companyceo(A, C), companyceo(D, C).;true;true',
          '6;;companyeconomicsector(A, B) :- companyceo(A, C), companyceo(D, C).;true;true',
          '7;;companyeconomicsector(A, B) :- companyceo(A, C), companyceo(D, C).;true;true',
          '8;;companyeconomicsector(A, B) :- companyceo(A, C), companyceo(D, C).;true;true',
          '9;;companyeconomicsector(A, B) :- companyceo(A, C), companyceo(D, C).;true;true',
         ]

# Load new predicate target dataset
tar_data = datasets.load(target, bk, target=new_target, balanced=balanced, seed=seed)
results = []

for i in range(n_folds):
    [tar_train_facts, tar_test_facts] =  [tar_data[0][0], tar_data[0][0]]
    to_folds_pos = datasets.split_into_folds(tar_data[1][0], n_folds=n_folds, seed=seed)
    to_folds_neg = datasets.split_into_folds(tar_data[2][0], n_folds=n_folds, seed=seed)
    [tar_train_pos, tar_test_pos] =  datasets.get_kfold_small(i, to_folds_pos)
    [tar_train_neg, tar_test_neg] =  datasets.get_kfold_small(i, to_folds_neg)
    
    [model, t_results, structured, will, variances] = revision.learn_test_model(background, boostsrl, new_target, tar_train_pos, tar_train_neg, tar_train_facts, tar_test_pos, tar_test_neg, tar_test_facts, refine=refine, trees=10, print_function=None)
    results.append(t_results)
    
    if i == 0:
        for line in will:
            print(line)
    print('\n')
    print('Fold ' + str(i+1))
    print(t_results)
print('\n')
auc_roc = np.array([item['AUC ROC'] for item in results])
auc_pr = np.array([item['AUC PR'] for item in results])
cll = np.array([item['CLL'] for item in results])
print('AUC ROC: %.3f +/- %.3f' % (auc_roc.mean(), 2 * auc_roc.std()))
print('AUC PR: %.3f +/- %.3f' % (auc_pr.mean(), 2 * auc_pr.std()))
print('CLL: %.3f +/- %.3f' % (cll.mean(), 2 * cll.std()))
# Out:
# WILL Produced-Tree #1
# % FOR companyeconomicsector(A, B):
# %   if ( companyceo(A, C), companyceo(D, C) )
# %   then if ( acquired(E, A), companyceo(E, F) )
# %   | then if ( economicsectorcompany(B, E) )
# %   | | then return 0.8581489350995122;  // std dev = 0,000, 5,000 (wgt'ed) examples reached here.  /* #pos=5 */
# %   | | else if ( cityhascompanyoffice(G, E) )
# %   | | | then return 0.13087620782678497;  // std dev = 1,477, 11,000 (wgt'ed) examples reached here.  /* #neg=8 #pos=3 */
# %   | | | else return 0.5248156017661788;  // std dev = 0,816, 3,000 (wgt'ed) examples reached here.  /* #neg=1 #pos=2 */
# %   | else if ( acquired(A, H), economicsectorcompany(B, H) )
# %   | | then return 0.7152917922423694;  // std dev = 0,350, 7,000 (wgt'ed) examples reached here.  /* #neg=1 #pos=6 */
# %   | | else return 0.14386322081379807;  // std dev = 0,452, 105,000 (wgt'ed) examples reached here.  /* #neg=75 #pos=30 */
# %   else if ( acquired(A, I), cityhascompanyoffice(J, I) )
# %   | then return -0.0168510649004878;  // std dev = 0,331, 16,000 (wgt'ed) examples reached here.  /* #neg=14 #pos=2 */
# %   | else if ( acquired(K, A), companyalsoknownas(K, L) )
# %   | | then return 0.08891816586874314;  // std dev = 0,421, 26,000 (wgt'ed) examples reached here.  /* #neg=20 #pos=6 */
# %   | | else if ( countryhascompanyoffice(M, A), bankbankincountry(N, M) )
# %   | | | then return 0.12130682983635446;  // std dev = 2,714, 38,000 (wgt'ed) examples reached here.  /* #neg=28 #pos=10 */
# %   | | | else return 0.20321935763471913;  // std dev = 11,330, 568,000 (wgt'ed) examples reached here.  /* #neg=372 #pos=196 */
# WILL Produced-Tree #2
# % FOR companyeconomicsector(A, B):
# %   if ( companyceo(A, C), companyceo(D, C) )
# %   then if ( companyalsoknownas(A, E), economicsectorcompany(B, E) )
# %   | then return 0.8408788865384285;  // std dev = 0,001, 3,000 (wgt'ed) examples reached here.  /* #pos=3 */
# %   | else if ( acquired(A, F), economicsectorcompany(B, F) )
# %   | | then return 0.6045267906174348;  // std dev = 0,350, 7,000 (wgt'ed) examples reached here.  /* #neg=1 #pos=6 */
# %   | | else if ( acquired(G, A), economicsectorcompany(B, G) )
# %   | | | then return 0.739514298464945;  // std dev = 0,110, 6,000 (wgt'ed) examples reached here.  /* #pos=6 */
# %   | | | else return 0.10790475361636612;  // std dev = 4,744, 115,000 (wgt'ed) examples reached here.  /* #neg=84 #pos=31 */
# %   else if ( countryhascompanyoffice(H, A), bankbankincountry(I, H) )
# %   | then return 0.08217460944721358;  // std dev = 0,425, 42,000 (wgt'ed) examples reached here.  /* #neg=32 #pos=10 */
# %   | else if ( cityhascompanyoffice(J, A) )
# %   | | then if ( cityhascompanyoffice(J, K), economicsectorcompany(B, K) )
# %   | | | then return 0.5250045824384324;  // std dev = 2,887, 39,000 (wgt'ed) examples reached here.  /* #neg=12 #pos=27 */
# %   | | | else return -0.16578126636742196;  // std dev = 0,056, 49,000 (wgt'ed) examples reached here.  /* #neg=49 */
# %   | | else if ( acquired(L, A), economicsectorcompany(B, L) )
# %   | | | then return 0.8354201034362729;  // std dev = 0,019, 8,000 (wgt'ed) examples reached here.  /* #pos=8 */
# %   | | | else return 0.16402391460145405;  // std dev = 10,620, 510,000 (wgt'ed) examples reached here.  /* #neg=341 #pos=169 */
# WILL Produced-Tree #3
# % FOR companyeconomicsector(A, B):
# %   if ( companyceo(A, C), companyceo(D, C) )
# %   then if ( acquired(E, A), economicsectorcompany(B, E) )
# %   | then return 0.5777358339889433;  // std dev = 0,150, 6,000 (wgt'ed) examples reached here.  /* #pos=6 */
# %   | else if ( acquired(A, F), economicsectorcompany(B, F) )
# %   | | then if ( companyalsoknownas(A, G) )
# %   | | | then return 0.6177907128699047;  // std dev = 0,000, 4,000 (wgt'ed) examples reached here.  /* #pos=4 */
# %   | | | else return 0.2844573795365714;  // std dev = 0,816, 3,000 (wgt'ed) examples reached here.  /* #neg=1 #pos=2 */
# %   | | else if ( bankchiefexecutiveceo(A, H), acquired(A, I) )
# %   | | | then return -0.17534176529818776;  // std dev = 0,000, 5,000 (wgt'ed) examples reached here.  /* #neg=5 */
# %   | | | else return 0.12060545042203956;  // std dev = 4,811, 113,000 (wgt'ed) examples reached here.  /* #neg=79 #pos=34 */
# %   else if ( cityhascompanyoffice(J, A), acquired(K, A) )
# %   | then return 0.25987994756054184;  // std dev = 0,464, 11,000 (wgt'ed) examples reached here.  /* #neg=6 #pos=5 */
# %   | else if ( acquired(A, L), countryhascompanyoffice(M, A) )
# %   | | then return -0.1592295716815713;  // std dev = 0,023, 6,000 (wgt'ed) examples reached here.  /* #neg=6 */
# %   | | else if ( acquired(N, A), companyalsoknownas(N, P) )
# %   | | | then return 0.02342171147076695;  // std dev = 1,898, 24,000 (wgt'ed) examples reached here.  /* #neg=19 #pos=5 */
# %   | | | else return 0.14403040370466375;  // std dev = 11,478, 607,000 (wgt'ed) examples reached here.  /* #neg=403 #pos=204 */
# WILL Produced-Tree #4
# % FOR companyeconomicsector(A, B):
# %   if ( companyceo(A, C), companyceo(D, C) )
# %   then if ( acquired(E, A), companyceo(E, F) )
# %   | then return 0.20385779555621034;  // std dev = 0,400, 19,000 (wgt'ed) examples reached here.  /* #neg=9 #pos=10 */
# %   | else if ( acquired(A, G), economicsectorcompany(B, G) )
# %   | | then return 0.35841909290742346;  // std dev = 0,333, 7,000 (wgt'ed) examples reached here.  /* #neg=1 #pos=6 */
# %   | | else if ( acquired(A, H), bankchiefexecutiveceo(A, I) )
# %   | | | then return -0.15141140931835714;  // std dev = 0,000, 5,000 (wgt'ed) examples reached here.  /* #neg=5 */
# %   | | | else return 0.10290982586729931;  // std dev = 4,534, 100,000 (wgt'ed) examples reached here.  /* #neg=70 #pos=30 */
# %   else if ( acquired(J, A), economicsectorcompany(B, J) )
# %   | then return 0.6708556741902669;  // std dev = 0,084, 10,000 (wgt'ed) examples reached here.  /* #pos=10 */
# %   | else if ( countryhascompanyoffice(K, A), bankbankincountry(L, K) )
# %   | | then if ( countryhascompanyoffice(K, M), economicsectorcompany(B, M) )
# %   | | | then return 0.47731161161804264;  // std dev = 1,814, 15,000 (wgt'ed) examples reached here.  /* #neg=5 #pos=10 */
# %   | | | else return -0.1783839916833948;  // std dev = 0,111, 27,000 (wgt'ed) examples reached here.  /* #neg=27 */
# %   | | else if ( acquired(N, A) )
# %   | | | then return -0.013666738835191202;  // std dev = 2,784, 53,000 (wgt'ed) examples reached here.  /* #neg=43 #pos=10 */
# %   | | | else return 0.12341648080559892;  // std dev = 10,898, 543,000 (wgt'ed) examples reached here.  /* #neg=359 #pos=184 */
# WILL Produced-Tree #5
# % FOR companyeconomicsector(A, B):
# %   if ( companyceo(A, C), companyceo(D, C) )
# %   then if ( countryhascompanyoffice(E, A), bankbankincountry(F, E) )
# %   | then if ( countryhascompanyoffice(E, G), economicsectorcompany(B, G) )
# %   | | then if ( companyalsoknownas(G, H) )
# %   | | | then return 0.7094865836274074;  // std dev = 0,400, 9,000 (wgt'ed) examples reached here.  /* #pos=9 */
# %   | | | else return -0.10697950097824385;  // std dev = 0,808, 5,000 (wgt'ed) examples reached here.  /* #neg=4 #pos=1 */
# %   | | else return -0.20468189759879254;  // std dev = 0,107, 26,000 (wgt'ed) examples reached here.  /* #neg=26 */
# %   | else if ( acquired(A, I), countryhascompanyoffice(J, I) )
# %   | | then if ( companyceo(I, K) )
# %   | | | then return 0.45663204697152265;  // std dev = 0,816, 3,000 (wgt'ed) examples reached here.  /* #neg=1 #pos=2 */
# %   | | | else return 0.289965380304856;  // std dev = 1,000, 4,000 (wgt'ed) examples reached here.  /* #neg=2 #pos=2 */
# %   | | else if ( acquired(L, A), economicsectorcompany(B, L) )
# %   | | | then return 0.3591036073738102;  // std dev = 0,000, 5,000 (wgt'ed) examples reached here.  /* #pos=5 */
# %   | | | else return 0.10261718982456619;  // std dev = 3,944, 79,000 (wgt'ed) examples reached here.  /* #neg=52 #pos=27 */
# %   else return 0.09502459619675299;  // std dev = 0,456, 648,000 (wgt'ed) examples reached here.  /* #neg=434 #pos=214 */
# WILL Produced-Tree #6
# % FOR companyeconomicsector(A, B):
# %   if ( companyceo(A, C), companyceo(D, C) )
# %   then if ( countryhascompanyoffice(E, A), bankbankincountry(F, E) )
# %   | then return 0.002486771447800743;  // std dev = 0,335, 40,000 (wgt'ed) examples reached here.  /* #neg=30 #pos=10 */
# %   | else if ( acquired(G, A), economicsectorcompany(B, G) )
# %   | | then return 0.2812316388401014;  // std dev = 7,45e-09, 5,000 (wgt'ed) examples reached here.  /* #pos=5 */
# %   | | else if ( acquired(A, H), countryhascompanyoffice(I, H) )
# %   | | | then return 0.2949121522614;  // std dev = 1,303, 7,000 (wgt'ed) examples reached here.  /* #neg=3 #pos=4 */
# %   | | | else return 0.0844360895857446;  // std dev = 3,939, 79,000 (wgt'ed) examples reached here.  /* #neg=52 #pos=27 */
# %   else if ( cityhascompanyoffice(J, A) )
# %   | then if ( cityhascompanyoffice(J, K), economicsectorcompany(B, K) )
# %   | | then return 0.36484170204959543;  // std dev = 0,456, 40,000 (wgt'ed) examples reached here.  /* #neg=12 #pos=28 */
# %   | | else return -0.1934463253696562;  // std dev = 0,071, 52,000 (wgt'ed) examples reached here.  /* #neg=52 */
# %   | else if ( companyalsoknownas(A, L), countryhascompanyoffice(M, L) )
# %   | | then return -0.23145320781735998;  // std dev = 0,106, 6,000 (wgt'ed) examples reached here.  /* #neg=6 */
# %   | | else if ( acquired(A, N) )
# %   | | | then return 0.028739308051785623;  // std dev = 2,584, 38,000 (wgt'ed) examples reached here.  /* #neg=28 #pos=10 */
# %   | | | else return 0.09007121754068072;  // std dev = 10,575, 512,000 (wgt'ed) examples reached here.  /* #neg=336 #pos=176 */
# WILL Produced-Tree #7
# % FOR companyeconomicsector(A, B):
# %   if ( companyceo(A, C), companyceo(D, C) )
# %   then if ( companyalsoknownas(A, E), economicsectorcompany(B, E) )
# %   | then return 0.49888148640566565;  // std dev = 0,099, 3,000 (wgt'ed) examples reached here.  /* #pos=3 */
# %   | else if ( countryhascompanyoffice(F, A), bankbankincountry(G, F) )
# %   | | then if ( countryhascompanyoffice(F, H), economicsectorcompany(B, H) )
# %   | | | then return 0.30694939638890467;  // std dev = 1,463, 12,000 (wgt'ed) examples reached here.  /* #neg=4 #pos=8 */
# %   | | | else return -0.17379362766343898;  // std dev = 0,093, 26,000 (wgt'ed) examples reached here.  /* #neg=26 */
# %   | | else if ( acquired(A, I), companyceo(I, J) )
# %   | | | then return 0.18322560398255644;  // std dev = 1,813, 15,000 (wgt'ed) examples reached here.  /* #neg=8 #pos=7 */
# %   | | | else return 0.06500248890420185;  // std dev = 3,709, 75,000 (wgt'ed) examples reached here.  /* #neg=47 #pos=28 */
# %   else if ( acquired(A, K), economicsectorcompany(B, K) )
# %   | then return 0.7237753524605739;  // std dev = 0,105, 4,000 (wgt'ed) examples reached here.  /* #pos=4 */
# %   | else if ( acquired(A, L), cityhascompanyoffice(M, L) )
# %   | | then return -0.17551075506618408;  // std dev = 0,160, 14,000 (wgt'ed) examples reached here.  /* #neg=14 */
# %   | | else if ( companyalsoknownas(A, N), economicsectorcompany(B, N) )
# %   | | | then return 0.695002532155742;  // std dev = 0,111, 4,000 (wgt'ed) examples reached here.  /* #pos=4 */
# %   | | | else return 0.058135059620895775;  // std dev = 11,296, 626,000 (wgt'ed) examples reached here.  /* #neg=420 #pos=206 */
# WILL Produced-Tree #8
# % FOR companyeconomicsector(A, B):
# %   if ( companyceo(A, C), companyceo(D, C) )
# %   then if ( countryhascompanyoffice(E, A), bankbankincountry(F, E) )
# %   | then return -0.008072891144219174;  // std dev = 0,300, 40,000 (wgt'ed) examples reached here.  /* #neg=30 #pos=10 */
# %   | else if ( acquired(G, A), companyalsoknownas(A, H) )
# %   | | then return -0.050428021820800126;  // std dev = 0,277, 8,000 (wgt'ed) examples reached here.  /* #neg=5 #pos=3 */
# %   | | else if ( acquired(I, A), cityhascompanyoffice(J, I) )
# %   | | | then return -0.025341393654137533;  // std dev = 1,053, 10,000 (wgt'ed) examples reached here.  /* #neg=6 #pos=4 */
# %   | | | else return 0.09930612156421065;  // std dev = 3,909, 73,000 (wgt'ed) examples reached here.  /* #neg=44 #pos=29 */
# %   else if ( acquired(K, A), countryhascompanyoffice(L, K) )
# %   | then if ( companyalsoknownas(K, M) )
# %   | | then return -0.23056239616724583;  // std dev = 0,069, 5,000 (wgt'ed) examples reached here.  /* #neg=5 */
# %   | | else return -0.035923537296677646;  // std dev = 0,374, 10,000 (wgt'ed) examples reached here.  /* #neg=8 #pos=2 */
# %   | else if ( acquired(A, N), companyalsoknownas(A, P) )
# %   | | then return -0.09021052477981081;  // std dev = 0,277, 7,000 (wgt'ed) examples reached here.  /* #neg=6 #pos=1 */
# %   | | else if ( acquired(A, Q), cityhascompanyoffice(R, Q) )
# %   | | | then return -0.057473895302007395;  // std dev = 0,935, 15,000 (wgt'ed) examples reached here.  /* #neg=13 #pos=2 */
# %   | | | else return 0.05649591174044619;  // std dev = 11,244, 611,000 (wgt'ed) examples reached here.  /* #neg=402 #pos=209 */
# WILL Produced-Tree #9
# % FOR companyeconomicsector(A, B):
# %   if ( companyceo(A, C), companyceo(D, C) )
# %   then if ( acquired(A, E), economicsectorcompany(B, E) )
# %   | then if ( companyalsoknownas(A, F) )
# %   | | then return 0.2703359187584067;  // std dev = 0,103, 4,000 (wgt'ed) examples reached here.  /* #pos=4 */
# %   | | else return 0.04430118950267407;  // std dev = 0,775, 3,000 (wgt'ed) examples reached here.  /* #neg=1 #pos=2 */
# %   | else if ( bankboughtbank(G, A), cityhascompanyoffice(H, G) )
# %   | | then return -0.16978058616930508;  // std dev = 0,130, 4,000 (wgt'ed) examples reached here.  /* #neg=4 */
# %   | | else if ( acquired(A, I), cityhascompanyoffice(J, I) )
# %   | | | then return -0.09028486390816733;  // std dev = 1,149, 12,000 (wgt'ed) examples reached here.  /* #neg=10 #pos=2 */
# %   | | | else return 0.05121587646869995;  // std dev = 4,280, 108,000 (wgt'ed) examples reached here.  /* #neg=70 #pos=38 */
# %   else if ( acquired(A, K), cityhascompanyoffice(L, K) )
# %   | then return -0.05632856482359067;  // std dev = 0,237, 16,000 (wgt'ed) examples reached here.  /* #neg=14 #pos=2 */
# %   | else if ( bankboughtbank(A, M) )
# %   | | then return 0.24030785311463593;  // std dev = 0,899, 4,000 (wgt'ed) examples reached here.  /* #neg=2 #pos=2 */
# %   | | else if ( cityhascompanyoffice(N, A) )
# %   | | | then return 0.00557550897906859;  // std dev = 3,454, 87,000 (wgt'ed) examples reached here.  /* #neg=60 #pos=27 */
# %   | | | else return 0.04522580848633894;  // std dev = 10,750, 541,000 (wgt'ed) examples reached here.  /* #neg=358 #pos=183 */
# WILL Produced-Tree #10
# % FOR companyeconomicsector(A, B):
# %   if ( companyceo(A, C), companyceo(D, C) )
# %   then if ( countryhascompanyoffice(E, A), bankbankincountry(F, E) )
# %   | then return -0.011439310999101237;  // std dev = 0,298, 40,000 (wgt'ed) examples reached here.  /* #neg=30 #pos=10 */
# %   | else if ( acquired(A, G), companyceo(G, H) )
# %   | | then if ( companyalsoknownas(A, I) )
# %   | | | then return -0.00980802706668222;  // std dev = 1,312, 9,000 (wgt'ed) examples reached here.  /* #neg=6 #pos=3 */
# %   | | | else return 0.32443029678927343;  // std dev = 1,041, 6,000 (wgt'ed) examples reached here.  /* #neg=2 #pos=4 */
# %   | | else return 0.03391628792625611;  // std dev = 0,424, 76,000 (wgt'ed) examples reached here.  /* #neg=47 #pos=29 */
# %   else if ( acquired(J, A), countryhascompanyoffice(K, J) )
# %   | then return -0.09155045435005153;  // std dev = 0,315, 15,000 (wgt'ed) examples reached here.  /* #neg=13 #pos=2 */
# %   | else if ( acquired(L, A), acquired(M, L) )
# %   | | then if ( companyalsoknownas(A, N) )
# %   | | | then return -0.2028065940495564;  // std dev = 0,067, 4,000 (wgt'ed) examples reached here.  /* #neg=4 */
# %   | | | else return 0.2552392818355706;  // std dev = 1,337, 10,000 (wgt'ed) examples reached here.  /* #neg=4 #pos=6 */
# %   | | else if ( companyalsoknownas(A, P), companyceo(P, Q) )
# %   | | | then return 0.23537679545980675;  // std dev = 1,372, 11,000 (wgt'ed) examples reached here.  /* #neg=5 #pos=6 */
# %   | | | else return 0.027676979891060643;  // std dev = 11,083, 608,000 (wgt'ed) examples reached here.  /* #neg=408 #pos=200 */
#
#
# Fold 1
# {'AUC ROC': 0.666437, 'Inference time': 1.88, 'AUC PR': 0.548302, 'Recall': 0.084942, 'CLL': -0.588754, 'Learning time': 47.553, 'Precision': [0.93617, 0.5], 'F1': 0.155752}
#
#
# Fold 2
# {'AUC ROC': 0.681348, 'Inference time': 1.637, 'AUC PR': 0.564893, 'Recall': 0.169884, 'CLL': -0.574717, 'Learning time': 16.666, 'Precision': [0.778761, 0.5], 'F1': 0.278922}
#
#
# Fold 3
# {'AUC ROC': 0.672532, 'Inference time': 1.502, 'AUC PR': 0.562604, 'Recall': 0.092308, 'CLL': -0.59023, 'Learning time': 55.895, 'Precision': [0.96, 0.5], 'F1': 0.168421}
#
#
# AUC ROC: 0.673 +/- 0.012
# AUC PR: 0.559 +/- 0.015
# CLL: -0.585 +/- 0.014

# %%
refine = ['0;;companyeconomicsector(A, B) :- companyceo(A, C), companyceo(D, C).;true;false',
          '0;true;economicsectorcompany(B, D).;false;false',
          '1;;companyeconomicsector(A, B) :- companyceo(A, C), companyceo(D, C).;true;false',
          '1;true;economicsectorcompany(B, D).;false;false',
          '2;;companyeconomicsector(A, B) :- companyceo(A, C), companyceo(D, C).;true;false',
          '2;true;economicsectorcompany(B, D).;false;false',
          '3;;companyeconomicsector(A, B) :- companyceo(A, C), companyceo(D, C).;true;false',
          '3;true;economicsectorcompany(B, D).;false;false',
          '4;;companyeconomicsector(A, B) :- companyceo(A, C), companyceo(D, C).;true;false',
          '4;true;economicsectorcompany(B, D).;false;false',
          '5;;companyeconomicsector(A, B) :- companyceo(A, C), companyceo(D, C).;true;false',
          '5;true;economicsectorcompany(B, D).;false;false',
          '6;;companyeconomicsector(A, B) :- companyceo(A, C), companyceo(D, C).;true;false',
          '6;true;economicsectorcompany(B, D).;false;false',
          '7;;companyeconomicsector(A, B) :- companyceo(A, C), companyceo(D, C).;true;false',
          '7;true;economicsectorcompany(B, D).;false;false',
          '8;;companyeconomicsector(A, B) :- companyceo(A, C), companyceo(D, C).;true;false',
          '8;true;economicsectorcompany(B, D).;false;false',
          '9;;companyeconomicsector(A, B) :- companyceo(A, C), companyceo(D, C).;true;false',
          '9;true;economicsectorcompany(B, D).;false;false',
         ]

# Load new predicate target dataset
tar_data = datasets.load(target, bk, target=new_target, balanced=balanced, seed=seed)
results = []

for i in range(n_folds):
    [tar_train_facts, tar_test_facts] =  [tar_data[0][0], tar_data[0][0]]
    to_folds_pos = datasets.split_into_folds(tar_data[1][0], n_folds=n_folds, seed=seed)
    to_folds_neg = datasets.split_into_folds(tar_data[2][0], n_folds=n_folds, seed=seed)
    [tar_train_pos, tar_test_pos] =  datasets.get_kfold_small(i, to_folds_pos)
    [tar_train_neg, tar_test_neg] =  datasets.get_kfold_small(i, to_folds_neg)
    
    [model, t_results, structured, will, variances] = revision.learn_test_model(background, boostsrl, new_target, tar_train_pos, tar_train_neg, tar_train_facts, tar_test_pos, tar_test_neg, tar_test_facts, refine=refine, trees=10, print_function=None)
    results.append(t_results)
    
    if i == 0:
        for line in will:
            print(line)
    print('\n')
    print('Fold ' + str(i+1))
    print(t_results)
print('\n')
auc_roc = np.array([item['AUC ROC'] for item in results])
auc_pr = np.array([item['AUC PR'] for item in results])
cll = np.array([item['CLL'] for item in results])
print('AUC ROC: %.3f +/- %.3f' % (auc_roc.mean(), 2 * auc_roc.std()))
print('AUC PR: %.3f +/- %.3f' % (auc_pr.mean(), 2 * auc_pr.std()))
print('CLL: %.3f +/- %.3f' % (cll.mean(), 2 * cll.std()))
# Out:
# WILL Produced-Tree #1
# % FOR companyeconomicsector(A, B):
# %   if ( companyceo(A, C), companyceo(D, C) )
# %   then if ( economicsectorcompany(B, D) )
# %   | then return 0.8581489350995121;  // std dev = 2,06e-07, 46,000 (wgt'ed) examples reached here.  /* #pos=46 */
# %   | else return -0.14185106490048766;  // std dev = 7,88e-08, 85,000 (wgt'ed) examples reached here.  /* #neg=85 */
# %   else return 0.18839584867975465;  // std dev = 11,972, 648,000 (wgt'ed) examples reached here.  /* #neg=434 #pos=214 */
# WILL Produced-Tree #2
# % FOR companyeconomicsector(A, B):
# %   if ( companyceo(A, C), companyceo(D, C) )
# %   then if ( economicsectorcompany(B, D) )
# %   | then return 0.719473412210955;  // std dev = 0,000, 46,000 (wgt'ed) examples reached here.  /* #pos=46 */
# %   | else return -0.12544463852839144;  // std dev = 0,000, 85,000 (wgt'ed) examples reached here.  /* #neg=85 */
# %   else return 0.16388089621524768;  // std dev = 11,972, 648,000 (wgt'ed) examples reached here.  /* #neg=434 #pos=214 */
# WILL Produced-Tree #3
# % FOR companyeconomicsector(A, B):
# %   if ( companyceo(A, C), companyceo(D, C) )
# %   then if ( economicsectorcompany(B, D) )
# %   | then return 0.5553664367462839;  // std dev = 0,000, 46,000 (wgt'ed) examples reached here.  /* #pos=46 */
# %   | else return -0.11231637819360622;  // std dev = 6,99e-08, 85,000 (wgt'ed) examples reached here.  /* #neg=85 */
# %   else return 0.1398947069888196;  // std dev = 11,972, 648,000 (wgt'ed) examples reached here.  /* #neg=434 #pos=214 */
# WILL Produced-Tree #4
# % FOR companyeconomicsector(A, B):
# %   if ( companyceo(A, C), companyceo(D, C) )
# %   then if ( economicsectorcompany(B, D) )
# %   | then return 0.41751358415831025;  // std dev = 0,000, 46,000 (wgt'ed) examples reached here.  /* #pos=46 */
# %   | else return -0.10159632948783619;  // std dev = 5,58e-08, 85,000 (wgt'ed) examples reached here.  /* #neg=85 */
# %   else return 0.11739648012954447;  // std dev = 11,972, 648,000 (wgt'ed) examples reached here.  /* #neg=434 #pos=214 */
# WILL Produced-Tree #5
# % FOR companyeconomicsector(A, B):
# %   if ( companyceo(A, C), companyceo(D, C) )
# %   then if ( economicsectorcompany(B, D) )
# %   | then return 0.32071184716014944;  // std dev = 2,98e-08, 46,000 (wgt'ed) examples reached here.  /* #pos=46 */
# %   | else return -0.09269127618926107;  // std dev = 0,000, 85,000 (wgt'ed) examples reached here.  /* #neg=85 */
# %   else return 0.09706524391841498;  // std dev = 11,972, 648,000 (wgt'ed) examples reached here.  /* #neg=434 #pos=214 */
# WILL Produced-Tree #6
# % FOR companyeconomicsector(A, B):
# %   if ( companyceo(A, C), companyceo(D, C) )
# %   then if ( economicsectorcompany(B, D) )
# %   | then return 0.2551722425694896;  // std dev = 0,000, 46,000 (wgt'ed) examples reached here.  /* #pos=46 */
# %   | else return -0.08518475138839679;  // std dev = 3,16e-08, 85,000 (wgt'ed) examples reached here.  /* #neg=85 */
# %   else return 0.07926209977436628;  // std dev = 11,972, 648,000 (wgt'ed) examples reached here.  /* #neg=434 #pos=214 */
# WILL Produced-Tree #7
# % FOR companyeconomicsector(A, B):
# %   if ( companyceo(A, C), companyceo(D, C) )
# %   then if ( economicsectorcompany(B, D) )
# %   | then return 0.2097577156325355;  // std dev = 5,16e-08, 46,000 (wgt'ed) examples reached here.  /* #pos=46 */
# %   | else return -0.07877675473109162;  // std dev = 4,71e-08, 85,000 (wgt'ed) examples reached here.  /* #neg=85 */
# %   else return 0.06406959523642201;  // std dev = 11,972, 648,000 (wgt'ed) examples reached here.  /* #neg=434 #pos=214 */
# WILL Produced-Tree #8
# % FOR companyeconomicsector(A, B):
# %   if ( companyceo(A, C), companyceo(D, C) )
# %   then if ( economicsectorcompany(B, D) )
# %   | then return 0.1770964977452775;  // std dev = 0,000, 46,000 (wgt'ed) examples reached here.  /* #pos=46 */
# %   | else return -0.07324622576333707;  // std dev = 0,000, 85,000 (wgt'ed) examples reached here.  /* #neg=85 */
# %   else return 0.0513691562854553;  // std dev = 11,972, 648,000 (wgt'ed) examples reached here.  /* #neg=434 #pos=214 */
# WILL Produced-Tree #9
# % FOR companyeconomicsector(A, B):
# %   if ( companyceo(A, C), companyceo(D, C) )
# %   then if ( economicsectorcompany(B, D) )
# %   | then return 0.15274385809367083;  // std dev = 0,000, 46,000 (wgt'ed) examples reached here.  /* #pos=46 */
# %   | else return -0.06842697784420267;  // std dev = 4,01e-08, 85,000 (wgt'ed) examples reached here.  /* #neg=85 */
# %   else return 0.04092219607161286;  // std dev = 11,972, 648,000 (wgt'ed) examples reached here.  /* #neg=434 #pos=214 */
# WILL Produced-Tree #10
# % FOR companyeconomicsector(A, B):
# %   if ( companyceo(A, C), companyceo(D, C) )
# %   then if ( economicsectorcompany(B, D) )
# %   | then return 0.13400703000801104;  // std dev = 2,79e-08, 46,000 (wgt'ed) examples reached here.  /* #pos=46 */
# %   | else return -0.06419184008202625;  // std dev = 0,000, 85,000 (wgt'ed) examples reached here.  /* #neg=85 */
# %   else return 0.03243596277587064;  // std dev = 11,972, 648,000 (wgt'ed) examples reached here.  /* #neg=434 #pos=214 */
#
#
# Fold 1
# {'AUC ROC': 0.642047, 'Inference time': 1.281, 'AUC PR': 0.531666, 'Recall': 0.150579, 'CLL': -0.553443, 'Learning time': 5.196, 'Precision': [1.0, 0.5], 'F1': 0.261745}
#
#
# Fold 2
# {'AUC ROC': 0.652593, 'Inference time': 1.3, 'AUC PR': 0.549724, 'Recall': 0.171815, 'CLL': -0.544434, 'Learning time': 5.182, 'Precision': [1.0, 0.5], 'F1': 0.293245}
#
#
# Fold 3
# {'AUC ROC': 0.645391, 'Inference time': 1.115, 'AUC PR': 0.537143, 'Recall': 0.155769, 'CLL': -0.55142, 'Learning time': 4.52, 'Precision': [1.0, 0.5], 'F1': 0.269551}
#
#
# AUC ROC: 0.647 +/- 0.009
# AUC PR: 0.540 +/- 0.015
# CLL: -0.550 +/- 0.008

# %% [markdown]
# #### Este padrão com o nó raiz companyceo(A, C), companyceo(D, C) e seu nó TRUE como economicsectorcompany(B, D) apresentou um resultado melhor.

# %%
refine = ['0;;companyeconomicsector(A, B) :- companyceo(A, C), companyceo(D, C).;true;true',
          '0;true;economicsectorcompany(B, D).;true;true',
          '1;;companyeconomicsector(A, B) :- companyceo(A, C), companyceo(D, C).;true;true',
          '1;true;economicsectorcompany(B, D).;true;true',
          '2;;companyeconomicsector(A, B) :- companyceo(A, C), companyceo(D, C).;true;true',
          '2;true;economicsectorcompany(B, D).;true;true',
          '3;;companyeconomicsector(A, B) :- companyceo(A, C), companyceo(D, C).;true;true',
          '3;true;economicsectorcompany(B, D).;true;true',
          '4;;companyeconomicsector(A, B) :- companyceo(A, C), companyceo(D, C).;true;true',
          '4;true;economicsectorcompany(B, D).;true;true',
          '5;;companyeconomicsector(A, B) :- companyceo(A, C), companyceo(D, C).;true;true',
          '5;true;economicsectorcompany(B, D).;true;true',
          '6;;companyeconomicsector(A, B) :- companyceo(A, C), companyceo(D, C).;true;true',
          '6;true;economicsectorcompany(B, D).;true;true',
          '7;;companyeconomicsector(A, B) :- companyceo(A, C), companyceo(D, C).;true;true',
          '7;true;economicsectorcompany(B, D).;true;true',
          '8;;companyeconomicsector(A, B) :- companyceo(A, C), companyceo(D, C).;true;true',
          '8;true;economicsectorcompany(B, D).;true;true',
          '9;;companyeconomicsector(A, B) :- companyceo(A, C), companyceo(D, C).;true;true',
          '9;true;economicsectorcompany(B, D).;true;true',
         ]

# Load new predicate target dataset
tar_data = datasets.load(target, bk, target=new_target, balanced=balanced, seed=seed)
results = []

for i in range(n_folds):
    [tar_train_facts, tar_test_facts] =  [tar_data[0][0], tar_data[0][0]]
    to_folds_pos = datasets.split_into_folds(tar_data[1][0], n_folds=n_folds, seed=seed)
    to_folds_neg = datasets.split_into_folds(tar_data[2][0], n_folds=n_folds, seed=seed)
    [tar_train_pos, tar_test_pos] =  datasets.get_kfold_small(i, to_folds_pos)
    [tar_train_neg, tar_test_neg] =  datasets.get_kfold_small(i, to_folds_neg)
    
    [model, t_results, structured, will, variances] = revision.learn_test_model(background, boostsrl, new_target, tar_train_pos, tar_train_neg, tar_train_facts, tar_test_pos, tar_test_neg, tar_test_facts, refine=refine, trees=10, print_function=None)
    results.append(t_results)
    
    if i == 0:
        for line in will:
            print(line)
    print('\n')
    print('Fold ' + str(i+1))
    print(t_results)
print('\n')
auc_roc = np.array([item['AUC ROC'] for item in results])
auc_pr = np.array([item['AUC PR'] for item in results])
cll = np.array([item['CLL'] for item in results])
print('AUC ROC: %.3f +/- %.3f' % (auc_roc.mean(), 2 * auc_roc.std()))
print('AUC PR: %.3f +/- %.3f' % (auc_pr.mean(), 2 * auc_pr.std()))
print('CLL: %.3f +/- %.3f' % (cll.mean(), 2 * cll.std()))
# Out:
# WILL Produced-Tree #1
# % FOR companyeconomicsector(A, B):
# %   if ( companyceo(A, C), companyceo(D, C) )
# %   then if ( economicsectorcompany(B, D) )
# %   | then return 0.8581489350995121;  // std dev = 2,06e-07, 46,000 (wgt'ed) examples reached here.  /* #pos=46 */
# %   | else return -0.14185106490048766;  // std dev = 7,88e-08, 85,000 (wgt'ed) examples reached here.  /* #neg=85 */
# %   else if ( cityhascompanyoffice(E, A) )
# %   | then if ( cityhascompanyoffice(E, F), economicsectorcompany(B, F) )
# %   | | then if ( companyalsoknownas(F, G), economicsectorcompany(B, G) )
# %   | | | then return 0.8581489350995123;  // std dev = 0,000, 17,000 (wgt'ed) examples reached here.  /* #pos=17 */
# %   | | | else return 0.3364098046647297;  // std dev = 2,396, 23,000 (wgt'ed) examples reached here.  /* #neg=12 #pos=11 */
# %   | | else return -0.14185106490048766;  // std dev = 5,37e-08, 52,000 (wgt'ed) examples reached here.  /* #neg=52 */
# %   | else if ( acquired(A, H) )
# %   | | then if ( economicsectorcompany(B, H) )
# %   | | | then return 0.8581489350995121;  // std dev = 2,11e-08, 3,000 (wgt'ed) examples reached here.  /* #pos=3 */
# %   | | | else return 0.03763611458669184;  // std dev = 2,397, 39,000 (wgt'ed) examples reached here.  /* #neg=32 #pos=7 */
# %   | | else if ( acquired(I, A), countryhascompanyoffice(J, I) )
# %   | | | then return 0.001006077956655051;  // std dev = 1,309, 14,000 (wgt'ed) examples reached here.  /* #neg=12 #pos=2 */
# %   | | | else return 0.20614893509950832;  // std dev = 10,651, 500,000 (wgt'ed) examples reached here.  /* #neg=326 #pos=174 */
# WILL Produced-Tree #2
# % FOR companyeconomicsector(A, B):
# %   if ( companyceo(A, C), companyceo(D, C) )
# %   then if ( economicsectorcompany(B, D) )
# %   | then return 0.719473412210955;  // std dev = 0,000, 46,000 (wgt'ed) examples reached here.  /* #pos=46 */
# %   | else return -0.12544463852839144;  // std dev = 0,000, 85,000 (wgt'ed) examples reached here.  /* #neg=85 */
# %   else if ( acquired(E, A), economicsectorcompany(B, E) )
# %   | then return 0.8110552916295661;  // std dev = 0,146, 10,000 (wgt'ed) examples reached here.  /* #pos=10 */
# %   | else if ( acquired(F, A), companyceo(F, G) )
# %   | | then if ( acquired(H, F), companyalsoknownas(F, I) )
# %   | | | then return 0.4978238979311766;  // std dev = 0,816, 3,000 (wgt'ed) examples reached here.  /* #neg=1 #pos=2 */
# %   | | | else return -0.05988615866031194;  // std dev = 1,656, 32,000 (wgt'ed) examples reached here.  /* #neg=29 #pos=3 */
# %   | | else if ( countryhascompanyoffice(J, A) )
# %   | | | then return 0.09774280443177603;  // std dev = 2,664, 38,000 (wgt'ed) examples reached here.  /* #neg=28 #pos=10 */
# %   | | | else return 0.16640711305153025;  // std dev = 11,040, 565,000 (wgt'ed) examples reached here.  /* #neg=376 #pos=189 */
# WILL Produced-Tree #3
# % FOR companyeconomicsector(A, B):
# %   if ( companyceo(A, C), companyceo(D, C) )
# %   then if ( economicsectorcompany(B, D) )
# %   | then return 0.5553664367462839;  // std dev = 0,000, 46,000 (wgt'ed) examples reached here.  /* #pos=46 */
# %   | else return -0.11231637819360622;  // std dev = 6,99e-08, 85,000 (wgt'ed) examples reached here.  /* #neg=85 */
# %   else if ( acquired(E, A), companyalsoknownas(E, F) )
# %   | then if ( cityhascompanyoffice(G, F), companyceo(E, H) )
# %   | | then if ( cityhascompanyoffice(G, E) )
# %   | | | then return -0.13998781138346778;  // std dev = 0,023, 5,000 (wgt'ed) examples reached here.  /* #neg=5 */
# %   | | | else return 0.7583976126416401;  // std dev = 0,109, 3,000 (wgt'ed) examples reached here.  /* #pos=3 */
# %   | | else return -0.036302960826722436;  // std dev = 0,313, 18,000 (wgt'ed) examples reached here.  /* #neg=15 #pos=3 */
# %   | else if ( countryhascompanyoffice(I, A), bankbankincountry(J, I) )
# %   | | then if ( countryhascompanyoffice(I, K), economicsectorcompany(B, K) )
# %   | | | then return 0.5263154250155309;  // std dev = 1,683, 14,000 (wgt'ed) examples reached here.  /* #neg=4 #pos=10 */
# %   | | | else return -0.16645099585856718;  // std dev = 0,104, 27,000 (wgt'ed) examples reached here.  /* #neg=27 */
# %   | | else if ( acquired(A, L), cityhascompanyoffice(M, L) )
# %   | | | then return -0.027732363719001556;  // std dev = 1,096, 13,000 (wgt'ed) examples reached here.  /* #neg=11 #pos=2 */
# %   | | | else return 0.1516155164929048;  // std dev = 11,103, 568,000 (wgt'ed) examples reached here.  /* #neg=372 #pos=196 */
# WILL Produced-Tree #4
# % FOR companyeconomicsector(A, B):
# %   if ( companyceo(A, C), companyceo(D, C) )
# %   then if ( economicsectorcompany(B, D) )
# %   | then return 0.41751358415831025;  // std dev = 0,000, 46,000 (wgt'ed) examples reached here.  /* #pos=46 */
# %   | else return -0.10159632948783619;  // std dev = 5,58e-08, 85,000 (wgt'ed) examples reached here.  /* #neg=85 */
# %   else if ( acquired(A, E), cityhascompanyoffice(F, E) )
# %   | then if ( cityhascompanyoffice(F, A) )
# %   | | then return 0.13590793598588669;  // std dev = 0,679, 3,000 (wgt'ed) examples reached here.  /* #neg=2 #pos=1 */
# %   | | else if ( acquired(E, G) )
# %   | | | then return -0.1466000381571569;  // std dev = 0,031, 6,000 (wgt'ed) examples reached here.  /* #neg=6 */
# %   | | | else return -0.03586615396788641;  // std dev = 0,785, 7,000 (wgt'ed) examples reached here.  /* #neg=6 #pos=1 */
# %   | else if ( acquired(H, A), countryhascompanyoffice(I, H) )
# %   | | then if ( companyalsoknownas(H, J) )
# %   | | | then return -0.12158839608068053;  // std dev = 0,010, 5,000 (wgt'ed) examples reached here.  /* #neg=5 */
# %   | | | else return 0.055356932209479584;  // std dev = 1,209, 10,000 (wgt'ed) examples reached here.  /* #neg=8 #pos=2 */
# %   | | else if ( acquired(K, A), economicsectorcompany(B, K) )
# %   | | | then return 0.6190311225963878;  // std dev = 0,225, 10,000 (wgt'ed) examples reached here.  /* #pos=10 */
# %   | | | else return 0.1140292715576456;  // std dev = 11,300, 607,000 (wgt'ed) examples reached here.  /* #neg=407 #pos=200 */
# WILL Produced-Tree #5
# % FOR companyeconomicsector(A, B):
# %   if ( companyceo(A, C), companyceo(D, C) )
# %   then if ( economicsectorcompany(B, D) )
# %   | then return 0.32071184716014944;  // std dev = 2,98e-08, 46,000 (wgt'ed) examples reached here.  /* #pos=46 */
# %   | else return -0.09269127618926107;  // std dev = 0,000, 85,000 (wgt'ed) examples reached here.  /* #neg=85 */
# %   else if ( countryhascompanyoffice(E, A), bankbankincountry(F, E) )
# %   | then if ( countryhascompanyoffice(E, G), economicsectorcompany(B, G) )
# %   | | then if ( companyalsoknownas(G, H) )
# %   | | | then return 0.5738848470464415;  // std dev = 0,936, 9,000 (wgt'ed) examples reached here.  /* #neg=1 #pos=8 */
# %   | | | else return 0.08032480063347984;  // std dev = 1,159, 6,000 (wgt'ed) examples reached here.  /* #neg=4 #pos=2 */
# %   | | else return -0.15495362502532894;  // std dev = 0,124, 27,000 (wgt'ed) examples reached here.  /* #neg=27 */
# %   | else if ( acquired(I, A), companyalsoknownas(I, J) )
# %   | | then if ( countryhascompanyoffice(K, J), acquired(L, I) )
# %   | | | then return 0.3416504384603715;  // std dev = 0,754, 3,000 (wgt'ed) examples reached here.  /* #neg=1 #pos=2 */
# %   | | | else return -0.0454340736479577;  // std dev = 1,233, 22,000 (wgt'ed) examples reached here.  /* #neg=18 #pos=4 */
# %   | | else if ( acquired(A, M) )
# %   | | | then return 0.08210652393748061;  // std dev = 2,765, 44,000 (wgt'ed) examples reached here.  /* #neg=31 #pos=13 */
# %   | | | else return 0.10449127305252306;  // std dev = 10,751, 537,000 (wgt'ed) examples reached here.  /* #neg=352 #pos=185 */
# WILL Produced-Tree #6
# % FOR companyeconomicsector(A, B):
# %   if ( companyceo(A, C), companyceo(D, C) )
# %   then if ( economicsectorcompany(B, D) )
# %   | then return 0.2551722425694896;  // std dev = 0,000, 46,000 (wgt'ed) examples reached here.  /* #pos=46 */
# %   | else return -0.08518475138839679;  // std dev = 3,16e-08, 85,000 (wgt'ed) examples reached here.  /* #neg=85 */
# %   else if ( acquired(E, A), companyalsoknownas(E, F) )
# %   | then if ( economicsectorcompany(B, E) )
# %   | | then return 0.44229045113567605;  // std dev = 0,147, 3,000 (wgt'ed) examples reached here.  /* #pos=3 */
# %   | | else if ( countryhascompanyoffice(G, F), acquired(H, F) )
# %   | | | then return 0.35037815213801576;  // std dev = 0,592, 3,000 (wgt'ed) examples reached here.  /* #neg=1 #pos=2 */
# %   | | | else return -0.12717538887945679;  // std dev = 0,841, 20,000 (wgt'ed) examples reached here.  /* #neg=19 #pos=1 */
# %   | else if ( cityhascompanyoffice(I, A) )
# %   | | then if ( cityhascompanyoffice(I, J), economicsectorcompany(B, J) )
# %   | | | then return 0.35026473200243213;  // std dev = 2,684, 39,000 (wgt'ed) examples reached here.  /* #neg=12 #pos=27 */
# %   | | | else return -0.18835716068654754;  // std dev = 0,156, 51,000 (wgt'ed) examples reached here.  /* #neg=51 */
# %   | | else if ( acquired(K, A), economicsectorcompany(B, K) )
# %   | | | then return 0.4848788686293359;  // std dev = 0,044, 6,000 (wgt'ed) examples reached here.  /* #pos=6 */
# %   | | | else return 0.08091130959024954;  // std dev = 10,625, 526,000 (wgt'ed) examples reached here.  /* #neg=351 #pos=175 */
# WILL Produced-Tree #7
# % FOR companyeconomicsector(A, B):
# %   if ( companyceo(A, C), companyceo(D, C) )
# %   then if ( economicsectorcompany(B, D) )
# %   | then return 0.2097577156325355;  // std dev = 5,16e-08, 46,000 (wgt'ed) examples reached here.  /* #pos=46 */
# %   | else return -0.07877675473109162;  // std dev = 4,71e-08, 85,000 (wgt'ed) examples reached here.  /* #neg=85 */
# %   else if ( countryhascompanyoffice(E, A), bankbankincountry(F, E) )
# %   | then if ( countryhascompanyoffice(E, G), economicsectorcompany(B, G) )
# %   | | then if ( companyalsoknownas(G, H) )
# %   | | | then return 0.41421060734062554;  // std dev = 0,940, 9,000 (wgt'ed) examples reached here.  /* #neg=1 #pos=8 */
# %   | | | else return 0.04422095663650402;  // std dev = 1,165, 6,000 (wgt'ed) examples reached here.  /* #neg=4 #pos=2 */
# %   | | else return -0.14264320393388716;  // std dev = 0,139, 27,000 (wgt'ed) examples reached here.  /* #neg=27 */
# %   | else if ( companyalsoknownas(A, I), countryhascompanyoffice(J, I) )
# %   | | then return -0.2518496026850109;  // std dev = 0,040, 5,000 (wgt'ed) examples reached here.  /* #neg=5 */
# %   | | else if ( acquired(K, A), economicsectorcompany(B, K) )
# %   | | | then return 0.34744818607415484;  // std dev = 0,180, 10,000 (wgt'ed) examples reached here.  /* #pos=10 */
# %   | | | else return 0.06140517793563608;  // std dev = 10,996, 591,000 (wgt'ed) examples reached here.  /* #neg=397 #pos=194 */
# WILL Produced-Tree #8
# % FOR companyeconomicsector(A, B):
# %   if ( companyceo(A, C), companyceo(D, C) )
# %   then if ( economicsectorcompany(B, D) )
# %   | then return 0.1770964977452775;  // std dev = 0,000, 46,000 (wgt'ed) examples reached here.  /* #pos=46 */
# %   | else return -0.07324622576333707;  // std dev = 0,000, 85,000 (wgt'ed) examples reached here.  /* #neg=85 */
# %   else if ( cityhascompanyoffice(E, A) )
# %   | then if ( cityhascompanyoffice(E, F), economicsectorcompany(B, F) )
# %   | | then if ( acquired(G, F), bankchiefexecutiveceo(F, H) )
# %   | | | then return -0.3739338535322341;  // std dev = 7,45e-09, 3,000 (wgt'ed) examples reached here.  /* #neg=3 */
# %   | | | else return 0.3032715766538023;  // std dev = 2,420, 37,000 (wgt'ed) examples reached here.  /* #neg=9 #pos=28 */
# %   | | else return -0.168216042056626;  // std dev = 0,171, 52,000 (wgt'ed) examples reached here.  /* #neg=52 */
# %   | else if ( companyalsoknownas(A, I), economicsectorcompany(B, I) )
# %   | | then return 0.7140204713589952;  // std dev = 0,000, 3,000 (wgt'ed) examples reached here.  /* #pos=3 */
# %   | | else if ( acquired(J, A) )
# %   | | | then return -3.077263582869138E-4;  // std dev = 2,596, 61,000 (wgt'ed) examples reached here.  /* #neg=44 #pos=17 */
# %   | | | else return 0.055019345284189704;  // std dev = 10,286, 492,000 (wgt'ed) examples reached here.  /* #neg=326 #pos=166 */
# WILL Produced-Tree #9
# % FOR companyeconomicsector(A, B):
# %   if ( companyceo(A, C), companyceo(D, C) )
# %   then if ( economicsectorcompany(B, D) )
# %   | then return 0.15274385809367083;  // std dev = 0,000, 46,000 (wgt'ed) examples reached here.  /* #pos=46 */
# %   | else return -0.06842697784420267;  // std dev = 4,01e-08, 85,000 (wgt'ed) examples reached here.  /* #neg=85 */
# %   else if ( cityhascompanyoffice(E, A) )
# %   | then if ( cityhascompanyoffice(E, F), economicsectorcompany(B, F) )
# %   | | then if ( acquired(F, G), cityhascompanyoffice(E, G) )
# %   | | | then return 0.39377445631629165;  // std dev = 0,348, 16,000 (wgt'ed) examples reached here.  /* #pos=16 */
# %   | | | else return 0.057739289831005146;  // std dev = 2,321, 24,000 (wgt'ed) examples reached here.  /* #neg=12 #pos=12 */
# %   | | else return -0.1460516769227195;  // std dev = 0,150, 52,000 (wgt'ed) examples reached here.  /* #neg=52 */
# %   | else if ( acquired(H, A), economicsectorcompany(B, H) )
# %   | | then return 0.28997435039492125;  // std dev = 0,119, 8,000 (wgt'ed) examples reached here.  /* #pos=8 */
# %   | | else if ( acquired(I, A) )
# %   | | | then return -0.04406525322142344;  // std dev = 2,440, 53,000 (wgt'ed) examples reached here.  /* #neg=44 #pos=9 */
# %   | | | else return 0.04693914888299648;  // std dev = 10,320, 495,000 (wgt'ed) examples reached here.  /* #neg=326 #pos=169 */
# WILL Produced-Tree #10
# % FOR companyeconomicsector(A, B):
# %   if ( companyceo(A, C), companyceo(D, C) )
# %   then if ( economicsectorcompany(B, D) )
# %   | then return 0.13400703000801104;  // std dev = 2,79e-08, 46,000 (wgt'ed) examples reached here.  /* #pos=46 */
# %   | else return -0.06419184008202625;  // std dev = 0,000, 85,000 (wgt'ed) examples reached here.  /* #neg=85 */
# %   else if ( acquired(A, E) )
# %   | then if ( economicsectorcompany(B, E) )
# %   | | then return 0.5222260474134932;  // std dev = 0,185, 4,000 (wgt'ed) examples reached here.  /* #pos=4 */
# %   | | else if ( cityhascompanyoffice(F, E) )
# %   | | | then return -0.15132422454947317;  // std dev = 0,171, 14,000 (wgt'ed) examples reached here.  /* #neg=14 */
# %   | | | else return 0.014885174584300205;  // std dev = 2,285, 34,000 (wgt'ed) examples reached here.  /* #neg=24 #pos=10 */
# %   | else return 0.02873085398279688;  // std dev = 0,438, 596,000 (wgt'ed) examples reached here.  /* #neg=396 #pos=200 */
#
#
# Fold 1
# {'AUC ROC': 0.778456, 'Inference time': 1.482, 'AUC PR': 0.699688, 'Recall': 0.281853, 'CLL': -0.494248, 'Learning time': 63.868, 'Precision': [0.954248, 0.5], 'F1': 0.435171}
#
#
# Fold 2
# {'AUC ROC': 0.782231, 'Inference time': 1.384, 'AUC PR': 0.690818, 'Recall': 0.260618, 'CLL': -0.508481, 'Learning time': 18.129, 'Precision': [0.918367, 0.5], 'F1': 0.406015}
#
#
# Fold 3
# {'AUC ROC': 0.78062, 'Inference time': 1.592, 'AUC PR': 0.699349, 'Recall': 0.269231, 'CLL': -0.504198, 'Learning time': 7.752, 'Precision': [0.972222, 0.5], 'F1': 0.421687}
#
#
# AUC ROC: 0.780 +/- 0.003
# AUC PR: 0.697 +/- 0.008
# CLL: -0.502 +/- 0.012

# %%
refine = ['0;;companyeconomicsector(A, B) :- companyceo(A, C), companyalsoknownas(C, D), economicsectorcompany(B, D).;true;true',
          '1;;companyeconomicsector(A, B) :- companyceo(A, C), companyalsoknownas(C, D), economicsectorcompany(B, D).;true;true',
          '2;;companyeconomicsector(A, B) :- companyceo(A, C), companyalsoknownas(C, D), economicsectorcompany(B, D).;true;true',
          '3;;companyeconomicsector(A, B) :- companyceo(A, C), companyalsoknownas(C, D), economicsectorcompany(B, D).;true;true',
          '4;;companyeconomicsector(A, B) :- companyceo(A, C), companyalsoknownas(C, D), economicsectorcompany(B, D).;true;true',
          '5;;companyeconomicsector(A, B) :- companyceo(A, C), companyalsoknownas(C, D), economicsectorcompany(B, D).;true;true',
          '6;;companyeconomicsector(A, B) :- companyceo(A, C), companyalsoknownas(C, D), economicsectorcompany(B, D).;true;true',
          '7;;companyeconomicsector(A, B) :- companyceo(A, C), companyalsoknownas(C, D), economicsectorcompany(B, D).;true;true',
          '8;;companyeconomicsector(A, B) :- companyceo(A, C), companyalsoknownas(C, D), economicsectorcompany(B, D).;true;true',
          '9;;companyeconomicsector(A, B) :- companyceo(A, C), companyalsoknownas(C, D), economicsectorcompany(B, D).;true;true',
         ]

# Load new predicate target dataset
tar_data = datasets.load(target, bk, target=new_target, balanced=balanced, seed=seed)
results = []

for i in range(n_folds):
    [tar_train_facts, tar_test_facts] =  [tar_data[0][0], tar_data[0][0]]
    to_folds_pos = datasets.split_into_folds(tar_data[1][0], n_folds=n_folds, seed=seed)
    to_folds_neg = datasets.split_into_folds(tar_data[2][0], n_folds=n_folds, seed=seed)
    [tar_train_pos, tar_test_pos] =  datasets.get_kfold_small(i, to_folds_pos)
    [tar_train_neg, tar_test_neg] =  datasets.get_kfold_small(i, to_folds_neg)
    
    [model, t_results, structured, will, variances] = revision.learn_test_model(background, boostsrl, new_target, tar_train_pos, tar_train_neg, tar_train_facts, tar_test_pos, tar_test_neg, tar_test_facts, refine=refine, trees=10, print_function=None)
    results.append(t_results)
    
    if i == 0:
        for line in will:
            print(line)
    print('\n')
    print('Fold ' + str(i+1))
    print(t_results)
print('\n')
auc_roc = np.array([item['AUC ROC'] for item in results])
auc_pr = np.array([item['AUC PR'] for item in results])
cll = np.array([item['CLL'] for item in results])
print('AUC ROC: %.3f +/- %.3f' % (auc_roc.mean(), 2 * auc_roc.std()))
print('AUC PR: %.3f +/- %.3f' % (auc_pr.mean(), 2 * auc_pr.std()))
print('CLL: %.3f +/- %.3f' % (cll.mean(), 2 * cll.std()))
# Out:
# WILL Produced-Tree #1
# % FOR companyeconomicsector(A, B):
# %   if ( companyceo(A, C), companyalsoknownas(C, D), economicsectorcompany(B, D) )
# %   then return 0;  // std dev = 0,000, 0,000 (wgt'ed) examples reached here.
# %   else if ( acquired(A, E), economicsectorcompany(B, E) )
# %   | then if ( cityhascompanyoffice(F, A) )
# %   | | then return 0.8581489350995123;  // std dev = 0,000, 6,000 (wgt'ed) examples reached here.  /* #pos=6 */
# %   | | else return 0.6581489350995122;  // std dev = 0,894, 5,000 (wgt'ed) examples reached here.  /* #neg=1 #pos=4 */
# %   | else if ( acquired(A, G), cityhascompanyoffice(H, G) )
# %   | | then if ( companyceo(A, I) )
# %   | | | then return 0.024815601766178853;  // std dev = 1,291, 12,000 (wgt'ed) examples reached here.  /* #neg=10 #pos=2 */
# %   | | | else return -0.1418510649004878;  // std dev = 0,000, 14,000 (wgt'ed) examples reached here.  /* #neg=14 */
# %   | | else if ( acquired(J, A), cityhascompanyoffice(K, J) )
# %   | | | then return 0.2528857772047755;  // std dev = 3,013, 38,000 (wgt'ed) examples reached here.  /* #neg=23 #pos=15 */
# %   | | | else return 0.18911484419041721;  // std dev = 12,485, 704,000 (wgt'ed) examples reached here.  /* #neg=471 #pos=233 */
# WILL Produced-Tree #2
# % FOR companyeconomicsector(A, B):
# %   if ( companyceo(A, C), companyalsoknownas(C, D), economicsectorcompany(B, D) )
# %   then return 0;  // std dev = 0,000, 0,000 (wgt'ed) examples reached here.
# %   else if ( acquired(E, A), economicsectorcompany(B, E) )
# %   | then return 0.8290153937400033;  // std dev = 0,018, 16,000 (wgt'ed) examples reached here.  /* #pos=16 */
# %   | else if ( countryhascompanyoffice(F, A), bankbankincountry(G, F) )
# %   | | then if ( companyalsoknownas(A, H), economicsectorcompany(B, H) )
# %   | | | then return 0.8305216766270687;  // std dev = 0,007, 3,000 (wgt'ed) examples reached here.  /* #pos=3 */
# %   | | | else return 0.03868398759472536;  // std dev = 3,544, 78,000 (wgt'ed) examples reached here.  /* #neg=62 #pos=16 */
# %   | | else if ( acquired(A, I), countryhascompanyoffice(J, I) )
# %   | | | then return 0.4049628138297709;  // std dev = 1,309, 7,000 (wgt'ed) examples reached here.  /* #neg=3 #pos=4 */
# %   | | | else return 0.16021185203230257;  // std dev = 12,135, 675,000 (wgt'ed) examples reached here.  /* #neg=454 #pos=221 */
# WILL Produced-Tree #3
# % FOR companyeconomicsector(A, B):
# %   if ( companyceo(A, C), companyalsoknownas(C, D), economicsectorcompany(B, D) )
# %   then return 0;  // std dev = 0,000, 0,000 (wgt'ed) examples reached here.
# %   else if ( acquired(E, A), economicsectorcompany(B, E) )
# %   | then return 0.6791355897312564;  // std dev = 0,028, 16,000 (wgt'ed) examples reached here.  /* #pos=16 */
# %   | else if ( countryhascompanyoffice(F, A), acquired(A, G) )
# %   | | then if ( companyalsoknownas(A, H), companyceo(H, I) )
# %   | | | then return 0.18098708282533615;  // std dev = 1,802, 16,000 (wgt'ed) examples reached here.  /* #neg=10 #pos=6 */
# %   | | | else return -0.16838760871693795;  // std dev = 0,105, 14,000 (wgt'ed) examples reached here.  /* #neg=14 */
# %   | | else if ( acquired(A, J), economicsectorcompany(B, J) )
# %   | | | then return 0.7044333194321534;  // std dev = 0,062, 9,000 (wgt'ed) examples reached here.  /* #pos=9 */
# %   | | | else return 0.12767950747464074;  // std dev = 12,485, 724,000 (wgt'ed) examples reached here.  /* #neg=495 #pos=229 */
# WILL Produced-Tree #4
# % FOR companyeconomicsector(A, B):
# %   if ( companyceo(A, C), companyalsoknownas(C, D), economicsectorcompany(B, D) )
# %   then return 0;  // std dev = 0,000, 0,000 (wgt'ed) examples reached here.
# %   else if ( acquired(E, A), economicsectorcompany(B, E) )
# %   | then return 0.5177002776287302;  // std dev = 0,032, 16,000 (wgt'ed) examples reached here.  /* #pos=16 */
# %   | else if ( acquired(F, A) )
# %   | | then if ( companyceo(A, G), companyceo(F, H) )
# %   | | | then return 0.1312182175187566;  // std dev = 1,742, 14,000 (wgt'ed) examples reached here.  /* #neg=9 #pos=5 */
# %   | | | else return -0.027806369745559802;  // std dev = 3,218, 71,000 (wgt'ed) examples reached here.  /* #neg=58 #pos=13 */
# %   | | else if ( acquired(A, I) )
# %   | | | then return 0.09456863581262677;  // std dev = 4,411, 108,000 (wgt'ed) examples reached here.  /* #neg=74 #pos=34 */
# %   | | | else return 0.12792226870737772;  // std dev = 11,281, 570,000 (wgt'ed) examples reached here.  /* #neg=378 #pos=192 */
# WILL Produced-Tree #5
# % FOR companyeconomicsector(A, B):
# %   if ( companyceo(A, C), companyalsoknownas(C, D), economicsectorcompany(B, D) )
# %   then return 0;  // std dev = 0,000, 0,000 (wgt'ed) examples reached here.
# %   else if ( acquired(A, E), cityhascompanyoffice(F, A) )
# %   | then if ( economicsectorcompany(B, E) )
# %   | | then return 0.5217074608627267;  // std dev = 0,143, 6,000 (wgt'ed) examples reached here.  /* #pos=6 */
# %   | | else if ( cityhascompanyoffice(G, E) )
# %   | | | then return -0.12312971592715848;  // std dev = 0,969, 15,000 (wgt'ed) examples reached here.  /* #neg=14 #pos=1 */
# %   | | | else return 0.1621028490020499;  // std dev = 3,112, 45,000 (wgt'ed) examples reached here.  /* #neg=26 #pos=19 */
# %   | else if ( cityhascompanyoffice(H, A) )
# %   | | then if ( cityhascompanyoffice(H, I), economicsectorcompany(B, I) )
# %   | | | then return 0.44121170715788627;  // std dev = 2,956, 42,000 (wgt'ed) examples reached here.  /* #neg=13 #pos=29 */
# %   | | | else return -0.22667201916737406;  // std dev = 0,082, 56,000 (wgt'ed) examples reached here.  /* #neg=56 */
# %   | | else if ( companyalsoknownas(A, J), economicsectorcompany(B, J) )
# %   | | | then return 0.7256704779948344;  // std dev = 0,145, 4,000 (wgt'ed) examples reached here.  /* #pos=4 */
# %   | | | else return 0.09440967455701696;  // std dev = 11,341, 611,000 (wgt'ed) examples reached here.  /* #neg=410 #pos=201 */
# WILL Produced-Tree #6
# % FOR companyeconomicsector(A, B):
# %   if ( companyceo(A, C), companyalsoknownas(C, D), economicsectorcompany(B, D) )
# %   then return 0;  // std dev = 0,000, 0,000 (wgt'ed) examples reached here.
# %   else if ( countryhascompanyoffice(E, A), bankbankincountry(F, E) )
# %   | then if ( companyalsoknownas(A, G), cityhascompanyoffice(H, A) )
# %   | | then if ( countryhascompanyoffice(E, I), economicsectorcompany(B, I) )
# %   | | | then return 0.5418482696363328;  // std dev = 0,816, 7,000 (wgt'ed) examples reached here.  /* #neg=1 #pos=6 */
# %   | | | else return -0.21663967808768608;  // std dev = 0,098, 8,000 (wgt'ed) examples reached here.  /* #neg=8 */
# %   | | else if ( acquired(A, J) )
# %   | | | then return -0.1435876871205341;  // std dev = 0,599, 17,000 (wgt'ed) examples reached here.  /* #neg=16 #pos=1 */
# %   | | | else return 0.03471759402792138;  // std dev = 2,959, 50,000 (wgt'ed) examples reached here.  /* #neg=37 #pos=13 */
# %   | else if ( acquired(K, A), companyalsoknownas(K, L) )
# %   | | then if ( economicsectorcompany(B, K) )
# %   | | | then return 0.3580848216580839;  // std dev = 0,026, 7,000 (wgt'ed) examples reached here.  /* #pos=7 */
# %   | | | else return -0.050692755082494975;  // std dev = 2,178, 32,000 (wgt'ed) examples reached here.  /* #neg=26 #pos=6 */
# %   | | else if ( cityhascompanyoffice(M, A) )
# %   | | | then return 0.059099120451540754;  // std dev = 4,686, 129,000 (wgt'ed) examples reached here.  /* #neg=87 #pos=42 */
# %   | | | else return 0.0956773333100618;  // std dev = 10,787, 529,000 (wgt'ed) examples reached here.  /* #neg=344 #pos=185 */
# WILL Produced-Tree #7
# % FOR companyeconomicsector(A, B):
# %   if ( companyceo(A, C), companyalsoknownas(C, D), economicsectorcompany(B, D) )
# %   then return 0;  // std dev = 0,000, 0,000 (wgt'ed) examples reached here.
# %   else if ( acquired(A, E), acquired(E, F) )
# %   | then if ( acquired(F, G), countryhascompanyoffice(H, E) )
# %   | | then return 0.3485569073659424;  // std dev = 0,816, 3,000 (wgt'ed) examples reached here.  /* #neg=1 #pos=2 */
# %   | | else if ( companyalsoknownas(F, I) )
# %   | | | then return -0.13245541904640673;  // std dev = 0,477, 8,000 (wgt'ed) examples reached here.  /* #neg=7 #pos=1 */
# %   | | | else return 0.03585658884173022;  // std dev = 1,722, 22,000 (wgt'ed) examples reached here.  /* #neg=15 #pos=7 */
# %   | else if ( acquired(J, A) )
# %   | | then if ( companyceo(J, K), companyceo(A, L) )
# %   | | | then return 0.15682628389936853;  // std dev = 1,680, 18,000 (wgt'ed) examples reached here.  /* #neg=8 #pos=10 */
# %   | | | else return -0.0033500140467191074;  // std dev = 3,189, 75,000 (wgt'ed) examples reached here.  /* #neg=54 #pos=21 */
# %   | | else if ( countryhascompanyoffice(M, A), bankbankincountry(N, M) )
# %   | | | then return 0.035885554823214136;  // std dev = 3,077, 57,000 (wgt'ed) examples reached here.  /* #neg=42 #pos=15 */
# %   | | | else return 0.07252407163138082;  // std dev = 11,317, 596,000 (wgt'ed) examples reached here.  /* #neg=392 #pos=204 */
# WILL Produced-Tree #8
# % FOR companyeconomicsector(A, B):
# %   if ( companyceo(A, C), companyalsoknownas(C, D), economicsectorcompany(B, D) )
# %   then return 0;  // std dev = 0,000, 0,000 (wgt'ed) examples reached here.
# %   else if ( companyalsoknownas(A, E), economicsectorcompany(B, E) )
# %   | then if ( countryhascompanyoffice(F, A) )
# %   | | then return 0.4281359886562181;  // std dev = 0,017, 3,000 (wgt'ed) examples reached here.  /* #pos=3 */
# %   | | else return 0.606704874423981;  // std dev = 0,111, 4,000 (wgt'ed) examples reached here.  /* #pos=4 */
# %   | else if ( acquired(G, A), economicsectorcompany(B, G) )
# %   | | then return 0.3035949360173299;  // std dev = 0,190, 16,000 (wgt'ed) examples reached here.  /* #pos=16 */
# %   | | else if ( acquired(A, H), economicsectorcompany(B, H) )
# %   | | | then return 0.3436513994003629;  // std dev = 0,641, 11,000 (wgt'ed) examples reached here.  /* #neg=1 #pos=10 */
# %   | | | else return 0.035728934960139576;  // std dev = 12,276, 745,000 (wgt'ed) examples reached here.  /* #neg=518 #pos=227 */
# WILL Produced-Tree #9
# % FOR companyeconomicsector(A, B):
# %   if ( companyceo(A, C), companyalsoknownas(C, D), economicsectorcompany(B, D) )
# %   then return 0;  // std dev = 0,000, 0,000 (wgt'ed) examples reached here.
# %   else if ( acquired(A, E), countryhascompanyoffice(F, A) )
# %   | then if ( cityhascompanyoffice(G, A) )
# %   | | then if ( countryhascompanyoffice(F, H), economicsectorcompany(B, H) )
# %   | | | then return 0.40404978664571134;  // std dev = 0,845, 6,000 (wgt'ed) examples reached here.  /* #neg=1 #pos=5 */
# %   | | | else return -0.19850069571399936;  // std dev = 0,080, 7,000 (wgt'ed) examples reached here.  /* #neg=7 */
# %   | | else if ( acquired(I, A) )
# %   | | | then return -0.02809068846503357;  // std dev = 0,432, 3,000 (wgt'ed) examples reached here.  /* #neg=2 #pos=1 */
# %   | | | else return -0.16583907247553614;  // std dev = 0,177, 14,000 (wgt'ed) examples reached here.  /* #neg=14 */
# %   | else if ( cityhascompanyoffice(J, A) )
# %   | | then if ( cityhascompanyoffice(J, K), economicsectorcompany(B, K) )
# %   | | | then return 0.34815160988361965;  // std dev = 3,366, 66,000 (wgt'ed) examples reached here.  /* #neg=16 #pos=50 */
# %   | | | else return -0.22807105947565143;  // std dev = 0,369, 85,000 (wgt'ed) examples reached here.  /* #neg=85 */
# %   | | else if ( companyalsoknownas(A, L), economicsectorcompany(B, L) )
# %   | | | then return 0.424212238724444;  // std dev = 0,000, 3,000 (wgt'ed) examples reached here.  /* #pos=3 */
# %   | | | else return 0.046300519331979;  // std dev = 11,237, 595,000 (wgt'ed) examples reached here.  /* #neg=394 #pos=201 */
# WILL Produced-Tree #10
# % FOR companyeconomicsector(A, B):
# %   if ( companyceo(A, C), companyalsoknownas(C, D), economicsectorcompany(B, D) )
# %   then return 0;  // std dev = 0,000, 0,000 (wgt'ed) examples reached here.
# %   else if ( acquired(E, A), countryhascompanyoffice(F, E) )
# %   | then if ( companyceo(A, G), companyceo(E, H) )
# %   | | then return 0.1288607610779652;  // std dev = 0,824, 5,000 (wgt'ed) examples reached here.  /* #neg=2 #pos=3 */
# %   | | else if ( companyalsoknownas(E, I) )
# %   | | | then return -0.23425642693978607;  // std dev = 0,010, 5,000 (wgt'ed) examples reached here.  /* #neg=5 */
# %   | | | else return -0.044266711227913466;  // std dev = 1,327, 14,000 (wgt'ed) examples reached here.  /* #neg=11 #pos=3 */
# %   | else if ( acquired(A, J) )
# %   | | then if ( cityhascompanyoffice(K, J) )
# %   | | | then return -0.06845168973451231;  // std dev = 1,416, 30,000 (wgt'ed) examples reached here.  /* #neg=24 #pos=6 */
# %   | | | else return 0.03505792848804417;  // std dev = 3,873, 99,000 (wgt'ed) examples reached here.  /* #neg=63 #pos=36 */
# %   | | else if ( acquired(L, A), acquired(M, L) )
# %   | | | then return 0.20073993229015244;  // std dev = 1,303, 8,000 (wgt'ed) examples reached here.  /* #neg=4 #pos=4 */
# %   | | | else return 0.03450986924611152;  // std dev = 11,218, 618,000 (wgt'ed) examples reached here.  /* #neg=410 #pos=208 */
#
#
# Fold 1
# {'AUC ROC': 0.666909, 'Inference time': 1.576, 'AUC PR': 0.566499, 'Recall': 0.106178, 'CLL': -0.585889, 'Learning time': 47.74, 'Precision': [0.982143, 0.5], 'F1': 0.191638}
#
#
# Fold 2
# {'AUC ROC': 0.527048, 'Inference time': 1.814, 'AUC PR': 0.396228, 'Recall': 0.044402, 'CLL': -0.632733, 'Learning time': 23.676, 'Precision': [0.884615, 0.5], 'F1': 0.084559}
#
#
# Fold 3
# {'AUC ROC': 0.64223, 'Inference time': 1.503, 'AUC PR': 0.535987, 'Recall': 0.117308, 'CLL': -0.595841, 'Learning time': 10.901, 'Precision': [0.968254, 0.5], 'F1': 0.209262}
#
#
# AUC ROC: 0.612 +/- 0.122
# AUC PR: 0.500 +/- 0.148
# CLL: -0.605 +/- 0.040

# %%
refine = ['0;;companyeconomicsector(A, B) :- companyceo(A, C), companyalsoknownas(C, D).;true;true',
          '0;true;economicsectorcompany(B, D).;true;true',
          '1;;companyeconomicsector(A, B) :- companyceo(A, C), companyalsoknownas(C, D).;true;true',
          '1;true;economicsectorcompany(B, D).;true;true',
          '2;;companyeconomicsector(A, B) :- companyceo(A, C), companyalsoknownas(C, D).;true;true',
          '2;true;economicsectorcompany(B, D).;true;true',
          '3;;companyeconomicsector(A, B) :- companyceo(A, C), companyalsoknownas(C, D).;true;true',
          '3;true;economicsectorcompany(B, D).;true;true',
          '4;;companyeconomicsector(A, B) :- companyceo(A, C), companyalsoknownas(C, D).;true;true',
          '4;true;economicsectorcompany(B, D).;true;true',
          '5;;companyeconomicsector(A, B) :- companyceo(A, C), companyalsoknownas(C, D).;true;true',
          '5;true;economicsectorcompany(B, D).;true;true',
          '6;;companyeconomicsector(A, B) :- companyceo(A, C), companyalsoknownas(C, D).;true;true',
          '6;true;economicsectorcompany(B, D).;true;true',
          '7;;companyeconomicsector(A, B) :- companyceo(A, C), companyalsoknownas(C, D).;true;true',
          '7;true;economicsectorcompany(B, D).;true;true',
          '8;;companyeconomicsector(A, B) :- companyceo(A, C), companyalsoknownas(C, D).;true;true',
          '8;true;economicsectorcompany(B, D).;true;true',
          '9;;companyeconomicsector(A, B) :- companyceo(A, C), companyalsoknownas(C, D).;true;true',
          '9;true;economicsectorcompany(B, D).;true;true',
         ]

# Load new predicate target dataset
tar_data = datasets.load(target, bk, target=new_target, balanced=balanced, seed=seed)
results = []

for i in range(n_folds):
    [tar_train_facts, tar_test_facts] =  [tar_data[0][0], tar_data[0][0]]
    to_folds_pos = datasets.split_into_folds(tar_data[1][0], n_folds=n_folds, seed=seed)
    to_folds_neg = datasets.split_into_folds(tar_data[2][0], n_folds=n_folds, seed=seed)
    [tar_train_pos, tar_test_pos] =  datasets.get_kfold_small(i, to_folds_pos)
    [tar_train_neg, tar_test_neg] =  datasets.get_kfold_small(i, to_folds_neg)
    
    [model, t_results, structured, will, variances] = revision.learn_test_model(background, boostsrl, new_target, tar_train_pos, tar_train_neg, tar_train_facts, tar_test_pos, tar_test_neg, tar_test_facts, refine=refine, trees=10, print_function=None)
    results.append(t_results)
    
    if i == 0:
        for line in will:
            print(line)
    print('\n')
    print('Fold ' + str(i+1))
    print(t_results)
print('\n')
auc_roc = np.array([item['AUC ROC'] for item in results])
auc_pr = np.array([item['AUC PR'] for item in results])
cll = np.array([item['CLL'] for item in results])
print('AUC ROC: %.3f +/- %.3f' % (auc_roc.mean(), 2 * auc_roc.std()))
print('AUC PR: %.3f +/- %.3f' % (auc_pr.mean(), 2 * auc_pr.std()))
print('CLL: %.3f +/- %.3f' % (cll.mean(), 2 * cll.std()))
# Out:
# WILL Produced-Tree #1
# % FOR companyeconomicsector(A, B):
# %   if ( companyceo(A, C), companyalsoknownas(C, D) )
# %   then return 0;  // std dev = 0,000, 0,000 (wgt'ed) examples reached here.
# %   else if ( countryhascompanyoffice(E, A), bankbankincountry(F, E) )
# %   | then if ( companyalsoknownas(A, G), economicsectorcompany(B, G) )
# %   | | then return 0.8581489350995121;  // std dev = 2,11e-08, 3,000 (wgt'ed) examples reached here.  /* #pos=3 */
# %   | | else if ( acquired(A, H), companyceo(H, I) )
# %   | | | then return -0.1418510649004878;  // std dev = 0,000, 10,000 (wgt'ed) examples reached here.  /* #neg=10 */
# %   | | | else return 0.10452574669371523;  // std dev = 3,579, 69,000 (wgt'ed) examples reached here.  /* #neg=52 #pos=17 */
# %   | else if ( acquired(J, A), economicsectorcompany(B, J) )
# %   | | then return 0.8581489350995123;  // std dev = 0,000, 15,000 (wgt'ed) examples reached here.  /* #pos=15 */
# %   | | else if ( acquired(A, K), companyceo(A, L) )
# %   | | | then return 0.25814893509951164;  // std dev = 3,633, 55,000 (wgt'ed) examples reached here.  /* #neg=33 #pos=22 */
# %   | | | else return 0.18191289044241082;  // std dev = 11,716, 627,000 (wgt'ed) examples reached here.  /* #neg=424 #pos=203 */
# WILL Produced-Tree #2
# % FOR companyeconomicsector(A, B):
# %   if ( companyceo(A, C), companyalsoknownas(C, D) )
# %   then return 0;  // std dev = 0,000, 0,000 (wgt'ed) examples reached here.
# %   else if ( acquired(E, A), economicsectorcompany(B, E) )
# %   | then return 0.7273152440482344;  // std dev = 0,121, 16,000 (wgt'ed) examples reached here.  /* #pos=16 */
# %   | else if ( acquired(F, A) )
# %   | | then if ( acquired(G, F), cityhascompanyoffice(H, F) )
# %   | | | then return 0.23237165078530264;  // std dev = 1,548, 10,000 (wgt'ed) examples reached here.  /* #neg=6 #pos=4 */
# %   | | | else return 0.018643728829278707;  // std dev = 3,317, 75,000 (wgt'ed) examples reached here.  /* #neg=61 #pos=14 */
# %   | | else if ( countryhascompanyoffice(I, A), bankbankincountry(J, I) )
# %   | | | then return 0.08629581249169509;  // std dev = 3,445, 67,000 (wgt'ed) examples reached here.  /* #neg=51 #pos=16 */
# %   | | | else return 0.1774347713140458;  // std dev = 11,737, 611,000 (wgt'ed) examples reached here.  /* #neg=401 #pos=210 */
# WILL Produced-Tree #3
# % FOR companyeconomicsector(A, B):
# %   if ( companyceo(A, C), companyalsoknownas(C, D) )
# %   then return 0;  // std dev = 0,000, 0,000 (wgt'ed) examples reached here.
# %   else if ( acquired(A, E), cityhascompanyoffice(F, E) )
# %   | then if ( economicsectorcompany(B, E) )
# %   | | then return 0.8025160865531757;  // std dev = 0,012, 4,000 (wgt'ed) examples reached here.  /* #pos=4 */
# %   | | else if ( companyalsoknownas(A, G), cityhascompanyoffice(F, G) )
# %   | | | then return 0.0832972924914116;  // std dev = 0,866, 4,000 (wgt'ed) examples reached here.  /* #neg=3 #pos=1 */
# %   | | | else return -0.14053740310012347;  // std dev = 0,964, 22,000 (wgt'ed) examples reached here.  /* #neg=21 #pos=1 */
# %   | else if ( countryhascompanyoffice(H, A), bankbankincountry(I, H) )
# %   | | then if ( acquired(A, J), countryhascompanyoffice(H, J) )
# %   | | | then return -0.16539026585898906;  // std dev = 0,009, 7,000 (wgt'ed) examples reached here.  /* #neg=7 */
# %   | | | else return 0.11044593892409331;  // std dev = 3,593, 68,000 (wgt'ed) examples reached here.  /* #neg=49 #pos=19 */
# %   | | else if ( companyceo(A, K) )
# %   | | | then return 0.19771023983570357;  // std dev = 4,270, 81,000 (wgt'ed) examples reached here.  /* #neg=48 #pos=33 */
# %   | | | else return 0.14651262379100427;  // std dev = 11,407, 593,000 (wgt'ed) examples reached here.  /* #neg=391 #pos=202 */
# WILL Produced-Tree #4
# % FOR companyeconomicsector(A, B):
# %   if ( companyceo(A, C), companyalsoknownas(C, D) )
# %   then return 0;  // std dev = 0,000, 0,000 (wgt'ed) examples reached here.
# %   else if ( companyalsoknownas(A, E), companyceo(E, F) )
# %   | then if ( acquired(A, G) )
# %   | | then if ( countryhascompanyoffice(H, E), countryhascompanyoffice(H, G) )
# %   | | | then return 0.35747892651713975;  // std dev = 1,323, 7,000 (wgt'ed) examples reached here.  /* #neg=3 #pos=4 */
# %   | | | else return 0.062145838753682243;  // std dev = 2,297, 29,000 (wgt'ed) examples reached here.  /* #neg=21 #pos=8 */
# %   | | else if ( acquired(E, I), acquired(I, J) )
# %   | | | then return 0.34792018670286706;  // std dev = 1,281, 7,000 (wgt'ed) examples reached here.  /* #neg=3 #pos=4 */
# %   | | | else return 0.5348470545547465;  // std dev = 0,866, 4,000 (wgt'ed) examples reached here.  /* #neg=1 #pos=3 */
# %   | else if ( acquired(K, A), economicsectorcompany(B, K) )
# %   | | then return 0.5245754098256228;  // std dev = 0,185, 16,000 (wgt'ed) examples reached here.  /* #pos=16 */
# %   | | else if ( acquired(L, A) )
# %   | | | then return 0.004795351448951111;  // std dev = 3,428, 76,000 (wgt'ed) examples reached here.  /* #neg=61 #pos=15 */
# %   | | | else return 0.11573170184554311;  // std dev = 11,806, 640,000 (wgt'ed) examples reached here.  /* #neg=430 #pos=210 */
# WILL Produced-Tree #5
# % FOR companyeconomicsector(A, B):
# %   if ( companyceo(A, C), companyalsoknownas(C, D) )
# %   then return 0;  // std dev = 0,000, 0,000 (wgt'ed) examples reached here.
# %   else if ( acquired(E, A), economicsectorcompany(B, E) )
# %   | then return 0.396198061291598;  // std dev = 0,194, 16,000 (wgt'ed) examples reached here.  /* #pos=16 */
# %   | else if ( cityhascompanyoffice(F, A) )
# %   | | then if ( cityhascompanyoffice(F, G), economicsectorcompany(B, G) )
# %   | | | then return 0.5118385293608734;  // std dev = 3,419, 66,000 (wgt'ed) examples reached here.  /* #neg=16 #pos=50 */
# %   | | | else return -0.2225074764320139;  // std dev = 0,266, 93,000 (wgt'ed) examples reached here.  /* #neg=93 */
# %   | | else if ( acquired(H, A) )
# %   | | | then return -0.007958695339964409;  // std dev = 3,054, 64,000 (wgt'ed) examples reached here.  /* #neg=52 #pos=12 */
# %   | | | else return 0.10419412737476831;  // std dev = 10,929, 540,000 (wgt'ed) examples reached here.  /* #neg=358 #pos=182 */
# WILL Produced-Tree #6
# % FOR companyeconomicsector(A, B):
# %   if ( companyceo(A, C), companyalsoknownas(C, D) )
# %   then return 0;  // std dev = 0,000, 0,000 (wgt'ed) examples reached here.
# %   else if ( companyceo(A, E) )
# %   | then if ( acquired(A, F), economicsectorcompany(B, F) )
# %   | | then if ( companyalsoknownas(A, G) )
# %   | | | then return 0.6652006934565973;  // std dev = 0,064, 4,000 (wgt'ed) examples reached here.  /* #pos=4 */
# %   | | | else return 0.26425335978918735;  // std dev = 0,537, 3,000 (wgt'ed) examples reached here.  /* #neg=1 #pos=2 */
# %   | | else if ( countryhascompanyoffice(H, A), bankchiefexecutiveceo(A, E) )
# %   | | | then return -0.16706566525075414;  // std dev = 0,028, 3,000 (wgt'ed) examples reached here.  /* #neg=3 */
# %   | | | else return 0.06617508914652512;  // std dev = 4,506, 121,000 (wgt'ed) examples reached here.  /* #neg=81 #pos=40 */
# %   | else if ( acquired(I, A), companyalsoknownas(I, J) )
# %   | | then if ( acquired(K, J), countryhascompanyoffice(L, J) )
# %   | | | then return 0.4715431055039306;  // std dev = 0,789, 3,000 (wgt'ed) examples reached here.  /* #neg=1 #pos=2 */
# %   | | | else return -0.08364918119299007;  // std dev = 1,180, 23,000 (wgt'ed) examples reached here.  /* #neg=19 #pos=4 */
# %   | | else if ( acquired(M, A), companyceo(M, N) )
# %   | | | then return 0.01690963246307739;  // std dev = 1,545, 24,000 (wgt'ed) examples reached here.  /* #neg=16 #pos=8 */
# %   | | | else return 0.08208847874426832;  // std dev = 11,294, 598,000 (wgt'ed) examples reached here.  /* #neg=398 #pos=200 */
# WILL Produced-Tree #7
# % FOR companyeconomicsector(A, B):
# %   if ( companyceo(A, C), companyalsoknownas(C, D) )
# %   then return 0;  // std dev = 0,000, 0,000 (wgt'ed) examples reached here.
# %   else if ( countryhascompanyoffice(E, A), bankbankincountry(F, E) )
# %   | then if ( countryhascompanyoffice(E, G), economicsectorcompany(B, G) )
# %   | | then if ( companyalsoknownas(G, H) )
# %   | | | then return 0.6380088181902518;  // std dev = 0,985, 18,000 (wgt'ed) examples reached here.  /* #neg=1 #pos=17 */
# %   | | | else return 0.04036807682267569;  // std dev = 1,344, 11,000 (wgt'ed) examples reached here.  /* #neg=8 #pos=3 */
# %   | | else return -0.19311517460454647;  // std dev = 0,267, 53,000 (wgt'ed) examples reached here.  /* #neg=53 */
# %   | else if ( acquired(A, I), companyceo(A, J) )
# %   | | then if ( companyalsoknownas(A, K), cityhascompanyoffice(L, I) )
# %   | | | then return -0.21969720676154503;  // std dev = 0,108, 3,000 (wgt'ed) examples reached here.  /* #neg=3 */
# %   | | | else return 0.1253293425824801;  // std dev = 3,081, 54,000 (wgt'ed) examples reached here.  /* #neg=30 #pos=24 */
# %   | | else if ( cityhascompanyoffice(M, A) )
# %   | | | then return 0.028664221084106652;  // std dev = 3,805, 93,000 (wgt'ed) examples reached here.  /* #neg=64 #pos=29 */
# %   | | | else return 0.06926915682533456;  // std dev = 10,826, 547,000 (wgt'ed) examples reached here.  /* #neg=360 #pos=187 */
# WILL Produced-Tree #8
# % FOR companyeconomicsector(A, B):
# %   if ( companyceo(A, C), companyalsoknownas(C, D) )
# %   then return 0;  // std dev = 0,000, 0,000 (wgt'ed) examples reached here.
# %   else if ( acquired(A, E), cityhascompanyoffice(F, E) )
# %   | then if ( economicsectorcompany(B, E) )
# %   | | then return 0.4543798971419476;  // std dev = 0,147, 4,000 (wgt'ed) examples reached here.  /* #pos=4 */
# %   | | else if ( companyceo(A, G) )
# %   | | | then return -0.04645846516592079;  // std dev = 1,105, 12,000 (wgt'ed) examples reached here.  /* #neg=10 #pos=2 */
# %   | | | else return -0.18699516310120506;  // std dev = 0,148, 14,000 (wgt'ed) examples reached here.  /* #neg=14 */
# %   | else if ( countryhascompanyoffice(H, A), bankbankincountry(I, H) )
# %   | | then if ( companyalsoknownas(A, J), cityhascompanyoffice(K, J) )
# %   | | | then return 0.10071863583448418;  // std dev = 1,082, 14,000 (wgt'ed) examples reached here.  /* #neg=8 #pos=6 */
# %   | | | else return -0.009301796483550527;  // std dev = 2,642, 61,000 (wgt'ed) examples reached here.  /* #neg=48 #pos=13 */
# %   | | else if ( acquired(L, A), acquired(M, L) )
# %   | | | then return 0.09506852628140798;  // std dev = 1,800, 20,000 (wgt'ed) examples reached here.  /* #neg=12 #pos=8 */
# %   | | | else return 0.05592567653338267;  // std dev = 11,649, 654,000 (wgt'ed) examples reached here.  /* #neg=427 #pos=227 */
# WILL Produced-Tree #9
# % FOR companyeconomicsector(A, B):
# %   if ( companyceo(A, C), companyalsoknownas(C, D) )
# %   then return 0;  // std dev = 0,000, 0,000 (wgt'ed) examples reached here.
# %   else if ( acquired(A, E), economicsectorcompany(B, E) )
# %   | then if ( companyceo(A, F) )
# %   | | then if ( companyalsoknownas(A, G) )
# %   | | | then return 0.4285932595329256;  // std dev = 0,149, 4,000 (wgt'ed) examples reached here.  /* #pos=4 */
# %   | | | else return 0.11768654140957467;  // std dev = 0,415, 3,000 (wgt'ed) examples reached here.  /* #neg=1 #pos=2 */
# %   | | else return 0.5565684836007474;  // std dev = 0,302, 4,000 (wgt'ed) examples reached here.  /* #pos=4 */
# %   | else if ( acquired(A, H) )
# %   | | then if ( cityhascompanyoffice(I, H) )
# %   | | | then return -0.10443391740079125;  // std dev = 1,158, 26,000 (wgt'ed) examples reached here.  /* #neg=24 #pos=2 */
# %   | | | else return 0.018430453984388827;  // std dev = 3,824, 95,000 (wgt'ed) examples reached here.  /* #neg=64 #pos=31 */
# %   | | else if ( countryhascompanyoffice(J, A), bankbankincountry(K, J) )
# %   | | | then return 0.036546893150470515;  // std dev = 2,648, 53,000 (wgt'ed) examples reached here.  /* #neg=38 #pos=15 */
# %   | | | else return 0.04174190414962309;  // std dev = 11,129, 594,000 (wgt'ed) examples reached here.  /* #neg=392 #pos=202 */
# WILL Produced-Tree #10
# % FOR companyeconomicsector(A, B):
# %   if ( companyceo(A, C), companyalsoknownas(C, D) )
# %   then return 0;  // std dev = 0,000, 0,000 (wgt'ed) examples reached here.
# %   else if ( acquired(A, E), cityhascompanyoffice(F, E) )
# %   | then if ( economicsectorcompany(B, E) )
# %   | | then return 0.2742442197121359;  // std dev = 0,057, 4,000 (wgt'ed) examples reached here.  /* #pos=4 */
# %   | | else if ( companyceo(A, G) )
# %   | | | then return -0.023157508847616897;  // std dev = 1,116, 12,000 (wgt'ed) examples reached here.  /* #neg=10 #pos=2 */
# %   | | | else return -0.14699592996048047;  // std dev = 0,122, 14,000 (wgt'ed) examples reached here.  /* #neg=14 */
# %   | else if ( cityhascompanyoffice(H, A), acquired(A, I) )
# %   | | then if ( companyalsoknownas(A, J), cityhascompanyoffice(K, J) )
# %   | | | then return -0.0040851843364742325;  // std dev = 1,687, 26,000 (wgt'ed) examples reached here.  /* #neg=17 #pos=9 */
# %   | | | else return 0.20267658801706248;  // std dev = 1,830, 22,000 (wgt'ed) examples reached here.  /* #neg=9 #pos=13 */
# %   | | else if ( acquired(L, A), acquired(M, L) )
# %   | | | then return 0.06241849109375011;  // std dev = 1,658, 16,000 (wgt'ed) examples reached here.  /* #neg=10 #pos=6 */
# %   | | | else return 0.028579219473027072;  // std dev = 11,695, 685,000 (wgt'ed) examples reached here.  /* #neg=459 #pos=226 */
#
#
# Fold 1
# {'AUC ROC': 0.66997, 'Inference time': 1.838, 'AUC PR': 0.554296, 'Recall': 0.07722, 'CLL': -0.591934, 'Learning time': 14.586, 'Precision': [1.0, 0.5], 'F1': 0.143369}
#
#
# Fold 2
# {'AUC ROC': 0.666849, 'Inference time': 1.503, 'AUC PR': 0.563759, 'Recall': 0.111969, 'CLL': -0.58904, 'Learning time': 13.719, 'Precision': [0.966667, 0.5], 'F1': 0.200692}
#
#
# Fold 3
# {'AUC ROC': 0.577636, 'Inference time': 1.437, 'AUC PR': 0.467007, 'Recall': 0.076923, 'CLL': -0.614734, 'Learning time': 15.366, 'Precision': [0.97561, 0.5], 'F1': 0.142602}
#
#
# AUC ROC: 0.638 +/- 0.086
# AUC PR: 0.528 +/- 0.087
# CLL: -0.599 +/- 0.023

# %%
refine = ['0;;companyeconomicsector(A, B) :- companyceo(A, C), companyalsoknownas(C, D).;true;true',
          '1;;companyeconomicsector(A, B) :- companyceo(A, C), companyalsoknownas(C, D).;true;true',
          '2;;companyeconomicsector(A, B) :- companyceo(A, C), companyalsoknownas(C, D).;true;true',
          '3;;companyeconomicsector(A, B) :- companyceo(A, C), companyalsoknownas(C, D).;true;true',
          '4;;companyeconomicsector(A, B) :- companyceo(A, C), companyalsoknownas(C, D).;true;true',
          '5;;companyeconomicsector(A, B) :- companyceo(A, C), companyalsoknownas(C, D).;true;true',
          '6;;companyeconomicsector(A, B) :- companyceo(A, C), companyalsoknownas(C, D).;true;true',
          '7;;companyeconomicsector(A, B) :- companyceo(A, C), companyalsoknownas(C, D).;true;true',
          '8;;companyeconomicsector(A, B) :- companyceo(A, C), companyalsoknownas(C, D).;true;true',
          '9;;companyeconomicsector(A, B) :- companyceo(A, C), companyalsoknownas(C, D).;true;true',
         ]

# Load new predicate target dataset
tar_data = datasets.load(target, bk, target=new_target, balanced=balanced, seed=seed)
results = []

for i in range(n_folds):
    [tar_train_facts, tar_test_facts] =  [tar_data[0][0], tar_data[0][0]]
    to_folds_pos = datasets.split_into_folds(tar_data[1][0], n_folds=n_folds, seed=seed)
    to_folds_neg = datasets.split_into_folds(tar_data[2][0], n_folds=n_folds, seed=seed)
    [tar_train_pos, tar_test_pos] =  datasets.get_kfold_small(i, to_folds_pos)
    [tar_train_neg, tar_test_neg] =  datasets.get_kfold_small(i, to_folds_neg)
    
    [model, t_results, structured, will, variances] = revision.learn_test_model(background, boostsrl, new_target, tar_train_pos, tar_train_neg, tar_train_facts, tar_test_pos, tar_test_neg, tar_test_facts, refine=refine, trees=10, print_function=None)
    results.append(t_results)
    
    if i == 0:
        for line in will:
            print(line)
    print('\n')
    print('Fold ' + str(i+1))
    print(t_results)
print('\n')
auc_roc = np.array([item['AUC ROC'] for item in results])
auc_pr = np.array([item['AUC PR'] for item in results])
cll = np.array([item['CLL'] for item in results])
print('AUC ROC: %.3f +/- %.3f' % (auc_roc.mean(), 2 * auc_roc.std()))
print('AUC PR: %.3f +/- %.3f' % (auc_pr.mean(), 2 * auc_pr.std()))
print('CLL: %.3f +/- %.3f' % (cll.mean(), 2 * cll.std()))
# Out:
# WILL Produced-Tree #1
# % FOR companyeconomicsector(A, B):
# %   if ( companyceo(A, C), companyalsoknownas(C, D) )
# %   then return 0;  // std dev = 0,000, 0,000 (wgt'ed) examples reached here.
# %   else if ( countryhascompanyoffice(E, A), bankbankincountry(F, E) )
# %   | then if ( companyalsoknownas(A, G), economicsectorcompany(B, G) )
# %   | | then return 0.8581489350995121;  // std dev = 2,11e-08, 3,000 (wgt'ed) examples reached here.  /* #pos=3 */
# %   | | else if ( acquired(A, H), companyceo(H, I) )
# %   | | | then return -0.1418510649004878;  // std dev = 0,000, 10,000 (wgt'ed) examples reached here.  /* #neg=10 */
# %   | | | else return 0.10452574669371523;  // std dev = 3,579, 69,000 (wgt'ed) examples reached here.  /* #neg=52 #pos=17 */
# %   | else if ( acquired(A, J), companyceo(A, K) )
# %   | | then if ( economicsectorcompany(B, J) )
# %   | | | then return 0.8581489350995122;  // std dev = 0,000, 5,000 (wgt'ed) examples reached here.  /* #pos=5 */
# %   | | | else return 0.22353355048412768;  // std dev = 3,472, 52,000 (wgt'ed) examples reached here.  /* #neg=33 #pos=19 */
# %   | | else if ( companyalsoknownas(A, L), countryhascompanyoffice(M, L) )
# %   | | | then return -0.14185106490048777;  // std dev = 0,000, 5,000 (wgt'ed) examples reached here.  /* #neg=5 */
# %   | | | else return 0.19830641541446872;  // std dev = 11,938, 635,000 (wgt'ed) examples reached here.  /* #neg=419 #pos=216 */
# WILL Produced-Tree #2
# % FOR companyeconomicsector(A, B):
# %   if ( companyceo(A, C), companyalsoknownas(C, D) )
# %   then return 0;  // std dev = 0,000, 0,000 (wgt'ed) examples reached here.
# %   else if ( acquired(A, E), economicsectorcompany(B, E) )
# %   | then if ( companyceo(A, F) )
# %   | | then if ( companyalsoknownas(A, G) )
# %   | | | then return 0.7508407395600754;  // std dev = 0,109, 4,000 (wgt'ed) examples reached here.  /* #pos=4 */
# %   | | | else return 0.42796318200978223;  // std dev = 0,714, 3,000 (wgt'ed) examples reached here.  /* #neg=1 #pos=2 */
# %   | | else return 0.8322549538581312;  // std dev = 0,000, 4,000 (wgt'ed) examples reached here.  /* #pos=4 */
# %   | else if ( acquired(H, A), economicsectorcompany(B, H) )
# %   | | then return 0.8326040074561392;  // std dev = 0,014, 16,000 (wgt'ed) examples reached here.  /* #pos=16 */
# %   | | else if ( acquired(A, I) )
# %   | | | then return 0.08299927845121675;  // std dev = 4,602, 117,000 (wgt'ed) examples reached here.  /* #neg=88 #pos=29 */
# %   | | | else return 0.15606423799796004;  // std dev = 11,771, 635,000 (wgt'ed) examples reached here.  /* #neg=430 #pos=205 */
# WILL Produced-Tree #3
# % FOR companyeconomicsector(A, B):
# %   if ( companyceo(A, C), companyalsoknownas(C, D) )
# %   then return 0;  // std dev = 0,000, 0,000 (wgt'ed) examples reached here.
# %   else if ( acquired(E, A), economicsectorcompany(B, E) )
# %   | then return 0.6838844183071531;  // std dev = 0,021, 16,000 (wgt'ed) examples reached here.  /* #pos=16 */
# %   | else if ( acquired(A, F), economicsectorcompany(B, F) )
# %   | | then if ( companyceo(A, G) )
# %   | | | then return 0.4849442413878445;  // std dev = 0,777, 7,000 (wgt'ed) examples reached here.  /* #neg=1 #pos=6 */
# %   | | | else return 0.6833994457807381;  // std dev = 0,000, 4,000 (wgt'ed) examples reached here.  /* #pos=4 */
# %   | | else if ( acquired(H, A) )
# %   | | | then return 0.022910701911297616;  // std dev = 3,714, 85,000 (wgt'ed) examples reached here.  /* #neg=67 #pos=18 */
# %   | | | else return 0.13643689433132483;  // std dev = 12,053, 667,000 (wgt'ed) examples reached here.  /* #neg=451 #pos=216 */
# WILL Produced-Tree #4
# % FOR companyeconomicsector(A, B):
# %   if ( companyceo(A, C), companyalsoknownas(C, D) )
# %   then return 0;  // std dev = 0,000, 0,000 (wgt'ed) examples reached here.
# %   else if ( acquired(A, E), cityhascompanyoffice(F, E) )
# %   | then if ( economicsectorcompany(B, E) )
# %   | | then return 0.5143659710172571;  // std dev = 0,014, 4,000 (wgt'ed) examples reached here.  /* #pos=4 */
# %   | | else if ( cityhascompanyoffice(F, G), economicsectorcompany(B, G) )
# %   | | | then return 0.13456506124063264;  // std dev = 0,809, 3,000 (wgt'ed) examples reached here.  /* #neg=2 #pos=1 */
# %   | | | else return -0.14834463319151436;  // std dev = 0,987, 23,000 (wgt'ed) examples reached here.  /* #neg=22 #pos=1 */
# %   | else if ( countryhascompanyoffice(H, A), bankbankincountry(I, H) )
# %   | | then if ( companyalsoknownas(A, J), economicsectorcompany(B, J) )
# %   | | | then return 0.684242030041022;  // std dev = 0,018, 3,000 (wgt'ed) examples reached here.  /* #pos=3 */
# %   | | | else return 0.02609497322968589;  // std dev = 3,421, 72,000 (wgt'ed) examples reached here.  /* #neg=56 #pos=16 */
# %   | | else if ( acquired(A, K), cityhascompanyoffice(L, A) )
# %   | | | then return 0.2358679587848703;  // std dev = 2,954, 40,000 (wgt'ed) examples reached here.  /* #neg=21 #pos=19 */
# %   | | | else return 0.12433139137872226;  // std dev = 11,733, 634,000 (wgt'ed) examples reached here.  /* #neg=418 #pos=216 */
# WILL Produced-Tree #5
# % FOR companyeconomicsector(A, B):
# %   if ( companyceo(A, C), companyalsoknownas(C, D) )
# %   then return 0;  // std dev = 0,000, 0,000 (wgt'ed) examples reached here.
# %   else if ( countryhascompanyoffice(E, A), bankbankincountry(F, E) )
# %   | then if ( countryhascompanyoffice(E, G), economicsectorcompany(B, G) )
# %   | | then if ( companyalsoknownas(G, H) )
# %   | | | then return 0.6889462458501632;  // std dev = 1,025, 18,000 (wgt'ed) examples reached here.  /* #neg=1 #pos=17 */
# %   | | | else return 0.050837372450764806;  // std dev = 1,379, 11,000 (wgt'ed) examples reached here.  /* #neg=8 #pos=3 */
# %   | | else return -0.18619005839702946;  // std dev = 0,147, 53,000 (wgt'ed) examples reached here.  /* #neg=53 */
# %   | else if ( acquired(A, I), economicsectorcompany(B, I) )
# %   | | then return 0.40776792641021997;  // std dev = 0,135, 9,000 (wgt'ed) examples reached here.  /* #pos=9 */
# %   | | else if ( cityhascompanyoffice(J, A) )
# %   | | | then return 0.07658275839250046;  // std dev = 5,164, 132,000 (wgt'ed) examples reached here.  /* #neg=90 #pos=42 */
# %   | | | else return 0.10456954963338692;  // std dev = 11,007, 556,000 (wgt'ed) examples reached here.  /* #neg=367 #pos=189 */
# WILL Produced-Tree #6
# % FOR companyeconomicsector(A, B):
# %   if ( companyceo(A, C), companyalsoknownas(C, D) )
# %   then return 0;  // std dev = 0,000, 0,000 (wgt'ed) examples reached here.
# %   else if ( acquired(A, E), cityhascompanyoffice(F, E) )
# %   | then if ( companyceo(E, G), companyceo(A, H) )
# %   | | then return 0.28358771143592765;  // std dev = 0,670, 3,000 (wgt'ed) examples reached here.  /* #neg=1 #pos=2 */
# %   | | else if ( economicsectorcompany(B, E) )
# %   | | | then return 0.29838924961707575;  // std dev = 0,010, 3,000 (wgt'ed) examples reached here.  /* #pos=3 */
# %   | | | else return -0.14194309606949554;  // std dev = 0,892, 24,000 (wgt'ed) examples reached here.  /* #neg=23 #pos=1 */
# %   | else if ( acquired(I, A), economicsectorcompany(B, I) )
# %   | | then return 0.4641837766918491;  // std dev = 0,076, 16,000 (wgt'ed) examples reached here.  /* #pos=16 */
# %   | | else if ( acquired(J, A) )
# %   | | | then return -0.014919351394044985;  // std dev = 3,594, 83,000 (wgt'ed) examples reached here.  /* #neg=65 #pos=18 */
# %   | | | else return 0.08605071050733344;  // std dev = 11,813, 650,000 (wgt'ed) examples reached here.  /* #neg=430 #pos=220 */
# WILL Produced-Tree #7
# % FOR companyeconomicsector(A, B):
# %   if ( companyceo(A, C), companyalsoknownas(C, D) )
# %   then return 0;  // std dev = 0,000, 0,000 (wgt'ed) examples reached here.
# %   else if ( acquired(A, E), cityhascompanyoffice(F, E) )
# %   | then if ( economicsectorcompany(B, E) )
# %   | | then return 0.2388194211432665;  // std dev = 0,009, 4,000 (wgt'ed) examples reached here.  /* #pos=4 */
# %   | | else if ( companyalsoknownas(A, G), cityhascompanyoffice(F, G) )
# %   | | | then return 0.08624650013580025;  // std dev = 0,762, 4,000 (wgt'ed) examples reached here.  /* #neg=3 #pos=1 */
# %   | | | else return -0.12781975777711127;  // std dev = 0,858, 22,000 (wgt'ed) examples reached here.  /* #neg=21 #pos=1 */
# %   | else if ( companyalsoknownas(A, H) )
# %   | | then if ( acquired(I, A), companyceo(I, J) )
# %   | | | then return 0.23495539458186598;  // std dev = 0,827, 6,000 (wgt'ed) examples reached here.  /* #neg=2 #pos=4 */
# %   | | | else return 0.07991015609515656;  // std dev = 4,060, 88,000 (wgt'ed) examples reached here.  /* #neg=56 #pos=32 */
# %   | | else if ( acquired(A, K), countryhascompanyoffice(L, A) )
# %   | | | then return -0.1874973941091722;  // std dev = 0,176, 9,000 (wgt'ed) examples reached here.  /* #neg=9 */
# %   | | | else return 0.06681477895357847;  // std dev = 11,670, 646,000 (wgt'ed) examples reached here.  /* #neg=428 #pos=218 */
# WILL Produced-Tree #8
# % FOR companyeconomicsector(A, B):
# %   if ( companyceo(A, C), companyalsoknownas(C, D) )
# %   then return 0;  // std dev = 0,000, 0,000 (wgt'ed) examples reached here.
# %   else if ( acquired(A, E), cityhascompanyoffice(F, E) )
# %   | then if ( economicsectorcompany(B, E) )
# %   | | then return 0.19814063886121827;  // std dev = 0,008, 4,000 (wgt'ed) examples reached here.  /* #pos=4 */
# %   | | else if ( companyalsoknownas(A, G), cityhascompanyoffice(F, G) )
# %   | | | then return 0.07435736863065007;  // std dev = 0,757, 4,000 (wgt'ed) examples reached here.  /* #neg=3 #pos=1 */
# %   | | | else return -0.11047376681889133;  // std dev = 0,865, 22,000 (wgt'ed) examples reached here.  /* #neg=21 #pos=1 */
# %   | else if ( acquired(A, H), cityhascompanyoffice(I, A) )
# %   | | then if ( companyalsoknownas(A, J), cityhascompanyoffice(K, J) )
# %   | | | then return 0.0201330216299351;  // std dev = 1,961, 26,000 (wgt'ed) examples reached here.  /* #neg=17 #pos=9 */
# %   | | | else return 0.2523412547117028;  // std dev = 2,176, 22,000 (wgt'ed) examples reached here.  /* #neg=9 #pos=13 */
# %   | | else if ( countryhascompanyoffice(L, A), acquired(A, M) )
# %   | | | then return -0.1310883614289946;  // std dev = 0,495, 14,000 (wgt'ed) examples reached here.  /* #neg=13 #pos=1 */
# %   | | | else return 0.0521410281387388;  // std dev = 11,982, 687,000 (wgt'ed) examples reached here.  /* #neg=456 #pos=231 */
# WILL Produced-Tree #9
# % FOR companyeconomicsector(A, B):
# %   if ( companyceo(A, C), companyalsoknownas(C, D) )
# %   then return 0;  // std dev = 0,000, 0,000 (wgt'ed) examples reached here.
# %   else if ( acquired(A, E) )
# %   | then if ( economicsectorcompany(B, E), companyalsoknownas(A, F) )
# %   | | then return 0.29644387704837394;  // std dev = 0,132, 5,000 (wgt'ed) examples reached here.  /* #pos=5 */
# %   | | else if ( companyalsoknownas(A, G), economicsectorcompany(B, G) )
# %   | | | then return 0.4385282829071446;  // std dev = 0,279, 3,000 (wgt'ed) examples reached here.  /* #pos=3 */
# %   | | | else return 0.0061738952850242295;  // std dev = 4,236, 124,000 (wgt'ed) examples reached here.  /* #neg=89 #pos=35 */
# %   | else if ( acquired(H, A), economicsectorcompany(B, H) )
# %   | | then return 0.3315947443644057;  // std dev = 0,053, 12,000 (wgt'ed) examples reached here.  /* #pos=12 */
# %   | | else if ( acquired(I, A), companyalsoknownas(I, J) )
# %   | | | then return -0.10742858020718604;  // std dev = 1,849, 28,000 (wgt'ed) examples reached here.  /* #neg=24 #pos=4 */
# %   | | | else return 0.043009367002274736;  // std dev = 11,444, 607,000 (wgt'ed) examples reached here.  /* #neg=406 #pos=201 */
# WILL Produced-Tree #10
# % FOR companyeconomicsector(A, B):
# %   if ( companyceo(A, C), companyalsoknownas(C, D) )
# %   then return 0;  // std dev = 0,000, 0,000 (wgt'ed) examples reached here.
# %   else if ( acquired(E, A), economicsectorcompany(B, E) )
# %   | then return 0.2625845656216605;  // std dev = 0,091, 16,000 (wgt'ed) examples reached here.  /* #pos=16 */
# %   | else if ( cityhascompanyoffice(F, A) )
# %   | | then if ( cityhascompanyoffice(F, G), economicsectorcompany(B, G) )
# %   | | | then return 0.39580311135028595;  // std dev = 3,325, 66,000 (wgt'ed) examples reached here.  /* #neg=16 #pos=50 */
# %   | | | else return -0.2610803949429796;  // std dev = 0,592, 93,000 (wgt'ed) examples reached here.  /* #neg=93 */
# %   | | else if ( acquired(H, A) )
# %   | | | then return -0.05036996763360452;  // std dev = 2,988, 64,000 (wgt'ed) examples reached here.  /* #neg=52 #pos=12 */
# %   | | | else return 0.039754556596824545;  // std dev = 10,753, 540,000 (wgt'ed) examples reached here.  /* #neg=358 #pos=182 */
#
#
# Fold 1
# {'AUC ROC': 0.67549, 'Inference time': 1.652, 'AUC PR': 0.571136, 'Recall': 0.088803, 'CLL': -0.588405, 'Learning time': 16.579, 'Precision': [1.0, 0.5], 'F1': 0.163121}
#
#
# Fold 2
# {'AUC ROC': 0.582056, 'Inference time': 1.503, 'AUC PR': 0.467887, 'Recall': 0.090734, 'CLL': -0.614334, 'Learning time': 10.979, 'Precision': [0.959184, 0.5], 'F1': 0.165785}
#
#
# Fold 3
# {'AUC ROC': 0.733842, 'Inference time': 1.49, 'AUC PR': 0.628662, 'Recall': 0.128846, 'CLL': -0.563563, 'Learning time': 12.803, 'Precision': [0.985294, 0.5], 'F1': 0.227891}
#
#
# AUC ROC: 0.664 +/- 0.125
# AUC PR: 0.556 +/- 0.133
# CLL: -0.589 +/- 0.041

# %%
refine = ['0;;companyeconomicsector(A, B) :- companyalsoknownas(A, C), economicsectorcompany(B, C).;true;true',
          '1;;companyeconomicsector(A, B) :- companyalsoknownas(A, C), economicsectorcompany(B, C).;true;true',
          '2;;companyeconomicsector(A, B) :- companyalsoknownas(A, C), economicsectorcompany(B, C).;true;true',
          '3;;companyeconomicsector(A, B) :- companyalsoknownas(A, C), economicsectorcompany(B, C).;true;true',
          '4;;companyeconomicsector(A, B) :- companyalsoknownas(A, C), economicsectorcompany(B, C).;true;true',
          '5;;companyeconomicsector(A, B) :- companyalsoknownas(A, C), economicsectorcompany(B, C).;true;true',
          '6;;companyeconomicsector(A, B) :- companyalsoknownas(A, C), economicsectorcompany(B, C).;true;true',
          '7;;companyeconomicsector(A, B) :- companyalsoknownas(A, C), economicsectorcompany(B, C).;true;true',
          '8;;companyeconomicsector(A, B) :- companyalsoknownas(A, C), economicsectorcompany(B, C).;true;true',
          '9;;companyeconomicsector(A, B) :- companyalsoknownas(A, C), economicsectorcompany(B, C).;true;true',
         ]

# Load new predicate target dataset
tar_data = datasets.load(target, bk, target=new_target, balanced=balanced, seed=seed)
results = []

for i in range(n_folds):
    [tar_train_facts, tar_test_facts] =  [tar_data[0][0], tar_data[0][0]]
    to_folds_pos = datasets.split_into_folds(tar_data[1][0], n_folds=n_folds, seed=seed)
    to_folds_neg = datasets.split_into_folds(tar_data[2][0], n_folds=n_folds, seed=seed)
    [tar_train_pos, tar_test_pos] =  datasets.get_kfold_small(i, to_folds_pos)
    [tar_train_neg, tar_test_neg] =  datasets.get_kfold_small(i, to_folds_neg)
    
    [model, t_results, structured, will, variances] = revision.learn_test_model(background, boostsrl, new_target, tar_train_pos, tar_train_neg, tar_train_facts, tar_test_pos, tar_test_neg, tar_test_facts, refine=refine, trees=10, print_function=None)
    results.append(t_results)
    
    if i == 0:
        for line in will:
            print(line)
    print('\n')
    print('Fold ' + str(i+1))
    print(t_results)
print('\n')
auc_roc = np.array([item['AUC ROC'] for item in results])
auc_pr = np.array([item['AUC PR'] for item in results])
cll = np.array([item['CLL'] for item in results])
print('AUC ROC: %.3f +/- %.3f' % (auc_roc.mean(), 2 * auc_roc.std()))
print('AUC PR: %.3f +/- %.3f' % (auc_pr.mean(), 2 * auc_pr.std()))
print('CLL: %.3f +/- %.3f' % (cll.mean(), 2 * cll.std()))
# Out:
# WILL Produced-Tree #1
# % FOR companyeconomicsector(A, B):
# %   if ( companyalsoknownas(A, C), economicsectorcompany(B, C) )
# %   then if ( companyalsoknownas(A, D), countryhascompanyoffice(E, D) )
# %   | then return 0.4581489350995122;  // std dev = 1,095, 5,000 (wgt'ed) examples reached here.  /* #neg=2 #pos=3 */
# %   | else return 0.8581489350995122;  // std dev = 0,000, 4,000 (wgt'ed) examples reached here.  /* #pos=4 */
# %   else if ( acquired(A, F), cityhascompanyoffice(G, F) )
# %   | then if ( economicsectorcompany(B, F) )
# %   | | then return 0.8581489350995122;  // std dev = 0,000, 4,000 (wgt'ed) examples reached here.  /* #pos=4 */
# %   | | else if ( companyceo(A, H) )
# %   | | | then return 0.024815601766178853;  // std dev = 1,291, 12,000 (wgt'ed) examples reached here.  /* #neg=10 #pos=2 */
# %   | | | else return -0.1418510649004878;  // std dev = 0,000, 14,000 (wgt'ed) examples reached here.  /* #neg=14 */
# %   | else if ( countryhascompanyoffice(I, A), bankbankincountry(J, I) )
# %   | | then if ( countryhascompanyoffice(I, K), acquired(A, K) )
# %   | | | then return -0.1418510649004878;  // std dev = 0,000, 7,000 (wgt'ed) examples reached here.  /* #neg=7 */
# %   | | | else return 0.10814893509951237;  // std dev = 3,464, 64,000 (wgt'ed) examples reached here.  /* #neg=48 #pos=16 */
# %   | | else if ( companyceo(A, L), cityhascompanyoffice(M, A) )
# %   | | | then return 0.29404637099694825;  // std dev = 3,097, 39,000 (wgt'ed) examples reached here.  /* #neg=22 #pos=17 */
# %   | | | else return 0.19783147478204777;  // std dev = 11,887, 630,000 (wgt'ed) examples reached here.  /* #neg=416 #pos=214 */
# WILL Produced-Tree #2
# % FOR companyeconomicsector(A, B):
# %   if ( companyalsoknownas(A, C), economicsectorcompany(B, C) )
# %   then if ( acquired(D, A) )
# %   | then return 0.7683539264550173;  // std dev = 0,060, 3,000 (wgt'ed) examples reached here.  /* #pos=3 */
# %   | else return 0.4228004645606684;  // std dev = 1,093, 6,000 (wgt'ed) examples reached here.  /* #neg=2 #pos=4 */
# %   else if ( acquired(A, E), economicsectorcompany(B, E) )
# %   | then if ( cityhascompanyoffice(F, E) )
# %   | | then return 0.7194734122109545;  // std dev = 0,000, 4,000 (wgt'ed) examples reached here.  /* #pos=4 */
# %   | | else return 0.8297254506055015;  // std dev = 0,022, 6,000 (wgt'ed) examples reached here.  /* #pos=6 */
# %   | else if ( acquired(G, A), economicsectorcompany(B, G) )
# %   | | then return 0.8304815436570264;  // std dev = 0,026, 16,000 (wgt'ed) examples reached here.  /* #pos=16 */
# %   | | else if ( cityhascompanyoffice(H, A) )
# %   | | | then return 0.10869062499345866;  // std dev = 5,427, 149,000 (wgt'ed) examples reached here.  /* #neg=108 #pos=41 */
# %   | | | else return 0.1470490567437176;  // std dev = 11,287, 595,000 (wgt'ed) examples reached here.  /* #neg=409 #pos=186 */
# WILL Produced-Tree #3
# % FOR companyeconomicsector(A, B):
# %   if ( companyalsoknownas(A, C), economicsectorcompany(B, C) )
# %   then if ( companyalsoknownas(A, D), countryhascompanyoffice(E, D) )
# %   | then return 0.28473706344207095;  // std dev = 1,042, 5,000 (wgt'ed) examples reached here.  /* #neg=2 #pos=3 */
# %   | else return 0.6060107559547048;  // std dev = 0,072, 4,000 (wgt'ed) examples reached here.  /* #pos=4 */
# %   else if ( acquired(F, A) )
# %   | then if ( economicsectorcompany(B, F) )
# %   | | then return 0.681109831785029;  // std dev = 0,040, 16,000 (wgt'ed) examples reached here.  /* #pos=16 */
# %   | | else if ( acquired(G, F), cityhascompanyoffice(H, F) )
# %   | | | then return 0.20897790188955842;  // std dev = 1,548, 10,000 (wgt'ed) examples reached here.  /* #neg=6 #pos=4 */
# %   | | | else return -0.03283045880485292;  // std dev = 3,046, 72,000 (wgt'ed) examples reached here.  /* #neg=61 #pos=11 */
# %   | else if ( acquired(A, I), economicsectorcompany(B, I) )
# %   | | then if ( cityhascompanyoffice(J, I) )
# %   | | | then return 0.5553664367462845;  // std dev = 0,000, 4,000 (wgt'ed) examples reached here.  /* #pos=4 */
# %   | | | else return 0.6801741143711774;  // std dev = 0,034, 6,000 (wgt'ed) examples reached here.  /* #pos=6 */
# %   | | else if ( acquired(A, K), cityhascompanyoffice(L, K) )
# %   | | | then return -0.06611757527338105;  // std dev = 1,337, 24,000 (wgt'ed) examples reached here.  /* #neg=22 #pos=2 */
# %   | | | else return 0.14191356848209508;  // std dev = 11,855, 638,000 (wgt'ed) examples reached here.  /* #neg=428 #pos=210 */
# WILL Produced-Tree #4
# % FOR companyeconomicsector(A, B):
# %   if ( companyalsoknownas(A, C), economicsectorcompany(B, C) )
# %   then if ( acquired(D, A) )
# %   | then return 0.5123037887764773;  // std dev = 0,145, 3,000 (wgt'ed) examples reached here.  /* #pos=3 */
# %   | else return 0.23253694159730962;  // std dev = 1,014, 6,000 (wgt'ed) examples reached here.  /* #neg=2 #pos=4 */
# %   else if ( countryhascompanyoffice(E, A), bankbankincountry(F, E) )
# %   | then if ( acquired(A, G), companyceo(G, H) )
# %   | | then return -0.17443546679357647;  // std dev = 0,028, 9,000 (wgt'ed) examples reached here.  /* #neg=9 */
# %   | | else if ( companyalsoknownas(A, I), cityhascompanyoffice(J, A) )
# %   | | | then return 0.24210422071053161;  // std dev = 1,393, 9,000 (wgt'ed) examples reached here.  /* #neg=5 #pos=4 */
# %   | | | else return 0.025656992844344462;  // std dev = 3,109, 60,000 (wgt'ed) examples reached here.  /* #neg=47 #pos=13 */
# %   | else if ( acquired(A, K), cityhascompanyoffice(L, K) )
# %   | | then if ( companyceo(K, M), companyceo(A, N) )
# %   | | | then return 0.370680787064202;  // std dev = 0,706, 3,000 (wgt'ed) examples reached here.  /* #neg=1 #pos=2 */
# %   | | | else return -0.056006946500191154;  // std dev = 0,890, 20,000 (wgt'ed) examples reached here.  /* #neg=17 #pos=3 */
# %   | | else if ( acquired(P, A), economicsectorcompany(B, P) )
# %   | | | then return 0.5178211682847362;  // std dev = 0,037, 15,000 (wgt'ed) examples reached here.  /* #pos=15 */
# %   | | | else return 0.11878413286509498;  // std dev = 11,945, 654,000 (wgt'ed) examples reached here.  /* #neg=438 #pos=216 */
# WILL Produced-Tree #5
# % FOR companyeconomicsector(A, B):
# %   if ( companyalsoknownas(A, C), economicsectorcompany(B, C) )
# %   then if ( companyalsoknownas(A, D), countryhascompanyoffice(E, D) )
# %   | then return 0.13720691521096273;  // std dev = 0,991, 5,000 (wgt'ed) examples reached here.  /* #neg=2 #pos=3 */
# %   | else return 0.38558080471345824;  // std dev = 0,122, 4,000 (wgt'ed) examples reached here.  /* #pos=4 */
# %   else if ( cityhascompanyoffice(F, A) )
# %   | then if ( cityhascompanyoffice(F, G), economicsectorcompany(B, G) )
# %   | | then if ( acquired(G, H) )
# %   | | | then return 0.6075013683457111;  // std dev = 1,769, 42,000 (wgt'ed) examples reached here.  /* #neg=3 #pos=39 */
# %   | | | else return 0.2671323675101564;  // std dev = 2,567, 27,000 (wgt'ed) examples reached here.  /* #neg=14 #pos=13 */
# %   | | else if ( acquired(A, I), cityhascompanyoffice(J, I) )
# %   | | | then return -0.15202877769466885;  // std dev = 0,096, 12,000 (wgt'ed) examples reached here.  /* #neg=12 */
# %   | | | else return -0.22203646910997038;  // std dev = 0,155, 79,000 (wgt'ed) examples reached here.  /* #neg=79 */
# %   | else if ( acquired(A, K), countryhascompanyoffice(L, A) )
# %   | | then return -0.16029536881675685;  // std dev = 0,102, 16,000 (wgt'ed) examples reached here.  /* #neg=16 */
# %   | | else if ( acquired(M, A) )
# %   | | | then return 0.043133269252852255;  // std dev = 3,255, 72,000 (wgt'ed) examples reached here.  /* #neg=50 #pos=22 */
# %   | | | else return 0.11112758184967936;  // std dev = 10,774, 522,000 (wgt'ed) examples reached here.  /* #neg=343 #pos=179 */
# WILL Produced-Tree #6
# % FOR companyeconomicsector(A, B):
# %   if ( companyalsoknownas(A, C), economicsectorcompany(B, C) )
# %   then if ( acquired(D, A) )
# %   | then return 0.3435497493467828;  // std dev = 0,165, 3,000 (wgt'ed) examples reached here.  /* #pos=3 */
# %   | else return 0.11488998739009511;  // std dev = 0,973, 6,000 (wgt'ed) examples reached here.  /* #neg=2 #pos=4 */
# %   else if ( countryhascompanyoffice(E, A), bankbankincountry(F, E) )
# %   | then if ( acquired(A, G) )
# %   | | then return -0.06579959875151166;  // std dev = 0,235, 26,000 (wgt'ed) examples reached here.  /* #neg=23 #pos=3 */
# %   | | else if ( countryhascompanyoffice(E, H), economicsectorcompany(B, H) )
# %   | | | then return 0.4953931328921003;  // std dev = 1,929, 19,000 (wgt'ed) examples reached here.  /* #neg=5 #pos=14 */
# %   | | | else return -0.19812061973254558;  // std dev = 0,146, 33,000 (wgt'ed) examples reached here.  /* #neg=33 */
# %   | else if ( companyalsoknownas(A, I), acquired(J, A) )
# %   | | then if ( acquired(A, K), acquired(I, L) )
# %   | | | then return -0.1839670240693964;  // std dev = 0,029, 5,000 (wgt'ed) examples reached here.  /* #neg=5 */
# %   | | | else return 0.041775771534204656;  // std dev = 0,955, 8,000 (wgt'ed) examples reached here.  /* #neg=5 #pos=3 */
# %   | | else if ( acquired(M, A), economicsectorcompany(B, M) )
# %   | | | then return 0.35489105435944085;  // std dev = 0,196, 13,000 (wgt'ed) examples reached here.  /* #pos=13 */
# %   | | | else return 0.07867354738653273;  // std dev = 11,700, 666,000 (wgt'ed) examples reached here.  /* #neg=446 #pos=220 */
# WILL Produced-Tree #7
# % FOR companyeconomicsector(A, B):
# %   if ( companyalsoknownas(A, C), economicsectorcompany(B, C) )
# %   then if ( companyalsoknownas(A, D), countryhascompanyoffice(E, D) )
# %   | then return 0.05475391745456126;  // std dev = 0,960, 5,000 (wgt'ed) examples reached here.  /* #neg=2 #pos=3 */
# %   | else return 0.268802487804281;  // std dev = 0,128, 4,000 (wgt'ed) examples reached here.  /* #pos=4 */
# %   else if ( countryhascompanyoffice(F, A), bankbankincountry(G, F) )
# %   | then if ( countryhascompanyoffice(F, H), economicsectorcompany(B, H) )
# %   | | then if ( companyalsoknownas(H, I), companyalsoknownas(I, A) )
# %   | | | then return 0.6049213933426436;  // std dev = 0,292, 5,000 (wgt'ed) examples reached here.  /* #pos=5 */
# %   | | | else return 0.31506533214066085;  // std dev = 2,009, 19,000 (wgt'ed) examples reached here.  /* #neg=7 #pos=12 */
# %   | | else return -0.15800639889732254;  // std dev = 0,027, 54,000 (wgt'ed) examples reached here.  /* #neg=54 */
# %   | else if ( acquired(A, J), countryhascompanyoffice(K, J) )
# %   | | then if ( acquired(J, L) )
# %   | | | then return 0.33463388474577344;  // std dev = 0,676, 3,000 (wgt'ed) examples reached here.  /* #neg=1 #pos=2 */
# %   | | | else return 0.1965848031538156;  // std dev = 0,828, 4,000 (wgt'ed) examples reached here.  /* #neg=2 #pos=2 */
# %   | | else if ( acquired(A, M), economicsectorcompany(B, M) )
# %   | | | then return 0.34354933073784866;  // std dev = 0,256, 9,000 (wgt'ed) examples reached here.  /* #pos=9 */
# %   | | | else return 0.06029649066159805;  // std dev = 11,672, 676,000 (wgt'ed) examples reached here.  /* #neg=453 #pos=223 */
# WILL Produced-Tree #8
# % FOR companyeconomicsector(A, B):
# %   if ( companyalsoknownas(A, C), economicsectorcompany(B, C) )
# %   then if ( acquired(D, A) )
# %   | then return 0.25434975001508525;  // std dev = 0,158, 3,000 (wgt'ed) examples reached here.  /* #pos=3 */
# %   | else return 0.05444843407603254;  // std dev = 0,949, 6,000 (wgt'ed) examples reached here.  /* #neg=2 #pos=4 */
# %   else if ( acquired(A, E), cityhascompanyoffice(F, E) )
# %   | then if ( economicsectorcompany(B, E) )
# %   | | then return 0.2210126981006846;  // std dev = 0,113, 4,000 (wgt'ed) examples reached here.  /* #pos=4 */
# %   | | else if ( cityhascompanyoffice(F, A) )
# %   | | | then return -0.1673277907955427;  // std dev = 0,132, 8,000 (wgt'ed) examples reached here.  /* #neg=8 */
# %   | | | else return -0.05078633772765316;  // std dev = 1,086, 18,000 (wgt'ed) examples reached here.  /* #neg=16 #pos=2 */
# %   | else if ( companyalsoknownas(A, G), acquired(H, G) )
# %   | | then return -0.21215193484692313;  // std dev = 0,145, 5,000 (wgt'ed) examples reached here.  /* #neg=5 */
# %   | | else if ( acquired(I, A) )
# %   | | | then return 0.013625328872753414;  // std dev = 3,477, 95,000 (wgt'ed) examples reached here.  /* #neg=64 #pos=31 */
# %   | | | else return 0.058465584756030795;  // std dev = 11,443, 640,000 (wgt'ed) examples reached here.  /* #neg=424 #pos=216 */
# WILL Produced-Tree #9
# % FOR companyeconomicsector(A, B):
# %   if ( companyalsoknownas(A, C), economicsectorcompany(B, C) )
# %   then if ( companyalsoknownas(A, D), countryhascompanyoffice(E, D) )
# %   | then return 0.012596453191524092;  // std dev = 0,939, 5,000 (wgt'ed) examples reached here.  /* #neg=2 #pos=3 */
# %   | else return 0.2063002039151856;  // std dev = 0,123, 4,000 (wgt'ed) examples reached here.  /* #pos=4 */
# %   else if ( acquired(A, F) )
# %   | then if ( countryhascompanyoffice(G, A), bankbankincountry(H, G) )
# %   | | then return -0.06201366420526878;  // std dev = 0,190, 26,000 (wgt'ed) examples reached here.  /* #neg=23 #pos=3 */
# %   | | else if ( economicsectorcompany(B, F) )
# %   | | | then return 0.25034582290112817;  // std dev = 0,239, 9,000 (wgt'ed) examples reached here.  /* #pos=9 */
# %   | | | else return 0.015567742874804086;  // std dev = 3,720, 93,000 (wgt'ed) examples reached here.  /* #neg=65 #pos=28 */
# %   | else if ( cityhascompanyoffice(I, A) )
# %   | | then if ( cityhascompanyoffice(I, J), economicsectorcompany(B, J) )
# %   | | | then return 0.31291560238424465;  // std dev = 2,838, 40,000 (wgt'ed) examples reached here.  /* #neg=12 #pos=28 */
# %   | | | else return -0.20556250145130356;  // std dev = 0,254, 57,000 (wgt'ed) examples reached here.  /* #neg=57 */
# %   | | else if ( companyalsoknownas(A, K), countryhascompanyoffice(L, A) )
# %   | | | then return 0.001871042335297779;  // std dev = 0,606, 4,000 (wgt'ed) examples reached here.  /* #neg=3 #pos=1 */
# %   | | | else return 0.048089657418709804;  // std dev = 10,695, 541,000 (wgt'ed) examples reached here.  /* #neg=357 #pos=184 */
# WILL Produced-Tree #10
# % FOR companyeconomicsector(A, B):
# %   if ( companyalsoknownas(A, C), economicsectorcompany(B, C) )
# %   then if ( acquired(D, A) )
# %   | then return 0.20354473885304755;  // std dev = 0,148, 3,000 (wgt'ed) examples reached here.  /* #pos=3 */
# %   | else return 0.023126060954852663;  // std dev = 0,931, 6,000 (wgt'ed) examples reached here.  /* #neg=2 #pos=4 */
# %   else if ( countryhascompanyoffice(E, A), bankbankincountry(F, E) )
# %   | then if ( acquired(A, G), companyceo(G, H) )
# %   | | then return -0.11395833265052266;  // std dev = 0,027, 9,000 (wgt'ed) examples reached here.  /* #neg=9 */
# %   | | else if ( cityhascompanyoffice(I, A), companyalsoknownas(A, J) )
# %   | | | then return 0.11248682743780443;  // std dev = 0,905, 9,000 (wgt'ed) examples reached here.  /* #neg=5 #pos=4 */
# %   | | | else return -0.02146084111034934;  // std dev = 2,470, 60,000 (wgt'ed) examples reached here.  /* #neg=47 #pos=13 */
# %   | else if ( acquired(K, A), economicsectorcompany(B, K) )
# %   | | then if ( cityhascompanyoffice(L, A) )
# %   | | | then return 0.18094229534661074;  // std dev = 0,082, 5,000 (wgt'ed) examples reached here.  /* #pos=5 */
# %   | | | else return 0.2800917021428013;  // std dev = 0,006, 10,000 (wgt'ed) examples reached here.  /* #pos=10 */
# %   | | else if ( acquired(M, A), companyceo(M, N) )
# %   | | | then return -0.07907513890089655;  // std dev = 2,309, 40,000 (wgt'ed) examples reached here.  /* #neg=33 #pos=7 */
# %   | | | else return 0.035781904233248285;  // std dev = 11,330, 637,000 (wgt'ed) examples reached here.  /* #neg=423 #pos=214 */
#
#
# Fold 1
# {'Learning time': 21.185, 'AUC PR': 0.632026, 'Inference time': 7.492, 'AUC ROC': 0.717858, 'CLL': -0.568227, 'F1': 0.195122, 'Precision': [1.0, 0.5], 'Recall': 0.108108}
#
#
# Fold 2
# {'Learning time': 12.228, 'AUC PR': 0.54189, 'Inference time': 1.562, 'AUC ROC': 0.654313, 'CLL': -0.597554, 'F1': 0.181818, 'Precision': [0.962963, 0.5], 'Recall': 0.100386}
#
#
# Fold 3
# {'Learning time': 89.406, 'AUC PR': 0.526751, 'Inference time': 1.571, 'AUC ROC': 0.63878, 'CLL': -0.593851, 'F1': 0.190641, 'Precision': [0.964912, 0.5], 'Recall': 0.105769}
#
#
# AUC ROC: 0.670 +/- 0.068
# AUC PR: 0.567 +/- 0.093
# CLL: -0.587 +/- 0.026

# %%
refine = ['0;;companyeconomicsector(A, B) :- acquired(A, C), economicsectorcompany(B, C).;true;true',
          '1;;companyeconomicsector(A, B) :- acquired(A, C), economicsectorcompany(B, C).;true;true',
          '2;;companyeconomicsector(A, B) :- acquired(A, C), economicsectorcompany(B, C).;true;true',
          '3;;companyeconomicsector(A, B) :- acquired(A, C), economicsectorcompany(B, C).;true;true',
          '4;;companyeconomicsector(A, B) :- acquired(A, C), economicsectorcompany(B, C).;true;true',
          '5;;companyeconomicsector(A, B) :- acquired(A, C), economicsectorcompany(B, C).;true;true',
          '6;;companyeconomicsector(A, B) :- acquired(A, C), economicsectorcompany(B, C).;true;true',
          '7;;companyeconomicsector(A, B) :- acquired(A, C), economicsectorcompany(B, C).;true;true',
          '8;;companyeconomicsector(A, B) :- acquired(A, C), economicsectorcompany(B, C).;true;true',
          '9;;companyeconomicsector(A, B) :- acquired(A, C), economicsectorcompany(B, C).;true;true',
         ]

# Load new predicate target dataset
tar_data = datasets.load(target, bk, target=new_target, balanced=balanced, seed=seed)
results = []

for i in range(n_folds):
    [tar_train_facts, tar_test_facts] =  [tar_data[0][0], tar_data[0][0]]
    to_folds_pos = datasets.split_into_folds(tar_data[1][0], n_folds=n_folds, seed=seed)
    to_folds_neg = datasets.split_into_folds(tar_data[2][0], n_folds=n_folds, seed=seed)
    [tar_train_pos, tar_test_pos] =  datasets.get_kfold_small(i, to_folds_pos)
    [tar_train_neg, tar_test_neg] =  datasets.get_kfold_small(i, to_folds_neg)
    
    [model, t_results, structured, will, variances] = revision.learn_test_model(background, boostsrl, new_target, tar_train_pos, tar_train_neg, tar_train_facts, tar_test_pos, tar_test_neg, tar_test_facts, refine=refine, trees=10, print_function=None)
    results.append(t_results)
    
    if i == 0:
        for line in will:
            print(line)
    print('\n')
    print('Fold ' + str(i+1))
    print(t_results)
print('\n')
auc_roc = np.array([item['AUC ROC'] for item in results])
auc_pr = np.array([item['AUC PR'] for item in results])
cll = np.array([item['CLL'] for item in results])
print('AUC ROC: %.3f +/- %.3f' % (auc_roc.mean(), 2 * auc_roc.std()))
print('AUC PR: %.3f +/- %.3f' % (auc_pr.mean(), 2 * auc_pr.std()))
print('CLL: %.3f +/- %.3f' % (cll.mean(), 2 * cll.std()))
# Out:
# WILL Produced-Tree #1
# % FOR companyeconomicsector(A, B):
# %   if ( acquired(A, C), economicsectorcompany(B, C) )
# %   then return 0.8581489350995122;  // std dev = 0,000, 10,000 (wgt'ed) examples reached here.  /* #pos=10 */
# %   else if ( countryhascompanyoffice(D, A), bankbankincountry(E, D) )
# %   | then if ( acquired(A, F) )
# %   | | then if ( companyalsoknownas(A, G), economicsectorcompany(B, G) )
# %   | | | then return 0.5248156017661788;  // std dev = 0,816, 3,000 (wgt'ed) examples reached here.  /* #neg=1 #pos=2 */
# %   | | | else return -0.06185106490048781;  // std dev = 1,356, 25,000 (wgt'ed) examples reached here.  /* #neg=23 #pos=2 */
# %   | | else if ( companyalsoknownas(A, H) )
# %   | | | then return 0.28672036367094084;  // std dev = 1,309, 7,000 (wgt'ed) examples reached here.  /* #neg=4 #pos=3 */
# %   | | | else return 0.11901850031690367;  // std dev = 2,978, 46,000 (wgt'ed) examples reached here.  /* #neg=34 #pos=12 */
# %   | else if ( acquired(I, A), companyceo(A, J) )
# %   | | then if ( economicsectorcompany(B, I) )
# %   | | | then return 0.8581489350995122;  // std dev = 0,000, 5,000 (wgt'ed) examples reached here.  /* #pos=5 */
# %   | | | else return 0.13592671287729013;  // std dev = 1,900, 18,000 (wgt'ed) examples reached here.  /* #neg=13 #pos=5 */
# %   | | else if ( companyalsoknownas(A, K), economicsectorcompany(B, K) )
# %   | | | then return 0.6081489350995122;  // std dev = 0,866, 4,000 (wgt'ed) examples reached here.  /* #neg=1 #pos=3 */
# %   | | | else return 0.1879522633899772;  // std dev = 12,087, 661,000 (wgt'ed) examples reached here.  /* #neg=443 #pos=218 */
# WILL Produced-Tree #2
# % FOR companyeconomicsector(A, B):
# %   if ( acquired(A, C), economicsectorcompany(B, C) )
# %   then return 0.7194734122109544;  // std dev = 2,98e-08, 10,000 (wgt'ed) examples reached here.  /* #pos=10 */
# %   else if ( companyalsoknownas(A, D), economicsectorcompany(B, D) )
# %   | then if ( cityhascompanyoffice(E, D) )
# %   | | then return 0.37580614863986594;  // std dev = 1,098, 5,000 (wgt'ed) examples reached here.  /* #neg=2 #pos=3 */
# %   | | else return 0.7986186751600624;  // std dev = 0,065, 4,000 (wgt'ed) examples reached here.  /* #pos=4 */
# %   | else if ( acquired(A, F), cityhascompanyoffice(G, F) )
# %   | | then if ( companyceo(A, H) )
# %   | | | then return 0.011558560577859386;  // std dev = 1,299, 12,000 (wgt'ed) examples reached here.  /* #neg=10 #pos=2 */
# %   | | | else return -0.15948656380233509;  // std dev = 0,049, 14,000 (wgt'ed) examples reached here.  /* #neg=14 */
# %   | | else if ( countryhascompanyoffice(I, A), bankbankincountry(J, I) )
# %   | | | then return 0.061087019865436555;  // std dev = 3,411, 70,000 (wgt'ed) examples reached here.  /* #neg=55 #pos=15 */
# %   | | | else return 0.1733676416444968;  // std dev = 12,181, 664,000 (wgt'ed) examples reached here.  /* #neg=438 #pos=226 */
# WILL Produced-Tree #3
# % FOR companyeconomicsector(A, B):
# %   if ( acquired(A, C), economicsectorcompany(B, C) )
# %   then return 0.5553664367462846;  // std dev = 0,000, 10,000 (wgt'ed) examples reached here.  /* #pos=10 */
# %   else if ( bankchiefexecutiveceo(A, D), acquired(A, E) )
# %   | then return -0.15107539869216918;  // std dev = 0,029, 6,000 (wgt'ed) examples reached here.  /* #neg=6 */
# %   | else if ( countryhascompanyoffice(F, A), bankbankincountry(G, F) )
# %   | | then if ( acquired(A, H), countryhascompanyoffice(F, H) )
# %   | | | then return -0.06332878992156186;  // std dev = 0,963, 14,000 (wgt'ed) examples reached here.  /* #neg=13 #pos=1 */
# %   | | | else return 0.1083086118055183;  // std dev = 3,524, 64,000 (wgt'ed) examples reached here.  /* #neg=46 #pos=18 */
# %   | | else if ( acquired(A, I), companyalsoknownas(I, J) )
# %   | | | then return 0.008250173363874503;  // std dev = 0,894, 5,000 (wgt'ed) examples reached here.  /* #neg=4 #pos=1 */
# %   | | | else return 0.14554320800005832;  // std dev = 12,266, 680,000 (wgt'ed) examples reached here.  /* #neg=450 #pos=230 */
# WILL Produced-Tree #4
# % FOR companyeconomicsector(A, B):
# %   if ( acquired(A, C), economicsectorcompany(B, C) )
# %   then return 0.41751358415830986;  // std dev = 3,65e-08, 10,000 (wgt'ed) examples reached here.  /* #pos=10 */
# %   else if ( acquired(D, A), economicsectorcompany(B, D) )
# %   | then if ( companyceo(A, E), companyceo(D, F) )
# %   | | then return 0.6508869589285798;  // std dev = 0,000, 5,000 (wgt'ed) examples reached here.  /* #pos=5 */
# %   | | else return 0.7878247981100389;  // std dev = 0,033, 11,000 (wgt'ed) examples reached here.  /* #pos=11 */
# %   | else if ( acquired(G, A) )
# %   | | then if ( acquired(H, G), cityhascompanyoffice(I, G) )
# %   | | | then return 0.1864096573674142;  // std dev = 1,550, 10,000 (wgt'ed) examples reached here.  /* #neg=6 #pos=4 */
# %   | | | else return -0.024029151330930597;  // std dev = 3,279, 75,000 (wgt'ed) examples reached here.  /* #neg=61 #pos=14 */
# %   | | else if ( acquired(A, J), cityhascompanyoffice(K, J) )
# %   | | | then return -0.07062448530497184;  // std dev = 1,353, 24,000 (wgt'ed) examples reached here.  /* #neg=22 #pos=2 */
# %   | | | else return 0.1195641083421682;  // std dev = 11,900, 644,000 (wgt'ed) examples reached here.  /* #neg=430 #pos=214 */
# WILL Produced-Tree #5
# % FOR companyeconomicsector(A, B):
# %   if ( acquired(A, C), economicsectorcompany(B, C) )
# %   then return 0.3207118471601497;  // std dev = 0,000, 10,000 (wgt'ed) examples reached here.  /* #pos=10 */
# %   else return 0.09313522516003712;  // std dev = 0,459, 769,000 (wgt'ed) examples reached here.  /* #neg=519 #pos=250 */
# WILL Produced-Tree #6
# % FOR companyeconomicsector(A, B):
# %   if ( acquired(A, C), economicsectorcompany(B, C) )
# %   then return 0.2551722425694894;  // std dev = 1,83e-08, 10,000 (wgt'ed) examples reached here.  /* #pos=10 */
# %   else if ( acquired(D, A), economicsectorcompany(B, D) )
# %   | then if ( companyceo(A, E), companyceo(D, F) )
# %   | | then return 0.4697664362308299;  // std dev = 0,000, 5,000 (wgt'ed) examples reached here.  /* #pos=5 */
# %   | | else return 0.6062480641704423;  // std dev = 0,049, 11,000 (wgt'ed) examples reached here.  /* #pos=11 */
# %   | else if ( acquired(A, G) )
# %   | | then if ( cityhascompanyoffice(H, A), countryhascompanyoffice(I, G) )
# %   | | | then return 0.16975717779963637;  // std dev = 2,013, 18,000 (wgt'ed) examples reached here.  /* #neg=11 #pos=7 */
# %   | | | else return 0.0011474479547200155;  // std dev = 3,977, 100,000 (wgt'ed) examples reached here.  /* #neg=78 #pos=22 */
# %   | | else if ( cityhascompanyoffice(J, A) )
# %   | | | then return 0.03422432315776763;  // std dev = 4,376, 96,000 (wgt'ed) examples reached here.  /* #neg=69 #pos=27 */
# %   | | | else return 0.08013303781757918;  // std dev = 10,868, 539,000 (wgt'ed) examples reached here.  /* #neg=361 #pos=178 */
# WILL Produced-Tree #7
# % FOR companyeconomicsector(A, B):
# %   if ( acquired(A, C), economicsectorcompany(B, C) )
# %   then return 0.2097577156325356;  // std dev = 0,000, 10,000 (wgt'ed) examples reached here.  /* #pos=10 */
# %   else if ( companyalsoknownas(A, D), economicsectorcompany(B, D) )
# %   | then if ( acquired(E, A) )
# %   | | then return 0.6509631023643211;  // std dev = 0,036, 3,000 (wgt'ed) examples reached here.  /* #pos=3 */
# %   | | else return 0.22759408581316123;  // std dev = 1,098, 6,000 (wgt'ed) examples reached here.  /* #neg=2 #pos=4 */
# %   | else if ( acquired(F, A) )
# %   | | then if ( economicsectorcompany(B, F) )
# %   | | | then return 0.4252896436245872;  // std dev = 0,193, 16,000 (wgt'ed) examples reached here.  /* #pos=16 */
# %   | | | else return -0.05026400079584281;  // std dev = 3,464, 82,000 (wgt'ed) examples reached here.  /* #neg=67 #pos=15 */
# %   | | else if ( acquired(A, G), cityhascompanyoffice(H, G) )
# %   | | | then return -0.07712305095800984;  // std dev = 1,342, 24,000 (wgt'ed) examples reached here.  /* #neg=22 #pos=2 */
# %   | | | else return 0.06723332655638124;  // std dev = 11,830, 638,000 (wgt'ed) examples reached here.  /* #neg=428 #pos=210 */
# WILL Produced-Tree #8
# % FOR companyeconomicsector(A, B):
# %   if ( acquired(A, C), economicsectorcompany(B, C) )
# %   then return 0.17709649774527736;  // std dev = 7,45e-09, 10,000 (wgt'ed) examples reached here.  /* #pos=10 */
# %   else if ( acquired(A, D) )
# %   | then if ( cityhascompanyoffice(E, D) )
# %   | | then if ( companyalsoknownas(A, F), cityhascompanyoffice(E, F) )
# %   | | | then return 0.1079633704095706;  // std dev = 0,866, 4,000 (wgt'ed) examples reached here.  /* #neg=3 #pos=1 */
# %   | | | else return -0.10874790214104513;  // std dev = 0,956, 22,000 (wgt'ed) examples reached here.  /* #neg=21 #pos=1 */
# %   | | else if ( countryhascompanyoffice(G, A), bankbankincountry(H, G) )
# %   | | | then return -0.08075888564208926;  // std dev = 1,344, 21,000 (wgt'ed) examples reached here.  /* #neg=18 #pos=3 */
# %   | | | else return 0.08785137476805625;  // std dev = 3,945, 75,000 (wgt'ed) examples reached here.  /* #neg=47 #pos=28 */
# %   | else if ( acquired(I, A), companyalsoknownas(I, J) )
# %   | | then if ( acquired(J, K), cityhascompanyoffice(L, K) )
# %   | | | then return 0.4402543036733158;  // std dev = 0,813, 3,000 (wgt'ed) examples reached here.  /* #neg=1 #pos=2 */
# %   | | | else return -0.09058879221689074;  // std dev = 1,562, 29,000 (wgt'ed) examples reached here.  /* #neg=23 #pos=6 */
# %   | | else if ( companyalsoknownas(A, M), companyceo(M, N) )
# %   | | | then return 0.32525463353391487;  // std dev = 1,513, 11,000 (wgt'ed) examples reached here.  /* #neg=4 #pos=7 */
# %   | | | else return 0.05300429370005698;  // std dev = 11,426, 604,000 (wgt'ed) examples reached here.  /* #neg=402 #pos=202 */
# WILL Produced-Tree #9
# % FOR companyeconomicsector(A, B):
# %   if ( acquired(A, C), economicsectorcompany(B, C) )
# %   then return 0.15274385809367094;  // std dev = 0,000, 10,000 (wgt'ed) examples reached here.  /* #pos=10 */
# %   else if ( acquired(A, D), cityhascompanyoffice(E, D) )
# %   | then if ( companyceo(A, F) )
# %   | | then if ( cityhascompanyoffice(E, A) )
# %   | | | then return -0.15992078373995264;  // std dev = 0,034, 6,000 (wgt'ed) examples reached here.  /* #neg=6 */
# %   | | | else return 0.18050205156177923;  // std dev = 1,141, 6,000 (wgt'ed) examples reached here.  /* #neg=4 #pos=2 */
# %   | | else return -0.1314017262872798;  // std dev = 0,077, 14,000 (wgt'ed) examples reached here.  /* #neg=14 */
# %   | else if ( countryhascompanyoffice(G, A), bankbankincountry(H, G) )
# %   | | then if ( acquired(A, I), countryhascompanyoffice(G, I) )
# %   | | | then return -0.15469406600816912;  // std dev = 0,030, 7,000 (wgt'ed) examples reached here.  /* #neg=7 */
# %   | | | else return 0.016148712189534946;  // std dev = 3,400, 67,000 (wgt'ed) examples reached here.  /* #neg=49 #pos=18 */
# %   | | else if ( acquired(A, J), cityhascompanyoffice(K, A) )
# %   | | | then return 0.12747309462146625;  // std dev = 2,828, 38,000 (wgt'ed) examples reached here.  /* #neg=21 #pos=17 */
# %   | | | else return 0.04165401324645928;  // std dev = 11,604, 631,000 (wgt'ed) examples reached here.  /* #neg=418 #pos=213 */
# WILL Produced-Tree #10
# % FOR companyeconomicsector(A, B):
# %   if ( acquired(A, C), economicsectorcompany(B, C) )
# %   then return 0.13400703000801117;  // std dev = 0,000, 10,000 (wgt'ed) examples reached here.  /* #pos=10 */
# %   else if ( acquired(D, A), countryhascompanyoffice(E, D) )
# %   | then if ( companyceo(A, F) )
# %   | | then if ( companyceo(D, G) )
# %   | | | then return 0.2408243635629126;  // std dev = 0,846, 5,000 (wgt'ed) examples reached here.  /* #neg=2 #pos=3 */
# %   | | | else return -0.05719801037313032;  // std dev = 0,510, 4,000 (wgt'ed) examples reached here.  /* #neg=3 #pos=1 */
# %   | | else if ( companyalsoknownas(D, H) )
# %   | | | then return -0.21599091503249634;  // std dev = 0,035, 5,000 (wgt'ed) examples reached here.  /* #neg=5 */
# %   | | | else return -0.03539122980702304;  // std dev = 1,256, 10,000 (wgt'ed) examples reached here.  /* #neg=8 #pos=2 */
# %   | else if ( acquired(I, A), economicsectorcompany(B, I) )
# %   | | then if ( companyceo(A, J) )
# %   | | | then return 0.2437529651296437;  // std dev = 0,041, 4,000 (wgt'ed) examples reached here.  /* #pos=4 */
# %   | | | else return 0.3318268910102136;  // std dev = 0,052, 10,000 (wgt'ed) examples reached here.  /* #pos=10 */
# %   | | else if ( acquired(K, A) )
# %   | | | then return -0.03221441204772771;  // std dev = 3,080, 63,000 (wgt'ed) examples reached here.  /* #neg=49 #pos=14 */
# %   | | | else return 0.03187338803531499;  // std dev = 11,936, 668,000 (wgt'ed) examples reached here.  /* #neg=452 #pos=216 */
#
#
# Fold 1
# {'Learning time': 18.775, 'AUC PR': 0.450916, 'Inference time': 1.626, 'AUC ROC': 0.5571, 'CLL': -0.61439, 'F1': 0.176056, 'Precision': [1.0, 0.5], 'Recall': 0.096525}
#
#
# Fold 2
# {'Learning time': 15.354, 'AUC PR': 0.419119, 'Inference time': 1.594, 'AUC ROC': 0.530448, 'CLL': -0.625867, 'F1': 0.112727, 'Precision': [0.96875, 0.5], 'Recall': 0.059846}
#
#
# Fold 3
# {'Learning time': 13.922, 'AUC PR': 0.619116, 'Inference time': 1.618, 'AUC ROC': 0.714966, 'CLL': -0.57446, 'F1': 0.208191, 'Precision': [0.924242, 0.5], 'Recall': 0.117308}
#
#
# AUC ROC: 0.601 +/- 0.163
# AUC PR: 0.496 +/- 0.176
# CLL: -0.605 +/- 0.044

# %%
refine = ['0;;companyeconomicsector(A, B) :- acquired(C, A), economicsectorcompany(B, C).;true;true',
          '0;false;acquired(A, D), economicsectorcompany(B, D).;true;true',
          '0;false,false;companyceo(A, E), companyceo(F, E), economicsectorcompany(B, F).;true;true',
          '1;;companyeconomicsector(A, B) :- acquired(C, A), economicsectorcompany(B, C).;true;true',
          '1;false;acquired(A, D), economicsectorcompany(B, D).;true;true',
          '1;false,false;companyceo(A, E), companyceo(F, E), economicsectorcompany(B, F).;true;true',
          '2;;companyeconomicsector(A, B) :- acquired(C, A), economicsectorcompany(B, C).;true;true',
          '2;false;acquired(A, D), economicsectorcompany(B, D).;true;true',
          '2;false,false;companyceo(A, E), companyceo(F, E), economicsectorcompany(B, F).;true;true',
          '3;;companyeconomicsector(A, B) :- acquired(C, A), economicsectorcompany(B, C).;true;true',
          '3;false;acquired(A, D), economicsectorcompany(B, D).;true;true',
          '3;false,false;companyceo(A, E), companyceo(F, E), economicsectorcompany(B, F).;true;true',
          '4;;companyeconomicsector(A, B) :- acquired(C, A), economicsectorcompany(B, C).;true;true',
          '4;false;acquired(A, D), economicsectorcompany(B, D).;true;true',
          '4;false,false;companyceo(A, E), companyceo(F, E), economicsectorcompany(B, F).;true;true',
          '5;;companyeconomicsector(A, B) :- acquired(C, A), economicsectorcompany(B, C).;true;true',
          '5;false;acquired(A, D), economicsectorcompany(B, D).;true;true',
          '5;false,false;companyceo(A, E), companyceo(F, E), economicsectorcompany(B, F).;true;true',
          '6;;companyeconomicsector(A, B) :- acquired(C, A), economicsectorcompany(B, C).;true;true',
          '6;false;acquired(A, D), economicsectorcompany(B, D).;true;true',
          '6;false,false;companyceo(A, E), companyceo(F, E), economicsectorcompany(B, F).;true;true',
          '7;;companyeconomicsector(A, B) :- acquired(C, A), economicsectorcompany(B, C).;true;true',
          '7;false;acquired(A, D), economicsectorcompany(B, D).;true;true',
          '7;false,false;companyceo(A, E), companyceo(F, E), economicsectorcompany(B, F).;true;true',
          '8;;companyeconomicsector(A, B) :- acquired(C, A), economicsectorcompany(B, C).;true;true',
          '8;false;acquired(A, D), economicsectorcompany(B, D).;true;true',
          '8;false,false;companyceo(A, E), companyceo(F, E), economicsectorcompany(B, F).;true;true',
          '9;;companyeconomicsector(A, B) :- acquired(C, A), economicsectorcompany(B, C).;true;true',
          '9;false;acquired(A, D), economicsectorcompany(B, D).;true;true',
          '9;false,false;companyceo(A, E), companyceo(F, E), economicsectorcompany(B, F).;true;true',
         ]

# Load new predicate target dataset
tar_data = datasets.load(target, bk, target=new_target, balanced=balanced, seed=seed)
results = []

for i in range(n_folds):
    [tar_train_facts, tar_test_facts] =  [tar_data[0][0], tar_data[0][0]]
    to_folds_pos = datasets.split_into_folds(tar_data[1][0], n_folds=n_folds, seed=seed)
    to_folds_neg = datasets.split_into_folds(tar_data[2][0], n_folds=n_folds, seed=seed)
    [tar_train_pos, tar_test_pos] =  datasets.get_kfold_small(i, to_folds_pos)
    [tar_train_neg, tar_test_neg] =  datasets.get_kfold_small(i, to_folds_neg)
    
    [model, t_results, structured, will, variances] = revision.learn_test_model(background, boostsrl, new_target, tar_train_pos, tar_train_neg, tar_train_facts, tar_test_pos, tar_test_neg, tar_test_facts, refine=refine, trees=10, print_function=None)
    results.append(t_results)
    
    if i == 0:
        for line in will:
            print(line)
    print('\n')
    print('Fold ' + str(i+1))
    print(t_results)
print('\n')
auc_roc = np.array([item['AUC ROC'] for item in results])
auc_pr = np.array([item['AUC PR'] for item in results])
cll = np.array([item['CLL'] for item in results])
print('AUC ROC: %.3f +/- %.3f' % (auc_roc.mean(), 2 * auc_roc.std()))
print('AUC PR: %.3f +/- %.3f' % (auc_pr.mean(), 2 * auc_pr.std()))
print('CLL: %.3f +/- %.3f' % (cll.mean(), 2 * cll.std()))
# Out:
# WILL Produced-Tree #1
# % FOR companyeconomicsector(A, B):
# %   if ( acquired(C, A), economicsectorcompany(B, C) )
# %   then return 0.8581489350995123;  // std dev = 0,000, 16,000 (wgt'ed) examples reached here.  /* #pos=16 */
# %   else if ( acquired(A, D), economicsectorcompany(B, D) )
# %   | then return 0.8581489350995122;  // std dev = 0,000, 10,000 (wgt'ed) examples reached here.  /* #pos=10 */
# %   | else if ( companyceo(A, E), companyceo(F, E), economicsectorcompany(B, F) )
# %   | | then return 0.8581489350995115;  // std dev = 2,38e-07, 34,000 (wgt'ed) examples reached here.  /* #pos=34 */
# %   | | else if ( companyceo(A, G) )
# %   | | | then return -0.14185106490048766;  // std dev = 7,88e-08, 85,000 (wgt'ed) examples reached here.  /* #neg=85 */
# %   | | | else return 0.1736063483487191;  // std dev = 11,701, 634,000 (wgt'ed) examples reached here.  /* #neg=434 #pos=200 */
# WILL Produced-Tree #2
# % FOR companyeconomicsector(A, B):
# %   if ( acquired(C, A), economicsectorcompany(B, C) )
# %   then return 0.7194734122109542;  // std dev = 5,96e-08, 16,000 (wgt'ed) examples reached here.  /* #pos=16 */
# %   else if ( acquired(A, D), economicsectorcompany(B, D) )
# %   | then return 0.7194734122109544;  // std dev = 2,98e-08, 10,000 (wgt'ed) examples reached here.  /* #pos=10 */
# %   | else if ( companyceo(A, E), companyceo(F, E), economicsectorcompany(B, F) )
# %   | | then return 0.7194734122109548;  // std dev = 0,000, 34,000 (wgt'ed) examples reached here.  /* #pos=34 */
# %   | | else if ( companyceo(A, G) )
# %   | | | then return -0.12544463852839144;  // std dev = 0,000, 85,000 (wgt'ed) examples reached here.  /* #neg=85 */
# %   | | | else return 0.15113241933015814;  // std dev = 11,701, 634,000 (wgt'ed) examples reached here.  /* #neg=434 #pos=200 */
# WILL Produced-Tree #3
# % FOR companyeconomicsector(A, B):
# %   if ( acquired(C, A), economicsectorcompany(B, C) )
# %   then return 0.5553664367462846;  // std dev = 0,000, 16,000 (wgt'ed) examples reached here.  /* #pos=16 */
# %   else if ( acquired(A, D), economicsectorcompany(B, D) )
# %   | then return 0.5553664367462846;  // std dev = 0,000, 10,000 (wgt'ed) examples reached here.  /* #pos=10 */
# %   | else if ( companyceo(A, E), companyceo(F, E), economicsectorcompany(B, F) )
# %   | | then return 0.5553664367462844;  // std dev = 7,30e-08, 34,000 (wgt'ed) examples reached here.  /* #pos=34 */
# %   | | else if ( companyceo(A, G) )
# %   | | | then return -0.11231637819360622;  // std dev = 6,99e-08, 85,000 (wgt'ed) examples reached here.  /* #neg=85 */
# %   | | | else return 0.129313163870072;  // std dev = 11,701, 634,000 (wgt'ed) examples reached here.  /* #neg=434 #pos=200 */
# WILL Produced-Tree #4
# % FOR companyeconomicsector(A, B):
# %   if ( acquired(C, A), economicsectorcompany(B, C) )
# %   then return 0.4175135841583098;  // std dev = 5,16e-08, 16,000 (wgt'ed) examples reached here.  /* #pos=16 */
# %   else if ( acquired(A, D), economicsectorcompany(B, D) )
# %   | then return 0.41751358415830986;  // std dev = 3,65e-08, 10,000 (wgt'ed) examples reached here.  /* #pos=10 */
# %   | else if ( companyceo(A, E), companyceo(F, E), economicsectorcompany(B, F) )
# %   | | then return 0.4175135841583102;  // std dev = 0,000, 34,000 (wgt'ed) examples reached here.  /* #pos=34 */
# %   | | else if ( companyceo(A, G) )
# %   | | | then return -0.10159632948783619;  // std dev = 5,58e-08, 85,000 (wgt'ed) examples reached here.  /* #neg=85 */
# %   | | | else return 0.10892381070187707;  // std dev = 11,701, 634,000 (wgt'ed) examples reached here.  /* #neg=434 #pos=200 */
# WILL Produced-Tree #5
# % FOR companyeconomicsector(A, B):
# %   if ( acquired(C, A), economicsectorcompany(B, C) )
# %   then return 0.32071184716014967;  // std dev = 0,000, 16,000 (wgt'ed) examples reached here.  /* #pos=16 */
# %   else if ( acquired(A, D), economicsectorcompany(B, D) )
# %   | then return 0.3207118471601497;  // std dev = 0,000, 10,000 (wgt'ed) examples reached here.  /* #pos=10 */
# %   | else if ( companyceo(A, E), companyceo(F, E), economicsectorcompany(B, F) )
# %   | | then return 0.3207118471601495;  // std dev = 2,11e-08, 34,000 (wgt'ed) examples reached here.  /* #pos=34 */
# %   | | else if ( companyceo(A, G) )
# %   | | | then return -0.09269127618926107;  // std dev = 0,000, 85,000 (wgt'ed) examples reached here.  /* #neg=85 */
# %   | | | else return 0.09050303180268504;  // std dev = 11,701, 634,000 (wgt'ed) examples reached here.  /* #neg=434 #pos=200 */
# WILL Produced-Tree #6
# % FOR companyeconomicsector(A, B):
# %   if ( acquired(C, A), economicsectorcompany(B, C) )
# %   then return 0.2551722425694894;  // std dev = 2,11e-08, 16,000 (wgt'ed) examples reached here.  /* #pos=16 */
# %   else if ( acquired(A, D), economicsectorcompany(B, D) )
# %   | then return 0.2551722425694894;  // std dev = 1,83e-08, 10,000 (wgt'ed) examples reached here.  /* #pos=10 */
# %   | else if ( companyceo(A, E), companyceo(F, E), economicsectorcompany(B, F) )
# %   | | then return 0.25517224256948956;  // std dev = 0,000, 34,000 (wgt'ed) examples reached here.  /* #pos=34 */
# %   | | else if ( acquired(G, A) )
# %   | | | then return -0.05566955749970052;  // std dev = 3,114, 79,000 (wgt'ed) examples reached here.  /* #neg=67 #pos=12 */
# %   | | | else return 0.06919358987779509;  // std dev = 11,315, 640,000 (wgt'ed) examples reached here.  /* #neg=452 #pos=188 */
# WILL Produced-Tree #7
# % FOR companyeconomicsector(A, B):
# %   if ( acquired(C, A), economicsectorcompany(B, C) )
# %   then return 0.20975771563253562;  // std dev = 0,000, 16,000 (wgt'ed) examples reached here.  /* #pos=16 */
# %   else if ( acquired(A, D), economicsectorcompany(B, D) )
# %   | then return 0.2097577156325356;  // std dev = 0,000, 10,000 (wgt'ed) examples reached here.  /* #pos=10 */
# %   | else if ( companyceo(A, E), companyceo(F, E), economicsectorcompany(B, F) )
# %   | | then return 0.20975771563253542;  // std dev = 4,94e-08, 34,000 (wgt'ed) examples reached here.  /* #pos=34 */
# %   | | else if ( acquired(A, G) )
# %   | | | then return -0.08299245813135436;  // std dev = 2,569, 97,000 (wgt'ed) examples reached here.  /* #neg=89 #pos=8 */
# %   | | | else return 0.0657267967799782;  // std dev = 11,396, 622,000 (wgt'ed) examples reached here.  /* #neg=430 #pos=192 */
# WILL Produced-Tree #8
# % FOR companyeconomicsector(A, B):
# %   if ( acquired(C, A), economicsectorcompany(B, C) )
# %   then return 0.17709649774527741;  // std dev = 0,000, 16,000 (wgt'ed) examples reached here.  /* #pos=16 */
# %   else if ( acquired(A, D), economicsectorcompany(B, D) )
# %   | then return 0.17709649774527736;  // std dev = 7,45e-09, 10,000 (wgt'ed) examples reached here.  /* #pos=10 */
# %   | else if ( companyceo(A, E), companyceo(F, E), economicsectorcompany(B, F) )
# %   | | then return 0.1770964977452775;  // std dev = 0,000, 34,000 (wgt'ed) examples reached here.  /* #pos=34 */
# %   | | else if ( companyceo(A, G) )
# %   | | | then return -0.08703743035229677;  // std dev = 0,061, 85,000 (wgt'ed) examples reached here.  /* #neg=85 */
# %   | | | else return 0.05312161323651058;  // std dev = 11,673, 634,000 (wgt'ed) examples reached here.  /* #neg=434 #pos=200 */
# WILL Produced-Tree #9
# % FOR companyeconomicsector(A, B):
# %   if ( acquired(C, A), economicsectorcompany(B, C) )
# %   then return 0.1527438580936708;  // std dev = 0,000, 16,000 (wgt'ed) examples reached here.  /* #pos=16 */
# %   else if ( acquired(A, D), economicsectorcompany(B, D) )
# %   | then return 0.15274385809367094;  // std dev = 0,000, 10,000 (wgt'ed) examples reached here.  /* #pos=10 */
# %   | else if ( companyceo(A, E), companyceo(F, E), economicsectorcompany(B, F) )
# %   | | then return 0.1527438580936709;  // std dev = 3,33e-08, 34,000 (wgt'ed) examples reached here.  /* #pos=34 */
# %   | | else if ( acquired(G, A), companyceo(G, H) )
# %   | | | then return -0.10097634599163935;  // std dev = 2,067, 44,000 (wgt'ed) examples reached here.  /* #neg=39 #pos=5 */
# %   | | | else return 0.03658562451612718;  // std dev = 11,503, 675,000 (wgt'ed) examples reached here.  /* #neg=480 #pos=195 */
# WILL Produced-Tree #10
# % FOR companyeconomicsector(A, B):
# %   if ( acquired(C, A), economicsectorcompany(B, C) )
# %   then return 0.13400703000801117;  // std dev = 0,000, 16,000 (wgt'ed) examples reached here.  /* #pos=16 */
# %   else if ( acquired(A, D), economicsectorcompany(B, D) )
# %   | then return 0.13400703000801117;  // std dev = 0,000, 10,000 (wgt'ed) examples reached here.  /* #pos=10 */
# %   | else if ( companyceo(A, E), companyceo(F, E), economicsectorcompany(B, F) )
# %   | | then return 0.13400703000801115;  // std dev = 0,000, 34,000 (wgt'ed) examples reached here.  /* #pos=34 */
# %   | | else if ( acquired(G, A), companyceo(G, H) )
# %   | | | then return -0.08491111543665354;  // std dev = 2,066, 44,000 (wgt'ed) examples reached here.  /* #neg=39 #pos=5 */
# %   | | | else return 0.0297652387353699;  // std dev = 11,500, 675,000 (wgt'ed) examples reached here.  /* #neg=480 #pos=195 */
#
#
# Fold 1
# {'Learning time': 4.943, 'AUC PR': 0.576822, 'Inference time': 1.433, 'AUC ROC': 0.674269, 'CLL': -0.540123, 'F1': 0.331723, 'Precision': [1.0, 0.5], 'Recall': 0.198842}
#
#
# Fold 2
# {'Learning time': 5.731, 'AUC PR': 0.622194, 'Inference time': 1.353, 'AUC ROC': 0.710456, 'CLL': -0.528052, 'F1': 0.373626, 'Precision': [1.0, 0.5], 'Recall': 0.22973}
#
#
# Fold 3
# {'Learning time': 5.331, 'AUC PR': 0.593631, 'Inference time': 1.262, 'AUC ROC': 0.682364, 'CLL': -0.53666, 'F1': 0.333333, 'Precision': [1.0, 0.5], 'Recall': 0.2}
#
#
# AUC ROC: 0.689 +/- 0.031
# AUC PR: 0.598 +/- 0.037
# CLL: -0.535 +/- 0.010
